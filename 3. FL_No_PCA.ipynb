# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(42)

# %%
#Benign
benign_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.benign.csv')
benign_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.benign.csv')
benign_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.benign.csv')
benign_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.benign.csv')
benign_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.benign.csv')
benign_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.benign.csv')
benign_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.benign.csv')

benign_traffic = pd.concat([benign_1, benign_2, benign_4, benign_5, benign_6, benign_8, benign_9], ignore_index=True)

benign_traffic.shape
# Out:
# (464682, 115)

# %%
#Scan
mirai_scan_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.scan.csv')
mirai_scan_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.scan.csv')
mirai_scan_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.scan.csv')
mirai_scan_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.scan.csv')
mirai_scan_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.scan.csv')
mirai_scan_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.scan.csv')
mirai_scan_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.scan.csv')

mirai_scan_traffic = pd.concat([mirai_scan_1, mirai_scan_2, mirai_scan_4, mirai_scan_5, mirai_scan_6, mirai_scan_8, mirai_scan_9], ignore_index=True)

mirai_scan_traffic.shape
# Out:
# (537979, 115)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')
mirai_syn_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.syn.csv')
mirai_syn_8  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.syn.csv')
mirai_syn_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.syn.csv')


mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5, mirai_syn_6, mirai_syn_8, mirai_syn_9], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (733299, 115)

# %%
#Ack
mirai_ack_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.ack.csv')
mirai_ack_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.ack.csv')
mirai_ack_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.ack.csv')
mirai_ack_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.ack.csv')
mirai_ack_6  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.ack.csv')
mirai_ack_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.ack.csv')
mirai_ack_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.ack.csv')

mirai_ack_traffic = pd.concat([mirai_ack_1 , mirai_ack_2, mirai_ack_4, mirai_ack_5, mirai_ack_6, mirai_ack_8, mirai_ack_9], ignore_index=True)

mirai_ack_traffic.shape
# Out:
# (643821, 115)

# %%
#Udp Flooding
mirai_udp_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udp.csv')
mirai_udp_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udp.csv')
mirai_udp_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udp.csv')
mirai_udp_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udp.csv')
mirai_udp_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udp.csv')
mirai_udp_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udp.csv')
mirai_udp_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udp.csv')

mirai_udp_traffic = pd.concat([mirai_udp_1 , mirai_udp_2, mirai_udp_4, mirai_udp_5], ignore_index=True)

mirai_udp_traffic.shape
# Out:
# (762428, 115)

# %%
#Udp plain Flooding
mirai_udpplain_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udpplain.csv')
mirai_udpplain_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udpplain.csv')
mirai_udpplain_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udpplain.csv')
mirai_udpplain_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udpplain.csv')
mirai_udpplain_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udpplain.csv')
mirai_udpplain_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udpplain.csv')
mirai_udpplain_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udpplain.csv')

mirai_udpplain_traffic = pd.concat([mirai_udpplain_1 , mirai_udpplain_2, mirai_udpplain_4, mirai_udpplain_5, mirai_udpplain_6, mirai_udpplain_8, mirai_udpplain_9], ignore_index=True)

mirai_udpplain_traffic.shape
# Out:
# (523304, 115)

# %%
benign_traffic['label'] = 'benign'
mirai_scan_traffic['label'] = 'mirai_scan'
mirai_syn_traffic['label'] = 'mirai_syn'
mirai_ack_traffic['label'] = 'mirai_ack'
mirai_udp_traffic['label'] = 'mirai_udp'
mirai_udpplain_traffic['label'] = 'mirai_udpplain'

mirai_dataset  = pd.concat([benign_traffic, mirai_scan_traffic, mirai_syn_traffic,
                mirai_ack_traffic, mirai_udp_traffic, mirai_udpplain_traffic],
                axis=0, sort=False, ignore_index=True)

# %%
selected_features = ['HH_L1_weight', 'HH_jit_L1_weight', 'MI_dir_L0.01_mean',
       'H_L0.1_weight', 'H_L0.1_mean', 'MI_dir_L1_mean', 'H_L1_mean',
       'H_L0.01_variance', 'MI_dir_L0.01_variance', 'H_L5_weight',
       'H_L0.1_variance', 'MI_dir_L0.1_weight', 'MI_dir_L0.1_mean',
       'MI_dir_L5_weight', 'H_L0.01_mean', 'H_L5_mean', 'MI_dir_L0.1_variance',
       'MI_dir_L3_mean',  'label']

# %%
selected_mirai_dataset = mirai_dataset[selected_features].copy()

# %%
selected_mirai_dataset.shape
# Out:
# (3665513, 19)

# %%
#Number of Missing Values in the Dataset
selected_mirai_dataset.isnull().sum().sum()
# Out:
# 0

# %%
#Number of Duplicate Rows in the Dataset
selected_mirai_dataset.duplicated().sum()
# Out:
# 1607967

# %%
# Remove duplicate rows from the Dataset
selected_mirai_dataset = selected_mirai_dataset.drop_duplicates()

# Check the number of duplicate rows after removal
selected_mirai_dataset.duplicated().sum()
# Out:
# 0

# %%
selected_mirai_dataset.shape
# Out:
# (2057546, 19)

# %%
import numpy as np

# Select columns for z-score calculation (excluding the last column)
column_features = selected_mirai_dataset.iloc[:, :-1]

# Calculate z-scores for each column
z_scores = (column_features - column_features.mean()) / column_features.std()

# Set a threshold for z-score beyond which a data point is considered an outlier
z_score_threshold = 3  # Adjust this threshold as needed

# Identify rows where any z-score exceeds the threshold
outlier_mask = (np.abs(z_scores) > z_score_threshold).any(axis=1)

# Remove outliers from the dataset
selected_mirai_dataset = selected_mirai_dataset[~outlier_mask]

# %%
selected_mirai_dataset.shape
# Out:
# (2046764, 19)

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the columns to be normalized (excluding the 'label' column)
column_to_normalize = selected_mirai_dataset.columns[selected_mirai_dataset.columns != 'label']


# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
selected_mirai_dataset[column_to_normalize] = scaler.fit_transform(selected_mirai_dataset[column_to_normalize])

# %%
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000       2.636780e-16       0.000000
# 1      0.000039          0.000039       5.547170e-01       0.000179
# 2      0.001219          0.001219       5.660395e-01       0.000289
# 3      0.000000          0.000000       5.226415e-01       0.000000
# 4      0.000000          0.000000       2.612201e-01       0.000111
#
#     H_L0.1_mean  MI_dir_L1_mean     H_L1_mean  H_L0.01_variance  \
# 0  4.163336e-17    1.249001e-16  1.249001e-16          0.000000
# 1  5.408092e-01    4.823113e-01  4.817053e-01          0.000193
# 2  5.509964e-01    4.923052e-01  4.918483e-01          0.000712
# 3  5.226581e-01    4.544225e-01  4.544225e-01          0.000000
# 4  2.603220e-01    2.184604e-01  2.184604e-01          0.167279
#
#    MI_dir_L0.01_variance   H_L5_weight  H_L0.1_variance  MI_dir_L0.1_weight  \
# 0               0.000000  0.000000e+00         0.000000            0.000000
# 1               0.000000  1.174467e-10         0.000295            0.000000
# 2               0.000314  3.148594e-03         0.000865            0.000111
# 3               0.000000  0.000000e+00         0.000000            0.000000
# 4               0.167279  2.496561e-03         0.165695            0.000111
#
#    MI_dir_L0.1_mean  MI_dir_L5_weight  H_L0.01_mean     H_L5_mean  \
# 0      4.163336e-17          0.000000  2.775558e-16  1.110223e-16
# 1      5.547170e-01          0.000000  5.617840e-01  4.221846e-01
# 2      5.660551e-01          0.003149  5.685832e-01  4.314597e-01
# 3      5.226415e-01          0.000000  5.474308e-01  3.977726e-01
# 4      2.603138e-01          0.002497  2.736099e-01  1.610346e-01
#
#    MI_dir_L0.1_variance  MI_dir_L3_mean   label
# 0              0.000000    1.249001e-16  benign
# 1              0.000000    4.510277e-01  benign
# 2              0.000311    4.606554e-01  benign
# 3              0.000000    4.249479e-01  benign
# 4              0.165695    1.880207e-01  benign

# %%
selected_mirai_dataset = selected_mirai_dataset.sample(frac=1).reset_index(drop=True)
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000002          0.000002           0.279473       0.000425
# 1      0.665321          0.665321           0.694284       0.734160
# 2      0.741479          0.741479           0.020245       0.789353
# 3      0.512558          0.512558           0.625278       0.709582
# 4      0.599735          0.599735           0.020243       0.729377
#
#    H_L0.1_mean  MI_dir_L1_mean  H_L1_mean  H_L0.01_variance  \
# 0     0.315775        0.000803   0.000803          0.202139
# 1     0.702951        0.658731   0.658731          0.404251
# 2     0.020530        0.018558   0.018558          0.000308
# 3     0.626823        0.548258   0.548258          0.504559
# 4     0.020426        0.018500   0.018500          0.000311
#
#    MI_dir_L0.01_variance  H_L5_weight  H_L0.1_variance  MI_dir_L0.1_weight  \
# 0               0.202139     0.000000         0.332439            0.000425
# 1               0.404251     0.470866         0.390801            0.734160
# 2               0.000308     0.506563         0.000293            0.789353
# 3               0.504559     0.437175         0.498676            0.709582
# 4               0.000311     0.395487         0.000299            0.729377
#
#    MI_dir_L0.1_mean  MI_dir_L5_weight  H_L0.01_mean     H_L5_mean  \
# 0          0.315765          0.000000      0.292728  1.110223e-16
# 1          0.702929          0.470866      0.727215  6.878239e-01
# 2          0.020529          0.506563      0.021205  1.847559e-02
# 3          0.626803          0.437175      0.654936  5.463245e-01
# 4          0.020425          0.395487      0.021203  1.553784e-02
#
#    MI_dir_L0.1_variance  MI_dir_L3_mean      label
# 0              0.332439    3.528449e-10     benign
# 1              0.390801    6.959258e-01  mirai_udp
# 2              0.000293    1.846649e-02  mirai_syn
# 3              0.498676    5.387942e-01  mirai_ack
# 4              0.000299    1.752443e-02  mirai_syn

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# Calculate percentage values
class_counts = selected_mirai_dataset['label'].value_counts(normalize=True) * 100

plt.title("Class Distribution")
bar_plot = selected_mirai_dataset['label'].value_counts().plot(kind='bar')
plt.xlabel('Classes')
plt.ylabel('Frequency')

# Annotate each bar with its percentage value
for i, val in enumerate(class_counts):
    plt.text(i, selected_mirai_dataset['label'].value_counts()[i], f'{val:.2f}%', ha='center')

plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(selected_mirai_dataset['label'].value_counts())
# Out:
# mirai_udp         544761
# benign            423659
# mirai_syn         312555
# mirai_ack         280143
# mirai_scan        256151
# mirai_udpplain    229495
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(selected_mirai_dataset, test_size=0.2, random_state=42, stratify=selected_mirai_dataset["label"])

# %%
features = list(train_df.columns)
features.remove("label")

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_df["label"] = label_encoder.fit_transform(train_df["label"])
test_df["label"] = label_encoder.transform(test_df["label"])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=18)
X_train = train_df[features].values
#X_train = pca.fit_transform(X_train)
y_train = train_df["label"].values

X_test = test_df[features].values
#X_test = pca.fit_transform(X_test)
y_test = test_df["label"].values

# %%
import statsmodels.api as sm
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from tabulate import tabulate

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train)

class_weights = {k: v for k,v in enumerate(class_weights)}
class_weights
# Out:
# {0: 0.805193547086344,
#  1: 1.217692037683203,
#  2: 1.3317416630473857,
#  3: 1.0914152442503453,
#  4: 0.6261959558736357,
#  5: 1.4864258117460802}

# %%
input_shape = X_train.shape[1:]
nb_classes = len(label_encoder.classes_)

# %%
input_shape
# Out:
# (18,)

# %%
from tensorflow.keras.utils import to_categorical

def convert_to_categorical(y, nb_classes):
    return to_categorical(y, num_classes=nb_classes)

# %%
import random

def data_indices(labels: np.ndarray, nb_clients: int):
    data_len = len(labels)
    indices = np.arange(data_len)
    np.random.shuffle(indices)
    chunk_size = data_len // nb_clients
    chunks = [indices[i:i+chunk_size] for i in range(0, data_len, chunk_size)]

    # Ensure non-IID distribution by shuffling 2 of the 4 chunks
    chunks[-1] = np.random.permutation(chunks[-1])
    chunks[-3] = np.random.permutation(chunks[-3])
    

    return chunks

# %%
def sample(y:np.ndarray, nb_clients: int):
    sampler_fn = data_indices
    client_data_indices = sampler_fn(y, nb_clients)
    return client_data_indices

# %%
def assign_data_to_clients(clients: dict, X:np.ndarray, y:np.ndarray, nb_classes:int):
    sampled_data_indices = sample(y, len(clients.keys()))  # Use the sample function to get data indices
    for client_name, data_indices in zip(clients.keys(), sampled_data_indices):
        X = X_train[data_indices]  # Subset the features for the current client
        y = y_train[data_indices]  # Subset the labels for the current client
        y = convert_to_categorical(y, nb_classes)  # Convert labels to categorical format if needed
        clients[client_name] = list(zip(X, y))  # Assign data to the current client
    return clients

# %%
def create_clients(X, y, nb_classes, num_clients=4, initial='clients'):
    # Create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]
    clients = {client_names[i] : [] for i in range(len(client_names))}
    return assign_data_to_clients(clients, X, y, nb_classes)

# %%
def batch_data(data_shard, batch_size=64):
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    del data_shard

    len_label = len(label)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    del data, label
    return dataset.shuffle(len_label).batch(batch_size)

# %%
import keras.backend as K
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import keras
import os
from keras.models import Model
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Activation, BatchNormalization, GRU, Dense, Dropout, Input

def get_model(input_shape, nb_classes):
    inputs = Input(shape=input_shape)
    
    x = Dense(32, activation="relu")(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = Dropout(0.2)(x)
    outputs = Dense(nb_classes, activation="softmax")(x)
    
    return keras.Model(inputs, outputs)

# %%
import tensorflow_privacy
from tensorflow_privacy.privacy.optimizers import dp_optimizer_keras  
from keras.metrics import Recall, Precision
from tensorflow.keras.utils import plot_model

learning_rate = 1e-3
comms_round = 5
loss='categorical_crossentropy'
metrics = ["accuracy", Recall(), Precision(), f1_score]
#optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
optimizer = tensorflow_privacy.DPKerasAdamOptimizer(l2_norm_clip= 1.6, noise_multiplier= 0.01, num_microbatches=1, learning_rate= learning_rate)


#initialize global model
global_model = get_model(input_shape, nb_classes)

global_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18)]              0
#
#  dense (Dense)               (None, 32)                608
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  batch_normalization_2 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 4358 (17.02 KB)
# Trainable params: 4166 (16.27 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
BATCH_SIZE = 64

# create clients
clients_batched = create_clients(X_train, y_train, nb_classes, num_clients=4, initial='client')

del X_train, y_train

# process and batch the training data for each client
client_set = {k: {} for k in clients_batched.keys()}

for (client_name, data) in clients_batched.items():
    client_set[client_name]["dataset"] = batch_data(data, BATCH_SIZE)
    local_model = get_model(input_shape, nb_classes)
    local_model.compile(loss=loss,
                      optimizer=optimizer,
                      metrics=metrics)
    client_set[client_name]["model"] = local_model

# %%
#process and batch the test set

y_test = convert_to_categorical(y_test, nb_classes)

test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

del X_test, y_test

# %%
# Define a function to calculate the weight scaling factor
def weight_scalling_factor(clients, client_name):
    client_names = list(clients.keys())
    # Get the batch size
    bs = list(clients[client_name]["dataset"])[0][0].shape[0]
    # Calculate the total training data points across clients
    global_count = sum([tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() for client_name in client_names]) * bs
    # Calculate the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() * bs
    return local_count / global_count

# %%
# Define a function to scale model weights
def scale_model_weights(weight, scalar):
    '''function for scaling a model's weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final

# %%
def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights --> FedAvg'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)

    return avg_grad

# %%
from sklearn.metrics import accuracy_score

def test_model(X_test, y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(y_test, logits)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(np.argmax(y_test, axis=1), np.argmax(logits, axis=1))

    r = Recall()
    r.update_state(y_test, logits)
    recall = r.result().numpy()

    p = Precision()
    p.update_state(y_test, logits)
    precision = p.result().numpy()

    f = f1_score(y_test, logits)
    f1 = f.numpy()

    print('comm_round: {} | global_loss: {} | global_accuracy: {:.4} | global_recall: {:.4} | global_precision: {:.4} | global_f1_score: {:.4} \n'.format(comm_round, loss, accuracy, recall, precision, f1))
    return loss, accuracy, precision, recall, f1

# %%
def train_client(client, global_weights):
    client_set[client]["model"] = client_set[client]["model"]

    #set local model weight to the weight of the global model
    client_set[client]["model"].set_weights(global_weights)

    #fit local model with client's data
    print(f"Round: {comm_round} | Client: {client} training")
    client_set[client]["model"].fit(client_set[client]["dataset"], epochs=20, verbose=1)

    #scale the model weights and add to list
    scaling_factor = weight_scalling_factor(client_set, client)
    scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
    return scaled_weights

# %%
import random

#commence global training loop
global_loss=[]
global_accuracy=[]
global_precision=[]
global_recall=[]
global_f1=[]
best_global_accuracy = 0

for comm_round in range(comms_round):
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()

    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(client_set.keys())
    random.shuffle(client_names)

    #loop through each client and create new local model
    for client in client_names:
        scaled_weights = train_client(client, global_weights)

        scaled_local_weight_list.append(scaled_weights)

    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)

    #update global model
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    g_accuracy = 0
    for(x_batch, y_batch) in test_batched:
        g_loss, g_accuracy, g_precision, g_recall, g_f1 = test_model(x_batch, y_batch, global_model, comm_round)
        global_loss.append(g_loss)
        global_accuracy.append(g_accuracy)
        global_precision.append(g_precision)
        global_recall.append(g_recall)
        global_f1.append(g_f1)

    if g_accuracy > best_global_accuracy:
        best_global_accuracy = g_accuracy
        global_model.save_weights('FL_DP_No_PCA.h5')
        print("New Weights Saved")
# Out:
# Round: 0 | Client: client_3 training
# Epoch 1/20
# 6397/6397 [==============================] - 69s 5ms/step - loss: 0.3748 - accuracy: 0.8353 - recall: 0.7853 - precision: 0.8871 - f1_score: 0.8281
# Epoch 2/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.2261 - accuracy: 0.9148 - recall: 0.9023 - precision: 0.9280 - f1_score: 0.9148
# Epoch 3/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1905 - accuracy: 0.9294 - recall: 0.9195 - precision: 0.9399 - f1_score: 0.9295
# Epoch 4/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1671 - accuracy: 0.9392 - recall: 0.9317 - precision: 0.9474 - f1_score: 0.9394
# Epoch 5/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1496 - accuracy: 0.9481 - recall: 0.9419 - precision: 0.9543 - f1_score: 0.9480
# Epoch 6/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1404 - accuracy: 0.9514 - recall: 0.9465 - precision: 0.9570 - f1_score: 0.9516
# Epoch 7/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1439 - accuracy: 0.9505 - recall: 0.9453 - precision: 0.9564 - f1_score: 0.9507
# Epoch 8/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1280 - accuracy: 0.9565 - recall: 0.9523 - precision: 0.9613 - f1_score: 0.9567
# Epoch 9/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1266 - accuracy: 0.9588 - recall: 0.9552 - precision: 0.9629 - f1_score: 0.9590
# Epoch 10/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1148 - accuracy: 0.9626 - recall: 0.9594 - precision: 0.9662 - f1_score: 0.9628
# Epoch 11/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1112 - accuracy: 0.9646 - recall: 0.9622 - precision: 0.9675 - f1_score: 0.9647
# Epoch 12/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1038 - accuracy: 0.9676 - recall: 0.9657 - precision: 0.9697 - f1_score: 0.9676
# Epoch 13/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0971 - accuracy: 0.9700 - recall: 0.9683 - precision: 0.9716 - f1_score: 0.9699
# Epoch 14/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0985 - accuracy: 0.9697 - recall: 0.9682 - precision: 0.9714 - f1_score: 0.9697
# Epoch 15/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0972 - accuracy: 0.9706 - recall: 0.9691 - precision: 0.9720 - f1_score: 0.9705
# Epoch 16/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1004 - accuracy: 0.9691 - recall: 0.9674 - precision: 0.9709 - f1_score: 0.9691
# Epoch 17/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.0924 - accuracy: 0.9715 - recall: 0.9697 - precision: 0.9735 - f1_score: 0.9716
# Epoch 18/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0874 - accuracy: 0.9732 - recall: 0.9717 - precision: 0.9749 - f1_score: 0.9733
# Epoch 19/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0842 - accuracy: 0.9743 - recall: 0.9728 - precision: 0.9759 - f1_score: 0.9743
# Epoch 20/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0805 - accuracy: 0.9757 - recall: 0.9741 - precision: 0.9773 - f1_score: 0.9756
# Round: 0 | Client: client_2 training
# Epoch 1/20
# 6397/6397 [==============================] - 47s 6ms/step - loss: 0.3419 - accuracy: 0.8536 - recall: 0.8924 - precision: 0.9393 - f1_score: 0.8487
# Epoch 2/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.2341 - accuracy: 0.9120 - recall: 0.8974 - precision: 0.9268 - f1_score: 0.9117
# Epoch 3/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1998 - accuracy: 0.9261 - recall: 0.9137 - precision: 0.9391 - f1_score: 0.9261
# Epoch 4/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1710 - accuracy: 0.9392 - recall: 0.9299 - precision: 0.9490 - f1_score: 0.9392
# Epoch 5/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1546 - accuracy: 0.9467 - recall: 0.9390 - precision: 0.9546 - f1_score: 0.9466
# Epoch 6/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1470 - accuracy: 0.9496 - recall: 0.9434 - precision: 0.9561 - f1_score: 0.9496
# Epoch 7/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1506 - accuracy: 0.9470 - recall: 0.9400 - precision: 0.9543 - f1_score: 0.9470
# Epoch 8/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1378 - accuracy: 0.9534 - recall: 0.9480 - precision: 0.9589 - f1_score: 0.9534
# Epoch 9/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1293 - accuracy: 0.9569 - recall: 0.9521 - precision: 0.9619 - f1_score: 0.9569
# Epoch 10/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1235 - accuracy: 0.9595 - recall: 0.9554 - precision: 0.9639 - f1_score: 0.9596
# Epoch 11/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1221 - accuracy: 0.9607 - recall: 0.9570 - precision: 0.9646 - f1_score: 0.9607
# Epoch 12/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1198 - accuracy: 0.9616 - recall: 0.9582 - precision: 0.9652 - f1_score: 0.9616
# Epoch 13/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1166 - accuracy: 0.9626 - recall: 0.9595 - precision: 0.9660 - f1_score: 0.9627
# Epoch 14/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1111 - accuracy: 0.9647 - recall: 0.9616 - precision: 0.9678 - f1_score: 0.9647
# Epoch 15/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1163 - accuracy: 0.9632 - recall: 0.9602 - precision: 0.9665 - f1_score: 0.9633
# Epoch 16/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1021 - accuracy: 0.9677 - recall: 0.9653 - precision: 0.9704 - f1_score: 0.9678
# Epoch 17/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0978 - accuracy: 0.9699 - recall: 0.9679 - precision: 0.9720 - f1_score: 0.9699
# Epoch 18/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0994 - accuracy: 0.9687 - recall: 0.9666 - precision: 0.9709 - f1_score: 0.9687
# Epoch 19/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1084 - accuracy: 0.9660 - recall: 0.9639 - precision: 0.9683 - f1_score: 0.9661
# Epoch 20/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1020 - accuracy: 0.9676 - recall: 0.9656 - precision: 0.9697 - f1_score: 0.9676
# Round: 0 | Client: client_4 training
# Epoch 1/20
# 6397/6397 [==============================] - 44s 5ms/step - loss: 0.3366 - accuracy: 0.8556 - recall: 0.8887 - precision: 0.9371 - f1_score: 0.8513
# Epoch 2/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.2463 - accuracy: 0.9058 - recall: 0.8885 - precision: 0.9229 - f1_score: 0.9052
# Epoch 3/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.2073 - accuracy: 0.9213 - recall: 0.9091 - precision: 0.9339 - f1_score: 0.9212
# Epoch 4/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1835 - accuracy: 0.9321 - recall: 0.9227 - precision: 0.9416 - f1_score: 0.9320
# Epoch 5/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1704 - accuracy: 0.9384 - recall: 0.9306 - precision: 0.9463 - f1_score: 0.9383
# Epoch 6/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1580 - accuracy: 0.9434 - recall: 0.9375 - precision: 0.9494 - f1_score: 0.9433
# Epoch 7/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1507 - accuracy: 0.9474 - recall: 0.9419 - precision: 0.9529 - f1_score: 0.9473
# Epoch 8/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1396 - accuracy: 0.9526 - recall: 0.9479 - precision: 0.9572 - f1_score: 0.9524
# Epoch 9/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1323 - accuracy: 0.9556 - recall: 0.9520 - precision: 0.9593 - f1_score: 0.9556
# Epoch 10/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1220 - accuracy: 0.9595 - recall: 0.9566 - precision: 0.9624 - f1_score: 0.9594
# Epoch 11/20
# 6397/6397 [==============================] - 45s 7ms/step - loss: 0.1089 - accuracy: 0.9653 - recall: 0.9633 - precision: 0.9673 - f1_score: 0.9652
# Epoch 12/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.1022 - accuracy: 0.9677 - recall: 0.9663 - precision: 0.9695 - f1_score: 0.9678
# Epoch 13/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0976 - accuracy: 0.9695 - recall: 0.9681 - precision: 0.9712 - f1_score: 0.9696
# Epoch 14/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0931 - accuracy: 0.9715 - recall: 0.9701 - precision: 0.9730 - f1_score: 0.9715
# Epoch 15/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0957 - accuracy: 0.9708 - recall: 0.9695 - precision: 0.9722 - f1_score: 0.9708
# Epoch 16/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1103 - accuracy: 0.9655 - recall: 0.9635 - precision: 0.9676 - f1_score: 0.9655
# Epoch 17/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1040 - accuracy: 0.9674 - recall: 0.9657 - precision: 0.9691 - f1_score: 0.9674
# Epoch 18/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0992 - accuracy: 0.9688 - recall: 0.9674 - precision: 0.9705 - f1_score: 0.9689
# Epoch 19/20
# 6397/6397 [==============================] - 45s 7ms/step - loss: 0.0987 - accuracy: 0.9688 - recall: 0.9673 - precision: 0.9703 - f1_score: 0.9688
# Epoch 20/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0954 - accuracy: 0.9698 - recall: 0.9685 - precision: 0.9713 - f1_score: 0.9699
# Round: 0 | Client: client_1 training
# Epoch 1/20
# 6397/6397 [==============================] - 46s 6ms/step - loss: 0.3113 - accuracy: 0.8698 - recall: 0.9018 - precision: 0.9394 - f1_score: 0.8659
# Epoch 2/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.2116 - accuracy: 0.9200 - recall: 0.9080 - precision: 0.9329 - f1_score: 0.9201
# Epoch 3/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1770 - accuracy: 0.9367 - recall: 0.9303 - precision: 0.9435 - f1_score: 0.9368
# Epoch 4/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1602 - accuracy: 0.9438 - recall: 0.9388 - precision: 0.9490 - f1_score: 0.9438
# Epoch 5/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1467 - accuracy: 0.9495 - recall: 0.9456 - precision: 0.9536 - f1_score: 0.9494
# Epoch 6/20
# 6397/6397 [==============================] - 34s 5ms/step - loss: 0.1366 - accuracy: 0.9538 - recall: 0.9508 - precision: 0.9570 - f1_score: 0.9538
# Epoch 7/20
# 6397/6397 [==============================] - 34s 5ms/step - loss: 0.1207 - accuracy: 0.9609 - recall: 0.9586 - precision: 0.9632 - f1_score: 0.9609
# Epoch 8/20
# 6397/6397 [==============================] - 47s 7ms/step - loss: 0.1164 - accuracy: 0.9636 - recall: 0.9617 - precision: 0.9656 - f1_score: 0.9636
# Epoch 9/20
# 6397/6397 [==============================] - 48s 7ms/step - loss: 0.1037 - accuracy: 0.9678 - recall: 0.9660 - precision: 0.9698 - f1_score: 0.9678
# Epoch 10/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.0991 - accuracy: 0.9695 - recall: 0.9678 - precision: 0.9711 - f1_score: 0.9694
# Epoch 11/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0964 - accuracy: 0.9707 - recall: 0.9693 - precision: 0.9722 - f1_score: 0.9708
# Epoch 12/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0914 - accuracy: 0.9718 - recall: 0.9706 - precision: 0.9734 - f1_score: 0.9720
# Epoch 13/20
# 6397/6397 [==============================] - 43s 6ms/step - loss: 0.0878 - accuracy: 0.9732 - recall: 0.9721 - precision: 0.9746 - f1_score: 0.9732
# Epoch 14/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.0864 - accuracy: 0.9739 - recall: 0.9728 - precision: 0.9751 - f1_score: 0.9739
# Epoch 15/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.0854 - accuracy: 0.9746 - recall: 0.9736 - precision: 0.9758 - f1_score: 0.9747
# Epoch 16/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.0829 - accuracy: 0.9754 - recall: 0.9743 - precision: 0.9765 - f1_score: 0.9754
# Epoch 17/20
# 6397/6397 [==============================] - 46s 7ms/step - loss: 0.0780 - accuracy: 0.9764 - recall: 0.9755 - precision: 0.9775 - f1_score: 0.9765
# Epoch 18/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.0765 - accuracy: 0.9769 - recall: 0.9760 - precision: 0.9781 - f1_score: 0.9770
# Epoch 19/20
# 6397/6397 [==============================] - 49s 7ms/step - loss: 0.0758 - accuracy: 0.9770 - recall: 0.9760 - precision: 0.9780 - f1_score: 0.9770
# Epoch 20/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.0732 - accuracy: 0.9779 - recall: 0.9768 - precision: 0.9791 - f1_score: 0.9779
# 12793/12793 [==============================] - 35s 3ms/step
# comm_round: 0 | global_loss: 1.7657593488693237 | global_accuracy: 0.1122 | global_recall: 0.0 | global_precision: 0.0 | global_f1_score: 0.0
#
# New Weights Saved
# Round: 1 | Client: client_4 training
# Epoch 1/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.2078 - accuracy: 0.9246 - recall: 0.9117 - precision: 0.9375 - f1_score: 0.9234
# Epoch 2/20
# 6397/6397 [==============================] - 49s 8ms/step - loss: 0.1534 - accuracy: 0.9473 - recall: 0.9423 - precision: 0.9525 - f1_score: 0.9473
# Epoch 3/20
# 6397/6397 [==============================] - 43s 6ms/step - loss: 0.1434 - accuracy: 0.9521 - recall: 0.9480 - precision: 0.9563 - f1_score: 0.9521
# Epoch 4/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1416 - accuracy: 0.9525 - recall: 0.9485 - precision: 0.9568 - f1_score: 0.9526
# Epoch 5/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1386 - accuracy: 0.9533 - recall: 0.9499 - precision: 0.9570 - f1_score: 0.9534
# Epoch 6/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1351 - accuracy: 0.9549 - recall: 0.9516 - precision: 0.9584 - f1_score: 0.9550
# Epoch 7/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.1315 - accuracy: 0.9564 - recall: 0.9534 - precision: 0.9595 - f1_score: 0.9564
# Epoch 8/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1297 - accuracy: 0.9569 - recall: 0.9544 - precision: 0.9599 - f1_score: 0.9571
# Epoch 9/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1265 - accuracy: 0.9580 - recall: 0.9554 - precision: 0.9611 - f1_score: 0.9582
# Epoch 10/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1251 - accuracy: 0.9590 - recall: 0.9565 - precision: 0.9619 - f1_score: 0.9591
# Epoch 11/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1171 - accuracy: 0.9616 - recall: 0.9595 - precision: 0.9640 - f1_score: 0.9617
# Epoch 12/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1141 - accuracy: 0.9624 - recall: 0.9603 - precision: 0.9647 - f1_score: 0.9624
# Epoch 13/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1121 - accuracy: 0.9628 - recall: 0.9608 - precision: 0.9650 - f1_score: 0.9629
# Epoch 14/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1102 - accuracy: 0.9639 - recall: 0.9621 - precision: 0.9659 - f1_score: 0.9640
# Epoch 15/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1071 - accuracy: 0.9648 - recall: 0.9631 - precision: 0.9669 - f1_score: 0.9649
# Epoch 16/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1068 - accuracy: 0.9647 - recall: 0.9630 - precision: 0.9667 - f1_score: 0.9648
# Epoch 17/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1020 - accuracy: 0.9660 - recall: 0.9645 - precision: 0.9677 - f1_score: 0.9661
# Epoch 18/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1039 - accuracy: 0.9655 - recall: 0.9640 - precision: 0.9671 - f1_score: 0.9655
# Epoch 19/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1040 - accuracy: 0.9650 - recall: 0.9634 - precision: 0.9669 - f1_score: 0.9651
# Epoch 20/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1040 - accuracy: 0.9653 - recall: 0.9637 - precision: 0.9671 - f1_score: 0.9654
# Round: 1 | Client: client_3 training
# Epoch 1/20
# 6397/6397 [==============================] - 43s 6ms/step - loss: 0.2214 - accuracy: 0.9175 - recall: 0.9013 - precision: 0.9346 - f1_score: 0.9166
# Epoch 2/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1582 - accuracy: 0.9449 - recall: 0.9386 - precision: 0.9515 - f1_score: 0.9449
# Epoch 3/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1488 - accuracy: 0.9492 - recall: 0.9441 - precision: 0.9550 - f1_score: 0.9495
# Epoch 4/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1411 - accuracy: 0.9522 - recall: 0.9479 - precision: 0.9567 - f1_score: 0.9522
# Epoch 5/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1373 - accuracy: 0.9536 - recall: 0.9499 - precision: 0.9577 - f1_score: 0.9537
# Epoch 6/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.1342 - accuracy: 0.9549 - recall: 0.9513 - precision: 0.9588 - f1_score: 0.9550
# Epoch 7/20
# 6397/6397 [==============================] - 43s 7ms/step - loss: 0.1318 - accuracy: 0.9568 - recall: 0.9536 - precision: 0.9603 - f1_score: 0.9568
# Epoch 8/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1393 - accuracy: 0.9533 - recall: 0.9501 - precision: 0.9570 - f1_score: 0.9535
# Epoch 9/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1565 - accuracy: 0.9441 - recall: 0.9395 - precision: 0.9493 - f1_score: 0.9443
# Epoch 10/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1487 - accuracy: 0.9477 - recall: 0.9432 - precision: 0.9527 - f1_score: 0.9478
# Epoch 11/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.1318 - accuracy: 0.9554 - recall: 0.9519 - precision: 0.9593 - f1_score: 0.9555
# Epoch 12/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.1177 - accuracy: 0.9630 - recall: 0.9605 - precision: 0.9657 - f1_score: 0.9631
# Epoch 13/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.1088 - accuracy: 0.9659 - recall: 0.9639 - precision: 0.9682 - f1_score: 0.9661
# Epoch 14/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0991 - accuracy: 0.9690 - recall: 0.9674 - precision: 0.9709 - f1_score: 0.9691
# Epoch 15/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.0947 - accuracy: 0.9708 - recall: 0.9692 - precision: 0.9724 - f1_score: 0.9707
# Epoch 16/20
# 6397/6397 [==============================] - 43s 7ms/step - loss: 0.0896 - accuracy: 0.9722 - recall: 0.9708 - precision: 0.9737 - f1_score: 0.9722
# Epoch 17/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0868 - accuracy: 0.9728 - recall: 0.9715 - precision: 0.9743 - f1_score: 0.9729
# Epoch 18/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0874 - accuracy: 0.9728 - recall: 0.9716 - precision: 0.9743 - f1_score: 0.9729
# Epoch 19/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0840 - accuracy: 0.9740 - recall: 0.9728 - precision: 0.9753 - f1_score: 0.9740
# Epoch 20/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0805 - accuracy: 0.9752 - recall: 0.9740 - precision: 0.9766 - f1_score: 0.9753
# Round: 1 | Client: client_1 training
# Epoch 1/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1985 - accuracy: 0.9278 - recall: 0.9159 - precision: 0.9399 - f1_score: 0.9272
# Epoch 2/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.1507 - accuracy: 0.9483 - recall: 0.9431 - precision: 0.9536 - f1_score: 0.9482
# Epoch 3/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.1444 - accuracy: 0.9505 - recall: 0.9461 - precision: 0.9553 - f1_score: 0.9506
# Epoch 4/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1401 - accuracy: 0.9523 - recall: 0.9484 - precision: 0.9567 - f1_score: 0.9524
# Epoch 5/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1351 - accuracy: 0.9546 - recall: 0.9511 - precision: 0.9582 - f1_score: 0.9546
# Epoch 6/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1498 - accuracy: 0.9472 - recall: 0.9426 - precision: 0.9523 - f1_score: 0.9474
# Epoch 7/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.1275 - accuracy: 0.9578 - recall: 0.9546 - precision: 0.9612 - f1_score: 0.9578
# Epoch 8/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1680 - accuracy: 0.9393 - recall: 0.9323 - precision: 0.9470 - f1_score: 0.9395
# Epoch 9/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1625 - accuracy: 0.9406 - recall: 0.9332 - precision: 0.9487 - f1_score: 0.9408
# Epoch 10/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1588 - accuracy: 0.9425 - recall: 0.9359 - precision: 0.9501 - f1_score: 0.9428
# Epoch 11/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1547 - accuracy: 0.9436 - recall: 0.9372 - precision: 0.9509 - f1_score: 0.9439
# Epoch 12/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1541 - accuracy: 0.9443 - recall: 0.9372 - precision: 0.9521 - f1_score: 0.9445
# Epoch 13/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1495 - accuracy: 0.9458 - recall: 0.9395 - precision: 0.9528 - f1_score: 0.9460
# Epoch 14/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1507 - accuracy: 0.9455 - recall: 0.9395 - precision: 0.9519 - f1_score: 0.9456
# Epoch 15/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1475 - accuracy: 0.9471 - recall: 0.9414 - precision: 0.9536 - f1_score: 0.9474
# Epoch 16/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1424 - accuracy: 0.9486 - recall: 0.9429 - precision: 0.9549 - f1_score: 0.9488
# Epoch 17/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1458 - accuracy: 0.9486 - recall: 0.9432 - precision: 0.9542 - f1_score: 0.9486
# Epoch 18/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1389 - accuracy: 0.9506 - recall: 0.9462 - precision: 0.9556 - f1_score: 0.9508
# Epoch 19/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1361 - accuracy: 0.9520 - recall: 0.9476 - precision: 0.9568 - f1_score: 0.9520
# Epoch 20/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1353 - accuracy: 0.9521 - recall: 0.9479 - precision: 0.9569 - f1_score: 0.9523
# Round: 1 | Client: client_2 training
# Epoch 1/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.2453 - accuracy: 0.9048 - recall: 0.8879 - precision: 0.9220 - f1_score: 0.9033
# Epoch 2/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.1824 - accuracy: 0.9325 - recall: 0.9249 - precision: 0.9405 - f1_score: 0.9326
# Epoch 3/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1690 - accuracy: 0.9378 - recall: 0.9316 - precision: 0.9446 - f1_score: 0.9380
# Epoch 4/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1601 - accuracy: 0.9413 - recall: 0.9357 - precision: 0.9472 - f1_score: 0.9413
# Epoch 5/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1546 - accuracy: 0.9434 - recall: 0.9383 - precision: 0.9492 - f1_score: 0.9436
# Epoch 6/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1498 - accuracy: 0.9454 - recall: 0.9406 - precision: 0.9509 - f1_score: 0.9456
# Epoch 7/20
# 6397/6397 [==============================] - 45s 7ms/step - loss: 0.1467 - accuracy: 0.9467 - recall: 0.9424 - precision: 0.9516 - f1_score: 0.9469
# Epoch 8/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.1396 - accuracy: 0.9492 - recall: 0.9448 - precision: 0.9539 - f1_score: 0.9492
# Epoch 9/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1357 - accuracy: 0.9507 - recall: 0.9466 - precision: 0.9554 - f1_score: 0.9509
# Epoch 10/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1367 - accuracy: 0.9507 - recall: 0.9469 - precision: 0.9549 - f1_score: 0.9508
# Epoch 11/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.1307 - accuracy: 0.9527 - recall: 0.9489 - precision: 0.9567 - f1_score: 0.9528
# Epoch 12/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.1308 - accuracy: 0.9526 - recall: 0.9489 - precision: 0.9566 - f1_score: 0.9527
# Epoch 13/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1321 - accuracy: 0.9524 - recall: 0.9487 - precision: 0.9562 - f1_score: 0.9524
# Epoch 14/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1299 - accuracy: 0.9528 - recall: 0.9493 - precision: 0.9565 - f1_score: 0.9528
# Epoch 15/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1283 - accuracy: 0.9535 - recall: 0.9501 - precision: 0.9573 - f1_score: 0.9536
# Epoch 16/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1258 - accuracy: 0.9541 - recall: 0.9508 - precision: 0.9578 - f1_score: 0.9542
# Epoch 17/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1243 - accuracy: 0.9544 - recall: 0.9510 - precision: 0.9583 - f1_score: 0.9545
# Epoch 18/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1242 - accuracy: 0.9545 - recall: 0.9514 - precision: 0.9579 - f1_score: 0.9546
# Epoch 19/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1224 - accuracy: 0.9552 - recall: 0.9521 - precision: 0.9585 - f1_score: 0.9552
# Epoch 20/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1218 - accuracy: 0.9555 - recall: 0.9525 - precision: 0.9587 - f1_score: 0.9556
# 12793/12793 [==============================] - 33s 3ms/step
# comm_round: 1 | global_loss: 1.0610514879226685 | global_accuracy: 0.9898 | global_recall: 0.9892 | global_precision: 0.9903 | global_f1_score: 0.9897
#
# New Weights Saved
# Round: 2 | Client: client_2 training
# Epoch 1/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1013 - accuracy: 0.9658 - recall: 0.9643 - precision: 0.9676 - f1_score: 0.9659
# Epoch 2/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1002 - accuracy: 0.9664 - recall: 0.9651 - precision: 0.9679 - f1_score: 0.9664
# Epoch 3/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0991 - accuracy: 0.9672 - recall: 0.9658 - precision: 0.9686 - f1_score: 0.9672
# Epoch 4/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0971 - accuracy: 0.9678 - recall: 0.9664 - precision: 0.9692 - f1_score: 0.9678
# Epoch 5/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0992 - accuracy: 0.9673 - recall: 0.9659 - precision: 0.9689 - f1_score: 0.9673
# Epoch 6/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0955 - accuracy: 0.9688 - recall: 0.9676 - precision: 0.9702 - f1_score: 0.9689
# Epoch 7/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0960 - accuracy: 0.9680 - recall: 0.9668 - precision: 0.9694 - f1_score: 0.9681
# Epoch 8/20
# 6397/6397 [==============================] - 43s 7ms/step - loss: 0.0968 - accuracy: 0.9679 - recall: 0.9668 - precision: 0.9694 - f1_score: 0.9681
# Epoch 9/20
# 6397/6397 [==============================] - 43s 6ms/step - loss: 0.0956 - accuracy: 0.9684 - recall: 0.9672 - precision: 0.9699 - f1_score: 0.9685
# Epoch 10/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.0940 - accuracy: 0.9687 - recall: 0.9674 - precision: 0.9701 - f1_score: 0.9687
# Epoch 11/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0937 - accuracy: 0.9686 - recall: 0.9673 - precision: 0.9702 - f1_score: 0.9686
# Epoch 12/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0943 - accuracy: 0.9685 - recall: 0.9673 - precision: 0.9701 - f1_score: 0.9687
# Epoch 13/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0933 - accuracy: 0.9692 - recall: 0.9680 - precision: 0.9707 - f1_score: 0.9693
# Epoch 14/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0893 - accuracy: 0.9711 - recall: 0.9699 - precision: 0.9725 - f1_score: 0.9712
# Epoch 15/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0852 - accuracy: 0.9731 - recall: 0.9720 - precision: 0.9744 - f1_score: 0.9732
# Epoch 16/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0788 - accuracy: 0.9757 - recall: 0.9749 - precision: 0.9768 - f1_score: 0.9758
# Epoch 17/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0754 - accuracy: 0.9771 - recall: 0.9762 - precision: 0.9780 - f1_score: 0.9771
# Epoch 18/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.0724 - accuracy: 0.9787 - recall: 0.9779 - precision: 0.9795 - f1_score: 0.9787
# Epoch 19/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.0721 - accuracy: 0.9785 - recall: 0.9779 - precision: 0.9794 - f1_score: 0.9786
# Epoch 20/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0689 - accuracy: 0.9797 - recall: 0.9790 - precision: 0.9804 - f1_score: 0.9797
# Round: 2 | Client: client_4 training
# Epoch 1/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1003 - accuracy: 0.9663 - recall: 0.9646 - precision: 0.9680 - f1_score: 0.9662
# Epoch 2/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.0982 - accuracy: 0.9669 - recall: 0.9656 - precision: 0.9684 - f1_score: 0.9670
# Epoch 3/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0996 - accuracy: 0.9670 - recall: 0.9656 - precision: 0.9685 - f1_score: 0.9671
# Epoch 4/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0960 - accuracy: 0.9686 - recall: 0.9672 - precision: 0.9701 - f1_score: 0.9687
# Epoch 5/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0985 - accuracy: 0.9673 - recall: 0.9660 - precision: 0.9688 - f1_score: 0.9673
# Epoch 6/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0948 - accuracy: 0.9686 - recall: 0.9673 - precision: 0.9701 - f1_score: 0.9686
# Epoch 7/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0965 - accuracy: 0.9683 - recall: 0.9671 - precision: 0.9696 - f1_score: 0.9683
# Epoch 8/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0965 - accuracy: 0.9682 - recall: 0.9671 - precision: 0.9696 - f1_score: 0.9683
# Epoch 9/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0960 - accuracy: 0.9683 - recall: 0.9671 - precision: 0.9697 - f1_score: 0.9684
# Epoch 10/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0961 - accuracy: 0.9680 - recall: 0.9666 - precision: 0.9695 - f1_score: 0.9680
# Epoch 11/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.0933 - accuracy: 0.9686 - recall: 0.9673 - precision: 0.9702 - f1_score: 0.9687
# Epoch 12/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0939 - accuracy: 0.9688 - recall: 0.9674 - precision: 0.9703 - f1_score: 0.9688
# Epoch 13/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0932 - accuracy: 0.9687 - recall: 0.9674 - precision: 0.9703 - f1_score: 0.9688
# Epoch 14/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.0890 - accuracy: 0.9701 - recall: 0.9688 - precision: 0.9714 - f1_score: 0.9701
# Epoch 15/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0894 - accuracy: 0.9698 - recall: 0.9687 - precision: 0.9711 - f1_score: 0.9698
# Epoch 16/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0894 - accuracy: 0.9699 - recall: 0.9687 - precision: 0.9712 - f1_score: 0.9699
# Epoch 17/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0897 - accuracy: 0.9695 - recall: 0.9683 - precision: 0.9710 - f1_score: 0.9696
# Epoch 18/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0983 - accuracy: 0.9664 - recall: 0.9649 - precision: 0.9680 - f1_score: 0.9664
# Epoch 19/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1179 - accuracy: 0.9571 - recall: 0.9552 - precision: 0.9593 - f1_score: 0.9572
# Epoch 20/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1132 - accuracy: 0.9589 - recall: 0.9570 - precision: 0.9611 - f1_score: 0.9589
# Round: 2 | Client: client_3 training
# Epoch 1/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1303 - accuracy: 0.9522 - recall: 0.9495 - precision: 0.9553 - f1_score: 0.9524
# Epoch 2/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1258 - accuracy: 0.9540 - recall: 0.9515 - precision: 0.9569 - f1_score: 0.9542
# Epoch 3/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1233 - accuracy: 0.9555 - recall: 0.9533 - precision: 0.9583 - f1_score: 0.9558
# Epoch 4/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.1089 - accuracy: 0.9642 - recall: 0.9623 - precision: 0.9663 - f1_score: 0.9642
# Epoch 5/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0975 - accuracy: 0.9698 - recall: 0.9685 - precision: 0.9714 - f1_score: 0.9699
# Epoch 6/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0930 - accuracy: 0.9713 - recall: 0.9700 - precision: 0.9727 - f1_score: 0.9713
# Epoch 7/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.0890 - accuracy: 0.9729 - recall: 0.9718 - precision: 0.9743 - f1_score: 0.9730
# Epoch 8/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0865 - accuracy: 0.9737 - recall: 0.9727 - precision: 0.9748 - f1_score: 0.9737
# Epoch 9/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0842 - accuracy: 0.9740 - recall: 0.9730 - precision: 0.9754 - f1_score: 0.9742
# Epoch 10/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0821 - accuracy: 0.9748 - recall: 0.9738 - precision: 0.9760 - f1_score: 0.9749
# Epoch 11/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0812 - accuracy: 0.9755 - recall: 0.9745 - precision: 0.9766 - f1_score: 0.9756
# Epoch 12/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0813 - accuracy: 0.9750 - recall: 0.9740 - precision: 0.9762 - f1_score: 0.9751
# Epoch 13/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.0803 - accuracy: 0.9756 - recall: 0.9746 - precision: 0.9768 - f1_score: 0.9756
# Epoch 14/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0772 - accuracy: 0.9762 - recall: 0.9751 - precision: 0.9773 - f1_score: 0.9762
# Epoch 15/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0793 - accuracy: 0.9756 - recall: 0.9746 - precision: 0.9766 - f1_score: 0.9756
# Epoch 16/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0760 - accuracy: 0.9767 - recall: 0.9757 - precision: 0.9779 - f1_score: 0.9768
# Epoch 17/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0754 - accuracy: 0.9767 - recall: 0.9758 - precision: 0.9778 - f1_score: 0.9767
# Epoch 18/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0762 - accuracy: 0.9768 - recall: 0.9759 - precision: 0.9779 - f1_score: 0.9769
# Epoch 19/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0734 - accuracy: 0.9778 - recall: 0.9770 - precision: 0.9788 - f1_score: 0.9778
# Epoch 20/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0722 - accuracy: 0.9777 - recall: 0.9769 - precision: 0.9786 - f1_score: 0.9777
# Round: 2 | Client: client_1 training
# Epoch 1/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1531 - accuracy: 0.9433 - recall: 0.9392 - precision: 0.9481 - f1_score: 0.9436
# Epoch 2/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.1447 - accuracy: 0.9460 - recall: 0.9419 - precision: 0.9508 - f1_score: 0.9463
# Epoch 3/20
# 6397/6397 [==============================] - 43s 7ms/step - loss: 0.1413 - accuracy: 0.9473 - recall: 0.9431 - precision: 0.9523 - f1_score: 0.9476
# Epoch 4/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.1379 - accuracy: 0.9486 - recall: 0.9445 - precision: 0.9534 - f1_score: 0.9488
# Epoch 5/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1332 - accuracy: 0.9504 - recall: 0.9466 - precision: 0.9552 - f1_score: 0.9508
# Epoch 6/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1335 - accuracy: 0.9503 - recall: 0.9462 - precision: 0.9552 - f1_score: 0.9506
# Epoch 7/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1326 - accuracy: 0.9511 - recall: 0.9472 - precision: 0.9556 - f1_score: 0.9513
# Epoch 8/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1307 - accuracy: 0.9512 - recall: 0.9476 - precision: 0.9556 - f1_score: 0.9515
# Epoch 9/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1315 - accuracy: 0.9514 - recall: 0.9478 - precision: 0.9560 - f1_score: 0.9517
# Epoch 10/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1291 - accuracy: 0.9519 - recall: 0.9482 - precision: 0.9564 - f1_score: 0.9522
# Epoch 11/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1263 - accuracy: 0.9536 - recall: 0.9499 - precision: 0.9577 - f1_score: 0.9537
# Epoch 12/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.1189 - accuracy: 0.9584 - recall: 0.9552 - precision: 0.9620 - f1_score: 0.9586
# Epoch 13/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.1066 - accuracy: 0.9648 - recall: 0.9623 - precision: 0.9677 - f1_score: 0.9649
# Epoch 14/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.1008 - accuracy: 0.9675 - recall: 0.9651 - precision: 0.9700 - f1_score: 0.9676
# Epoch 15/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0960 - accuracy: 0.9694 - recall: 0.9676 - precision: 0.9717 - f1_score: 0.9695
# Epoch 16/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.0901 - accuracy: 0.9712 - recall: 0.9695 - precision: 0.9731 - f1_score: 0.9713
# Epoch 17/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0871 - accuracy: 0.9726 - recall: 0.9711 - precision: 0.9742 - f1_score: 0.9726
# Epoch 18/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0835 - accuracy: 0.9735 - recall: 0.9723 - precision: 0.9751 - f1_score: 0.9736
# Epoch 19/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0824 - accuracy: 0.9743 - recall: 0.9730 - precision: 0.9756 - f1_score: 0.9742
# Epoch 20/20
# 6397/6397 [==============================] - 43s 7ms/step - loss: 0.0804 - accuracy: 0.9751 - recall: 0.9739 - precision: 0.9765 - f1_score: 0.9752
# 12793/12793 [==============================] - 42s 3ms/step
# comm_round: 2 | global_loss: 1.0522366762161255 | global_accuracy: 0.9948 | global_recall: 0.9947 | global_precision: 0.9949 | global_f1_score: 0.9948
#
# New Weights Saved
# Round: 3 | Client: client_2 training
# Epoch 1/20
# 6397/6397 [==============================] - 49s 8ms/step - loss: 0.1127 - accuracy: 0.9592 - recall: 0.9572 - precision: 0.9613 - f1_score: 0.9592
# Epoch 2/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.1119 - accuracy: 0.9598 - recall: 0.9579 - precision: 0.9620 - f1_score: 0.9599
# Epoch 3/20
# 6397/6397 [==============================] - 48s 7ms/step - loss: 0.1111 - accuracy: 0.9598 - recall: 0.9578 - precision: 0.9623 - f1_score: 0.9600
# Epoch 4/20
# 6397/6397 [==============================] - 48s 7ms/step - loss: 0.1052 - accuracy: 0.9643 - recall: 0.9624 - precision: 0.9665 - f1_score: 0.9644
# Epoch 5/20
# 6397/6397 [==============================] - 51s 8ms/step - loss: 0.1067 - accuracy: 0.9655 - recall: 0.9635 - precision: 0.9681 - f1_score: 0.9658
# Epoch 6/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.1037 - accuracy: 0.9666 - recall: 0.9648 - precision: 0.9688 - f1_score: 0.9667
# Epoch 7/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.0946 - accuracy: 0.9695 - recall: 0.9678 - precision: 0.9716 - f1_score: 0.9696
# Epoch 8/20
# 6397/6397 [==============================] - 45s 7ms/step - loss: 0.0929 - accuracy: 0.9702 - recall: 0.9686 - precision: 0.9721 - f1_score: 0.9703
# Epoch 9/20
# 6397/6397 [==============================] - 46s 7ms/step - loss: 0.0899 - accuracy: 0.9717 - recall: 0.9702 - precision: 0.9733 - f1_score: 0.9717
# Epoch 10/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0852 - accuracy: 0.9728 - recall: 0.9714 - precision: 0.9743 - f1_score: 0.9728
# Epoch 11/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0843 - accuracy: 0.9732 - recall: 0.9718 - precision: 0.9747 - f1_score: 0.9732
# Epoch 12/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0814 - accuracy: 0.9743 - recall: 0.9729 - precision: 0.9758 - f1_score: 0.9743
# Epoch 13/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0802 - accuracy: 0.9745 - recall: 0.9733 - precision: 0.9759 - f1_score: 0.9746
# Epoch 14/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0799 - accuracy: 0.9748 - recall: 0.9736 - precision: 0.9761 - f1_score: 0.9748
# Epoch 15/20
# 6397/6397 [==============================] - 36s 6ms/step - loss: 0.0781 - accuracy: 0.9752 - recall: 0.9741 - precision: 0.9765 - f1_score: 0.9752
# Epoch 16/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0779 - accuracy: 0.9758 - recall: 0.9747 - precision: 0.9772 - f1_score: 0.9759
# Epoch 17/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0745 - accuracy: 0.9768 - recall: 0.9756 - precision: 0.9780 - f1_score: 0.9768
# Epoch 18/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0768 - accuracy: 0.9764 - recall: 0.9754 - precision: 0.9778 - f1_score: 0.9766
# Epoch 19/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0750 - accuracy: 0.9769 - recall: 0.9757 - precision: 0.9783 - f1_score: 0.9769
# Epoch 20/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0731 - accuracy: 0.9773 - recall: 0.9762 - precision: 0.9787 - f1_score: 0.9774
# Round: 3 | Client: client_3 training
# Epoch 1/20
# 6397/6397 [==============================] - 49s 7ms/step - loss: 0.1144 - accuracy: 0.9583 - recall: 0.9565 - precision: 0.9605 - f1_score: 0.9585
# Epoch 2/20
# 6397/6397 [==============================] - 49s 7ms/step - loss: 0.1125 - accuracy: 0.9591 - recall: 0.9571 - precision: 0.9613 - f1_score: 0.9592
# Epoch 3/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.1100 - accuracy: 0.9601 - recall: 0.9581 - precision: 0.9625 - f1_score: 0.9603
# Epoch 4/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.1069 - accuracy: 0.9628 - recall: 0.9607 - precision: 0.9651 - f1_score: 0.9629
# Epoch 5/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0947 - accuracy: 0.9698 - recall: 0.9684 - precision: 0.9716 - f1_score: 0.9700
# Epoch 6/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0843 - accuracy: 0.9737 - recall: 0.9725 - precision: 0.9749 - f1_score: 0.9737
# Epoch 7/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0821 - accuracy: 0.9745 - recall: 0.9733 - precision: 0.9758 - f1_score: 0.9745
# Epoch 8/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0797 - accuracy: 0.9751 - recall: 0.9739 - precision: 0.9764 - f1_score: 0.9751
# Epoch 9/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0780 - accuracy: 0.9759 - recall: 0.9750 - precision: 0.9772 - f1_score: 0.9761
# Epoch 10/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0899 - accuracy: 0.9718 - recall: 0.9704 - precision: 0.9734 - f1_score: 0.9718
# Epoch 11/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0883 - accuracy: 0.9721 - recall: 0.9707 - precision: 0.9739 - f1_score: 0.9722
# Epoch 12/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0849 - accuracy: 0.9732 - recall: 0.9718 - precision: 0.9747 - f1_score: 0.9732
# Epoch 13/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0856 - accuracy: 0.9732 - recall: 0.9720 - precision: 0.9746 - f1_score: 0.9733
# Epoch 14/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0828 - accuracy: 0.9740 - recall: 0.9727 - precision: 0.9754 - f1_score: 0.9740
# Epoch 15/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0802 - accuracy: 0.9750 - recall: 0.9738 - precision: 0.9765 - f1_score: 0.9751
# Epoch 16/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0792 - accuracy: 0.9752 - recall: 0.9740 - precision: 0.9765 - f1_score: 0.9752
# Epoch 17/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0801 - accuracy: 0.9751 - recall: 0.9739 - precision: 0.9766 - f1_score: 0.9752
# Epoch 18/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0763 - accuracy: 0.9767 - recall: 0.9756 - precision: 0.9781 - f1_score: 0.9768
# Epoch 19/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0763 - accuracy: 0.9763 - recall: 0.9752 - precision: 0.9777 - f1_score: 0.9764
# Epoch 20/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0743 - accuracy: 0.9771 - recall: 0.9760 - precision: 0.9784 - f1_score: 0.9772
# Round: 3 | Client: client_1 training
# Epoch 1/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1406 - accuracy: 0.9484 - recall: 0.9450 - precision: 0.9525 - f1_score: 0.9487
# Epoch 2/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1341 - accuracy: 0.9507 - recall: 0.9469 - precision: 0.9552 - f1_score: 0.9510
# Epoch 3/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1303 - accuracy: 0.9520 - recall: 0.9482 - precision: 0.9565 - f1_score: 0.9523
# Epoch 4/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1235 - accuracy: 0.9574 - recall: 0.9543 - precision: 0.9610 - f1_score: 0.9576
# Epoch 5/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.1069 - accuracy: 0.9654 - recall: 0.9632 - precision: 0.9679 - f1_score: 0.9655
# Epoch 6/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0980 - accuracy: 0.9687 - recall: 0.9668 - precision: 0.9707 - f1_score: 0.9686
# Epoch 7/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0924 - accuracy: 0.9704 - recall: 0.9687 - precision: 0.9725 - f1_score: 0.9706
# Epoch 8/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0895 - accuracy: 0.9717 - recall: 0.9699 - precision: 0.9737 - f1_score: 0.9717
# Epoch 9/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0862 - accuracy: 0.9728 - recall: 0.9714 - precision: 0.9744 - f1_score: 0.9728
# Epoch 10/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0837 - accuracy: 0.9736 - recall: 0.9724 - precision: 0.9751 - f1_score: 0.9737
# Epoch 11/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0824 - accuracy: 0.9739 - recall: 0.9726 - precision: 0.9754 - f1_score: 0.9740
# Epoch 12/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0819 - accuracy: 0.9739 - recall: 0.9726 - precision: 0.9755 - f1_score: 0.9740
# Epoch 13/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0809 - accuracy: 0.9743 - recall: 0.9731 - precision: 0.9756 - f1_score: 0.9743
# Epoch 14/20
# ...
# Epoch 5/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.0869 - accuracy: 0.9732 - recall: 0.9719 - precision: 0.9747 - f1_score: 0.9733
# Epoch 6/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0810 - accuracy: 0.9748 - recall: 0.9737 - precision: 0.9762 - f1_score: 0.9749
# Epoch 7/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.0801 - accuracy: 0.9754 - recall: 0.9744 - precision: 0.9766 - f1_score: 0.9754
# Epoch 8/20
# 6397/6397 [==============================] - 46s 7ms/step - loss: 0.0774 - accuracy: 0.9756 - recall: 0.9746 - precision: 0.9769 - f1_score: 0.9757
# Epoch 9/20
# 6397/6397 [==============================] - 46s 7ms/step - loss: 0.0764 - accuracy: 0.9766 - recall: 0.9757 - precision: 0.9778 - f1_score: 0.9767
# Epoch 10/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0746 - accuracy: 0.9772 - recall: 0.9762 - precision: 0.9783 - f1_score: 0.9772
# Epoch 11/20
# 6397/6397 [==============================] - 48s 7ms/step - loss: 0.0741 - accuracy: 0.9772 - recall: 0.9762 - precision: 0.9783 - f1_score: 0.9772
# Epoch 12/20
# 6397/6397 [==============================] - 53s 8ms/step - loss: 0.0733 - accuracy: 0.9773 - recall: 0.9763 - precision: 0.9784 - f1_score: 0.9773
# Epoch 13/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.0740 - accuracy: 0.9771 - recall: 0.9764 - precision: 0.9782 - f1_score: 0.9773
# Epoch 14/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.0720 - accuracy: 0.9777 - recall: 0.9768 - precision: 0.9787 - f1_score: 0.9777
# Epoch 15/20
# 6397/6397 [==============================] - 53s 8ms/step - loss: 0.0799 - accuracy: 0.9750 - recall: 0.9739 - precision: 0.9762 - f1_score: 0.9750
# Epoch 16/20
# 6397/6397 [==============================] - 53s 8ms/step - loss: 0.0852 - accuracy: 0.9735 - recall: 0.9722 - precision: 0.9749 - f1_score: 0.9735
# Epoch 17/20
# 6397/6397 [==============================] - 53s 8ms/step - loss: 0.0831 - accuracy: 0.9738 - recall: 0.9725 - precision: 0.9754 - f1_score: 0.9739
# Epoch 18/20
# 6397/6397 [==============================] - 53s 8ms/step - loss: 0.0848 - accuracy: 0.9736 - recall: 0.9723 - precision: 0.9751 - f1_score: 0.9737
# Epoch 19/20
# 6397/6397 [==============================] - 54s 8ms/step - loss: 0.0810 - accuracy: 0.9744 - recall: 0.9733 - precision: 0.9759 - f1_score: 0.9745
# Epoch 20/20
# 6397/6397 [==============================] - 51s 8ms/step - loss: 0.0792 - accuracy: 0.9752 - recall: 0.9740 - precision: 0.9767 - f1_score: 0.9753
# 12793/12793 [==============================] - 44s 3ms/step
# comm_round: 3 | global_loss: 1.0809980630874634 | global_accuracy: 0.9628 | global_recall: 0.9616 | global_precision: 0.9632 | global_f1_score: 0.9624
#
# Round: 4 | Client: client_2 training
# Epoch 1/20
# 6397/6397 [==============================] - 50s 8ms/step - loss: 0.1188 - accuracy: 0.9592 - recall: 0.9566 - precision: 0.9622 - f1_score: 0.9593
# Epoch 2/20
# 6397/6397 [==============================] - 50s 8ms/step - loss: 0.1037 - accuracy: 0.9667 - recall: 0.9651 - precision: 0.9688 - f1_score: 0.9668
# Epoch 3/20
# 6397/6397 [==============================] - 50s 8ms/step - loss: 0.0950 - accuracy: 0.9696 - recall: 0.9682 - precision: 0.9714 - f1_score: 0.9698
# Epoch 4/20
# 6397/6397 [==============================] - 51s 8ms/step - loss: 0.0895 - accuracy: 0.9715 - recall: 0.9702 - precision: 0.9731 - f1_score: 0.9716
# Epoch 5/20
# 6397/6397 [==============================] - 50s 8ms/step - loss: 0.0863 - accuracy: 0.9726 - recall: 0.9714 - precision: 0.9741 - f1_score: 0.9727
# Epoch 6/20
# 6397/6397 [==============================] - 50s 8ms/step - loss: 0.0807 - accuracy: 0.9744 - recall: 0.9732 - precision: 0.9757 - f1_score: 0.9744
# Epoch 7/20
# 6397/6397 [==============================] - 51s 8ms/step - loss: 0.0805 - accuracy: 0.9750 - recall: 0.9740 - precision: 0.9762 - f1_score: 0.9751
# Epoch 8/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.0779 - accuracy: 0.9762 - recall: 0.9752 - precision: 0.9774 - f1_score: 0.9763
# Epoch 9/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.0759 - accuracy: 0.9767 - recall: 0.9756 - precision: 0.9780 - f1_score: 0.9767
# Epoch 10/20
# 6397/6397 [==============================] - 55s 8ms/step - loss: 0.0740 - accuracy: 0.9775 - recall: 0.9764 - precision: 0.9785 - f1_score: 0.9774
# Epoch 11/20
# 6397/6397 [==============================] - 56s 8ms/step - loss: 0.0730 - accuracy: 0.9777 - recall: 0.9766 - precision: 0.9789 - f1_score: 0.9777
# Epoch 12/20
# 6397/6397 [==============================] - 58s 9ms/step - loss: 0.0729 - accuracy: 0.9782 - recall: 0.9773 - precision: 0.9794 - f1_score: 0.9783
# Epoch 13/20
# 6397/6397 [==============================] - 56s 9ms/step - loss: 0.0718 - accuracy: 0.9782 - recall: 0.9773 - precision: 0.9794 - f1_score: 0.9783
# Epoch 14/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.0714 - accuracy: 0.9785 - recall: 0.9774 - precision: 0.9797 - f1_score: 0.9785
# Epoch 15/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.0699 - accuracy: 0.9789 - recall: 0.9780 - precision: 0.9800 - f1_score: 0.9790
# Epoch 16/20
# 6397/6397 [==============================] - 55s 8ms/step - loss: 0.0695 - accuracy: 0.9791 - recall: 0.9783 - precision: 0.9801 - f1_score: 0.9792
# Epoch 17/20
# 6397/6397 [==============================] - 61s 9ms/step - loss: 0.0700 - accuracy: 0.9793 - recall: 0.9785 - precision: 0.9802 - f1_score: 0.9793
# Epoch 18/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.0703 - accuracy: 0.9790 - recall: 0.9781 - precision: 0.9800 - f1_score: 0.9790
# Epoch 19/20
# 6397/6397 [==============================] - 55s 8ms/step - loss: 0.0694 - accuracy: 0.9793 - recall: 0.9784 - precision: 0.9804 - f1_score: 0.9794
# Epoch 20/20
# 6397/6397 [==============================] - 56s 9ms/step - loss: 0.0678 - accuracy: 0.9799 - recall: 0.9789 - precision: 0.9811 - f1_score: 0.9800
# Round: 4 | Client: client_3 training
# Epoch 1/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.1217 - accuracy: 0.9584 - recall: 0.9558 - precision: 0.9615 - f1_score: 0.9586
# Epoch 2/20
# 6397/6397 [==============================] - 50s 8ms/step - loss: 0.1044 - accuracy: 0.9664 - recall: 0.9645 - precision: 0.9685 - f1_score: 0.9665
# Epoch 3/20
# 6397/6397 [==============================] - 50s 8ms/step - loss: 0.0955 - accuracy: 0.9696 - recall: 0.9681 - precision: 0.9713 - f1_score: 0.9697
# Epoch 4/20
# 6397/6397 [==============================] - 51s 8ms/step - loss: 0.0883 - accuracy: 0.9721 - recall: 0.9709 - precision: 0.9735 - f1_score: 0.9721
# Epoch 5/20
# 6397/6397 [==============================] - 50s 8ms/step - loss: 0.0838 - accuracy: 0.9738 - recall: 0.9726 - precision: 0.9751 - f1_score: 0.9738
# Epoch 6/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.0816 - accuracy: 0.9746 - recall: 0.9734 - precision: 0.9759 - f1_score: 0.9747
# Epoch 7/20
# 6397/6397 [==============================] - 53s 8ms/step - loss: 0.0774 - accuracy: 0.9761 - recall: 0.9751 - precision: 0.9773 - f1_score: 0.9761
# Epoch 8/20
# 6397/6397 [==============================] - 52s 8ms/step - loss: 0.0768 - accuracy: 0.9763 - recall: 0.9752 - precision: 0.9776 - f1_score: 0.9764
# Epoch 9/20
# 6397/6397 [==============================] - 46s 7ms/step - loss: 0.0732 - accuracy: 0.9777 - recall: 0.9768 - precision: 0.9788 - f1_score: 0.9778
# Epoch 10/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.0729 - accuracy: 0.9778 - recall: 0.9769 - precision: 0.9789 - f1_score: 0.9778
# Epoch 11/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0714 - accuracy: 0.9780 - recall: 0.9770 - precision: 0.9790 - f1_score: 0.9780
# Epoch 12/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0713 - accuracy: 0.9784 - recall: 0.9775 - precision: 0.9796 - f1_score: 0.9785
# Epoch 13/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0715 - accuracy: 0.9788 - recall: 0.9779 - precision: 0.9799 - f1_score: 0.9789
# Epoch 14/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0677 - accuracy: 0.9793 - recall: 0.9785 - precision: 0.9804 - f1_score: 0.9794
# Epoch 15/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0696 - accuracy: 0.9793 - recall: 0.9785 - precision: 0.9804 - f1_score: 0.9794
# Epoch 16/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0668 - accuracy: 0.9799 - recall: 0.9791 - precision: 0.9808 - f1_score: 0.9799
# Epoch 17/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0687 - accuracy: 0.9796 - recall: 0.9788 - precision: 0.9805 - f1_score: 0.9796
# Epoch 18/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0686 - accuracy: 0.9796 - recall: 0.9789 - precision: 0.9805 - f1_score: 0.9797
# Epoch 19/20
# 6397/6397 [==============================] - 46s 7ms/step - loss: 0.0682 - accuracy: 0.9797 - recall: 0.9788 - precision: 0.9807 - f1_score: 0.9797
# Epoch 20/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.0667 - accuracy: 0.9799 - recall: 0.9790 - precision: 0.9809 - f1_score: 0.9799
# Round: 4 | Client: client_4 training
# Epoch 1/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.1206 - accuracy: 0.9586 - recall: 0.9561 - precision: 0.9616 - f1_score: 0.9587
# Epoch 2/20
# 6397/6397 [==============================] - 43s 6ms/step - loss: 0.1034 - accuracy: 0.9667 - recall: 0.9649 - precision: 0.9688 - f1_score: 0.9668
# Epoch 3/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0952 - accuracy: 0.9697 - recall: 0.9682 - precision: 0.9714 - f1_score: 0.9698
# Epoch 4/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.0901 - accuracy: 0.9715 - recall: 0.9703 - precision: 0.9729 - f1_score: 0.9716
# Epoch 5/20
# 6397/6397 [==============================] - 47s 7ms/step - loss: 0.0856 - accuracy: 0.9734 - recall: 0.9723 - precision: 0.9748 - f1_score: 0.9735
# Epoch 6/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.0818 - accuracy: 0.9746 - recall: 0.9735 - precision: 0.9759 - f1_score: 0.9746
# Epoch 7/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0802 - accuracy: 0.9753 - recall: 0.9742 - precision: 0.9766 - f1_score: 0.9753
# Epoch 8/20
# 6397/6397 [==============================] - 42s 6ms/step - loss: 0.0775 - accuracy: 0.9761 - recall: 0.9751 - precision: 0.9773 - f1_score: 0.9762
# Epoch 9/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0740 - accuracy: 0.9772 - recall: 0.9763 - precision: 0.9784 - f1_score: 0.9773
# Epoch 10/20
# 6397/6397 [==============================] - 34s 5ms/step - loss: 0.0747 - accuracy: 0.9772 - recall: 0.9763 - precision: 0.9784 - f1_score: 0.9773
# Epoch 11/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0721 - accuracy: 0.9781 - recall: 0.9771 - precision: 0.9793 - f1_score: 0.9782
# Epoch 12/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0723 - accuracy: 0.9779 - recall: 0.9770 - precision: 0.9790 - f1_score: 0.9780
# Epoch 13/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0704 - accuracy: 0.9787 - recall: 0.9778 - precision: 0.9798 - f1_score: 0.9787
# Epoch 14/20
# 6397/6397 [==============================] - 34s 5ms/step - loss: 0.0691 - accuracy: 0.9795 - recall: 0.9786 - precision: 0.9805 - f1_score: 0.9795
# Epoch 15/20
# 6397/6397 [==============================] - 34s 5ms/step - loss: 0.0692 - accuracy: 0.9792 - recall: 0.9784 - precision: 0.9803 - f1_score: 0.9793
# Epoch 16/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0687 - accuracy: 0.9794 - recall: 0.9786 - precision: 0.9804 - f1_score: 0.9794
# Epoch 17/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.0678 - accuracy: 0.9796 - recall: 0.9788 - precision: 0.9806 - f1_score: 0.9797
# Epoch 18/20
# 6397/6397 [==============================] - 45s 7ms/step - loss: 0.0682 - accuracy: 0.9798 - recall: 0.9790 - precision: 0.9808 - f1_score: 0.9799
# Epoch 19/20
# 6397/6397 [==============================] - 34s 5ms/step - loss: 0.0685 - accuracy: 0.9799 - recall: 0.9790 - precision: 0.9808 - f1_score: 0.9799
# Epoch 20/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0670 - accuracy: 0.9801 - recall: 0.9792 - precision: 0.9812 - f1_score: 0.9802
# Round: 4 | Client: client_1 training
# Epoch 1/20
# 6397/6397 [==============================] - 37s 6ms/step - loss: 0.1204 - accuracy: 0.9589 - recall: 0.9564 - precision: 0.9619 - f1_score: 0.9591
# Epoch 2/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.1018 - accuracy: 0.9676 - recall: 0.9658 - precision: 0.9694 - f1_score: 0.9676
# Epoch 3/20
# 6397/6397 [==============================] - 40s 6ms/step - loss: 0.0941 - accuracy: 0.9700 - recall: 0.9685 - precision: 0.9717 - f1_score: 0.9701
# Epoch 4/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0895 - accuracy: 0.9718 - recall: 0.9705 - precision: 0.9734 - f1_score: 0.9719
# Epoch 5/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0841 - accuracy: 0.9734 - recall: 0.9722 - precision: 0.9749 - f1_score: 0.9735
# Epoch 6/20
# 6397/6397 [==============================] - 36s 5ms/step - loss: 0.0822 - accuracy: 0.9744 - recall: 0.9733 - precision: 0.9757 - f1_score: 0.9745
# Epoch 7/20
# 6397/6397 [==============================] - 35s 5ms/step - loss: 0.0785 - accuracy: 0.9755 - recall: 0.9744 - precision: 0.9768 - f1_score: 0.9755
# Epoch 8/20
# 6397/6397 [==============================] - 34s 5ms/step - loss: 0.0784 - accuracy: 0.9759 - recall: 0.9750 - precision: 0.9772 - f1_score: 0.9761
# Epoch 9/20
# 6397/6397 [==============================] - 34s 5ms/step - loss: 0.0766 - accuracy: 0.9767 - recall: 0.9758 - precision: 0.9779 - f1_score: 0.9768
# Epoch 10/20
# 6397/6397 [==============================] - 39s 6ms/step - loss: 0.0735 - accuracy: 0.9773 - recall: 0.9763 - precision: 0.9784 - f1_score: 0.9773
# Epoch 11/20
# 6397/6397 [==============================] - 43s 7ms/step - loss: 0.0729 - accuracy: 0.9777 - recall: 0.9767 - precision: 0.9790 - f1_score: 0.9778
# Epoch 12/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.0727 - accuracy: 0.9780 - recall: 0.9771 - precision: 0.9791 - f1_score: 0.9780
# Epoch 13/20
# 6397/6397 [==============================] - 44s 7ms/step - loss: 0.0711 - accuracy: 0.9786 - recall: 0.9777 - precision: 0.9797 - f1_score: 0.9787
# Epoch 14/20
# 6397/6397 [==============================] - 41s 6ms/step - loss: 0.0704 - accuracy: 0.9788 - recall: 0.9780 - precision: 0.9799 - f1_score: 0.9789
# Epoch 15/20
# 6397/6397 [==============================] - 46s 7ms/step - loss: 0.0699 - accuracy: 0.9792 - recall: 0.9784 - precision: 0.9802 - f1_score: 0.9793
# Epoch 16/20
# 6397/6397 [==============================] - 43s 6ms/step - loss: 0.0680 - accuracy: 0.9796 - recall: 0.9788 - precision: 0.9805 - f1_score: 0.9796
# Epoch 17/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0697 - accuracy: 0.9792 - recall: 0.9784 - precision: 0.9801 - f1_score: 0.9792
# Epoch 18/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0681 - accuracy: 0.9797 - recall: 0.9788 - precision: 0.9807 - f1_score: 0.9797
# Epoch 19/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0687 - accuracy: 0.9791 - recall: 0.9783 - precision: 0.9801 - f1_score: 0.9792
# Epoch 20/20
# 6397/6397 [==============================] - 38s 6ms/step - loss: 0.0680 - accuracy: 0.9795 - recall: 0.9786 - precision: 0.9805 - f1_score: 0.9795
# 12793/12793 [==============================] - 29s 2ms/step
# comm_round: 4 | global_loss: 1.051636815071106 | global_accuracy: 0.9939 | global_recall: 0.9933 | global_precision: 0.994 | global_f1_score: 0.9937

# %%
global_model.load_weights("FL_DP_No_PCA.h5")

# %%
loss, accuracy, precision, recall, f1_score = test_model(x_batch, y_batch, global_model, comm_round)
print("loss : ", loss.numpy())
print("accuracy : ", accuracy)
print("precision : ", precision)
print("recall : ", recall)
print("f1_score : ", f1_score)
# Out:
# 12793/12793 [==============================] - 28s 2ms/step
# comm_round: 4 | global_loss: 1.0522366762161255 | global_accuracy: 0.9948 | global_recall: 0.9947 | global_precision: 0.9949 | global_f1_score: 0.9948
#
# loss :  1.0522367
# accuracy :  0.994777123900399
# precision :  0.9948714
# recall :  0.9946794
# f1_score :  0.9947753

# %%
for(x_batch, y_batch) in test_batched:
    logits = global_model.predict(x_batch)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_batch, axis=1)
# Out:
# 12793/12793 [==============================] - 32s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report, precision_score, recall_score
from sklearn.metrics import matthews_corrcoef, roc_auc_score
from sklearn.metrics import f1_score as f1_score_rep
import seaborn as sn
import numpy as np

def print_score(y_pred, y_real, label_encoder):
    accuracy = accuracy_score(y_real, y_pred)
    precision = precision_score(y_real, y_pred, average="weighted")
    recall = recall_score(y_real, y_pred, average="weighted")
    f1 = f1_score_rep(y_real, y_pred, average="weighted")
    auc = roc_auc_score(y_real, logits, multi_class='ovr')

    print("Accuracy: {:.4f}".format(accuracy))
    print("Precision:: {:.4f}".format(precision))
    print("Recall:: {:.4f}".format(recall))
    print("F1_Score:: {:.4f}".format(f1))
    print("AUC:: {:.4f}".format(auc))
    
    print()
    print("Confusion Matrix")
    cm = confusion_matrix(y_real, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cm, index=[str(i) for i in label_encoder.classes_], columns=[str(i) for i in label_encoder.classes_])
    plt.figure(figsize=(10, 7))
    sn.heatmap(df_cm, annot=True)

    print()
    print("Classification Report")
    print(classification_report(y_real, y_pred, target_names=[str(i) for i in label_encoder.classes_]))

# %%
print_score(y_hat, y_true, label_encoder)
# Out:
# Accuracy: 0.9948
# Precision:: 0.9948
# Recall:: 0.9948
# F1_Score:: 0.9948
# AUC:: 0.9999
#
# Confusion Matrix
#
# Classification Report
#                 precision    recall  f1-score   support
#
#         benign       1.00      1.00      1.00     84732
#      mirai_ack       1.00      1.00      1.00     56029
#     mirai_scan       1.00      1.00      1.00     51230
#      mirai_syn       1.00      1.00      1.00     62511
#      mirai_udp       0.99      0.99      0.99    108952
# mirai_udpplain       0.98      0.97      0.98     45899
#
#       accuracy                           0.99    409353
#      macro avg       0.99      0.99      0.99    409353
#   weighted avg       0.99      0.99      0.99    409353

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, n_classes):
    lw = 2
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_ohe[:, i], y_hat_ohe[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes
    fpr["weighted"] = all_fpr
    tpr["weighted"] = mean_tpr
    roc_auc["weighted"] = auc(fpr["weighted"], tpr["weighted"])

    #fpr["micro"], tpr["micro"], _ = roc_curve(y_true_ohe.ravel(), y_hat_ohe.ravel())
    #roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    plt.figure(figsize=(8,8))
    plt.plot(
        fpr["weighted"],
        tpr["weighted"],
        label="weighted-average ROC curve (area = {0:0.2f})".format(roc_auc["weighted"]),
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )



    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(label_encoder.classes_[i], roc_auc[i]))

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("multiclass characteristic")
    plt.legend(loc="lower right")
    plt.show()

# %%
y_true_ohe = to_categorical(y_true, num_classes=len(label_encoder.classes_))
y_hat_ohe =  to_categorical(y_hat, num_classes=len(label_encoder.classes_))

# %%
ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, len(label_encoder.classes_))

# %%
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  forward_pass = tf.function(model.call, input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])
  graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
  flops = graph_info.total_float_ops
  return flops

# %%
# Calculate FLOPS
flops = get_flops(global_model)
# Out:
# WARNING:tensorflow:From c:\Users\Lambert\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.

# %%
print(f"FLOPS: {flops / 10 ** 6:.03} M")
# Out:
# FLOPS: 0.00861 M

# %%
print(f"FLOPS: {flops}")
# Out:
# FLOPS: 8612

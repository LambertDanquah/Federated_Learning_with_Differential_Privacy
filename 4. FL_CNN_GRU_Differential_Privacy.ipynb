# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(42)

# %%
#Benign
benign_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.benign.csv')
benign_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.benign.csv')
benign_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.benign.csv')
benign_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.benign.csv')
benign_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.benign.csv')
benign_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.benign.csv')
benign_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.benign.csv')

benign_traffic = pd.concat([benign_1, benign_2, benign_4, benign_5, benign_6, benign_8, benign_9], ignore_index=True)

benign_traffic.shape
# Out:
# (464682, 115)

# %%
#Scan
mirai_scan_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.scan.csv')
mirai_scan_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.scan.csv')
mirai_scan_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.scan.csv')
mirai_scan_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.scan.csv')
mirai_scan_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.scan.csv')
mirai_scan_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.scan.csv')
mirai_scan_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.scan.csv')

mirai_scan_traffic = pd.concat([mirai_scan_1, mirai_scan_2, mirai_scan_4, mirai_scan_5, mirai_scan_6, mirai_scan_8, mirai_scan_9], ignore_index=True)

mirai_scan_traffic.shape
# Out:
# (537979, 115)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')
mirai_syn_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.syn.csv')
mirai_syn_8  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.syn.csv')
mirai_syn_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.syn.csv')


mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5, mirai_syn_6, mirai_syn_8, mirai_syn_9], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (733299, 115)

# %%
#Ack
mirai_ack_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.ack.csv')
mirai_ack_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.ack.csv')
mirai_ack_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.ack.csv')
mirai_ack_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.ack.csv')
mirai_ack_6  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.ack.csv')
mirai_ack_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.ack.csv')
mirai_ack_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.ack.csv')

mirai_ack_traffic = pd.concat([mirai_ack_1 , mirai_ack_2, mirai_ack_4, mirai_ack_5, mirai_ack_6, mirai_ack_8, mirai_ack_9], ignore_index=True)

mirai_ack_traffic.shape
# Out:
# (643821, 115)

# %%
#Udp Flooding
mirai_udp_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udp.csv')
mirai_udp_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udp.csv')
mirai_udp_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udp.csv')
mirai_udp_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udp.csv')
mirai_udp_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udp.csv')
mirai_udp_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udp.csv')
mirai_udp_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udp.csv')

mirai_udp_traffic = pd.concat([mirai_udp_1 , mirai_udp_2, mirai_udp_4, mirai_udp_5], ignore_index=True)

mirai_udp_traffic.shape
# Out:
# (762428, 115)

# %%
#Udp plain Flooding
mirai_udpplain_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udpplain.csv')
mirai_udpplain_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udpplain.csv')
mirai_udpplain_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udpplain.csv')
mirai_udpplain_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udpplain.csv')
mirai_udpplain_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udpplain.csv')
mirai_udpplain_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udpplain.csv')
mirai_udpplain_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udpplain.csv')

mirai_udpplain_traffic = pd.concat([mirai_udpplain_1 , mirai_udpplain_2, mirai_udpplain_4, mirai_udpplain_5, mirai_udpplain_6, mirai_udpplain_8, mirai_udpplain_9], ignore_index=True)

mirai_udpplain_traffic.shape
# Out:
# (523304, 115)

# %%
benign_traffic['label'] = 'benign'
mirai_scan_traffic['label'] = 'mirai_scan'
mirai_syn_traffic['label'] = 'mirai_syn'
mirai_ack_traffic['label'] = 'mirai_ack'
mirai_udp_traffic['label'] = 'mirai_udp'
mirai_udpplain_traffic['label'] = 'mirai_udpplain'

mirai_dataset = pd.concat([benign_traffic, mirai_scan_traffic, mirai_syn_traffic,
                mirai_ack_traffic, mirai_udp_traffic, mirai_udpplain_traffic],
                axis=0, sort=False, ignore_index=True)

# %%
selected_features = ['HH_L1_weight', 'HH_jit_L1_weight', 'MI_dir_L0.01_mean',
       'H_L0.1_weight', 'H_L0.1_mean', 'MI_dir_L1_mean', 'H_L1_mean',
       'H_L0.01_variance', 'MI_dir_L0.01_variance', 'H_L5_weight',
       'H_L0.1_variance', 'MI_dir_L0.1_weight', 'MI_dir_L0.1_mean',
       'MI_dir_L5_weight', 'H_L0.01_mean', 'H_L5_mean', 'MI_dir_L0.1_variance',
       'MI_dir_L3_mean', 'MI_dir_L5_mean', 'HH_jit_L5_mean', 'HH_jit_L3_mean',
       'H_L3_mean', 'HH_L3_magnitude', 'MI_dir_L3_weight', 'HpHp_L0.01_weight', 'label']

# %%
selected_mirai_dataset = mirai_dataset[selected_features].copy()

# %%
selected_mirai_dataset.shape
# Out:
# (3665513, 26)

# %%
#Number of Missing Values in the Dataset
selected_mirai_dataset.isnull().sum().sum()
# Out:
# 0

# %%
#Number of Duplicate Rows in the Dataset
selected_mirai_dataset.duplicated().sum()
# Out:
# 1607667

# %%
# Remove duplicate rows from the Dataset
selected_mirai_dataset = selected_mirai_dataset.drop_duplicates()

# Check the number of duplicate rows after removal
selected_mirai_dataset.duplicated().sum()
# Out:
# 0

# %%
selected_mirai_dataset.shape
# Out:
# (2057846, 26)

# %%
import numpy as np

# Select columns for z-score calculation (excluding the last column)
column_features = selected_mirai_dataset.iloc[:, :-1]

# Calculate z-scores for each column
z_scores = (column_features - column_features.mean()) / column_features.std()

# Set a threshold for z-score beyond which a data point is considered an outlier
z_score_threshold = 3  # Adjust this threshold as needed

# Identify rows where any z-score exceeds the threshold
outlier_mask = (np.abs(z_scores) > z_score_threshold).any(axis=1)

# Remove outliers from the dataset
selected_mirai_dataset = selected_mirai_dataset[~outlier_mask]

# %%
selected_mirai_dataset.shape
# Out:
# (1970649, 26)

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the columns to be normalized (excluding the 'label' column)
column_to_normalize = selected_mirai_dataset.columns[selected_mirai_dataset.columns != 'label']


# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
selected_mirai_dataset[column_to_normalize] = scaler.fit_transform(selected_mirai_dataset[column_to_normalize])

# %%
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000       2.636780e-16       0.000000
# 1      0.000039          0.000039       5.547170e-01       0.000179
# 2      0.001219          0.001219       5.660395e-01       0.000289
# 3      0.000000          0.000000       5.226415e-01       0.000000
# 4      0.000000          0.000000       2.612201e-01       0.000111
#
#     H_L0.1_mean  MI_dir_L1_mean     H_L1_mean  H_L0.01_variance  \
# 0  4.163336e-17    1.249001e-16  1.249001e-16          0.000000
# 1  5.408092e-01    4.823113e-01  4.817053e-01          0.000193
# 2  5.509964e-01    4.923052e-01  4.918483e-01          0.000712
# 3  5.226581e-01    4.544225e-01  4.544225e-01          0.000000
# 4  2.603220e-01    2.184604e-01  2.184604e-01          0.167279
#
#    MI_dir_L0.01_variance   H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.000000  0.000000e+00  ...              0.000000
# 1               0.000000  1.174383e-10  ...              0.000000
# 2               0.000314  3.148369e-03  ...              0.000311
# 3               0.000000  0.000000e+00  ...              0.000000
# 4               0.167279  2.496382e-03  ...              0.165695
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  \
# 0    1.249001e-16    1.110223e-16    9.813673e-01    9.813673e-01
# 1    4.510277e-01    4.226888e-01    3.245507e-09    3.245505e-09
# 2    4.606554e-01    4.319749e-01    1.513729e-09    1.562845e-09
# 3    4.249479e-01    3.982476e-01    9.813673e-01    9.813673e-01
# 4    1.880207e-01    1.612269e-01    9.813673e-01    9.813673e-01
#
#       H_L3_mean  HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight   label
# 0  1.249001e-16         0.000000          0.000000           0.000000  benign
# 1  4.510271e-01         0.331530          0.000000           0.000291  benign
# 2  4.606549e-01         0.338607          0.002146           0.000359  benign
# 3  4.249479e-01         0.312360          0.000000           0.000000  benign
# 4  1.880207e-01         0.477094          0.001867           0.000000  benign
#
# [5 rows x 26 columns]

# %%
selected_mirai_dataset = selected_mirai_dataset.sample(frac=1).reset_index(drop=True)
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000           0.521544       0.505705
# 1      0.000108          0.000108           0.185116       0.001147
# 2      0.001207          0.001207           0.020756       0.001147
# 3      0.365574          0.365574           0.523108       0.516265
# 4      0.000000          0.000000           0.017738       0.744389
#
#    H_L0.1_mean  MI_dir_L1_mean  H_L1_mean  H_L0.01_variance  \
# 0     0.522337        0.444576   0.444576          0.524454
# 1     0.118109        0.018681   0.018681          0.421878
# 2     0.023412        0.014130   0.014130          0.003344
# 3     0.525792        0.477173   0.477173          0.524025
# 4     0.017960        0.016922   0.016922          0.000378
#
#    MI_dir_L0.01_variance  H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.524454     0.457333  ...              0.519279
# 1               0.421878     0.000004  ...              0.242123
# 2               0.003344     0.003073  ...              0.003812
# 3               0.524025     0.323968  ...              0.518312
# 4               0.000378     0.378821  ...              0.000369
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  H_L3_mean  \
# 0        0.372336        0.294594    9.826693e-01    9.826693e-01   0.372336
# 1        0.021151        0.020109    2.614423e-09    2.614027e-09   0.021151
# 2        0.010392        0.008908    1.420423e-09    1.504356e-09   0.010392
# 3        0.497183        0.525856    2.188626e-12    2.208649e-12   0.497183
# 4        0.017771        0.017381    9.826679e-01    9.826679e-01   0.017771
#
#    HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight           label
# 0         0.000000          0.436825           0.000000  mirai_udpplain
# 1         0.050352          0.000037           0.000195          benign
# 2         0.070288          0.002636           0.001276          benign
# 3         0.557061          0.375316           0.405565  mirai_udpplain
# 4         0.000000          0.431810           0.000000       mirai_syn
#
# [5 rows x 26 columns]

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# Calculate percentage values
class_counts = selected_mirai_dataset['label'].value_counts(normalize=True) * 100

plt.title("Class Distribution")
bar_plot = selected_mirai_dataset['label'].value_counts().plot(kind='bar')
plt.xlabel('Classes')
plt.ylabel('Frequency')

# Annotate each bar with its percentage value
for i, val in enumerate(class_counts):
    plt.text(i, selected_mirai_dataset['label'].value_counts()[i], f'{val:.2f}%', ha='center')

plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(selected_mirai_dataset['label'].value_counts())
# Out:
# mirai_udp         544764
# benign            422293
# mirai_syn         312508
# mirai_ack         280144
# mirai_scan        256151
# mirai_udpplain    154789
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(selected_mirai_dataset, test_size=0.2, random_state=42, stratify=selected_mirai_dataset["label"])

# %%
features = list(train_df.columns)
features.remove("label")

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_df["label"] = label_encoder.fit_transform(train_df["label"])
test_df["label"] = label_encoder.transform(test_df["label"])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=18)
X_train = train_df[features].values
X_train = pca.fit_transform(X_train)
y_train = train_df["label"].values

X_test = test_df[features].values
X_test = pca.fit_transform(X_test)
y_test = test_df["label"].values

# %%
import statsmodels.api as sm
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from tabulate import tabulate

# %%
X_train = X_train.reshape((-1, X_train.shape[-1], 1))
X_test = X_test.reshape((-1, X_test.shape[-1], 1))

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train)

class_weights = {k: v for k,v in enumerate(class_weights)}
class_weights
# Out:
# {0: 0.7777582086665837,
#  1: 1.1724033048509321,
#  2: 1.282216886832812,
#  3: 1.0509832391359708,
#  4: 0.6029062292293372,
#  5: 2.1218690527143176}

# %%
input_shape = X_train.shape[1:]
nb_classes = len(label_encoder.classes_)

# %%
input_shape
# Out:
# (18, 1)

# %%
from tensorflow.keras.utils import to_categorical

def convert_to_categorical(y, nb_classes):
    return to_categorical(y, num_classes=nb_classes)

# %%
import random

def data_indices(labels: np.ndarray, nb_clients: int):
    data_len = len(labels)
    indices = np.arange(data_len)
    np.random.shuffle(indices)
    chunk_size = data_len // nb_clients
    chunks = [indices[i:i+chunk_size] for i in range(0, data_len, chunk_size)]

    # Ensure non-IID distribution by shuffling 2 of the 4 chunks
    chunks[-1] = np.random.permutation(chunks[-1])
    chunks[-3] = np.random.permutation(chunks[-3])
    

    return chunks

# %%
def sample(y:np.ndarray, nb_clients: int):
    sampler_fn = data_indices
    client_data_indices = sampler_fn(y, nb_clients)
    return client_data_indices

# %%
def assign_data_to_clients(clients: dict, X:np.ndarray, y:np.ndarray, nb_classes:int):
    sampled_data_indices = sample(y, len(clients.keys()))  # Use the sample function to get data indices
    for client_name, data_indices in zip(clients.keys(), sampled_data_indices):
        X = X_train[data_indices]  # Subset the features for the current client
        y = y_train[data_indices]  # Subset the labels for the current client
        y = convert_to_categorical(y, nb_classes)  # Convert labels to categorical format if needed
        clients[client_name] = list(zip(X, y))  # Assign data to the current client
    return clients

# %%
def create_clients(X, y, nb_classes, num_clients=4, initial='clients'):
    # Create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]
    clients = {client_names[i] : [] for i in range(len(client_names))}
    return assign_data_to_clients(clients, X, y, nb_classes)

# %%
def batch_data(data_shard, batch_size=64):
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    del data_shard

    len_label = len(label)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    del data, label
    return dataset.shuffle(len_label).batch(batch_size)

# %%
import keras.backend as K
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import keras
import os
from keras.models import Model
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Activation, BatchNormalization, GRU, Dense, Dropout, Input

def get_model(input_shape, nb_classes):
    inputs = Input(shape=input_shape)
    
    # CNN layers
    x = Conv1D(10, 10, padding='same', activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Conv1D(10, 10, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = MaxPooling1D(pool_size=2)(x)
    
    # GRU layers
    x = GRU(32, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)
    
    x = GlobalAveragePooling1D(data_format="channels_last")(x)
    
    # Dense layers
    x = Dense(32, activation="relu")(x)
    x = Dropout(0.2)(x)
    
    outputs = Dense(nb_classes, activation="softmax")(x)
    
    return keras.Model(inputs, outputs)

# %%
import tensorflow_privacy
from tensorflow_privacy.privacy.optimizers import dp_optimizer_keras  
from keras.metrics import Recall, Precision
from tensorflow.keras.utils import plot_model

learning_rate = 1e-3
comms_round = 5
loss='categorical_crossentropy'
metrics = ["accuracy", Recall(), Precision(), f1_score]
#optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
optimizer = tensorflow_privacy.DPKerasAdamOptimizer(l2_norm_clip= 1.6, noise_multiplier= 0.01, num_microbatches=1, learning_rate= learning_rate)


#initialize global model
global_model = get_model(input_shape, nb_classes)

global_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18, 1)]           0
#
#  conv1d (Conv1D)             (None, 18, 10)            110
#
#  batch_normalization (Batch  (None, 18, 10)            40
#  Normalization)
#
#  dropout (Dropout)           (None, 18, 10)            0
#
#  max_pooling1d (MaxPooling1  (None, 9, 10)             0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 9, 10)             1010
#
#  batch_normalization_1 (Bat  (None, 9, 10)             40
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 9, 10)             0
#
#  max_pooling1d_1 (MaxPoolin  (None, 4, 10)             0
#  g1D)
#
#  gru (GRU)                   (None, 4, 32)             4224
#
#  dropout_2 (Dropout)         (None, 4, 32)             0
#
#  batch_normalization_2 (Bat  (None, 4, 32)             128
#  chNormalization)
#
#  global_average_pooling1d (  (None, 32)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 32)                1056
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 6806 (26.59 KB)
# Trainable params: 6702 (26.18 KB)
# Non-trainable params: 104 (416.00 Byte)
# _________________________________________________________________

# %%
BATCH_SIZE = 64

# create clients
clients_batched = create_clients(X_train, y_train, nb_classes, num_clients=4, initial='client')

del X_train, y_train

# process and batch the training data for each client
client_set = {k: {} for k in clients_batched.keys()}

for (client_name, data) in clients_batched.items():
    client_set[client_name]["dataset"] = batch_data(data, BATCH_SIZE)
    local_model = get_model(input_shape, nb_classes)
    local_model.compile(loss=loss,
                      optimizer=optimizer,
                      metrics=metrics)
    client_set[client_name]["model"] = local_model

# %%
#process and batch the test set

y_test = convert_to_categorical(y_test, nb_classes)

test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

del X_test, y_test

# %%
# Define a function to calculate the weight scaling factor
def weight_scalling_factor(clients, client_name):
    client_names = list(clients.keys())
    # Get the batch size
    bs = list(clients[client_name]["dataset"])[0][0].shape[0]
    # Calculate the total training data points across clients
    global_count = sum([tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() for client_name in client_names]) * bs
    # Calculate the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() * bs
    return local_count / global_count

# %%
# Define a function to scale model weights
def scale_model_weights(weight, scalar):
    '''function for scaling a model's weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final

# %%
def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights --> FedAvg'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)

    return avg_grad

# %%
from sklearn.metrics import accuracy_score

def test_model(X_test, y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(y_test, logits)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(np.argmax(y_test, axis=1), np.argmax(logits, axis=1))

    r = Recall()
    r.update_state(y_test, logits)
    recall = r.result().numpy()

    p = Precision()
    p.update_state(y_test, logits)
    precision = p.result().numpy()

    f = f1_score(y_test, logits)
    f1 = f.numpy()

    print('comm_round: {} | global_loss: {} | global_accuracy: {:.4} | global_recall: {:.4} | global_precision: {:.4} | global_f1_score: {:.4} \n'.format(comm_round, loss, accuracy, recall, precision, f1))
    return loss, accuracy, precision, recall, f1

# %%
def train_client(client, global_weights):
    client_set[client]["model"] = client_set[client]["model"]

    #set local model weight to the weight of the global model
    client_set[client]["model"].set_weights(global_weights)

    #fit local model with client's data
    print(f"Round: {comm_round} | Client: {client} training")
    client_set[client]["model"].fit(client_set[client]["dataset"], epochs=20, verbose=1)

    #scale the model weights and add to list
    scaling_factor = weight_scalling_factor(client_set, client)
    scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
    return scaled_weights

# %%
import random

#commence global training loop
global_loss=[]
global_accuracy=[]
global_precision=[]
global_recall=[]
global_f1=[]
best_global_accuracy = 0

for comm_round in range(comms_round):
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()

    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(client_set.keys())
    random.shuffle(client_names)

    #loop through each client and create new local model
    for client in client_names:
        scaled_weights = train_client(client, global_weights)

        scaled_local_weight_list.append(scaled_weights)

    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)

    #update global model
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    g_accuracy = 0
    for(x_batch, y_batch) in test_batched:
        g_loss, g_accuracy, g_precision, g_recall, g_f1 = test_model(x_batch, y_batch, global_model, comm_round)
        global_loss.append(g_loss)
        global_accuracy.append(g_accuracy)
        global_precision.append(g_precision)
        global_recall.append(g_recall)
        global_f1.append(g_f1)

    if g_accuracy > best_global_accuracy:
        best_global_accuracy = g_accuracy
        global_model.save_weights('FL_DP_Mirai_Final.h5')
        print("New Weights Saved")
# Out:
# Round: 0 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 99s 9ms/step - loss: 0.3714 - accuracy: 0.8362 - recall: 0.8047 - precision: 0.8651 - f1_score: 0.8305
# Epoch 2/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.2122 - accuracy: 0.9211 - recall: 0.9118 - precision: 0.9316 - f1_score: 0.9215
# Epoch 3/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.1860 - accuracy: 0.9339 - recall: 0.9273 - precision: 0.9411 - f1_score: 0.9341
# Epoch 4/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.1702 - accuracy: 0.9403 - recall: 0.9350 - precision: 0.9461 - f1_score: 0.9405
# Epoch 5/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1608 - accuracy: 0.9446 - recall: 0.9398 - precision: 0.9499 - f1_score: 0.9448
# Epoch 6/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1543 - accuracy: 0.9475 - recall: 0.9431 - precision: 0.9527 - f1_score: 0.9478
# Epoch 7/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1511 - accuracy: 0.9494 - recall: 0.9450 - precision: 0.9543 - f1_score: 0.9496
# Epoch 8/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1450 - accuracy: 0.9512 - recall: 0.9467 - precision: 0.9563 - f1_score: 0.9514
# Epoch 9/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1403 - accuracy: 0.9527 - recall: 0.9490 - precision: 0.9570 - f1_score: 0.9529
# Epoch 10/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1384 - accuracy: 0.9542 - recall: 0.9506 - precision: 0.9583 - f1_score: 0.9544
# Epoch 11/20
# 6159/6159 [==============================] - 78s 12ms/step - loss: 0.1358 - accuracy: 0.9545 - recall: 0.9510 - precision: 0.9584 - f1_score: 0.9547
# Epoch 12/20
# 6159/6159 [==============================] - 77s 12ms/step - loss: 0.1313 - accuracy: 0.9567 - recall: 0.9534 - precision: 0.9605 - f1_score: 0.9569
# Epoch 13/20
# 6159/6159 [==============================] - 77s 12ms/step - loss: 0.1296 - accuracy: 0.9573 - recall: 0.9543 - precision: 0.9610 - f1_score: 0.9576
# Epoch 14/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1246 - accuracy: 0.9597 - recall: 0.9570 - precision: 0.9630 - f1_score: 0.9599
# Epoch 15/20
# 6159/6159 [==============================] - 89s 14ms/step - loss: 0.1163 - accuracy: 0.9633 - recall: 0.9609 - precision: 0.9662 - f1_score: 0.9635
# Epoch 16/20
# 6159/6159 [==============================] - 91s 14ms/step - loss: 0.1104 - accuracy: 0.9664 - recall: 0.9641 - precision: 0.9692 - f1_score: 0.9666
# Epoch 17/20
# 6159/6159 [==============================] - 87s 14ms/step - loss: 0.1062 - accuracy: 0.9681 - recall: 0.9662 - precision: 0.9706 - f1_score: 0.9684
# Epoch 18/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1030 - accuracy: 0.9693 - recall: 0.9674 - precision: 0.9714 - f1_score: 0.9693
# Epoch 19/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1028 - accuracy: 0.9689 - recall: 0.9668 - precision: 0.9714 - f1_score: 0.9691
# Epoch 20/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1009 - accuracy: 0.9696 - recall: 0.9677 - precision: 0.9717 - f1_score: 0.9697
# Round: 0 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 105s 13ms/step - loss: 0.3615 - accuracy: 0.8344 - recall: 0.8872 - precision: 0.9180 - f1_score: 0.8317
# Epoch 2/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1889 - accuracy: 0.9341 - recall: 0.9263 - precision: 0.9426 - f1_score: 0.9343
# Epoch 3/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1622 - accuracy: 0.9473 - recall: 0.9423 - precision: 0.9529 - f1_score: 0.9475
# Epoch 4/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1507 - accuracy: 0.9517 - recall: 0.9469 - precision: 0.9574 - f1_score: 0.9521
# Epoch 5/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1453 - accuracy: 0.9538 - recall: 0.9491 - precision: 0.9589 - f1_score: 0.9539
# Epoch 6/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1414 - accuracy: 0.9558 - recall: 0.9517 - precision: 0.9605 - f1_score: 0.9560
# Epoch 7/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1361 - accuracy: 0.9579 - recall: 0.9538 - precision: 0.9626 - f1_score: 0.9582
# Epoch 8/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1324 - accuracy: 0.9591 - recall: 0.9553 - precision: 0.9633 - f1_score: 0.9593
# Epoch 9/20
# 6159/6159 [==============================] - 77s 12ms/step - loss: 0.1302 - accuracy: 0.9597 - recall: 0.9562 - precision: 0.9637 - f1_score: 0.9599
# Epoch 10/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1274 - accuracy: 0.9612 - recall: 0.9578 - precision: 0.9651 - f1_score: 0.9614
# Epoch 11/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1266 - accuracy: 0.9611 - recall: 0.9581 - precision: 0.9646 - f1_score: 0.9613
# Epoch 12/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1237 - accuracy: 0.9625 - recall: 0.9595 - precision: 0.9657 - f1_score: 0.9626
# Epoch 13/20
# 6159/6159 [==============================] - 88s 14ms/step - loss: 0.1206 - accuracy: 0.9632 - recall: 0.9603 - precision: 0.9666 - f1_score: 0.9634
# Epoch 14/20
# 6159/6159 [==============================] - 91s 15ms/step - loss: 0.1184 - accuracy: 0.9637 - recall: 0.9609 - precision: 0.9669 - f1_score: 0.9639
# Epoch 15/20
# 6159/6159 [==============================] - 80s 13ms/step - loss: 0.1150 - accuracy: 0.9648 - recall: 0.9619 - precision: 0.9678 - f1_score: 0.9648
# Epoch 16/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1158 - accuracy: 0.9648 - recall: 0.9618 - precision: 0.9680 - f1_score: 0.9648
# Epoch 17/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1138 - accuracy: 0.9649 - recall: 0.9622 - precision: 0.9682 - f1_score: 0.9651
# Epoch 18/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1149 - accuracy: 0.9650 - recall: 0.9625 - precision: 0.9681 - f1_score: 0.9653
# Epoch 19/20
# 6159/6159 [==============================] - 87s 14ms/step - loss: 0.1110 - accuracy: 0.9662 - recall: 0.9635 - precision: 0.9694 - f1_score: 0.9664
# Epoch 20/20
# 6159/6159 [==============================] - 89s 14ms/step - loss: 0.1112 - accuracy: 0.9663 - recall: 0.9636 - precision: 0.9692 - f1_score: 0.9664
# Round: 0 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 110s 13ms/step - loss: 0.3193 - accuracy: 0.8669 - recall: 0.9046 - precision: 0.9296 - f1_score: 0.8651
# Epoch 2/20
# 6159/6159 [==============================] - 87s 14ms/step - loss: 0.2276 - accuracy: 0.9149 - recall: 0.9020 - precision: 0.9285 - f1_score: 0.9149
# Epoch 3/20
# 6159/6159 [==============================] - 80s 13ms/step - loss: 0.2139 - accuracy: 0.9219 - recall: 0.9114 - precision: 0.9326 - f1_score: 0.9218
# Epoch 4/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.2037 - accuracy: 0.9267 - recall: 0.9184 - precision: 0.9356 - f1_score: 0.9268
# Epoch 5/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1963 - accuracy: 0.9290 - recall: 0.9216 - precision: 0.9369 - f1_score: 0.9291
# Epoch 6/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1899 - accuracy: 0.9320 - recall: 0.9248 - precision: 0.9396 - f1_score: 0.9321
# Epoch 7/20
# 6159/6159 [==============================] - 94s 15ms/step - loss: 0.1854 - accuracy: 0.9331 - recall: 0.9264 - precision: 0.9402 - f1_score: 0.9332
# Epoch 8/20
# 6159/6159 [==============================] - 88s 14ms/step - loss: 0.1815 - accuracy: 0.9343 - recall: 0.9279 - precision: 0.9411 - f1_score: 0.9344
# Epoch 9/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1768 - accuracy: 0.9365 - recall: 0.9307 - precision: 0.9430 - f1_score: 0.9367
# Epoch 10/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1740 - accuracy: 0.9374 - recall: 0.9318 - precision: 0.9436 - f1_score: 0.9376
# Epoch 11/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1699 - accuracy: 0.9391 - recall: 0.9340 - precision: 0.9447 - f1_score: 0.9393
# Epoch 12/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1659 - accuracy: 0.9403 - recall: 0.9355 - precision: 0.9456 - f1_score: 0.9405
# Epoch 13/20
# 6159/6159 [==============================] - 104s 17ms/step - loss: 0.1641 - accuracy: 0.9413 - recall: 0.9366 - precision: 0.9466 - f1_score: 0.9415
# Epoch 14/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1570 - accuracy: 0.9453 - recall: 0.9410 - precision: 0.9500 - f1_score: 0.9454
# Epoch 15/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1496 - accuracy: 0.9495 - recall: 0.9457 - precision: 0.9539 - f1_score: 0.9497
# Epoch 16/20
# 6159/6159 [==============================] - 79s 13ms/step - loss: 0.1455 - accuracy: 0.9517 - recall: 0.9481 - precision: 0.9558 - f1_score: 0.9519
# Epoch 17/20
# 6159/6159 [==============================] - 80s 13ms/step - loss: 0.1421 - accuracy: 0.9536 - recall: 0.9501 - precision: 0.9577 - f1_score: 0.9539
# Epoch 18/20
# 6159/6159 [==============================] - 81s 13ms/step - loss: 0.1381 - accuracy: 0.9553 - recall: 0.9524 - precision: 0.9586 - f1_score: 0.9555
# Epoch 19/20
# 6159/6159 [==============================] - 80s 13ms/step - loss: 0.1352 - accuracy: 0.9568 - recall: 0.9540 - precision: 0.9604 - f1_score: 0.9571
# Epoch 20/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1338 - accuracy: 0.9572 - recall: 0.9544 - precision: 0.9605 - f1_score: 0.9574
# Round: 0 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 105s 13ms/step - loss: 0.3069 - accuracy: 0.8745 - recall: 0.9041 - precision: 0.9285 - f1_score: 0.8726
# Epoch 2/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1877 - accuracy: 0.9362 - recall: 0.9289 - precision: 0.9442 - f1_score: 0.9364
# Epoch 3/20
# 6159/6159 [==============================] - 81s 13ms/step - loss: 0.1574 - accuracy: 0.9513 - recall: 0.9470 - precision: 0.9561 - f1_score: 0.9515
# Epoch 4/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1459 - accuracy: 0.9561 - recall: 0.9529 - precision: 0.9600 - f1_score: 0.9564
# Epoch 5/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1400 - accuracy: 0.9580 - recall: 0.9549 - precision: 0.9617 - f1_score: 0.9582
# Epoch 6/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1337 - accuracy: 0.9608 - recall: 0.9580 - precision: 0.9640 - f1_score: 0.9610
# Epoch 7/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1300 - accuracy: 0.9619 - recall: 0.9590 - precision: 0.9651 - f1_score: 0.9620
# Epoch 8/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1262 - accuracy: 0.9626 - recall: 0.9598 - precision: 0.9659 - f1_score: 0.9628
# Epoch 9/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1232 - accuracy: 0.9634 - recall: 0.9604 - precision: 0.9669 - f1_score: 0.9636
# Epoch 10/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1204 - accuracy: 0.9645 - recall: 0.9617 - precision: 0.9677 - f1_score: 0.9647
# Epoch 11/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1165 - accuracy: 0.9663 - recall: 0.9638 - precision: 0.9693 - f1_score: 0.9665
# Epoch 12/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1145 - accuracy: 0.9669 - recall: 0.9646 - precision: 0.9698 - f1_score: 0.9672
# Epoch 13/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1116 - accuracy: 0.9676 - recall: 0.9655 - precision: 0.9702 - f1_score: 0.9679
# Epoch 14/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1119 - accuracy: 0.9676 - recall: 0.9655 - precision: 0.9701 - f1_score: 0.9678
# Epoch 15/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1073 - accuracy: 0.9688 - recall: 0.9669 - precision: 0.9710 - f1_score: 0.9689
# Epoch 16/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1056 - accuracy: 0.9696 - recall: 0.9674 - precision: 0.9720 - f1_score: 0.9697
# Epoch 17/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1061 - accuracy: 0.9690 - recall: 0.9670 - precision: 0.9715 - f1_score: 0.9692
# Epoch 18/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1042 - accuracy: 0.9695 - recall: 0.9675 - precision: 0.9717 - f1_score: 0.9696
# Epoch 19/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1025 - accuracy: 0.9706 - recall: 0.9689 - precision: 0.9728 - f1_score: 0.9709
# Epoch 20/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1022 - accuracy: 0.9706 - recall: 0.9686 - precision: 0.9728 - f1_score: 0.9707
# 12317/12317 [==============================] - 51s 4ms/step
# comm_round: 0 | global_loss: 1.7539293766021729 | global_accuracy: 0.2764 | global_recall: 0.0 | global_precision: 0.0 | global_f1_score: 0.0
#
# New Weights Saved
# Round: 1 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.2004 - accuracy: 0.9305 - recall: 0.9227 - precision: 0.9387 - f1_score: 0.9303
# Epoch 2/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1728 - accuracy: 0.9423 - recall: 0.9379 - precision: 0.9473 - f1_score: 0.9425
# Epoch 3/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1644 - accuracy: 0.9457 - recall: 0.9417 - precision: 0.9501 - f1_score: 0.9458
# Epoch 4/20
# 6159/6159 [==============================] - 86s 14ms/step - loss: 0.1596 - accuracy: 0.9475 - recall: 0.9437 - precision: 0.9519 - f1_score: 0.9478
# Epoch 5/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1569 - accuracy: 0.9486 - recall: 0.9449 - precision: 0.9527 - f1_score: 0.9487
# Epoch 6/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1548 - accuracy: 0.9499 - recall: 0.9465 - precision: 0.9538 - f1_score: 0.9501
# Epoch 7/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1526 - accuracy: 0.9508 - recall: 0.9474 - precision: 0.9546 - f1_score: 0.9509
# Epoch 8/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1503 - accuracy: 0.9517 - recall: 0.9485 - precision: 0.9554 - f1_score: 0.9519
# Epoch 9/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1472 - accuracy: 0.9531 - recall: 0.9500 - precision: 0.9566 - f1_score: 0.9533
# Epoch 10/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1456 - accuracy: 0.9532 - recall: 0.9502 - precision: 0.9568 - f1_score: 0.9534
# Epoch 11/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1443 - accuracy: 0.9535 - recall: 0.9507 - precision: 0.9571 - f1_score: 0.9538
# Epoch 12/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1408 - accuracy: 0.9547 - recall: 0.9522 - precision: 0.9579 - f1_score: 0.9550
# Epoch 13/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1410 - accuracy: 0.9553 - recall: 0.9525 - precision: 0.9585 - f1_score: 0.9555
# Epoch 14/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1386 - accuracy: 0.9561 - recall: 0.9534 - precision: 0.9590 - f1_score: 0.9562
# Epoch 15/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1386 - accuracy: 0.9559 - recall: 0.9531 - precision: 0.9591 - f1_score: 0.9560
# Epoch 16/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1370 - accuracy: 0.9567 - recall: 0.9538 - precision: 0.9599 - f1_score: 0.9568
# Epoch 17/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1363 - accuracy: 0.9567 - recall: 0.9541 - precision: 0.9599 - f1_score: 0.9570
# Epoch 18/20
# 6159/6159 [==============================] - 84s 13ms/step - loss: 0.1349 - accuracy: 0.9576 - recall: 0.9549 - precision: 0.9608 - f1_score: 0.9578
# Epoch 19/20
# 6159/6159 [==============================] - 84s 13ms/step - loss: 0.1357 - accuracy: 0.9575 - recall: 0.9549 - precision: 0.9606 - f1_score: 0.9577
# Epoch 20/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1341 - accuracy: 0.9576 - recall: 0.9549 - precision: 0.9605 - f1_score: 0.9577
# Round: 1 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 89s 14ms/step - loss: 0.2102 - accuracy: 0.9262 - recall: 0.9176 - precision: 0.9351 - f1_score: 0.9260
# Epoch 2/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1742 - accuracy: 0.9396 - recall: 0.9345 - precision: 0.9450 - f1_score: 0.9396
# Epoch 3/20
# 6159/6159 [==============================] - 88s 14ms/step - loss: 0.1593 - accuracy: 0.9475 - recall: 0.9435 - precision: 0.9520 - f1_score: 0.9477
# Epoch 4/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1542 - accuracy: 0.9497 - recall: 0.9461 - precision: 0.9539 - f1_score: 0.9500
# Epoch 5/20
# 6159/6159 [==============================] - 86s 14ms/step - loss: 0.1486 - accuracy: 0.9522 - recall: 0.9487 - precision: 0.9561 - f1_score: 0.9523
# Epoch 6/20
# 6159/6159 [==============================] - 86s 14ms/step - loss: 0.1484 - accuracy: 0.9529 - recall: 0.9496 - precision: 0.9565 - f1_score: 0.9530
# Epoch 7/20
# 6159/6159 [==============================] - 86s 14ms/step - loss: 0.1465 - accuracy: 0.9537 - recall: 0.9506 - precision: 0.9574 - f1_score: 0.9539
# Epoch 8/20
# 6159/6159 [==============================] - 87s 14ms/step - loss: 0.1435 - accuracy: 0.9548 - recall: 0.9517 - precision: 0.9584 - f1_score: 0.9550
# Epoch 9/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1421 - accuracy: 0.9558 - recall: 0.9530 - precision: 0.9593 - f1_score: 0.9561
# Epoch 10/20
# 6159/6159 [==============================] - 99s 16ms/step - loss: 0.1382 - accuracy: 0.9571 - recall: 0.9544 - precision: 0.9601 - f1_score: 0.9572
# Epoch 11/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1393 - accuracy: 0.9565 - recall: 0.9539 - precision: 0.9596 - f1_score: 0.9567
# Epoch 12/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1365 - accuracy: 0.9577 - recall: 0.9552 - precision: 0.9607 - f1_score: 0.9579
# Epoch 13/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1369 - accuracy: 0.9577 - recall: 0.9552 - precision: 0.9607 - f1_score: 0.9579
# Epoch 14/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1344 - accuracy: 0.9584 - recall: 0.9559 - precision: 0.9611 - f1_score: 0.9585
# Epoch 15/20
# 6159/6159 [==============================] - 96s 15ms/step - loss: 0.1327 - accuracy: 0.9593 - recall: 0.9566 - precision: 0.9624 - f1_score: 0.9595
# Epoch 16/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1339 - accuracy: 0.9587 - recall: 0.9561 - precision: 0.9619 - f1_score: 0.9590
# Epoch 17/20
# 6159/6159 [==============================] - 94s 15ms/step - loss: 0.1324 - accuracy: 0.9592 - recall: 0.9568 - precision: 0.9621 - f1_score: 0.9594
# Epoch 18/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1313 - accuracy: 0.9593 - recall: 0.9568 - precision: 0.9624 - f1_score: 0.9595
# Epoch 19/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1312 - accuracy: 0.9595 - recall: 0.9569 - precision: 0.9623 - f1_score: 0.9596
# Epoch 20/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1305 - accuracy: 0.9594 - recall: 0.9569 - precision: 0.9623 - f1_score: 0.9596
# Round: 1 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1952 - accuracy: 0.9329 - recall: 0.9250 - precision: 0.9409 - f1_score: 0.9326
# Epoch 2/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1508 - accuracy: 0.9511 - recall: 0.9475 - precision: 0.9551 - f1_score: 0.9512
# Epoch 3/20
# 6159/6159 [==============================] - 80s 13ms/step - loss: 0.1469 - accuracy: 0.9531 - recall: 0.9498 - precision: 0.9566 - f1_score: 0.9532
# Epoch 4/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1455 - accuracy: 0.9537 - recall: 0.9506 - precision: 0.9573 - f1_score: 0.9539
# Epoch 5/20
# 6159/6159 [==============================] - 80s 13ms/step - loss: 0.1403 - accuracy: 0.9556 - recall: 0.9526 - precision: 0.9588 - f1_score: 0.9556
# Epoch 6/20
# 6159/6159 [==============================] - 89s 14ms/step - loss: 0.1397 - accuracy: 0.9569 - recall: 0.9540 - precision: 0.9601 - f1_score: 0.9570
# Epoch 7/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1387 - accuracy: 0.9566 - recall: 0.9539 - precision: 0.9599 - f1_score: 0.9568
# Epoch 8/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1352 - accuracy: 0.9578 - recall: 0.9551 - precision: 0.9611 - f1_score: 0.9581
# Epoch 9/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1341 - accuracy: 0.9583 - recall: 0.9555 - precision: 0.9614 - f1_score: 0.9584
# Epoch 10/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1297 - accuracy: 0.9598 - recall: 0.9571 - precision: 0.9629 - f1_score: 0.9600
# Epoch 11/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1298 - accuracy: 0.9605 - recall: 0.9583 - precision: 0.9633 - f1_score: 0.9608
# Epoch 12/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1286 - accuracy: 0.9607 - recall: 0.9583 - precision: 0.9633 - f1_score: 0.9608
# Epoch 13/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1285 - accuracy: 0.9607 - recall: 0.9584 - precision: 0.9635 - f1_score: 0.9609
# Epoch 14/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1262 - accuracy: 0.9614 - recall: 0.9593 - precision: 0.9640 - f1_score: 0.9616
# Epoch 15/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1246 - accuracy: 0.9622 - recall: 0.9601 - precision: 0.9648 - f1_score: 0.9624
# Epoch 16/20
# 6159/6159 [==============================] - 80s 13ms/step - loss: 0.1245 - accuracy: 0.9618 - recall: 0.9594 - precision: 0.9644 - f1_score: 0.9618
# Epoch 17/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1237 - accuracy: 0.9623 - recall: 0.9603 - precision: 0.9650 - f1_score: 0.9627
# Epoch 18/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1215 - accuracy: 0.9637 - recall: 0.9615 - precision: 0.9661 - f1_score: 0.9638
# Epoch 19/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1226 - accuracy: 0.9633 - recall: 0.9611 - precision: 0.9659 - f1_score: 0.9634
# Epoch 20/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1221 - accuracy: 0.9635 - recall: 0.9614 - precision: 0.9661 - f1_score: 0.9637
# Round: 1 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 79s 13ms/step - loss: 0.1896 - accuracy: 0.9351 - recall: 0.9275 - precision: 0.9428 - f1_score: 0.9348
# Epoch 2/20
# 6159/6159 [==============================] - 81s 13ms/step - loss: 0.1500 - accuracy: 0.9520 - recall: 0.9486 - precision: 0.9561 - f1_score: 0.9523
# Epoch 3/20
# 6159/6159 [==============================] - 82s 13ms/step - loss: 0.1476 - accuracy: 0.9535 - recall: 0.9503 - precision: 0.9570 - f1_score: 0.9536
# Epoch 4/20
# 6159/6159 [==============================] - 79s 13ms/step - loss: 0.1445 - accuracy: 0.9540 - recall: 0.9511 - precision: 0.9574 - f1_score: 0.9542
# Epoch 5/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1405 - accuracy: 0.9556 - recall: 0.9527 - precision: 0.9590 - f1_score: 0.9558
# Epoch 6/20
# 6159/6159 [==============================] - 77s 12ms/step - loss: 0.1403 - accuracy: 0.9565 - recall: 0.9538 - precision: 0.9598 - f1_score: 0.9567
# Epoch 7/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1385 - accuracy: 0.9569 - recall: 0.9542 - precision: 0.9601 - f1_score: 0.9571
# Epoch 8/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1334 - accuracy: 0.9581 - recall: 0.9555 - precision: 0.9612 - f1_score: 0.9583
# Epoch 9/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1343 - accuracy: 0.9582 - recall: 0.9557 - precision: 0.9614 - f1_score: 0.9585
# Epoch 10/20
# 6159/6159 [==============================] - 91s 15ms/step - loss: 0.1307 - accuracy: 0.9598 - recall: 0.9572 - precision: 0.9627 - f1_score: 0.9599
# Epoch 11/20
# 6159/6159 [==============================] - 81s 13ms/step - loss: 0.1286 - accuracy: 0.9606 - recall: 0.9583 - precision: 0.9633 - f1_score: 0.9608
# Epoch 12/20
# 6159/6159 [==============================] - 83s 13ms/step - loss: 0.1291 - accuracy: 0.9609 - recall: 0.9587 - precision: 0.9634 - f1_score: 0.9610
# Epoch 13/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1275 - accuracy: 0.9610 - recall: 0.9588 - precision: 0.9638 - f1_score: 0.9612
# Epoch 14/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1274 - accuracy: 0.9611 - recall: 0.9589 - precision: 0.9636 - f1_score: 0.9612
# Epoch 15/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1258 - accuracy: 0.9619 - recall: 0.9597 - precision: 0.9645 - f1_score: 0.9620
# Epoch 16/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1238 - accuracy: 0.9626 - recall: 0.9604 - precision: 0.9652 - f1_score: 0.9627
# Epoch 17/20
# 6159/6159 [==============================] - 87s 14ms/step - loss: 0.1225 - accuracy: 0.9628 - recall: 0.9606 - precision: 0.9655 - f1_score: 0.9630
# Epoch 18/20
# 6159/6159 [==============================] - 88s 14ms/step - loss: 0.1206 - accuracy: 0.9633 - recall: 0.9612 - precision: 0.9659 - f1_score: 0.9635
# Epoch 19/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1205 - accuracy: 0.9637 - recall: 0.9615 - precision: 0.9663 - f1_score: 0.9639
# Epoch 20/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1196 - accuracy: 0.9638 - recall: 0.9616 - precision: 0.9662 - f1_score: 0.9639
# 12317/12317 [==============================] - 54s 4ms/step
# comm_round: 1 | global_loss: 1.0672874450683594 | global_accuracy: 0.9827 | global_recall: 0.9819 | global_precision: 0.9837 | global_f1_score: 0.9828
#
# New Weights Saved
# Round: 2 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 96s 15ms/step - loss: 0.1324 - accuracy: 0.9587 - recall: 0.9561 - precision: 0.9616 - f1_score: 0.9588
# Epoch 2/20
# 6159/6159 [==============================] - 101s 16ms/step - loss: 0.1316 - accuracy: 0.9583 - recall: 0.9559 - precision: 0.9612 - f1_score: 0.9585
# Epoch 3/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1319 - accuracy: 0.9585 - recall: 0.9561 - precision: 0.9613 - f1_score: 0.9587
# Epoch 4/20
# 6159/6159 [==============================] - 109s 18ms/step - loss: 0.1304 - accuracy: 0.9587 - recall: 0.9565 - precision: 0.9615 - f1_score: 0.9590
# Epoch 5/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1300 - accuracy: 0.9588 - recall: 0.9566 - precision: 0.9616 - f1_score: 0.9590
# Epoch 6/20
# 6159/6159 [==============================] - 116s 19ms/step - loss: 0.1290 - accuracy: 0.9594 - recall: 0.9569 - precision: 0.9621 - f1_score: 0.9595
# Epoch 7/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1297 - accuracy: 0.9591 - recall: 0.9568 - precision: 0.9618 - f1_score: 0.9592
# Epoch 8/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1288 - accuracy: 0.9594 - recall: 0.9570 - precision: 0.9623 - f1_score: 0.9596
# Epoch 9/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1278 - accuracy: 0.9598 - recall: 0.9573 - precision: 0.9624 - f1_score: 0.9598
# Epoch 10/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1269 - accuracy: 0.9602 - recall: 0.9578 - precision: 0.9627 - f1_score: 0.9602
# Epoch 11/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1270 - accuracy: 0.9602 - recall: 0.9579 - precision: 0.9629 - f1_score: 0.9604
# Epoch 12/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1248 - accuracy: 0.9604 - recall: 0.9581 - precision: 0.9630 - f1_score: 0.9605
# Epoch 13/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1272 - accuracy: 0.9601 - recall: 0.9579 - precision: 0.9628 - f1_score: 0.9603
# Epoch 14/20
# 6159/6159 [==============================] - 114s 18ms/step - loss: 0.1257 - accuracy: 0.9605 - recall: 0.9582 - precision: 0.9631 - f1_score: 0.9606
# Epoch 15/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1253 - accuracy: 0.9606 - recall: 0.9583 - precision: 0.9633 - f1_score: 0.9608
# Epoch 16/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1244 - accuracy: 0.9606 - recall: 0.9581 - precision: 0.9633 - f1_score: 0.9607
# Epoch 17/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1238 - accuracy: 0.9609 - recall: 0.9585 - precision: 0.9636 - f1_score: 0.9610
# Epoch 18/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1242 - accuracy: 0.9609 - recall: 0.9585 - precision: 0.9635 - f1_score: 0.9610
# Epoch 19/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1241 - accuracy: 0.9608 - recall: 0.9585 - precision: 0.9634 - f1_score: 0.9609
# Epoch 20/20
# 6159/6159 [==============================] - 112s 18ms/step - loss: 0.1239 - accuracy: 0.9606 - recall: 0.9583 - precision: 0.9634 - f1_score: 0.9608
# Round: 2 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1334 - accuracy: 0.9580 - recall: 0.9555 - precision: 0.9611 - f1_score: 0.9583
# Epoch 2/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1310 - accuracy: 0.9583 - recall: 0.9557 - precision: 0.9613 - f1_score: 0.9585
# Epoch 3/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1302 - accuracy: 0.9587 - recall: 0.9563 - precision: 0.9616 - f1_score: 0.9589
# Epoch 4/20
# 6159/6159 [==============================] - 107s 17ms/step - loss: 0.1296 - accuracy: 0.9588 - recall: 0.9563 - precision: 0.9616 - f1_score: 0.9589
# Epoch 5/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1288 - accuracy: 0.9593 - recall: 0.9571 - precision: 0.9618 - f1_score: 0.9595
# Epoch 6/20
# 6159/6159 [==============================] - 106s 17ms/step - loss: 0.1298 - accuracy: 0.9590 - recall: 0.9568 - precision: 0.9615 - f1_score: 0.9591
# Epoch 7/20
# 6159/6159 [==============================] - 107s 17ms/step - loss: 0.1302 - accuracy: 0.9591 - recall: 0.9568 - precision: 0.9619 - f1_score: 0.9593
# Epoch 8/20
# 6159/6159 [==============================] - 107s 17ms/step - loss: 0.1285 - accuracy: 0.9595 - recall: 0.9569 - precision: 0.9622 - f1_score: 0.9595
# Epoch 9/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1277 - accuracy: 0.9596 - recall: 0.9572 - precision: 0.9623 - f1_score: 0.9597
# Epoch 10/20
# 6159/6159 [==============================] - 107s 17ms/step - loss: 0.1273 - accuracy: 0.9602 - recall: 0.9579 - precision: 0.9628 - f1_score: 0.9603
# Epoch 11/20
# 6159/6159 [==============================] - 118s 19ms/step - loss: 0.1270 - accuracy: 0.9601 - recall: 0.9579 - precision: 0.9626 - f1_score: 0.9602
# Epoch 12/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1267 - accuracy: 0.9599 - recall: 0.9575 - precision: 0.9626 - f1_score: 0.9601
# Epoch 13/20
# 6159/6159 [==============================] - 136s 22ms/step - loss: 0.1265 - accuracy: 0.9597 - recall: 0.9574 - precision: 0.9624 - f1_score: 0.9598
# Epoch 14/20
# 6159/6159 [==============================] - 129s 21ms/step - loss: 0.1250 - accuracy: 0.9604 - recall: 0.9581 - precision: 0.9633 - f1_score: 0.9606
# Epoch 15/20
# 6159/6159 [==============================] - 112s 18ms/step - loss: 0.1270 - accuracy: 0.9594 - recall: 0.9570 - precision: 0.9623 - f1_score: 0.9596
# Epoch 16/20
# 6159/6159 [==============================] - 119s 19ms/step - loss: 0.1249 - accuracy: 0.9603 - recall: 0.9579 - precision: 0.9631 - f1_score: 0.9605
# Epoch 17/20
# 6159/6159 [==============================] - 113s 18ms/step - loss: 0.1237 - accuracy: 0.9609 - recall: 0.9585 - precision: 0.9635 - f1_score: 0.9610
# Epoch 18/20
# 6159/6159 [==============================] - 112s 18ms/step - loss: 0.1236 - accuracy: 0.9605 - recall: 0.9582 - precision: 0.9632 - f1_score: 0.9607
# Epoch 19/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1234 - accuracy: 0.9605 - recall: 0.9581 - precision: 0.9632 - f1_score: 0.9606
# Epoch 20/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1231 - accuracy: 0.9611 - recall: 0.9588 - precision: 0.9638 - f1_score: 0.9613
# Round: 2 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 112s 18ms/step - loss: 0.1324 - accuracy: 0.9586 - recall: 0.9561 - precision: 0.9616 - f1_score: 0.9588
# Epoch 2/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1315 - accuracy: 0.9585 - recall: 0.9561 - precision: 0.9613 - f1_score: 0.9587
# Epoch 3/20
# 6159/6159 [==============================] - 93s 15ms/step - loss: 0.1309 - accuracy: 0.9590 - recall: 0.9566 - precision: 0.9617 - f1_score: 0.9591
# Epoch 4/20
# 6159/6159 [==============================] - 104s 17ms/step - loss: 0.1298 - accuracy: 0.9593 - recall: 0.9569 - precision: 0.9619 - f1_score: 0.9594
# Epoch 5/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1294 - accuracy: 0.9592 - recall: 0.9570 - precision: 0.9618 - f1_score: 0.9593
# Epoch 6/20
# 6159/6159 [==============================] - 102s 16ms/step - loss: 0.1291 - accuracy: 0.9594 - recall: 0.9571 - precision: 0.9620 - f1_score: 0.9595
# Epoch 7/20
# 6159/6159 [==============================] - 94s 15ms/step - loss: 0.1286 - accuracy: 0.9597 - recall: 0.9572 - precision: 0.9625 - f1_score: 0.9598
# Epoch 8/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1286 - accuracy: 0.9595 - recall: 0.9571 - precision: 0.9624 - f1_score: 0.9597
# Epoch 9/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1298 - accuracy: 0.9596 - recall: 0.9572 - precision: 0.9623 - f1_score: 0.9597
# Epoch 10/20
# 6159/6159 [==============================] - 93s 15ms/step - loss: 0.1278 - accuracy: 0.9607 - recall: 0.9583 - precision: 0.9632 - f1_score: 0.9607
# Epoch 11/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1273 - accuracy: 0.9604 - recall: 0.9579 - precision: 0.9632 - f1_score: 0.9606
# Epoch 12/20
# 6159/6159 [==============================] - 100s 16ms/step - loss: 0.1258 - accuracy: 0.9606 - recall: 0.9582 - precision: 0.9633 - f1_score: 0.9607
# Epoch 13/20
# 6159/6159 [==============================] - 105s 17ms/step - loss: 0.1257 - accuracy: 0.9606 - recall: 0.9582 - precision: 0.9632 - f1_score: 0.9607
# Epoch 14/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1257 - accuracy: 0.9602 - recall: 0.9579 - precision: 0.9629 - f1_score: 0.9604
# Epoch 15/20
# 6159/6159 [==============================] - 114s 18ms/step - loss: 0.1247 - accuracy: 0.9608 - recall: 0.9586 - precision: 0.9634 - f1_score: 0.9609
# Epoch 16/20
# 6159/6159 [==============================] - 118s 19ms/step - loss: 0.1246 - accuracy: 0.9606 - recall: 0.9580 - precision: 0.9634 - f1_score: 0.9607
# Epoch 17/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1237 - accuracy: 0.9609 - recall: 0.9585 - precision: 0.9637 - f1_score: 0.9611
# Epoch 18/20
# 6159/6159 [==============================] - 100s 16ms/step - loss: 0.1247 - accuracy: 0.9608 - recall: 0.9584 - precision: 0.9635 - f1_score: 0.9609
# Epoch 19/20
# 6159/6159 [==============================] - 106s 17ms/step - loss: 0.1231 - accuracy: 0.9613 - recall: 0.9588 - precision: 0.9638 - f1_score: 0.9613
# Epoch 20/20
# 6159/6159 [==============================] - 94s 15ms/step - loss: 0.1233 - accuracy: 0.9610 - recall: 0.9588 - precision: 0.9635 - f1_score: 0.9611
# Round: 2 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1343 - accuracy: 0.9579 - recall: 0.9552 - precision: 0.9609 - f1_score: 0.9580
# Epoch 2/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1314 - accuracy: 0.9585 - recall: 0.9561 - precision: 0.9614 - f1_score: 0.9587
# Epoch 3/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1311 - accuracy: 0.9588 - recall: 0.9564 - precision: 0.9615 - f1_score: 0.9589
# Epoch 4/20
# 6159/6159 [==============================] - 93s 15ms/step - loss: 0.1307 - accuracy: 0.9587 - recall: 0.9564 - precision: 0.9613 - f1_score: 0.9588
# Epoch 5/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1300 - accuracy: 0.9589 - recall: 0.9567 - precision: 0.9615 - f1_score: 0.9591
# Epoch 6/20
# 6159/6159 [==============================] - 94s 15ms/step - loss: 0.1304 - accuracy: 0.9589 - recall: 0.9565 - precision: 0.9616 - f1_score: 0.9590
# Epoch 7/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1314 - accuracy: 0.9589 - recall: 0.9564 - precision: 0.9615 - f1_score: 0.9589
# Epoch 8/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1284 - accuracy: 0.9593 - recall: 0.9569 - precision: 0.9624 - f1_score: 0.9596
# Epoch 9/20
# 6159/6159 [==============================] - 94s 15ms/step - loss: 0.1287 - accuracy: 0.9597 - recall: 0.9572 - precision: 0.9625 - f1_score: 0.9598
# Epoch 10/20
# 6159/6159 [==============================] - 100s 16ms/step - loss: 0.1283 - accuracy: 0.9600 - recall: 0.9576 - precision: 0.9627 - f1_score: 0.9601
# Epoch 11/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1275 - accuracy: 0.9600 - recall: 0.9576 - precision: 0.9627 - f1_score: 0.9601
# Epoch 12/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1276 - accuracy: 0.9600 - recall: 0.9577 - precision: 0.9626 - f1_score: 0.9601
# Epoch 13/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1265 - accuracy: 0.9605 - recall: 0.9582 - precision: 0.9631 - f1_score: 0.9606
# Epoch 14/20
# 6159/6159 [==============================] - 115s 19ms/step - loss: 0.1265 - accuracy: 0.9604 - recall: 0.9580 - precision: 0.9630 - f1_score: 0.9605
# Epoch 15/20
# 6159/6159 [==============================] - 131s 21ms/step - loss: 0.1260 - accuracy: 0.9606 - recall: 0.9584 - precision: 0.9630 - f1_score: 0.9607
# Epoch 16/20
# 6159/6159 [==============================] - 133s 21ms/step - loss: 0.1259 - accuracy: 0.9603 - recall: 0.9579 - precision: 0.9630 - f1_score: 0.9604
# Epoch 17/20
# 6159/6159 [==============================] - 119s 19ms/step - loss: 0.1259 - accuracy: 0.9605 - recall: 0.9581 - precision: 0.9633 - f1_score: 0.9607
# Epoch 18/20
# 6159/6159 [==============================] - 115s 18ms/step - loss: 0.1246 - accuracy: 0.9608 - recall: 0.9585 - precision: 0.9636 - f1_score: 0.9610
# Epoch 19/20
# 6159/6159 [==============================] - 114s 18ms/step - loss: 0.1250 - accuracy: 0.9606 - recall: 0.9582 - precision: 0.9633 - f1_score: 0.9607
# Epoch 20/20
# 6159/6159 [==============================] - 114s 18ms/step - loss: 0.1241 - accuracy: 0.9611 - recall: 0.9587 - precision: 0.9636 - f1_score: 0.9612
# 12317/12317 [==============================] - 75s 6ms/step
# comm_round: 2 | global_loss: 1.0622252225875854 | global_accuracy: 0.9856 | global_recall: 0.985 | global_precision: 0.9866 | global_f1_score: 0.9858
#
# New Weights Saved
# Round: 3 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 130s 21ms/step - loss: 0.1239 - accuracy: 0.9605 - recall: 0.9582 - precision: 0.9632 - f1_score: 0.9606
# Epoch 2/20
# 6159/6159 [==============================] - 123s 20ms/step - loss: 0.1222 - accuracy: 0.9615 - recall: 0.9594 - precision: 0.9640 - f1_score: 0.9616
# Epoch 3/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1235 - accuracy: 0.9605 - recall: 0.9583 - precision: 0.9630 - f1_score: 0.9606
# Epoch 4/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1222 - accuracy: 0.9615 - recall: 0.9591 - precision: 0.9640 - f1_score: 0.9615
# Epoch 5/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1208 - accuracy: 0.9614 - recall: 0.9592 - precision: 0.9643 - f1_score: 0.9617
# Epoch 6/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1219 - accuracy: 0.9614 - recall: 0.9591 - precision: 0.9640 - f1_score: 0.9615
# Epoch 7/20
# 6159/6159 [==============================] - 99s 16ms/step - loss: 0.1208 - accuracy: 0.9614 - recall: 0.9593 - precision: 0.9640 - f1_score: 0.9617
# Epoch 8/20
# 6159/6159 [==============================] - 94s 15ms/step - loss: 0.1209 - accuracy: 0.9615 - recall: 0.9596 - precision: 0.9640 - f1_score: 0.9617
# Epoch 9/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1203 - accuracy: 0.9618 - recall: 0.9596 - precision: 0.9643 - f1_score: 0.9619
# Epoch 10/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1213 - accuracy: 0.9616 - recall: 0.9593 - precision: 0.9642 - f1_score: 0.9617
# Epoch 11/20
# 6159/6159 [==============================] - 100s 16ms/step - loss: 0.1198 - accuracy: 0.9618 - recall: 0.9597 - precision: 0.9643 - f1_score: 0.9620
# Epoch 12/20
# 6159/6159 [==============================] - 106s 17ms/step - loss: 0.1207 - accuracy: 0.9616 - recall: 0.9595 - precision: 0.9643 - f1_score: 0.9619
# Epoch 13/20
# 6159/6159 [==============================] - 100s 16ms/step - loss: 0.1211 - accuracy: 0.9616 - recall: 0.9593 - precision: 0.9642 - f1_score: 0.9617
# Epoch 14/20
# 6159/6159 [==============================] - 99s 16ms/step - loss: 0.1193 - accuracy: 0.9618 - recall: 0.9597 - precision: 0.9642 - f1_score: 0.9619
# Epoch 15/20
# 6159/6159 [==============================] - 91s 15ms/step - loss: 0.1191 - accuracy: 0.9619 - recall: 0.9597 - precision: 0.9644 - f1_score: 0.9620
# Epoch 16/20
# 6159/6159 [==============================] - 90s 14ms/step - loss: 0.1188 - accuracy: 0.9619 - recall: 0.9598 - precision: 0.9643 - f1_score: 0.9620
# Epoch 17/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1183 - accuracy: 0.9621 - recall: 0.9599 - precision: 0.9647 - f1_score: 0.9623
# Epoch 18/20
# 6159/6159 [==============================] - 101s 16ms/step - loss: 0.1176 - accuracy: 0.9622 - recall: 0.9599 - precision: 0.9648 - f1_score: 0.9623
# Epoch 19/20
# 6159/6159 [==============================] - 87s 14ms/step - loss: 0.1184 - accuracy: 0.9621 - recall: 0.9600 - precision: 0.9650 - f1_score: 0.9625
# Epoch 20/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1179 - accuracy: 0.9620 - recall: 0.9597 - precision: 0.9646 - f1_score: 0.9622
# Round: 3 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 100s 16ms/step - loss: 0.1226 - accuracy: 0.9612 - recall: 0.9590 - precision: 0.9639 - f1_score: 0.9614
# Epoch 2/20
# 6159/6159 [==============================] - 96s 15ms/step - loss: 0.1218 - accuracy: 0.9614 - recall: 0.9594 - precision: 0.9639 - f1_score: 0.9616
# Epoch 3/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1218 - accuracy: 0.9615 - recall: 0.9593 - precision: 0.9641 - f1_score: 0.9617
# Epoch 4/20
# 6159/6159 [==============================] - 112s 18ms/step - loss: 0.1225 - accuracy: 0.9608 - recall: 0.9585 - precision: 0.9634 - f1_score: 0.9609
# Epoch 5/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1229 - accuracy: 0.9611 - recall: 0.9588 - precision: 0.9638 - f1_score: 0.9613
# Epoch 6/20
# 6159/6159 [==============================] - 126s 20ms/step - loss: 0.1213 - accuracy: 0.9616 - recall: 0.9593 - precision: 0.9643 - f1_score: 0.9618
# Epoch 7/20
# 6159/6159 [==============================] - 113s 18ms/step - loss: 0.1207 - accuracy: 0.9619 - recall: 0.9595 - precision: 0.9645 - f1_score: 0.9620
# Epoch 8/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1212 - accuracy: 0.9613 - recall: 0.9593 - precision: 0.9638 - f1_score: 0.9615
# Epoch 9/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1200 - accuracy: 0.9621 - recall: 0.9598 - precision: 0.9647 - f1_score: 0.9622
# Epoch 10/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1216 - accuracy: 0.9611 - recall: 0.9589 - precision: 0.9637 - f1_score: 0.9613
# Epoch 11/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1207 - accuracy: 0.9617 - recall: 0.9595 - precision: 0.9643 - f1_score: 0.9619
# Epoch 12/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1199 - accuracy: 0.9622 - recall: 0.9601 - precision: 0.9648 - f1_score: 0.9624
# Epoch 13/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1195 - accuracy: 0.9621 - recall: 0.9598 - precision: 0.9646 - f1_score: 0.9622
# Epoch 14/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1190 - accuracy: 0.9619 - recall: 0.9600 - precision: 0.9645 - f1_score: 0.9622
# Epoch 15/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1187 - accuracy: 0.9621 - recall: 0.9601 - precision: 0.9646 - f1_score: 0.9624
# Epoch 16/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1194 - accuracy: 0.9618 - recall: 0.9596 - precision: 0.9643 - f1_score: 0.9619
# Epoch 17/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1174 - accuracy: 0.9623 - recall: 0.9602 - precision: 0.9649 - f1_score: 0.9625
# Epoch 18/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1187 - accuracy: 0.9620 - recall: 0.9598 - precision: 0.9647 - f1_score: 0.9622
# Epoch 19/20
# 6159/6159 [==============================] - 109s 18ms/step - loss: 0.1180 - accuracy: 0.9626 - recall: 0.9603 - precision: 0.9652 - f1_score: 0.9627
# Epoch 20/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1177 - accuracy: 0.9624 - recall: 0.9603 - precision: 0.9649 - f1_score: 0.9626
# Round: 3 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 106s 17ms/step - loss: 0.1221 - accuracy: 0.9611 - recall: 0.9588 - precision: 0.9638 - f1_score: 0.9613
# Epoch 2/20
# 6159/6159 [==============================] - 107s 17ms/step - loss: 0.1235 - accuracy: 0.9606 - recall: 0.9583 - precision: 0.9633 - f1_score: 0.9608
# Epoch 3/20
# 6159/6159 [==============================] - 107s 17ms/step - loss: 0.1218 - accuracy: 0.9615 - recall: 0.9593 - precision: 0.9640 - f1_score: 0.9616
# Epoch 4/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1212 - accuracy: 0.9612 - recall: 0.9592 - precision: 0.9638 - f1_score: 0.9615
# Epoch 5/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1219 - accuracy: 0.9611 - recall: 0.9587 - precision: 0.9638 - f1_score: 0.9612
# Epoch 6/20
# 6159/6159 [==============================] - 109s 18ms/step - loss: 0.1215 - accuracy: 0.9613 - recall: 0.9590 - precision: 0.9640 - f1_score: 0.9615
# Epoch 7/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1213 - accuracy: 0.9612 - recall: 0.9589 - precision: 0.9638 - f1_score: 0.9613
# Epoch 8/20
# 6159/6159 [==============================] - 109s 18ms/step - loss: 0.1214 - accuracy: 0.9616 - recall: 0.9594 - precision: 0.9639 - f1_score: 0.9616
# Epoch 9/20
# 6159/6159 [==============================] - 103s 17ms/step - loss: 0.1208 - accuracy: 0.9614 - recall: 0.9592 - precision: 0.9640 - f1_score: 0.9615
# Epoch 10/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1202 - accuracy: 0.9618 - recall: 0.9596 - precision: 0.9644 - f1_score: 0.9619
# Epoch 11/20
# ...
# Epoch 6/20
# 6159/6159 [==============================] - 113s 18ms/step - loss: 0.1227 - accuracy: 0.9605 - recall: 0.9580 - precision: 0.9634 - f1_score: 0.9607
# Epoch 7/20
# 6159/6159 [==============================] - 109s 18ms/step - loss: 0.1218 - accuracy: 0.9610 - recall: 0.9587 - precision: 0.9637 - f1_score: 0.9612
# Epoch 8/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1201 - accuracy: 0.9619 - recall: 0.9598 - precision: 0.9644 - f1_score: 0.9621
# Epoch 9/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1202 - accuracy: 0.9613 - recall: 0.9593 - precision: 0.9641 - f1_score: 0.9616
# Epoch 10/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1196 - accuracy: 0.9613 - recall: 0.9591 - precision: 0.9639 - f1_score: 0.9615
# Epoch 11/20
# 6159/6159 [==============================] - 116s 19ms/step - loss: 0.1190 - accuracy: 0.9621 - recall: 0.9599 - precision: 0.9645 - f1_score: 0.9622
# Epoch 12/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1201 - accuracy: 0.9619 - recall: 0.9595 - precision: 0.9643 - f1_score: 0.9619
# Epoch 13/20
# 6159/6159 [==============================] - 127s 20ms/step - loss: 0.1203 - accuracy: 0.9617 - recall: 0.9596 - precision: 0.9644 - f1_score: 0.9619
# Epoch 14/20
# 6159/6159 [==============================] - 116s 19ms/step - loss: 0.1171 - accuracy: 0.9622 - recall: 0.9601 - precision: 0.9646 - f1_score: 0.9623
# Epoch 15/20
# 6159/6159 [==============================] - 112s 18ms/step - loss: 0.1183 - accuracy: 0.9620 - recall: 0.9597 - precision: 0.9646 - f1_score: 0.9621
# Epoch 16/20
# 6159/6159 [==============================] - 113s 18ms/step - loss: 0.1182 - accuracy: 0.9617 - recall: 0.9596 - precision: 0.9643 - f1_score: 0.9619
# Epoch 17/20
# 6159/6159 [==============================] - 113s 18ms/step - loss: 0.1169 - accuracy: 0.9625 - recall: 0.9604 - precision: 0.9649 - f1_score: 0.9626
# Epoch 18/20
# 6159/6159 [==============================] - 113s 18ms/step - loss: 0.1188 - accuracy: 0.9620 - recall: 0.9597 - precision: 0.9646 - f1_score: 0.9621
# Epoch 19/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1170 - accuracy: 0.9624 - recall: 0.9602 - precision: 0.9650 - f1_score: 0.9625
# Epoch 20/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1160 - accuracy: 0.9629 - recall: 0.9607 - precision: 0.9653 - f1_score: 0.9630
# 12317/12317 [==============================] - 66s 5ms/step
# comm_round: 3 | global_loss: 1.0615928173065186 | global_accuracy: 0.9857 | global_recall: 0.9852 | global_precision: 0.9864 | global_f1_score: 0.9858
#
# New Weights Saved
# Round: 4 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 112s 18ms/step - loss: 0.1190 - accuracy: 0.9619 - recall: 0.9598 - precision: 0.9645 - f1_score: 0.9621
# Epoch 2/20
# 6159/6159 [==============================] - 99s 16ms/step - loss: 0.1184 - accuracy: 0.9622 - recall: 0.9600 - precision: 0.9649 - f1_score: 0.9624
# Epoch 3/20
# 6159/6159 [==============================] - 100s 16ms/step - loss: 0.1192 - accuracy: 0.9620 - recall: 0.9595 - precision: 0.9646 - f1_score: 0.9620
# Epoch 4/20
# 6159/6159 [==============================] - 108s 17ms/step - loss: 0.1191 - accuracy: 0.9618 - recall: 0.9594 - precision: 0.9645 - f1_score: 0.9619
# Epoch 5/20
# 6159/6159 [==============================] - 102s 16ms/step - loss: 0.1176 - accuracy: 0.9624 - recall: 0.9601 - precision: 0.9650 - f1_score: 0.9625
# Epoch 6/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1179 - accuracy: 0.9622 - recall: 0.9599 - precision: 0.9647 - f1_score: 0.9623
# Epoch 7/20
# 6159/6159 [==============================] - 89s 14ms/step - loss: 0.1172 - accuracy: 0.9626 - recall: 0.9606 - precision: 0.9650 - f1_score: 0.9628
# Epoch 8/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1168 - accuracy: 0.9630 - recall: 0.9607 - precision: 0.9655 - f1_score: 0.9631
# Epoch 9/20
# 6159/6159 [==============================] - 87s 14ms/step - loss: 0.1167 - accuracy: 0.9628 - recall: 0.9605 - precision: 0.9654 - f1_score: 0.9629
# Epoch 10/20
# 6159/6159 [==============================] - 89s 14ms/step - loss: 0.1182 - accuracy: 0.9623 - recall: 0.9601 - precision: 0.9646 - f1_score: 0.9623
# Epoch 11/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1166 - accuracy: 0.9630 - recall: 0.9608 - precision: 0.9655 - f1_score: 0.9631
# Epoch 12/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1174 - accuracy: 0.9626 - recall: 0.9601 - precision: 0.9651 - f1_score: 0.9626
# Epoch 13/20
# 6159/6159 [==============================] - 87s 14ms/step - loss: 0.1180 - accuracy: 0.9624 - recall: 0.9604 - precision: 0.9646 - f1_score: 0.9625
# Epoch 14/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1155 - accuracy: 0.9631 - recall: 0.9610 - precision: 0.9655 - f1_score: 0.9632
# Epoch 15/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1163 - accuracy: 0.9629 - recall: 0.9608 - precision: 0.9653 - f1_score: 0.9630
# Epoch 16/20
# 6159/6159 [==============================] - 86s 14ms/step - loss: 0.1154 - accuracy: 0.9633 - recall: 0.9612 - precision: 0.9658 - f1_score: 0.9634
# Epoch 17/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1160 - accuracy: 0.9627 - recall: 0.9605 - precision: 0.9652 - f1_score: 0.9628
# Epoch 18/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1148 - accuracy: 0.9635 - recall: 0.9615 - precision: 0.9660 - f1_score: 0.9637
# Epoch 19/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1140 - accuracy: 0.9635 - recall: 0.9617 - precision: 0.9659 - f1_score: 0.9638
# Epoch 20/20
# 6159/6159 [==============================] - 86s 14ms/step - loss: 0.1166 - accuracy: 0.9626 - recall: 0.9606 - precision: 0.9651 - f1_score: 0.9628
# Round: 4 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 84s 14ms/step - loss: 0.1173 - accuracy: 0.9628 - recall: 0.9609 - precision: 0.9652 - f1_score: 0.9630
# Epoch 2/20
# 6159/6159 [==============================] - 91s 15ms/step - loss: 0.1187 - accuracy: 0.9623 - recall: 0.9601 - precision: 0.9648 - f1_score: 0.9624
# Epoch 3/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1195 - accuracy: 0.9622 - recall: 0.9600 - precision: 0.9647 - f1_score: 0.9623
# Epoch 4/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1190 - accuracy: 0.9621 - recall: 0.9597 - precision: 0.9648 - f1_score: 0.9622
# Epoch 5/20
# 6159/6159 [==============================] - 115s 19ms/step - loss: 0.1179 - accuracy: 0.9626 - recall: 0.9602 - precision: 0.9652 - f1_score: 0.9627
# Epoch 6/20
# 6159/6159 [==============================] - 115s 19ms/step - loss: 0.1177 - accuracy: 0.9627 - recall: 0.9604 - precision: 0.9654 - f1_score: 0.9629
# Epoch 7/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1172 - accuracy: 0.9625 - recall: 0.9605 - precision: 0.9650 - f1_score: 0.9627
# Epoch 8/20
# 6159/6159 [==============================] - 122s 20ms/step - loss: 0.1185 - accuracy: 0.9626 - recall: 0.9605 - precision: 0.9650 - f1_score: 0.9627
# Epoch 9/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1177 - accuracy: 0.9630 - recall: 0.9609 - precision: 0.9654 - f1_score: 0.9631
# Epoch 10/20
# 6159/6159 [==============================] - 114s 18ms/step - loss: 0.1173 - accuracy: 0.9628 - recall: 0.9607 - precision: 0.9653 - f1_score: 0.9629
# Epoch 11/20
# 6159/6159 [==============================] - 114s 18ms/step - loss: 0.1162 - accuracy: 0.9632 - recall: 0.9611 - precision: 0.9656 - f1_score: 0.9633
# Epoch 12/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1156 - accuracy: 0.9633 - recall: 0.9613 - precision: 0.9658 - f1_score: 0.9635
# Epoch 13/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1176 - accuracy: 0.9627 - recall: 0.9607 - precision: 0.9652 - f1_score: 0.9630
# Epoch 14/20
# 6159/6159 [==============================] - 112s 18ms/step - loss: 0.1160 - accuracy: 0.9635 - recall: 0.9615 - precision: 0.9659 - f1_score: 0.9637
# Epoch 15/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1165 - accuracy: 0.9630 - recall: 0.9609 - precision: 0.9654 - f1_score: 0.9631
# Epoch 16/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1140 - accuracy: 0.9635 - recall: 0.9614 - precision: 0.9659 - f1_score: 0.9636
# Epoch 17/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1147 - accuracy: 0.9635 - recall: 0.9614 - precision: 0.9658 - f1_score: 0.9636
# Epoch 18/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1157 - accuracy: 0.9636 - recall: 0.9616 - precision: 0.9658 - f1_score: 0.9637
# Epoch 19/20
# 6159/6159 [==============================] - 113s 18ms/step - loss: 0.1147 - accuracy: 0.9636 - recall: 0.9617 - precision: 0.9659 - f1_score: 0.9638
# Epoch 20/20
# 6159/6159 [==============================] - 110s 18ms/step - loss: 0.1156 - accuracy: 0.9633 - recall: 0.9612 - precision: 0.9657 - f1_score: 0.9634
# Round: 4 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 112s 18ms/step - loss: 0.1175 - accuracy: 0.9629 - recall: 0.9608 - precision: 0.9654 - f1_score: 0.9631
# Epoch 2/20
# 6159/6159 [==============================] - 113s 18ms/step - loss: 0.1187 - accuracy: 0.9619 - recall: 0.9597 - precision: 0.9644 - f1_score: 0.9620
# Epoch 3/20
# 6159/6159 [==============================] - 111s 18ms/step - loss: 0.1191 - accuracy: 0.9619 - recall: 0.9596 - precision: 0.9645 - f1_score: 0.9620
# Epoch 4/20
# 6159/6159 [==============================] - 115s 19ms/step - loss: 0.1181 - accuracy: 0.9621 - recall: 0.9599 - precision: 0.9646 - f1_score: 0.9622
# Epoch 5/20
# 6159/6159 [==============================] - 115s 18ms/step - loss: 0.1185 - accuracy: 0.9623 - recall: 0.9599 - precision: 0.9649 - f1_score: 0.9624
# Epoch 6/20
# 6159/6159 [==============================] - 106s 17ms/step - loss: 0.1170 - accuracy: 0.9624 - recall: 0.9600 - precision: 0.9649 - f1_score: 0.9624
# Epoch 7/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1181 - accuracy: 0.9622 - recall: 0.9601 - precision: 0.9645 - f1_score: 0.9623
# Epoch 8/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1185 - accuracy: 0.9622 - recall: 0.9600 - precision: 0.9647 - f1_score: 0.9623
# Epoch 9/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1178 - accuracy: 0.9623 - recall: 0.9599 - precision: 0.9647 - f1_score: 0.9623
# Epoch 10/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1161 - accuracy: 0.9628 - recall: 0.9608 - precision: 0.9653 - f1_score: 0.9630
# Epoch 11/20
# 6159/6159 [==============================] - 89s 14ms/step - loss: 0.1151 - accuracy: 0.9629 - recall: 0.9607 - precision: 0.9654 - f1_score: 0.9630
# Epoch 12/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1152 - accuracy: 0.9633 - recall: 0.9612 - precision: 0.9657 - f1_score: 0.9634
# Epoch 13/20
# 6159/6159 [==============================] - 87s 14ms/step - loss: 0.1172 - accuracy: 0.9628 - recall: 0.9606 - precision: 0.9651 - f1_score: 0.9628
# Epoch 14/20
# 6159/6159 [==============================] - 91s 15ms/step - loss: 0.1168 - accuracy: 0.9631 - recall: 0.9610 - precision: 0.9656 - f1_score: 0.9632
# Epoch 15/20
# 6159/6159 [==============================] - 98s 16ms/step - loss: 0.1170 - accuracy: 0.9626 - recall: 0.9605 - precision: 0.9649 - f1_score: 0.9627
# Epoch 16/20
# 6159/6159 [==============================] - 106s 17ms/step - loss: 0.1155 - accuracy: 0.9630 - recall: 0.9609 - precision: 0.9655 - f1_score: 0.9632
# Epoch 17/20
# 6159/6159 [==============================] - 101s 16ms/step - loss: 0.1152 - accuracy: 0.9630 - recall: 0.9610 - precision: 0.9653 - f1_score: 0.9631
# Epoch 18/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1154 - accuracy: 0.9635 - recall: 0.9616 - precision: 0.9658 - f1_score: 0.9637
# Epoch 19/20
# 6159/6159 [==============================] - 97s 16ms/step - loss: 0.1152 - accuracy: 0.9634 - recall: 0.9614 - precision: 0.9657 - f1_score: 0.9635
# Epoch 20/20
# 6159/6159 [==============================] - 98s 16ms/step - loss: 0.1143 - accuracy: 0.9634 - recall: 0.9615 - precision: 0.9657 - f1_score: 0.9636
# Round: 4 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 98s 16ms/step - loss: 0.1188 - accuracy: 0.9621 - recall: 0.9599 - precision: 0.9645 - f1_score: 0.9622
# Epoch 2/20
# 6159/6159 [==============================] - 100s 16ms/step - loss: 0.1200 - accuracy: 0.9618 - recall: 0.9597 - precision: 0.9643 - f1_score: 0.9620
# Epoch 3/20
# 6159/6159 [==============================] - 100s 16ms/step - loss: 0.1197 - accuracy: 0.9618 - recall: 0.9594 - precision: 0.9645 - f1_score: 0.9619
# Epoch 4/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1183 - accuracy: 0.9624 - recall: 0.9601 - precision: 0.9650 - f1_score: 0.9625
# Epoch 5/20
# 6159/6159 [==============================] - 92s 15ms/step - loss: 0.1189 - accuracy: 0.9624 - recall: 0.9601 - precision: 0.9649 - f1_score: 0.9624
# Epoch 6/20
# 6159/6159 [==============================] - 85s 14ms/step - loss: 0.1184 - accuracy: 0.9625 - recall: 0.9601 - precision: 0.9651 - f1_score: 0.9626
# Epoch 7/20
# 6159/6159 [==============================] - 90s 14ms/step - loss: 0.1184 - accuracy: 0.9620 - recall: 0.9599 - precision: 0.9646 - f1_score: 0.9622
# Epoch 8/20
# 6159/6159 [==============================] - 95s 15ms/step - loss: 0.1190 - accuracy: 0.9618 - recall: 0.9598 - precision: 0.9643 - f1_score: 0.9620
# Epoch 9/20
# 6159/6159 [==============================] - 101s 16ms/step - loss: 0.1183 - accuracy: 0.9623 - recall: 0.9601 - precision: 0.9646 - f1_score: 0.9623
# Epoch 10/20
# 6159/6159 [==============================] - 105s 17ms/step - loss: 0.1183 - accuracy: 0.9625 - recall: 0.9602 - precision: 0.9650 - f1_score: 0.9626
# Epoch 11/20
# 6159/6159 [==============================] - 147s 23ms/step - loss: 0.1174 - accuracy: 0.9626 - recall: 0.9604 - precision: 0.9651 - f1_score: 0.9627
# Epoch 12/20
# 6159/6159 [==============================] - 138s 22ms/step - loss: 0.1175 - accuracy: 0.9624 - recall: 0.9604 - precision: 0.9651 - f1_score: 0.9627
# Epoch 13/20
# 6159/6159 [==============================] - 135s 22ms/step - loss: 0.1173 - accuracy: 0.9628 - recall: 0.9608 - precision: 0.9653 - f1_score: 0.9630
# Epoch 14/20
# 6159/6159 [==============================] - 134s 22ms/step - loss: 0.1155 - accuracy: 0.9632 - recall: 0.9611 - precision: 0.9657 - f1_score: 0.9634
# Epoch 15/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1161 - accuracy: 0.9630 - recall: 0.9611 - precision: 0.9653 - f1_score: 0.9632
# Epoch 16/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1152 - accuracy: 0.9635 - recall: 0.9615 - precision: 0.9658 - f1_score: 0.9636
# Epoch 17/20
# 6159/6159 [==============================] - 116s 19ms/step - loss: 0.1145 - accuracy: 0.9637 - recall: 0.9617 - precision: 0.9661 - f1_score: 0.9639
# Epoch 18/20
# 6159/6159 [==============================] - 117s 19ms/step - loss: 0.1158 - accuracy: 0.9633 - recall: 0.9614 - precision: 0.9656 - f1_score: 0.9635
# Epoch 19/20
# 6159/6159 [==============================] - 123s 20ms/step - loss: 0.1160 - accuracy: 0.9632 - recall: 0.9615 - precision: 0.9655 - f1_score: 0.9635
# Epoch 20/20
# 6159/6159 [==============================] - 130s 21ms/step - loss: 0.1158 - accuracy: 0.9633 - recall: 0.9614 - precision: 0.9656 - f1_score: 0.9635
# 12317/12317 [==============================] - 77s 6ms/step
# comm_round: 4 | global_loss: 1.0614575147628784 | global_accuracy: 0.9847 | global_recall: 0.9842 | global_precision: 0.9853 | global_f1_score: 0.9848

# %%
global_model.load_weights("FL_DP_Mirai_Final.h5")

# %%
loss, accuracy, precision, recall, f1_score = test_model(x_batch, y_batch, global_model, comm_round)
print("loss : ", loss.numpy())
print("accuracy : ", accuracy)
print("precision : ", precision)
print("recall : ", recall)
print("f1_score : ", f1_score)
# Out:
# 12317/12317 [==============================] - 60s 5ms/step
# comm_round: 4 | global_loss: 1.0615928173065186 | global_accuracy: 0.9857 | global_recall: 0.9852 | global_precision: 0.9864 | global_f1_score: 0.9858
#
# loss :  1.0615928
# accuracy :  0.9857331337375993
# precision :  0.98636603
# recall :  0.98516226
# f1_score :  0.9857637

# %%
for(x_batch, y_batch) in test_batched:
    logits = global_model.predict(x_batch)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_batch, axis=1)
# Out:
# 12317/12317 [==============================] - 58s 5ms/step

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report, precision_score, recall_score
from sklearn.metrics import matthews_corrcoef, roc_auc_score
from sklearn.metrics import f1_score as f1_score_rep
import seaborn as sn
import numpy as np

def print_score(y_pred, y_real, label_encoder):
    accuracy = accuracy_score(y_real, y_pred)
    precision = precision_score(y_real, y_pred, average="weighted")
    recall = recall_score(y_real, y_pred, average="weighted")
    f1 = f1_score_rep(y_real, y_pred, average="weighted")
    auc = roc_auc_score(y_real, logits, multi_class='ovr')

    print("Accuracy: {:.4f}".format(accuracy))
    print("Precision:: {:.4f}".format(precision))
    print("Recall:: {:.4f}".format(recall))
    print("F1_Score:: {:.4f}".format(f1))
    print("AUC:: {:.4f}".format(auc))
    
    print()
    print("Confusion Matrix")
    cm = confusion_matrix(y_real, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cm, index=[str(i) for i in label_encoder.classes_], columns=[str(i) for i in label_encoder.classes_])
    plt.figure(figsize=(10, 7))
    sn.heatmap(df_cm, annot=True)

    print()
    print("Classification Report")
    print(classification_report(y_real, y_pred, target_names=[str(i) for i in label_encoder.classes_]))

# %%
print_score(y_hat, y_true, label_encoder)
# Out:
# Accuracy: 0.9857
# Precision:: 0.9858
# Recall:: 0.9857
# F1_Score:: 0.9857
# AUC:: 0.9996
#
# Confusion Matrix
#
# Classification Report
#                 precision    recall  f1-score   support
#
#         benign       1.00      1.00      1.00     84459
#      mirai_ack       0.98      0.95      0.97     56029
#     mirai_scan       0.99      1.00      1.00     51230
#      mirai_syn       1.00      0.99      1.00     62501
#      mirai_udp       0.97      0.99      0.98    108953
# mirai_udpplain       0.96      0.97      0.96     30958
#
#       accuracy                           0.99    394130
#      macro avg       0.98      0.98      0.98    394130
#   weighted avg       0.99      0.99      0.99    394130

# %%
figure, axis = plt.subplots(3, 2, figsize=(15, 15))
axis[0, 1].plot(global_accuracy)
axis[0, 1].set_title("global accuracy")

axis[1, 0].plot(global_precision)
axis[1, 0].set_title("global precision")

axis[1, 1].plot(global_recall)
axis[1, 1].set_title("global recall")

axis[2, 0].plot(global_f1)
axis[2, 0].set_title("global f1 score")

plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, n_classes):
    lw = 2
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_ohe[:, i], y_hat_ohe[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes
    fpr["weighted"] = all_fpr
    tpr["weighted"] = mean_tpr
    roc_auc["weighted"] = auc(fpr["weighted"], tpr["weighted"])

    #fpr["micro"], tpr["micro"], _ = roc_curve(y_true_ohe.ravel(), y_hat_ohe.ravel())
    #roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    plt.figure(figsize=(8,8))
    plt.plot(
        fpr["weighted"],
        tpr["weighted"],
        label="weighted-average ROC curve (area = {0:0.2f})".format(roc_auc["weighted"]),
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )



    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(label_encoder.classes_[i], roc_auc[i]))

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("multiclass characteristic")
    plt.legend(loc="lower right")
    plt.show()

# %%
y_true_ohe = to_categorical(y_true, num_classes=len(label_encoder.classes_))
y_hat_ohe =  to_categorical(y_hat, num_classes=len(label_encoder.classes_))

# %%
ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, len(label_encoder.classes_))

# %%
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  forward_pass = tf.function(model.call, input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])
  graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
  flops = graph_info.total_float_ops
  return flops

# %%
# Calculate FLOPS
flops = get_flops(global_model)
# Out:
# WARNING:tensorflow:From c:\Users\Lambert\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\nn_ops.py:5253: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.

# %%
print(f"FLOPS: {flops / 10 ** 6:.03} M")
# Out:
# FLOPS: 0.0259 M

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(42)

# %%
#Benign
benign_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.benign.csv')
benign_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.benign.csv')
benign_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.benign.csv')
benign_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.benign.csv')
benign_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.benign.csv')
benign_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.benign.csv')
benign_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.benign.csv')

benign_traffic = pd.concat([benign_1, benign_2, benign_4, benign_5, benign_6, benign_8, benign_9], ignore_index=True)

benign_traffic.shape
# Out:
# (464682, 115)

# %%
#Scan
mirai_scan_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.scan.csv')
mirai_scan_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.scan.csv')
mirai_scan_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.scan.csv')
mirai_scan_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.scan.csv')
mirai_scan_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.scan.csv')
mirai_scan_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.scan.csv')
mirai_scan_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.scan.csv')

mirai_scan_traffic = pd.concat([mirai_scan_1, mirai_scan_2, mirai_scan_4, mirai_scan_5, mirai_scan_6, mirai_scan_8, mirai_scan_9], ignore_index=True)

mirai_scan_traffic.shape
# Out:
# (537979, 115)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')
mirai_syn_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.syn.csv')
mirai_syn_8  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.syn.csv')
mirai_syn_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.syn.csv')


mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5, mirai_syn_6, mirai_syn_8, mirai_syn_9], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (733299, 115)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')
mirai_syn_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.syn.csv')
mirai_syn_8  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.syn.csv')
mirai_syn_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.syn.csv')


mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5, mirai_syn_6, mirai_syn_8, mirai_syn_9], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (733299, 115)

# %%
#Ack
mirai_ack_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.ack.csv')
mirai_ack_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.ack.csv')
mirai_ack_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.ack.csv')
mirai_ack_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.ack.csv')
mirai_ack_6  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.ack.csv')
mirai_ack_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.ack.csv')
mirai_ack_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.ack.csv')

mirai_ack_traffic = pd.concat([mirai_ack_1 , mirai_ack_2, mirai_ack_4, mirai_ack_5, mirai_ack_6, mirai_ack_8, mirai_ack_9], ignore_index=True)

mirai_ack_traffic.shape
# Out:
# (643821, 115)

# %%
#Udp Flooding
mirai_udp_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udp.csv')
mirai_udp_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udp.csv')
mirai_udp_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udp.csv')
mirai_udp_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udp.csv')
mirai_udp_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udp.csv')
mirai_udp_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udp.csv')
mirai_udp_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udp.csv')

mirai_udp_traffic = pd.concat([mirai_udp_1 , mirai_udp_2, mirai_udp_4, mirai_udp_5], ignore_index=True)

mirai_udp_traffic.shape
# Out:
# (762428, 115)

# %%
#Udp plain Flooding
mirai_udpplain_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udpplain.csv')
mirai_udpplain_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udpplain.csv')
mirai_udpplain_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udpplain.csv')
mirai_udpplain_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udpplain.csv')
mirai_udpplain_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udpplain.csv')
mirai_udpplain_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udpplain.csv')
mirai_udpplain_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udpplain.csv')

mirai_udpplain_traffic = pd.concat([mirai_udpplain_1 , mirai_udpplain_2, mirai_udpplain_4, mirai_udpplain_5, mirai_udpplain_6, mirai_udpplain_8, mirai_udpplain_9], ignore_index=True)

mirai_udpplain_traffic.shape
# Out:
# (523304, 115)

# %%
benign_traffic['label'] = 'benign'
mirai_scan_traffic['label'] = 'mirai_scan'
mirai_syn_traffic['label'] = 'mirai_syn'
mirai_ack_traffic['label'] = 'mirai_ack'
mirai_udp_traffic['label'] = 'mirai_udp'
mirai_udpplain_traffic['label'] = 'mirai_udpplain'

mirai_dataset = pd.concat([benign_traffic, mirai_scan_traffic, mirai_syn_traffic,
                mirai_ack_traffic, mirai_udp_traffic, mirai_udpplain_traffic],
                axis=0, sort=False, ignore_index=True)

# %%
selected_features = ['HH_L1_weight', 'HH_jit_L1_weight', 'MI_dir_L0.01_mean',
       'H_L0.1_weight', 'H_L0.1_mean', 'MI_dir_L1_mean', 'H_L1_mean',
       'H_L0.01_variance', 'MI_dir_L0.01_variance', 'H_L5_weight',
       'H_L0.1_variance', 'MI_dir_L0.1_weight', 'MI_dir_L0.1_mean',
       'MI_dir_L5_weight', 'H_L0.01_mean', 'H_L5_mean', 'MI_dir_L0.1_variance',
       'MI_dir_L3_mean', 'MI_dir_L5_mean', 'HH_jit_L5_mean', 'HH_jit_L3_mean',
       'H_L3_mean', 'HH_L3_magnitude', 'MI_dir_L3_weight', 'HpHp_L0.01_weight', 'label']

# %%
selected_mirai_dataset = mirai_dataset[selected_features].copy()

# %%
selected_mirai_dataset.shape
# Out:
# (3665513, 26)

# %%
#Number of Missing Values in the Dataset
selected_mirai_dataset.isnull().sum().sum()
# Out:
# 0

# %%
#Number of Duplicate Rows in the Dataset
selected_mirai_dataset.duplicated().sum()
# Out:
# 1607667

# %%
# Remove duplicate rows from the Dataset
selected_mirai_dataset = selected_mirai_dataset.drop_duplicates()

# Check the number of duplicate rows after removal
selected_mirai_dataset.duplicated().sum()
# Out:
# 0

# %%
# Remove duplicate rows from the Dataset
selected_mirai_dataset = selected_mirai_dataset.drop_duplicates()

# Check the number of duplicate rows after removal
selected_mirai_dataset.duplicated().sum()
# Out:
# 0

# %%
import numpy as np

# Select columns for z-score calculation (excluding the last column)
column_features = selected_mirai_dataset.iloc[:, :-1]

# Calculate z-scores for each column
z_scores = (column_features - column_features.mean()) / column_features.std()

# Set a threshold for z-score beyond which a data point is considered an outlier
z_score_threshold = 3  # Adjust this threshold as needed

# Identify rows where any z-score exceeds the threshold
outlier_mask = (np.abs(z_scores) > z_score_threshold).any(axis=1)

# Remove outliers from the dataset
selected_mirai_dataset = selected_mirai_dataset[~outlier_mask]

# %%
selected_mirai_dataset.shape
# Out:
# (1970649, 26)

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the columns to be normalized (excluding the 'label' column)
column_to_normalize = selected_mirai_dataset.columns[selected_mirai_dataset.columns != 'label']


# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
selected_mirai_dataset[column_to_normalize] = scaler.fit_transform(selected_mirai_dataset[column_to_normalize])

# %%
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000       2.636780e-16       0.000000
# 1      0.000039          0.000039       5.547170e-01       0.000179
# 2      0.001219          0.001219       5.660395e-01       0.000289
# 3      0.000000          0.000000       5.226415e-01       0.000000
# 4      0.000000          0.000000       2.612201e-01       0.000111
#
#     H_L0.1_mean  MI_dir_L1_mean     H_L1_mean  H_L0.01_variance  \
# 0  4.163336e-17    1.249001e-16  1.249001e-16          0.000000
# 1  5.408092e-01    4.823113e-01  4.817053e-01          0.000193
# 2  5.509964e-01    4.923052e-01  4.918483e-01          0.000712
# 3  5.226581e-01    4.544225e-01  4.544225e-01          0.000000
# 4  2.603220e-01    2.184604e-01  2.184604e-01          0.167279
#
#    MI_dir_L0.01_variance   H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.000000  0.000000e+00  ...              0.000000
# 1               0.000000  1.174383e-10  ...              0.000000
# 2               0.000314  3.148369e-03  ...              0.000311
# 3               0.000000  0.000000e+00  ...              0.000000
# 4               0.167279  2.496382e-03  ...              0.165695
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  \
# 0    1.249001e-16    1.110223e-16    9.813673e-01    9.813673e-01
# 1    4.510277e-01    4.226888e-01    3.245507e-09    3.245505e-09
# 2    4.606554e-01    4.319749e-01    1.513729e-09    1.562845e-09
# 3    4.249479e-01    3.982476e-01    9.813673e-01    9.813673e-01
# 4    1.880207e-01    1.612269e-01    9.813673e-01    9.813673e-01
#
#       H_L3_mean  HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight   label
# 0  1.249001e-16         0.000000          0.000000           0.000000  benign
# 1  4.510271e-01         0.331530          0.000000           0.000291  benign
# 2  4.606549e-01         0.338607          0.002146           0.000359  benign
# 3  4.249479e-01         0.312360          0.000000           0.000000  benign
# 4  1.880207e-01         0.477094          0.001867           0.000000  benign
#
# [5 rows x 26 columns]

# %%
selected_mirai_dataset = selected_mirai_dataset.sample(frac=1).reset_index(drop=True)
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000           0.521544       0.505705
# 1      0.000108          0.000108           0.185116       0.001147
# 2      0.001207          0.001207           0.020756       0.001147
# 3      0.365574          0.365574           0.523108       0.516265
# 4      0.000000          0.000000           0.017738       0.744389
#
#    H_L0.1_mean  MI_dir_L1_mean  H_L1_mean  H_L0.01_variance  \
# 0     0.522337        0.444576   0.444576          0.524454
# 1     0.118109        0.018681   0.018681          0.421878
# 2     0.023412        0.014130   0.014130          0.003344
# 3     0.525792        0.477173   0.477173          0.524025
# 4     0.017960        0.016922   0.016922          0.000378
#
#    MI_dir_L0.01_variance  H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.524454     0.457333  ...              0.519279
# 1               0.421878     0.000004  ...              0.242123
# 2               0.003344     0.003073  ...              0.003812
# 3               0.524025     0.323968  ...              0.518312
# 4               0.000378     0.378821  ...              0.000369
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  H_L3_mean  \
# 0        0.372336        0.294594    9.826693e-01    9.826693e-01   0.372336
# 1        0.021151        0.020109    2.614423e-09    2.614027e-09   0.021151
# 2        0.010392        0.008908    1.420423e-09    1.504356e-09   0.010392
# 3        0.497183        0.525856    2.188626e-12    2.208649e-12   0.497183
# 4        0.017771        0.017381    9.826679e-01    9.826679e-01   0.017771
#
#    HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight           label
# 0         0.000000          0.436825           0.000000  mirai_udpplain
# 1         0.050352          0.000037           0.000195          benign
# 2         0.070288          0.002636           0.001276          benign
# 3         0.557061          0.375316           0.405565  mirai_udpplain
# 4         0.000000          0.431810           0.000000       mirai_syn
#
# [5 rows x 26 columns]

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# Calculate percentage values
class_counts = selected_mirai_dataset['label'].value_counts(normalize=True) * 100

plt.title("Class Distribution")
bar_plot = selected_mirai_dataset['label'].value_counts().plot(kind='bar')
plt.xlabel('Classes')
plt.ylabel('Frequency')

# Annotate each bar with its percentage value
for i, val in enumerate(class_counts):
    plt.text(i, selected_mirai_dataset['label'].value_counts()[i], f'{val:.2f}%', ha='center')

plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(selected_mirai_dataset['label'].value_counts())
# Out:
# mirai_udp         544764
# benign            422293
# mirai_syn         312508
# mirai_ack         280144
# mirai_scan        256151
# mirai_udpplain    154789
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(selected_mirai_dataset, test_size=0.2, random_state=42, stratify=selected_mirai_dataset["label"])

# %%
features = list(train_df.columns)
features.remove("label")

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_df["label"] = label_encoder.fit_transform(train_df["label"])
test_df["label"] = label_encoder.transform(test_df["label"])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=18)
X_train = train_df[features].values
X_train = pca.fit_transform(X_train)
y_train = train_df["label"].values

X_test = test_df[features].values
X_test = pca.fit_transform(X_test)
y_test = test_df["label"].values

# %%
import statsmodels.api as sm
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from tabulate import tabulate

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train)

class_weights = {k: v for k,v in enumerate(class_weights)}
class_weights
# Out:
# {0: 0.7777582086665837,
#  1: 1.1724033048509321,
#  2: 1.282216886832812,
#  3: 1.0509832391359708,
#  4: 0.6029062292293372,
#  5: 2.1218690527143176}

# %%
input_shape = X_train.shape[1:]
nb_classes = len(label_encoder.classes_)

# %%
input_shape
# Out:
# (18,)

# %%
from tensorflow.keras.utils import to_categorical

def convert_to_categorical(y, nb_classes):
    return to_categorical(y, num_classes=nb_classes)

# %%
import random

def data_indices(labels: np.ndarray, nb_clients: int):
    data_len = len(labels)
    indices = np.arange(data_len)
    np.random.shuffle(indices)
    chunk_size = data_len // nb_clients
    chunks = [indices[i:i+chunk_size] for i in range(0, data_len, chunk_size)]

    # Ensure non-IID distribution by shuffling 2 of the 4 chunks
    chunks[-1] = np.random.permutation(chunks[-1])
    chunks[-3] = np.random.permutation(chunks[-3])
    

    return chunks

# %%
def sample(y:np.ndarray, nb_clients: int):
    sampler_fn = data_indices
    client_data_indices = sampler_fn(y, nb_clients)
    return client_data_indices

# %%
def assign_data_to_clients(clients: dict, X:np.ndarray, y:np.ndarray, nb_classes:int):
    sampled_data_indices = sample(y, len(clients.keys()))  # Use the sample function to get data indices
    for client_name, data_indices in zip(clients.keys(), sampled_data_indices):
        X = X_train[data_indices]  # Subset the features for the current client
        y = y_train[data_indices]  # Subset the labels for the current client
        y = convert_to_categorical(y, nb_classes)  # Convert labels to categorical format if needed
        clients[client_name] = list(zip(X, y))  # Assign data to the current client
    return clients

# %%
def create_clients(X, y, nb_classes, num_clients=4, initial='clients'):
    # Create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]
    clients = {client_names[i] : [] for i in range(len(client_names))}
    return assign_data_to_clients(clients, X, y, nb_classes)

# %%
def batch_data(data_shard, batch_size=64):
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    del data_shard

    len_label = len(label)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    del data, label
    return dataset.shuffle(len_label).batch(batch_size)

# %%
import keras.backend as K
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import keras
import os
from keras.models import Model
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Activation, BatchNormalization, GRU, Dense, Dropout, Input

def get_model(input_shape, nb_classes):
    inputs = Input(shape=input_shape)
    
    x = Dense(32, activation="relu")(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = Dropout(0.2)(x)
    outputs = Dense(nb_classes, activation="softmax")(x)
    
    return keras.Model(inputs, outputs)

# %%
import tensorflow_privacy
from tensorflow_privacy.privacy.optimizers import dp_optimizer_keras  
from keras.metrics import Recall, Precision
from tensorflow.keras.utils import plot_model

learning_rate = 1e-3
comms_round = 5
loss='categorical_crossentropy'
metrics = ["accuracy", Recall(), Precision(), f1_score]
#optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
optimizer = tensorflow_privacy.DPKerasAdamOptimizer(l2_norm_clip= 1.6, noise_multiplier= 0.1, num_microbatches=1, learning_rate= learning_rate)


#initialize global model
global_model = get_model(input_shape, nb_classes)

global_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18)]              0
#
#  dense (Dense)               (None, 32)                608
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  batch_normalization_2 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 4358 (17.02 KB)
# Trainable params: 4166 (16.27 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
BATCH_SIZE = 64

# create clients
clients_batched = create_clients(X_train, y_train, nb_classes, num_clients=4, initial='client')

del X_train, y_train

# process and batch the training data for each client
client_set = {k: {} for k in clients_batched.keys()}

for (client_name, data) in clients_batched.items():
    client_set[client_name]["dataset"] = batch_data(data, BATCH_SIZE)
    local_model = get_model(input_shape, nb_classes)
    local_model.compile(loss=loss,
                      optimizer=optimizer,
                      metrics=metrics)
    client_set[client_name]["model"] = local_model

# %%
#process and batch the test set

y_test = convert_to_categorical(y_test, nb_classes)

test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

del X_test, y_test

# %%
# Define a function to calculate the weight scaling factor
def weight_scalling_factor(clients, client_name):
    client_names = list(clients.keys())
    # Get the batch size
    bs = list(clients[client_name]["dataset"])[0][0].shape[0]
    # Calculate the total training data points across clients
    global_count = sum([tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() for client_name in client_names]) * bs
    # Calculate the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() * bs
    return local_count / global_count

# %%
# Define a function to scale model weights
def scale_model_weights(weight, scalar):
    '''function for scaling a model's weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final

# %%
def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights --> FedAvg'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)

    return avg_grad

# %%
from sklearn.metrics import accuracy_score

def test_model(X_test, y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(y_test, logits)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(np.argmax(y_test, axis=1), np.argmax(logits, axis=1))

    r = Recall()
    r.update_state(y_test, logits)
    recall = r.result().numpy()

    p = Precision()
    p.update_state(y_test, logits)
    precision = p.result().numpy()

    f = f1_score(y_test, logits)
    f1 = f.numpy()

    print('comm_round: {} | global_loss: {} | global_accuracy: {:.4} | global_recall: {:.4} | global_precision: {:.4} | global_f1_score: {:.4} \n'.format(comm_round, loss, accuracy, recall, precision, f1))
    return loss, accuracy, precision, recall, f1

# %%
def train_client(client, global_weights):
    client_set[client]["model"] = client_set[client]["model"]

    #set local model weight to the weight of the global model
    client_set[client]["model"].set_weights(global_weights)

    #fit local model with client's data
    print(f"Round: {comm_round} | Client: {client} training")
    client_set[client]["model"].fit(client_set[client]["dataset"], epochs=20, verbose=1)

    #scale the model weights and add to list
    scaling_factor = weight_scalling_factor(client_set, client)
    scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
    return scaled_weights

# %%
import random

#commence global training loop
global_loss=[]
global_accuracy=[]
global_precision=[]
global_recall=[]
global_f1=[]
best_global_accuracy = 0

for comm_round in range(comms_round):
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()

    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(client_set.keys())
    random.shuffle(client_names)

    #loop through each client and create new local model
    for client in client_names:
        scaled_weights = train_client(client, global_weights)

        scaled_local_weight_list.append(scaled_weights)

    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)

    #update global model
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    g_accuracy = 0
    for(x_batch, y_batch) in test_batched:
        g_loss, g_accuracy, g_precision, g_recall, g_f1 = test_model(x_batch, y_batch, global_model, comm_round)
        global_loss.append(g_loss)
        global_accuracy.append(g_accuracy)
        global_precision.append(g_precision)
        global_recall.append(g_recall)
        global_f1.append(g_f1)

    if g_accuracy > best_global_accuracy:
        best_global_accuracy = g_accuracy
        global_model.save_weights('FL_DP_0_1.h5')
        print("New Weights Saved")
# Out:
# Round: 0 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 67s 5ms/step - loss: 0.5223 - accuracy: 0.7708 - recall: 0.7032 - precision: 0.8299 - f1_score: 0.7559
# Epoch 2/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.4017 - accuracy: 0.8044 - recall: 0.7662 - precision: 0.8410 - f1_score: 0.8015
# Epoch 3/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.3867 - accuracy: 0.8099 - recall: 0.7750 - precision: 0.8440 - f1_score: 0.8078
# Epoch 4/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2954 - accuracy: 0.8717 - recall: 0.8426 - precision: 0.9046 - f1_score: 0.8721
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2076 - accuracy: 0.9206 - recall: 0.9019 - precision: 0.9412 - f1_score: 0.9210
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1751 - accuracy: 0.9373 - recall: 0.9270 - precision: 0.9482 - f1_score: 0.9374
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1627 - accuracy: 0.9445 - recall: 0.9372 - precision: 0.9521 - f1_score: 0.9445
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1544 - accuracy: 0.9496 - recall: 0.9446 - precision: 0.9550 - f1_score: 0.9497
# Epoch 9/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.1414 - accuracy: 0.9549 - recall: 0.9506 - precision: 0.9593 - f1_score: 0.9549
# Epoch 10/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1385 - accuracy: 0.9563 - recall: 0.9522 - precision: 0.9609 - f1_score: 0.9565
# Epoch 11/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1357 - accuracy: 0.9570 - recall: 0.9534 - precision: 0.9610 - f1_score: 0.9572
# Epoch 12/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1326 - accuracy: 0.9581 - recall: 0.9546 - precision: 0.9622 - f1_score: 0.9584
# Epoch 13/20
# 6159/6159 [==============================] - 35s 5ms/step - loss: 0.1310 - accuracy: 0.9588 - recall: 0.9554 - precision: 0.9627 - f1_score: 0.9590
# Epoch 14/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.1326 - accuracy: 0.9582 - recall: 0.9546 - precision: 0.9622 - f1_score: 0.9584
# Epoch 15/20
# 6159/6159 [==============================] - 35s 5ms/step - loss: 0.1303 - accuracy: 0.9592 - recall: 0.9561 - precision: 0.9626 - f1_score: 0.9593
# Epoch 16/20
# 6159/6159 [==============================] - 35s 5ms/step - loss: 0.1283 - accuracy: 0.9599 - recall: 0.9567 - precision: 0.9637 - f1_score: 0.9601
# Epoch 17/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1250 - accuracy: 0.9607 - recall: 0.9574 - precision: 0.9645 - f1_score: 0.9609
# Epoch 18/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1220 - accuracy: 0.9621 - recall: 0.9593 - precision: 0.9654 - f1_score: 0.9623
# Epoch 19/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1234 - accuracy: 0.9624 - recall: 0.9600 - precision: 0.9651 - f1_score: 0.9625
# Epoch 20/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1183 - accuracy: 0.9641 - recall: 0.9614 - precision: 0.9669 - f1_score: 0.9641
# Round: 0 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 41s 5ms/step - loss: 0.4719 - accuracy: 0.7856 - recall: 0.8476 - precision: 0.9018 - f1_score: 0.7764
# Epoch 2/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4005 - accuracy: 0.8042 - recall: 0.7671 - precision: 0.8409 - f1_score: 0.8020
# Epoch 3/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.3893 - accuracy: 0.8087 - recall: 0.7755 - precision: 0.8417 - f1_score: 0.8069
# Epoch 4/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.3793 - accuracy: 0.8107 - recall: 0.7766 - precision: 0.8451 - f1_score: 0.8091
# Epoch 5/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.3620 - accuracy: 0.8250 - recall: 0.7862 - precision: 0.8623 - f1_score: 0.8222
# Epoch 6/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2306 - accuracy: 0.9091 - recall: 0.8875 - precision: 0.9331 - f1_score: 0.9094
# Epoch 7/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.1785 - accuracy: 0.9338 - recall: 0.9234 - precision: 0.9452 - f1_score: 0.9341
# Epoch 8/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.1601 - accuracy: 0.9449 - recall: 0.9382 - precision: 0.9519 - f1_score: 0.9450
# Epoch 9/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.1479 - accuracy: 0.9514 - recall: 0.9458 - precision: 0.9572 - f1_score: 0.9514
# Epoch 10/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1433 - accuracy: 0.9532 - recall: 0.9482 - precision: 0.9585 - f1_score: 0.9533
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1369 - accuracy: 0.9557 - recall: 0.9515 - precision: 0.9601 - f1_score: 0.9557
# Epoch 12/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.1354 - accuracy: 0.9573 - recall: 0.9536 - precision: 0.9612 - f1_score: 0.9574
# Epoch 13/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1303 - accuracy: 0.9595 - recall: 0.9561 - precision: 0.9630 - f1_score: 0.9595
# Epoch 14/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.1293 - accuracy: 0.9600 - recall: 0.9566 - precision: 0.9637 - f1_score: 0.9601
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1212 - accuracy: 0.9624 - recall: 0.9593 - precision: 0.9656 - f1_score: 0.9624
# Epoch 16/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1233 - accuracy: 0.9632 - recall: 0.9606 - precision: 0.9662 - f1_score: 0.9633
# Epoch 17/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1210 - accuracy: 0.9644 - recall: 0.9621 - precision: 0.9669 - f1_score: 0.9644
# Epoch 18/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1204 - accuracy: 0.9649 - recall: 0.9625 - precision: 0.9676 - f1_score: 0.9650
# Epoch 19/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1222 - accuracy: 0.9645 - recall: 0.9622 - precision: 0.9670 - f1_score: 0.9646
# Epoch 20/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1219 - accuracy: 0.9651 - recall: 0.9631 - precision: 0.9676 - f1_score: 0.9653
# Round: 0 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 49s 6ms/step - loss: 0.4719 - accuracy: 0.7848 - recall: 0.8469 - precision: 0.9034 - f1_score: 0.7757
# Epoch 2/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4027 - accuracy: 0.8029 - recall: 0.7646 - precision: 0.8398 - f1_score: 0.8001
# Epoch 3/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.3903 - accuracy: 0.8073 - recall: 0.7731 - precision: 0.8409 - f1_score: 0.8053
# Epoch 4/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.3831 - accuracy: 0.8088 - recall: 0.7754 - precision: 0.8429 - f1_score: 0.8074
# Epoch 5/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.3760 - accuracy: 0.8143 - recall: 0.7788 - precision: 0.8482 - f1_score: 0.8117
# Epoch 6/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.3007 - accuracy: 0.8733 - recall: 0.8452 - precision: 0.9032 - f1_score: 0.8729
# Epoch 7/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2078 - accuracy: 0.9232 - recall: 0.9062 - precision: 0.9414 - f1_score: 0.9234
# Epoch 8/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1805 - accuracy: 0.9347 - recall: 0.9233 - precision: 0.9472 - f1_score: 0.9350
# Epoch 9/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1661 - accuracy: 0.9413 - recall: 0.9324 - precision: 0.9505 - f1_score: 0.9413
# Epoch 10/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1613 - accuracy: 0.9445 - recall: 0.9362 - precision: 0.9529 - f1_score: 0.9444
# Epoch 11/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1557 - accuracy: 0.9461 - recall: 0.9394 - precision: 0.9533 - f1_score: 0.9463
# Epoch 12/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1569 - accuracy: 0.9460 - recall: 0.9399 - precision: 0.9528 - f1_score: 0.9462
# Epoch 13/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1506 - accuracy: 0.9491 - recall: 0.9443 - precision: 0.9544 - f1_score: 0.9492
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1518 - accuracy: 0.9491 - recall: 0.9444 - precision: 0.9543 - f1_score: 0.9493
# Epoch 15/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1454 - accuracy: 0.9523 - recall: 0.9478 - precision: 0.9569 - f1_score: 0.9523
# Epoch 16/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1417 - accuracy: 0.9538 - recall: 0.9500 - precision: 0.9580 - f1_score: 0.9539
# Epoch 17/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.1402 - accuracy: 0.9542 - recall: 0.9505 - precision: 0.9583 - f1_score: 0.9544
# Epoch 18/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1414 - accuracy: 0.9540 - recall: 0.9506 - precision: 0.9578 - f1_score: 0.9541
# Epoch 19/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1440 - accuracy: 0.9532 - recall: 0.9502 - precision: 0.9565 - f1_score: 0.9533
# Epoch 20/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1374 - accuracy: 0.9555 - recall: 0.9522 - precision: 0.9591 - f1_score: 0.9556
# Round: 0 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 35s 5ms/step - loss: 0.4737 - accuracy: 0.7850 - recall: 0.8418 - precision: 0.8981 - f1_score: 0.7755
# Epoch 2/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4030 - accuracy: 0.8037 - recall: 0.7663 - precision: 0.8398 - f1_score: 0.8010
# Epoch 3/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.3899 - accuracy: 0.8087 - recall: 0.7767 - precision: 0.8396 - f1_score: 0.8067
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3813 - accuracy: 0.8113 - recall: 0.7797 - precision: 0.8427 - f1_score: 0.8097
# Epoch 5/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.3657 - accuracy: 0.8212 - recall: 0.7877 - precision: 0.8527 - f1_score: 0.8187
# Epoch 6/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2580 - accuracy: 0.8981 - recall: 0.8747 - precision: 0.9232 - f1_score: 0.8980
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1962 - accuracy: 0.9279 - recall: 0.9143 - precision: 0.9432 - f1_score: 0.9284
# Epoch 8/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.1770 - accuracy: 0.9363 - recall: 0.9267 - precision: 0.9466 - f1_score: 0.9364
# Epoch 9/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.1650 - accuracy: 0.9409 - recall: 0.9330 - precision: 0.9493 - f1_score: 0.9410
# Epoch 10/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.1601 - accuracy: 0.9433 - recall: 0.9360 - precision: 0.9510 - f1_score: 0.9433
# Epoch 11/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1525 - accuracy: 0.9454 - recall: 0.9400 - precision: 0.9513 - f1_score: 0.9456
# Epoch 12/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.1581 - accuracy: 0.9449 - recall: 0.9398 - precision: 0.9508 - f1_score: 0.9452
# Epoch 13/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.1517 - accuracy: 0.9470 - recall: 0.9426 - precision: 0.9518 - f1_score: 0.9471
# Epoch 14/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.1509 - accuracy: 0.9474 - recall: 0.9432 - precision: 0.9522 - f1_score: 0.9476
# Epoch 15/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1490 - accuracy: 0.9481 - recall: 0.9437 - precision: 0.9532 - f1_score: 0.9484
# Epoch 16/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1458 - accuracy: 0.9492 - recall: 0.9453 - precision: 0.9538 - f1_score: 0.9494
# Epoch 17/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1453 - accuracy: 0.9506 - recall: 0.9465 - precision: 0.9551 - f1_score: 0.9507
# Epoch 18/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1435 - accuracy: 0.9511 - recall: 0.9476 - precision: 0.9551 - f1_score: 0.9513
# Epoch 19/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1470 - accuracy: 0.9507 - recall: 0.9477 - precision: 0.9541 - f1_score: 0.9508
# Epoch 20/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1434 - accuracy: 0.9519 - recall: 0.9486 - precision: 0.9556 - f1_score: 0.9521
# 12317/12317 [==============================] - 30s 2ms/step
# comm_round: 0 | global_loss: 1.7202309370040894 | global_accuracy: 0.2764 | global_recall: 0.1764 | global_precision: 0.6495 | global_f1_score: 0.2774
#
# New Weights Saved
# Round: 1 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2463 - accuracy: 0.9150 - recall: 0.8951 - precision: 0.9314 - f1_score: 0.9120
# Epoch 2/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1747 - accuracy: 0.9411 - recall: 0.9342 - precision: 0.9475 - f1_score: 0.9407
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1678 - accuracy: 0.9444 - recall: 0.9383 - precision: 0.9506 - f1_score: 0.9443
# Epoch 4/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1597 - accuracy: 0.9471 - recall: 0.9413 - precision: 0.9525 - f1_score: 0.9469
# Epoch 5/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.1441 - accuracy: 0.9526 - recall: 0.9483 - precision: 0.9572 - f1_score: 0.9527
# Epoch 6/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1307 - accuracy: 0.9572 - recall: 0.9538 - precision: 0.9604 - f1_score: 0.9571
# Epoch 7/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1259 - accuracy: 0.9593 - recall: 0.9563 - precision: 0.9623 - f1_score: 0.9593
# Epoch 8/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1213 - accuracy: 0.9623 - recall: 0.9598 - precision: 0.9649 - f1_score: 0.9623
# Epoch 9/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1209 - accuracy: 0.9626 - recall: 0.9602 - precision: 0.9651 - f1_score: 0.9626
# Epoch 10/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1178 - accuracy: 0.9633 - recall: 0.9607 - precision: 0.9661 - f1_score: 0.9634
# Epoch 11/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1207 - accuracy: 0.9630 - recall: 0.9603 - precision: 0.9660 - f1_score: 0.9631
# Epoch 12/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1173 - accuracy: 0.9646 - recall: 0.9623 - precision: 0.9670 - f1_score: 0.9646
# Epoch 13/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1166 - accuracy: 0.9648 - recall: 0.9626 - precision: 0.9673 - f1_score: 0.9649
# Epoch 14/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.1179 - accuracy: 0.9655 - recall: 0.9634 - precision: 0.9678 - f1_score: 0.9656
# Epoch 15/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1148 - accuracy: 0.9658 - recall: 0.9635 - precision: 0.9684 - f1_score: 0.9659
# Epoch 16/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.1112 - accuracy: 0.9669 - recall: 0.9646 - precision: 0.9692 - f1_score: 0.9669
# Epoch 17/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.1083 - accuracy: 0.9682 - recall: 0.9661 - precision: 0.9704 - f1_score: 0.9683
# Epoch 18/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1068 - accuracy: 0.9687 - recall: 0.9671 - precision: 0.9708 - f1_score: 0.9689
# Epoch 19/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1046 - accuracy: 0.9696 - recall: 0.9678 - precision: 0.9716 - f1_score: 0.9697
# Epoch 20/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1067 - accuracy: 0.9703 - recall: 0.9687 - precision: 0.9720 - f1_score: 0.9703
# Round: 1 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2477 - accuracy: 0.9141 - recall: 0.8947 - precision: 0.9308 - f1_score: 0.9114
# Epoch 2/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1517 - accuracy: 0.9512 - recall: 0.9455 - precision: 0.9566 - f1_score: 0.9509
# Epoch 3/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1505 - accuracy: 0.9522 - recall: 0.9472 - precision: 0.9573 - f1_score: 0.9522
# Epoch 4/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1504 - accuracy: 0.9518 - recall: 0.9467 - precision: 0.9572 - f1_score: 0.9518
# Epoch 5/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.1437 - accuracy: 0.9539 - recall: 0.9494 - precision: 0.9585 - f1_score: 0.9539
# Epoch 6/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.1439 - accuracy: 0.9544 - recall: 0.9510 - precision: 0.9581 - f1_score: 0.9545
# Epoch 7/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.1414 - accuracy: 0.9549 - recall: 0.9514 - precision: 0.9586 - f1_score: 0.9549
# Epoch 8/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1321 - accuracy: 0.9590 - recall: 0.9557 - precision: 0.9623 - f1_score: 0.9590
# Epoch 9/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1327 - accuracy: 0.9591 - recall: 0.9559 - precision: 0.9625 - f1_score: 0.9591
# Epoch 10/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1292 - accuracy: 0.9600 - recall: 0.9564 - precision: 0.9636 - f1_score: 0.9600
# Epoch 11/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.1323 - accuracy: 0.9590 - recall: 0.9555 - precision: 0.9627 - f1_score: 0.9591
# Epoch 12/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1282 - accuracy: 0.9605 - recall: 0.9577 - precision: 0.9638 - f1_score: 0.9607
# Epoch 13/20
# 6159/6159 [==============================] - 41s 7ms/step - loss: 0.1255 - accuracy: 0.9610 - recall: 0.9580 - precision: 0.9642 - f1_score: 0.9611
# Epoch 14/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.1230 - accuracy: 0.9622 - recall: 0.9594 - precision: 0.9651 - f1_score: 0.9622
# Epoch 15/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1213 - accuracy: 0.9625 - recall: 0.9596 - precision: 0.9656 - f1_score: 0.9625
# Epoch 16/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1179 - accuracy: 0.9635 - recall: 0.9606 - precision: 0.9664 - f1_score: 0.9635
# Epoch 17/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1161 - accuracy: 0.9652 - recall: 0.9626 - precision: 0.9678 - f1_score: 0.9652
# Epoch 18/20
# 6159/6159 [==============================] - 41s 7ms/step - loss: 0.1140 - accuracy: 0.9653 - recall: 0.9629 - precision: 0.9679 - f1_score: 0.9654
# Epoch 19/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1150 - accuracy: 0.9656 - recall: 0.9633 - precision: 0.9679 - f1_score: 0.9656
# Epoch 20/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1157 - accuracy: 0.9666 - recall: 0.9645 - precision: 0.9689 - f1_score: 0.9667
# Round: 1 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2692 - accuracy: 0.9013 - recall: 0.8813 - precision: 0.9182 - f1_score: 0.8982
# Epoch 2/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1580 - accuracy: 0.9470 - recall: 0.9408 - precision: 0.9527 - f1_score: 0.9467
# Epoch 3/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1459 - accuracy: 0.9529 - recall: 0.9481 - precision: 0.9576 - f1_score: 0.9528
# Epoch 4/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.1425 - accuracy: 0.9537 - recall: 0.9492 - precision: 0.9584 - f1_score: 0.9537
# Epoch 5/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1350 - accuracy: 0.9566 - recall: 0.9526 - precision: 0.9604 - f1_score: 0.9565
# Epoch 6/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1276 - accuracy: 0.9586 - recall: 0.9557 - precision: 0.9618 - f1_score: 0.9587
# Epoch 7/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1237 - accuracy: 0.9607 - recall: 0.9580 - precision: 0.9636 - f1_score: 0.9607
# Epoch 8/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1199 - accuracy: 0.9631 - recall: 0.9606 - precision: 0.9656 - f1_score: 0.9631
# Epoch 9/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1215 - accuracy: 0.9631 - recall: 0.9606 - precision: 0.9656 - f1_score: 0.9630
# Epoch 10/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1158 - accuracy: 0.9649 - recall: 0.9622 - precision: 0.9679 - f1_score: 0.9650
# Epoch 11/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1214 - accuracy: 0.9630 - recall: 0.9605 - precision: 0.9659 - f1_score: 0.9631
# Epoch 12/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.1205 - accuracy: 0.9638 - recall: 0.9615 - precision: 0.9664 - f1_score: 0.9639
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1197 - accuracy: 0.9636 - recall: 0.9613 - precision: 0.9661 - f1_score: 0.9637
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1194 - accuracy: 0.9648 - recall: 0.9627 - precision: 0.9673 - f1_score: 0.9650
# Epoch 15/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1148 - accuracy: 0.9651 - recall: 0.9627 - precision: 0.9676 - f1_score: 0.9651
# Epoch 16/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1117 - accuracy: 0.9661 - recall: 0.9639 - precision: 0.9686 - f1_score: 0.9662
# Epoch 17/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1097 - accuracy: 0.9669 - recall: 0.9649 - precision: 0.9692 - f1_score: 0.9670
# Epoch 18/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1083 - accuracy: 0.9675 - recall: 0.9656 - precision: 0.9697 - f1_score: 0.9676
# Epoch 19/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1080 - accuracy: 0.9679 - recall: 0.9661 - precision: 0.9700 - f1_score: 0.9680
# Epoch 20/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1110 - accuracy: 0.9683 - recall: 0.9665 - precision: 0.9701 - f1_score: 0.9683
# Round: 1 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2909 - accuracy: 0.8916 - recall: 0.8702 - precision: 0.9086 - f1_score: 0.8879
# Epoch 2/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1458 - accuracy: 0.9517 - recall: 0.9460 - precision: 0.9570 - f1_score: 0.9514
# Epoch 3/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1366 - accuracy: 0.9566 - recall: 0.9522 - precision: 0.9608 - f1_score: 0.9565
# Epoch 4/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1370 - accuracy: 0.9563 - recall: 0.9522 - precision: 0.9606 - f1_score: 0.9563
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1290 - accuracy: 0.9587 - recall: 0.9552 - precision: 0.9622 - f1_score: 0.9587
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1271 - accuracy: 0.9595 - recall: 0.9568 - precision: 0.9624 - f1_score: 0.9596
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1264 - accuracy: 0.9610 - recall: 0.9583 - precision: 0.9637 - f1_score: 0.9610
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1234 - accuracy: 0.9631 - recall: 0.9606 - precision: 0.9655 - f1_score: 0.9630
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1213 - accuracy: 0.9634 - recall: 0.9610 - precision: 0.9660 - f1_score: 0.9635
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1188 - accuracy: 0.9645 - recall: 0.9619 - precision: 0.9674 - f1_score: 0.9646
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1216 - accuracy: 0.9635 - recall: 0.9608 - precision: 0.9664 - f1_score: 0.9636
# Epoch 12/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1196 - accuracy: 0.9645 - recall: 0.9622 - precision: 0.9669 - f1_score: 0.9645
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1188 - accuracy: 0.9641 - recall: 0.9617 - precision: 0.9669 - f1_score: 0.9642
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1185 - accuracy: 0.9653 - recall: 0.9633 - precision: 0.9677 - f1_score: 0.9655
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1184 - accuracy: 0.9647 - recall: 0.9623 - precision: 0.9673 - f1_score: 0.9648
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1118 - accuracy: 0.9658 - recall: 0.9636 - precision: 0.9683 - f1_score: 0.9659
# Epoch 17/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1124 - accuracy: 0.9667 - recall: 0.9646 - precision: 0.9690 - f1_score: 0.9668
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1101 - accuracy: 0.9669 - recall: 0.9650 - precision: 0.9690 - f1_score: 0.9670
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1094 - accuracy: 0.9677 - recall: 0.9659 - precision: 0.9697 - f1_score: 0.9678
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1124 - accuracy: 0.9685 - recall: 0.9666 - precision: 0.9704 - f1_score: 0.9685
# 12317/12317 [==============================] - 24s 2ms/step
# comm_round: 1 | global_loss: 1.0518029928207397 | global_accuracy: 0.9936 | global_recall: 0.9936 | global_precision: 0.9936 | global_f1_score: 0.9936
#
# New Weights Saved
# Round: 2 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1044 - accuracy: 0.9702 - recall: 0.9685 - precision: 0.9720 - f1_score: 0.9702
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1022 - accuracy: 0.9705 - recall: 0.9690 - precision: 0.9723 - f1_score: 0.9706
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1029 - accuracy: 0.9705 - recall: 0.9689 - precision: 0.9723 - f1_score: 0.9706
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1013 - accuracy: 0.9709 - recall: 0.9691 - precision: 0.9729 - f1_score: 0.9710
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0997 - accuracy: 0.9718 - recall: 0.9701 - precision: 0.9736 - f1_score: 0.9718
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1001 - accuracy: 0.9722 - recall: 0.9703 - precision: 0.9742 - f1_score: 0.9722
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1030 - accuracy: 0.9718 - recall: 0.9699 - precision: 0.9737 - f1_score: 0.9718
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1045 - accuracy: 0.9716 - recall: 0.9699 - precision: 0.9733 - f1_score: 0.9716
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1056 - accuracy: 0.9706 - recall: 0.9690 - precision: 0.9725 - f1_score: 0.9707
# Epoch 10/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1033 - accuracy: 0.9718 - recall: 0.9703 - precision: 0.9735 - f1_score: 0.9718
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1083 - accuracy: 0.9704 - recall: 0.9689 - precision: 0.9721 - f1_score: 0.9705
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1034 - accuracy: 0.9714 - recall: 0.9699 - precision: 0.9730 - f1_score: 0.9714
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1019 - accuracy: 0.9715 - recall: 0.9700 - precision: 0.9730 - f1_score: 0.9715
# Epoch 14/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1010 - accuracy: 0.9723 - recall: 0.9711 - precision: 0.9738 - f1_score: 0.9725
# Epoch 15/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1037 - accuracy: 0.9718 - recall: 0.9704 - precision: 0.9735 - f1_score: 0.9719
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0992 - accuracy: 0.9719 - recall: 0.9703 - precision: 0.9738 - f1_score: 0.9720
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0966 - accuracy: 0.9726 - recall: 0.9711 - precision: 0.9745 - f1_score: 0.9727
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0972 - accuracy: 0.9727 - recall: 0.9712 - precision: 0.9743 - f1_score: 0.9727
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0966 - accuracy: 0.9730 - recall: 0.9718 - precision: 0.9744 - f1_score: 0.9731
# Epoch 20/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0958 - accuracy: 0.9736 - recall: 0.9724 - precision: 0.9751 - f1_score: 0.9737
# Round: 2 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1043 - accuracy: 0.9702 - recall: 0.9683 - precision: 0.9721 - f1_score: 0.9702
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1030 - accuracy: 0.9706 - recall: 0.9690 - precision: 0.9724 - f1_score: 0.9707
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0999 - accuracy: 0.9709 - recall: 0.9693 - precision: 0.9727 - f1_score: 0.9710
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1006 - accuracy: 0.9712 - recall: 0.9694 - precision: 0.9733 - f1_score: 0.9713
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1011 - accuracy: 0.9717 - recall: 0.9700 - precision: 0.9735 - f1_score: 0.9717
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0990 - accuracy: 0.9721 - recall: 0.9702 - precision: 0.9742 - f1_score: 0.9721
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1001 - accuracy: 0.9719 - recall: 0.9700 - precision: 0.9738 - f1_score: 0.9719
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1046 - accuracy: 0.9711 - recall: 0.9695 - precision: 0.9729 - f1_score: 0.9712
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1065 - accuracy: 0.9703 - recall: 0.9687 - precision: 0.9722 - f1_score: 0.9705
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1011 - accuracy: 0.9723 - recall: 0.9708 - precision: 0.9741 - f1_score: 0.9724
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1053 - accuracy: 0.9709 - recall: 0.9694 - precision: 0.9727 - f1_score: 0.9710
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1014 - accuracy: 0.9719 - recall: 0.9704 - precision: 0.9735 - f1_score: 0.9719
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1011 - accuracy: 0.9721 - recall: 0.9707 - precision: 0.9738 - f1_score: 0.9722
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0985 - accuracy: 0.9730 - recall: 0.9719 - precision: 0.9744 - f1_score: 0.9731
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1017 - accuracy: 0.9723 - recall: 0.9710 - precision: 0.9740 - f1_score: 0.9724
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0986 - accuracy: 0.9723 - recall: 0.9708 - precision: 0.9741 - f1_score: 0.9724
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0959 - accuracy: 0.9731 - recall: 0.9714 - precision: 0.9749 - f1_score: 0.9731
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0956 - accuracy: 0.9731 - recall: 0.9717 - precision: 0.9748 - f1_score: 0.9732
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0961 - accuracy: 0.9733 - recall: 0.9719 - precision: 0.9747 - f1_score: 0.9733
# Epoch 20/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0955 - accuracy: 0.9734 - recall: 0.9721 - precision: 0.9748 - f1_score: 0.9734
# Round: 2 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1057 - accuracy: 0.9698 - recall: 0.9681 - precision: 0.9717 - f1_score: 0.9699
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1030 - accuracy: 0.9709 - recall: 0.9693 - precision: 0.9725 - f1_score: 0.9709
# Epoch 3/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1028 - accuracy: 0.9707 - recall: 0.9691 - precision: 0.9725 - f1_score: 0.9707
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1009 - accuracy: 0.9713 - recall: 0.9696 - precision: 0.9733 - f1_score: 0.9714
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1020 - accuracy: 0.9714 - recall: 0.9696 - precision: 0.9734 - f1_score: 0.9715
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0998 - accuracy: 0.9723 - recall: 0.9704 - precision: 0.9743 - f1_score: 0.9723
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1015 - accuracy: 0.9717 - recall: 0.9698 - precision: 0.9737 - f1_score: 0.9717
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1033 - accuracy: 0.9716 - recall: 0.9699 - precision: 0.9736 - f1_score: 0.9717
# Epoch 9/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.1067 - accuracy: 0.9711 - recall: 0.9693 - precision: 0.9728 - f1_score: 0.9711
# Epoch 10/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.1026 - accuracy: 0.9722 - recall: 0.9709 - precision: 0.9740 - f1_score: 0.9724
# Epoch 11/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1071 - accuracy: 0.9706 - recall: 0.9690 - precision: 0.9724 - f1_score: 0.9706
# Epoch 12/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1023 - accuracy: 0.9715 - recall: 0.9699 - precision: 0.9731 - f1_score: 0.9715
# Epoch 13/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1002 - accuracy: 0.9721 - recall: 0.9707 - precision: 0.9738 - f1_score: 0.9722
# Epoch 14/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1011 - accuracy: 0.9729 - recall: 0.9717 - precision: 0.9743 - f1_score: 0.9730
# Epoch 15/20
# 6159/6159 [==============================] - 35s 5ms/step - loss: 0.1047 - accuracy: 0.9714 - recall: 0.9700 - precision: 0.9731 - f1_score: 0.9715
# Epoch 16/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.1012 - accuracy: 0.9721 - recall: 0.9704 - precision: 0.9738 - f1_score: 0.9721
# Epoch 17/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0967 - accuracy: 0.9727 - recall: 0.9711 - precision: 0.9746 - f1_score: 0.9728
# Epoch 18/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0954 - accuracy: 0.9736 - recall: 0.9721 - precision: 0.9752 - f1_score: 0.9736
# Epoch 19/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0967 - accuracy: 0.9731 - recall: 0.9719 - precision: 0.9746 - f1_score: 0.9732
# Epoch 20/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0964 - accuracy: 0.9735 - recall: 0.9722 - precision: 0.9748 - f1_score: 0.9735
# Round: 2 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1057 - accuracy: 0.9700 - recall: 0.9682 - precision: 0.9719 - f1_score: 0.9700
# Epoch 2/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.1025 - accuracy: 0.9709 - recall: 0.9694 - precision: 0.9727 - f1_score: 0.9710
# Epoch 3/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1009 - accuracy: 0.9707 - recall: 0.9691 - precision: 0.9725 - f1_score: 0.9708
# Epoch 4/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1018 - accuracy: 0.9709 - recall: 0.9692 - precision: 0.9728 - f1_score: 0.9710
# Epoch 5/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0992 - accuracy: 0.9723 - recall: 0.9707 - precision: 0.9740 - f1_score: 0.9723
# Epoch 6/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.1006 - accuracy: 0.9719 - recall: 0.9701 - precision: 0.9739 - f1_score: 0.9720
# Epoch 7/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.1004 - accuracy: 0.9717 - recall: 0.9698 - precision: 0.9737 - f1_score: 0.9717
# Epoch 8/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1037 - accuracy: 0.9711 - recall: 0.9695 - precision: 0.9729 - f1_score: 0.9712
# Epoch 9/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.1056 - accuracy: 0.9710 - recall: 0.9694 - precision: 0.9728 - f1_score: 0.9711
# Epoch 10/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.1049 - accuracy: 0.9717 - recall: 0.9701 - precision: 0.9734 - f1_score: 0.9718
# Epoch 11/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.1107 - accuracy: 0.9699 - recall: 0.9683 - precision: 0.9717 - f1_score: 0.9700
# Epoch 12/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.1016 - accuracy: 0.9720 - recall: 0.9705 - precision: 0.9736 - f1_score: 0.9720
# Epoch 13/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.1005 - accuracy: 0.9723 - recall: 0.9710 - precision: 0.9738 - f1_score: 0.9724
# Epoch 14/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.1008 - accuracy: 0.9724 - recall: 0.9712 - precision: 0.9739 - f1_score: 0.9725
# Epoch 15/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.1021 - accuracy: 0.9721 - recall: 0.9708 - precision: 0.9737 - f1_score: 0.9722
# Epoch 16/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0996 - accuracy: 0.9724 - recall: 0.9710 - precision: 0.9741 - f1_score: 0.9725
# Epoch 17/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0963 - accuracy: 0.9723 - recall: 0.9706 - precision: 0.9741 - f1_score: 0.9723
# Epoch 18/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0952 - accuracy: 0.9736 - recall: 0.9722 - precision: 0.9750 - f1_score: 0.9736
# Epoch 19/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0952 - accuracy: 0.9734 - recall: 0.9722 - precision: 0.9748 - f1_score: 0.9735
# Epoch 20/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0954 - accuracy: 0.9738 - recall: 0.9726 - precision: 0.9751 - f1_score: 0.9738
# 12317/12317 [==============================] - 23s 2ms/step
# comm_round: 2 | global_loss: 1.0518587827682495 | global_accuracy: 0.9936 | global_recall: 0.9935 | global_precision: 0.9937 | global_f1_score: 0.9936
#
# Round: 3 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0858 - accuracy: 0.9758 - recall: 0.9748 - precision: 0.9770 - f1_score: 0.9759
# Epoch 2/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0902 - accuracy: 0.9751 - recall: 0.9741 - precision: 0.9763 - f1_score: 0.9752
# Epoch 3/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0893 - accuracy: 0.9746 - recall: 0.9736 - precision: 0.9756 - f1_score: 0.9746
# Epoch 4/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0892 - accuracy: 0.9744 - recall: 0.9735 - precision: 0.9755 - f1_score: 0.9745
# Epoch 5/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0859 - accuracy: 0.9754 - recall: 0.9743 - precision: 0.9766 - f1_score: 0.9754
# Epoch 6/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0869 - accuracy: 0.9753 - recall: 0.9743 - precision: 0.9764 - f1_score: 0.9754
# Epoch 7/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0860 - accuracy: 0.9760 - recall: 0.9751 - precision: 0.9770 - f1_score: 0.9760
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0877 - accuracy: 0.9754 - recall: 0.9745 - precision: 0.9765 - f1_score: 0.9755
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0880 - accuracy: 0.9750 - recall: 0.9740 - precision: 0.9761 - f1_score: 0.9751
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0887 - accuracy: 0.9748 - recall: 0.9738 - precision: 0.9761 - f1_score: 0.9749
# Epoch 11/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0921 - accuracy: 0.9742 - recall: 0.9730 - precision: 0.9755 - f1_score: 0.9742
# Epoch 12/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0933 - accuracy: 0.9743 - recall: 0.9731 - precision: 0.9757 - f1_score: 0.9744
# Epoch 13/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0950 - accuracy: 0.9738 - recall: 0.9725 - precision: 0.9753 - f1_score: 0.9739
# Epoch 14/20
# 6159/6159 [==============================] - 35s 5ms/step - loss: 0.0902 - accuracy: 0.9747 - recall: 0.9736 - precision: 0.9760 - f1_score: 0.9748
# Epoch 15/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0947 - accuracy: 0.9738 - recall: 0.9727 - precision: 0.9749 - f1_score: 0.9738
# Epoch 16/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0948 - accuracy: 0.9735 - recall: 0.9724 - precision: 0.9747 - f1_score: 0.9735
# Epoch 17/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0921 - accuracy: 0.9744 - recall: 0.9733 - precision: 0.9755 - f1_score: 0.9744
# Epoch 18/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0918 - accuracy: 0.9745 - recall: 0.9735 - precision: 0.9758 - f1_score: 0.9746
# Epoch 19/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0931 - accuracy: 0.9746 - recall: 0.9736 - precision: 0.9757 - f1_score: 0.9747
# Epoch 20/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0924 - accuracy: 0.9747 - recall: 0.9736 - precision: 0.9760 - f1_score: 0.9748
# Round: 3 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0864 - accuracy: 0.9762 - recall: 0.9752 - precision: 0.9774 - f1_score: 0.9763
# Epoch 2/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0910 - accuracy: 0.9754 - recall: 0.9744 - precision: 0.9765 - f1_score: 0.9754
# Epoch 3/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0899 - accuracy: 0.9744 - recall: 0.9734 - precision: 0.9756 - f1_score: 0.9744
# Epoch 4/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0897 - accuracy: 0.9742 - recall: 0.9732 - precision: 0.9753 - f1_score: 0.9743
# Epoch 5/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0876 - accuracy: 0.9752 - recall: 0.9742 - precision: 0.9763 - f1_score: 0.9753
# Epoch 6/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0863 - accuracy: 0.9757 - recall: 0.9749 - precision: 0.9768 - f1_score: 0.9759
# Epoch 7/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0869 - accuracy: 0.9757 - recall: 0.9749 - precision: 0.9767 - f1_score: 0.9758
# Epoch 8/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0852 - accuracy: 0.9762 - recall: 0.9754 - precision: 0.9772 - f1_score: 0.9763
# Epoch 9/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0865 - accuracy: 0.9755 - recall: 0.9745 - precision: 0.9766 - f1_score: 0.9755
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0872 - accuracy: 0.9753 - recall: 0.9742 - precision: 0.9765 - f1_score: 0.9753
# Epoch 11/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0923 - accuracy: 0.9745 - recall: 0.9733 - precision: 0.9758 - f1_score: 0.9745
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0947 - accuracy: 0.9740 - recall: 0.9727 - precision: 0.9755 - f1_score: 0.9741
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0930 - accuracy: 0.9740 - recall: 0.9728 - precision: 0.9754 - f1_score: 0.9741
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0898 - accuracy: 0.9749 - recall: 0.9738 - precision: 0.9761 - f1_score: 0.9749
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0949 - accuracy: 0.9740 - recall: 0.9731 - precision: 0.9751 - f1_score: 0.9741
# Epoch 16/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0934 - accuracy: 0.9738 - recall: 0.9729 - precision: 0.9751 - f1_score: 0.9740
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0924 - accuracy: 0.9750 - recall: 0.9739 - precision: 0.9762 - f1_score: 0.9751
# Epoch 18/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0908 - accuracy: 0.9748 - recall: 0.9736 - precision: 0.9761 - f1_score: 0.9748
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0929 - accuracy: 0.9748 - recall: 0.9739 - precision: 0.9760 - f1_score: 0.9749
# Epoch 20/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0913 - accuracy: 0.9748 - recall: 0.9737 - precision: 0.9762 - f1_score: 0.9749
# Round: 3 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0849 - accuracy: 0.9767 - recall: 0.9757 - precision: 0.9779 - f1_score: 0.9767
# Epoch 2/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0903 - accuracy: 0.9749 - recall: 0.9739 - precision: 0.9761 - f1_score: 0.9750
# Epoch 3/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0882 - accuracy: 0.9746 - recall: 0.9736 - precision: 0.9759 - f1_score: 0.9747
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0878 - accuracy: 0.9750 - recall: 0.9740 - precision: 0.9762 - f1_score: 0.9751
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0864 - accuracy: 0.9754 - recall: 0.9744 - precision: 0.9766 - f1_score: 0.9755
# Epoch 6/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0859 - accuracy: 0.9758 - recall: 0.9749 - precision: 0.9769 - f1_score: 0.9759
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0873 - accuracy: 0.9756 - recall: 0.9747 - precision: 0.9765 - f1_score: 0.9756
# Epoch 8/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0847 - accuracy: 0.9764 - recall: 0.9756 - precision: 0.9774 - f1_score: 0.9765
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0874 - accuracy: 0.9756 - recall: 0.9747 - precision: 0.9766 - f1_score: 0.9756
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0880 - accuracy: 0.9752 - recall: 0.9742 - precision: 0.9763 - f1_score: 0.9752
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0912 - accuracy: 0.9745 - recall: 0.9734 - precision: 0.9759 - f1_score: 0.9746
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0951 - accuracy: 0.9741 - recall: 0.9729 - precision: 0.9755 - f1_score: 0.9742
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0940 - accuracy: 0.9742 - recall: 0.9730 - precision: 0.9756 - f1_score: 0.9743
# Epoch 14/20
# ...
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0860 - accuracy: 0.9754 - recall: 0.9745 - precision: 0.9766 - f1_score: 0.9755
# Epoch 6/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0859 - accuracy: 0.9754 - recall: 0.9744 - precision: 0.9765 - f1_score: 0.9754
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0867 - accuracy: 0.9756 - recall: 0.9748 - precision: 0.9766 - f1_score: 0.9757
# Epoch 8/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0852 - accuracy: 0.9758 - recall: 0.9751 - precision: 0.9769 - f1_score: 0.9760
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0853 - accuracy: 0.9758 - recall: 0.9750 - precision: 0.9769 - f1_score: 0.9759
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0874 - accuracy: 0.9751 - recall: 0.9740 - precision: 0.9762 - f1_score: 0.9751
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0916 - accuracy: 0.9746 - recall: 0.9733 - precision: 0.9760 - f1_score: 0.9746
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0936 - accuracy: 0.9744 - recall: 0.9731 - precision: 0.9758 - f1_score: 0.9744
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0917 - accuracy: 0.9743 - recall: 0.9732 - precision: 0.9757 - f1_score: 0.9744
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0921 - accuracy: 0.9745 - recall: 0.9735 - precision: 0.9759 - f1_score: 0.9747
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0924 - accuracy: 0.9739 - recall: 0.9729 - precision: 0.9751 - f1_score: 0.9740
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0932 - accuracy: 0.9736 - recall: 0.9726 - precision: 0.9749 - f1_score: 0.9737
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0927 - accuracy: 0.9742 - recall: 0.9732 - precision: 0.9754 - f1_score: 0.9743
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0903 - accuracy: 0.9747 - recall: 0.9736 - precision: 0.9760 - f1_score: 0.9748
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0897 - accuracy: 0.9755 - recall: 0.9745 - precision: 0.9766 - f1_score: 0.9755
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0897 - accuracy: 0.9752 - recall: 0.9741 - precision: 0.9765 - f1_score: 0.9753
# 12317/12317 [==============================] - 23s 2ms/step
# comm_round: 3 | global_loss: 1.0544027090072632 | global_accuracy: 0.9896 | global_recall: 0.9895 | global_precision: 0.9896 | global_f1_score: 0.9896
#
# Round: 4 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0839 - accuracy: 0.9772 - recall: 0.9763 - precision: 0.9783 - f1_score: 0.9773
# Epoch 2/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0875 - accuracy: 0.9761 - recall: 0.9750 - precision: 0.9773 - f1_score: 0.9762
# Epoch 3/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0851 - accuracy: 0.9760 - recall: 0.9750 - precision: 0.9774 - f1_score: 0.9762
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0858 - accuracy: 0.9765 - recall: 0.9756 - precision: 0.9776 - f1_score: 0.9766
# Epoch 5/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0871 - accuracy: 0.9761 - recall: 0.9752 - precision: 0.9772 - f1_score: 0.9761
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0901 - accuracy: 0.9750 - recall: 0.9738 - precision: 0.9763 - f1_score: 0.9751
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0920 - accuracy: 0.9749 - recall: 0.9738 - precision: 0.9761 - f1_score: 0.9749
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0933 - accuracy: 0.9748 - recall: 0.9738 - precision: 0.9759 - f1_score: 0.9749
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0908 - accuracy: 0.9754 - recall: 0.9746 - precision: 0.9763 - f1_score: 0.9754
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0925 - accuracy: 0.9754 - recall: 0.9744 - precision: 0.9764 - f1_score: 0.9754
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0930 - accuracy: 0.9755 - recall: 0.9747 - precision: 0.9766 - f1_score: 0.9756
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0912 - accuracy: 0.9754 - recall: 0.9744 - precision: 0.9764 - f1_score: 0.9754
# Epoch 13/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0932 - accuracy: 0.9754 - recall: 0.9745 - precision: 0.9765 - f1_score: 0.9755
# Epoch 14/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0945 - accuracy: 0.9754 - recall: 0.9745 - precision: 0.9765 - f1_score: 0.9755
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0918 - accuracy: 0.9756 - recall: 0.9746 - precision: 0.9769 - f1_score: 0.9757
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0931 - accuracy: 0.9746 - recall: 0.9735 - precision: 0.9760 - f1_score: 0.9747
# Epoch 17/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0960 - accuracy: 0.9743 - recall: 0.9732 - precision: 0.9756 - f1_score: 0.9744
# Epoch 18/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0949 - accuracy: 0.9753 - recall: 0.9743 - precision: 0.9766 - f1_score: 0.9754
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0965 - accuracy: 0.9746 - recall: 0.9733 - precision: 0.9759 - f1_score: 0.9746
# Epoch 20/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0990 - accuracy: 0.9745 - recall: 0.9734 - precision: 0.9758 - f1_score: 0.9746
# Round: 4 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0838 - accuracy: 0.9774 - recall: 0.9765 - precision: 0.9785 - f1_score: 0.9775
# Epoch 2/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0855 - accuracy: 0.9767 - recall: 0.9756 - precision: 0.9779 - f1_score: 0.9767
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0879 - accuracy: 0.9762 - recall: 0.9751 - precision: 0.9774 - f1_score: 0.9762
# Epoch 4/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0878 - accuracy: 0.9761 - recall: 0.9751 - precision: 0.9771 - f1_score: 0.9761
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0866 - accuracy: 0.9760 - recall: 0.9750 - precision: 0.9772 - f1_score: 0.9761
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0884 - accuracy: 0.9756 - recall: 0.9745 - precision: 0.9769 - f1_score: 0.9757
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0927 - accuracy: 0.9747 - recall: 0.9737 - precision: 0.9760 - f1_score: 0.9748
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0930 - accuracy: 0.9746 - recall: 0.9735 - precision: 0.9758 - f1_score: 0.9746
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0925 - accuracy: 0.9751 - recall: 0.9742 - precision: 0.9761 - f1_score: 0.9751
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0905 - accuracy: 0.9758 - recall: 0.9749 - precision: 0.9769 - f1_score: 0.9759
# Epoch 11/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0929 - accuracy: 0.9758 - recall: 0.9749 - precision: 0.9769 - f1_score: 0.9759
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0896 - accuracy: 0.9761 - recall: 0.9752 - precision: 0.9771 - f1_score: 0.9761
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0950 - accuracy: 0.9755 - recall: 0.9746 - precision: 0.9765 - f1_score: 0.9755
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0936 - accuracy: 0.9756 - recall: 0.9746 - precision: 0.9767 - f1_score: 0.9757
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0936 - accuracy: 0.9758 - recall: 0.9746 - precision: 0.9770 - f1_score: 0.9758
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0928 - accuracy: 0.9750 - recall: 0.9738 - precision: 0.9763 - f1_score: 0.9751
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0925 - accuracy: 0.9754 - recall: 0.9745 - precision: 0.9766 - f1_score: 0.9755
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0947 - accuracy: 0.9752 - recall: 0.9743 - precision: 0.9766 - f1_score: 0.9754
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0952 - accuracy: 0.9743 - recall: 0.9731 - precision: 0.9757 - f1_score: 0.9744
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0998 - accuracy: 0.9742 - recall: 0.9732 - precision: 0.9755 - f1_score: 0.9743
# Round: 4 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0820 - accuracy: 0.9778 - recall: 0.9768 - precision: 0.9789 - f1_score: 0.9778
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0864 - accuracy: 0.9763 - recall: 0.9751 - precision: 0.9775 - f1_score: 0.9763
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0855 - accuracy: 0.9764 - recall: 0.9752 - precision: 0.9775 - f1_score: 0.9763
# Epoch 4/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0860 - accuracy: 0.9761 - recall: 0.9752 - precision: 0.9772 - f1_score: 0.9762
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0858 - accuracy: 0.9762 - recall: 0.9753 - precision: 0.9772 - f1_score: 0.9762
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0877 - accuracy: 0.9754 - recall: 0.9744 - precision: 0.9767 - f1_score: 0.9755
# Epoch 7/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0919 - accuracy: 0.9746 - recall: 0.9735 - precision: 0.9757 - f1_score: 0.9746
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0935 - accuracy: 0.9746 - recall: 0.9735 - precision: 0.9757 - f1_score: 0.9746
# Epoch 9/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0906 - accuracy: 0.9754 - recall: 0.9746 - precision: 0.9765 - f1_score: 0.9755
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0914 - accuracy: 0.9752 - recall: 0.9744 - precision: 0.9763 - f1_score: 0.9753
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0914 - accuracy: 0.9758 - recall: 0.9750 - precision: 0.9769 - f1_score: 0.9760
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0897 - accuracy: 0.9755 - recall: 0.9746 - precision: 0.9766 - f1_score: 0.9756
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0931 - accuracy: 0.9756 - recall: 0.9746 - precision: 0.9767 - f1_score: 0.9756
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0940 - accuracy: 0.9754 - recall: 0.9745 - precision: 0.9764 - f1_score: 0.9754
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0920 - accuracy: 0.9759 - recall: 0.9748 - precision: 0.9771 - f1_score: 0.9759
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0922 - accuracy: 0.9745 - recall: 0.9735 - precision: 0.9759 - f1_score: 0.9746
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0937 - accuracy: 0.9749 - recall: 0.9740 - precision: 0.9761 - f1_score: 0.9750
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0959 - accuracy: 0.9749 - recall: 0.9739 - precision: 0.9760 - f1_score: 0.9750
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0949 - accuracy: 0.9745 - recall: 0.9734 - precision: 0.9759 - f1_score: 0.9746
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0989 - accuracy: 0.9744 - recall: 0.9733 - precision: 0.9756 - f1_score: 0.9744
# Round: 4 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0820 - accuracy: 0.9773 - recall: 0.9763 - precision: 0.9784 - f1_score: 0.9773
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0863 - accuracy: 0.9766 - recall: 0.9756 - precision: 0.9778 - f1_score: 0.9767
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0868 - accuracy: 0.9760 - recall: 0.9749 - precision: 0.9772 - f1_score: 0.9760
# Epoch 4/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0853 - accuracy: 0.9766 - recall: 0.9757 - precision: 0.9776 - f1_score: 0.9767
# Epoch 5/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0871 - accuracy: 0.9757 - recall: 0.9747 - precision: 0.9768 - f1_score: 0.9757
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0890 - accuracy: 0.9754 - recall: 0.9744 - precision: 0.9766 - f1_score: 0.9755
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0945 - accuracy: 0.9744 - recall: 0.9733 - precision: 0.9756 - f1_score: 0.9744
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0913 - accuracy: 0.9752 - recall: 0.9742 - precision: 0.9764 - f1_score: 0.9753
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0891 - accuracy: 0.9756 - recall: 0.9748 - precision: 0.9766 - f1_score: 0.9757
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0922 - accuracy: 0.9756 - recall: 0.9746 - precision: 0.9766 - f1_score: 0.9756
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0937 - accuracy: 0.9755 - recall: 0.9747 - precision: 0.9766 - f1_score: 0.9756
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0915 - accuracy: 0.9753 - recall: 0.9744 - precision: 0.9763 - f1_score: 0.9754
# Epoch 13/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0931 - accuracy: 0.9756 - recall: 0.9748 - precision: 0.9766 - f1_score: 0.9757
# Epoch 14/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0944 - accuracy: 0.9752 - recall: 0.9743 - precision: 0.9762 - f1_score: 0.9752
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0936 - accuracy: 0.9751 - recall: 0.9741 - precision: 0.9764 - f1_score: 0.9753
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0926 - accuracy: 0.9745 - recall: 0.9734 - precision: 0.9759 - f1_score: 0.9747
# Epoch 17/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0939 - accuracy: 0.9748 - recall: 0.9738 - precision: 0.9759 - f1_score: 0.9749
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0947 - accuracy: 0.9751 - recall: 0.9740 - precision: 0.9764 - f1_score: 0.9752
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0956 - accuracy: 0.9745 - recall: 0.9734 - precision: 0.9759 - f1_score: 0.9746
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0997 - accuracy: 0.9744 - recall: 0.9733 - precision: 0.9757 - f1_score: 0.9745
# 12317/12317 [==============================] - 23s 2ms/step
# comm_round: 4 | global_loss: 1.0496723651885986 | global_accuracy: 0.9956 | global_recall: 0.9956 | global_precision: 0.9956 | global_f1_score: 0.9956
#
# New Weights Saved

# %%
global_model.load_weights("FL_DP_0_1.h5")

# %%
loss, accuracy, precision, recall, f1_score = test_model(x_batch, y_batch, global_model, comm_round)
print("loss : ", loss.numpy())
print("accuracy : ", accuracy)
print("precision : ", precision)
print("recall : ", recall)
print("f1_score : ", f1_score)
# Out:
# 12317/12317 [==============================] - 22s 2ms/step
# comm_round: 4 | global_loss: 1.0496723651885986 | global_accuracy: 0.9956 | global_recall: 0.9956 | global_precision: 0.9956 | global_f1_score: 0.9956
#
# loss :  1.0496724
# accuracy :  0.9955750640651562
# precision :  0.9955826
# recall :  0.9955573
# f1_score :  0.9955699

# %%
for(x_batch, y_batch) in test_batched:
    logits = global_model.predict(x_batch)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_batch, axis=1)
# Out:
# 12317/12317 [==============================] - 25s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report, precision_score, recall_score
from sklearn.metrics import matthews_corrcoef, roc_auc_score
from sklearn.metrics import f1_score as f1_score_rep
import seaborn as sn
import numpy as np

def print_score(y_pred, y_real, label_encoder):
    accuracy = accuracy_score(y_real, y_pred)
    precision = precision_score(y_real, y_pred, average="weighted")
    recall = recall_score(y_real, y_pred, average="weighted")
    f1 = f1_score_rep(y_real, y_pred, average="weighted")
    auc = roc_auc_score(y_real, logits, multi_class='ovr')

    print("Accuracy: {:.4f}".format(accuracy))
    print("Precision:: {:.4f}".format(precision))
    print("Recall:: {:.4f}".format(recall))
    print("F1_Score:: {:.4f}".format(f1))
    print("AUC:: {:.4f}".format(auc))
    
    print()
    print("Confusion Matrix")
    cm = confusion_matrix(y_real, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cm, index=[str(i) for i in label_encoder.classes_], columns=[str(i) for i in label_encoder.classes_])
    plt.figure(figsize=(10, 7))
    sn.heatmap(df_cm, annot=True)

    print()
    print("Classification Report")
    print(classification_report(y_real, y_pred, target_names=[str(i) for i in label_encoder.classes_]))

# %%
print_score(y_hat, y_true, label_encoder)
# Out:
# Accuracy: 0.9956
# Precision:: 0.9956
# Recall:: 0.9956
# F1_Score:: 0.9956
# AUC:: 0.9997
#
# Confusion Matrix
#
# Classification Report
#                 precision    recall  f1-score   support
#
#         benign       1.00      1.00      1.00     84459
#      mirai_ack       1.00      1.00      1.00     56029
#     mirai_scan       0.99      1.00      0.99     51230
#      mirai_syn       1.00      0.99      1.00     62501
#      mirai_udp       0.99      1.00      1.00    108953
# mirai_udpplain       0.99      0.98      0.98     30958
#
#       accuracy                           1.00    394130
#      macro avg       0.99      0.99      0.99    394130
#   weighted avg       1.00      1.00      1.00    394130

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, n_classes):
    lw = 2
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_ohe[:, i], y_hat_ohe[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes
    fpr["weighted"] = all_fpr
    tpr["weighted"] = mean_tpr
    roc_auc["weighted"] = auc(fpr["weighted"], tpr["weighted"])

    #fpr["micro"], tpr["micro"], _ = roc_curve(y_true_ohe.ravel(), y_hat_ohe.ravel())
    #roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    plt.figure(figsize=(8,8))
    plt.plot(
        fpr["weighted"],
        tpr["weighted"],
        label="weighted-average ROC curve (area = {0:0.2f})".format(roc_auc["weighted"]),
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )



    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(label_encoder.classes_[i], roc_auc[i]))

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("multiclass characteristic")
    plt.legend(loc="lower right")
    plt.show()

# %%
y_true_ohe = to_categorical(y_true, num_classes=len(label_encoder.classes_))
y_hat_ohe =  to_categorical(y_hat, num_classes=len(label_encoder.classes_))

# %%
ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, len(label_encoder.classes_))

# %%
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  forward_pass = tf.function(model.call, input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])
  graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
  flops = graph_info.total_float_ops
  return flops

# %%
# Calculate FLOPS
flops = get_flops(global_model)
# Out:
# WARNING:tensorflow:From c:\Users\Lambert\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.

# %%
print(f"FLOPS: {flops / 10 ** 6:.03} M")
# Out:
# FLOPS: 0.00861 M

# %%
print(f"FLOPS: {flops}")
# Out:
# FLOPS: 8612

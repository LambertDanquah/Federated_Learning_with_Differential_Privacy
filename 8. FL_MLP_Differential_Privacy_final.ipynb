# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(42)

# %%
#Benign
benign_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.benign.csv')
benign_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.benign.csv')
benign_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.benign.csv')
benign_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.benign.csv')
benign_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.benign.csv')
benign_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.benign.csv')
benign_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.benign.csv')

benign_traffic = pd.concat([benign_1, benign_2, benign_4, benign_5, benign_6, benign_8, benign_9], ignore_index=True)

benign_traffic.shape
# Out:
# (464682, 115)

# %%
#Scan
mirai_scan_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.scan.csv')
mirai_scan_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.scan.csv')
mirai_scan_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.scan.csv')
mirai_scan_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.scan.csv')
mirai_scan_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.scan.csv')
mirai_scan_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.scan.csv')
mirai_scan_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.scan.csv')

mirai_scan_traffic = pd.concat([mirai_scan_1, mirai_scan_2, mirai_scan_4, mirai_scan_5, mirai_scan_6, mirai_scan_8, mirai_scan_9], ignore_index=True)

mirai_scan_traffic.shape
# Out:
# (537979, 115)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')
mirai_syn_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.syn.csv')
mirai_syn_8  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.syn.csv')
mirai_syn_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.syn.csv')


mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5, mirai_syn_6, mirai_syn_8, mirai_syn_9], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (733299, 115)

# %%
#Ack
mirai_ack_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.ack.csv')
mirai_ack_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.ack.csv')
mirai_ack_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.ack.csv')
mirai_ack_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.ack.csv')
mirai_ack_6  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.ack.csv')
mirai_ack_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.ack.csv')
mirai_ack_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.ack.csv')

mirai_ack_traffic = pd.concat([mirai_ack_1 , mirai_ack_2, mirai_ack_4, mirai_ack_5, mirai_ack_6, mirai_ack_8, mirai_ack_9], ignore_index=True)

mirai_ack_traffic.shape
# Out:
# (643821, 115)

# %%
#Udp Flooding
mirai_udp_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udp.csv')
mirai_udp_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udp.csv')
mirai_udp_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udp.csv')
mirai_udp_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udp.csv')
mirai_udp_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udp.csv')
mirai_udp_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udp.csv')
mirai_udp_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udp.csv')

mirai_udp_traffic = pd.concat([mirai_udp_1 , mirai_udp_2, mirai_udp_4, mirai_udp_5], ignore_index=True)

mirai_udp_traffic.shape
# Out:
# (762428, 115)

# %%
#Udp plain Flooding
mirai_udpplain_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udpplain.csv')
mirai_udpplain_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udpplain.csv')
mirai_udpplain_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udpplain.csv')
mirai_udpplain_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udpplain.csv')
mirai_udpplain_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udpplain.csv')
mirai_udpplain_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udpplain.csv')
mirai_udpplain_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udpplain.csv')

mirai_udpplain_traffic = pd.concat([mirai_udpplain_1 , mirai_udpplain_2, mirai_udpplain_4, mirai_udpplain_5, mirai_udpplain_6, mirai_udpplain_8, mirai_udpplain_9], ignore_index=True)

mirai_udpplain_traffic.shape
# Out:
# (523304, 115)

# %%
benign_traffic['label'] = 'benign'
mirai_scan_traffic['label'] = 'mirai_scan'
mirai_syn_traffic['label'] = 'mirai_syn'
mirai_ack_traffic['label'] = 'mirai_ack'
mirai_udp_traffic['label'] = 'mirai_udp'
mirai_udpplain_traffic['label'] = 'mirai_udpplain'

mirai_dataset = pd.concat([benign_traffic, mirai_scan_traffic, mirai_syn_traffic,
                mirai_ack_traffic, mirai_udp_traffic, mirai_udpplain_traffic],
                axis=0, sort=False, ignore_index=True)

# %%
selected_features = ['HH_L1_weight', 'HH_jit_L1_weight', 'MI_dir_L0.01_mean',
       'H_L0.1_weight', 'H_L0.1_mean', 'MI_dir_L1_mean', 'H_L1_mean',
       'H_L0.01_variance', 'MI_dir_L0.01_variance', 'H_L5_weight',
       'H_L0.1_variance', 'MI_dir_L0.1_weight', 'MI_dir_L0.1_mean',
       'MI_dir_L5_weight', 'H_L0.01_mean', 'H_L5_mean', 'MI_dir_L0.1_variance',
       'MI_dir_L3_mean', 'MI_dir_L5_mean', 'HH_jit_L5_mean', 'HH_jit_L3_mean',
       'H_L3_mean', 'HH_L3_magnitude', 'MI_dir_L3_weight', 'HpHp_L0.01_weight', 'label']

# %%
selected_mirai_dataset = mirai_dataset[selected_features].copy()

# %%
selected_mirai_dataset.shape
# Out:
# (3665513, 26)

# %%
#Number of Missing Values in the Dataset
selected_mirai_dataset.isnull().sum().sum()
# Out:
# 0

# %%
#Number of Duplicate Rows in the Dataset
selected_mirai_dataset.duplicated().sum()
# Out:
# 1607667

# %%
# Remove duplicate rows from the Dataset
selected_mirai_dataset = selected_mirai_dataset.drop_duplicates()

# Check the number of duplicate rows after removal
selected_mirai_dataset.duplicated().sum()
# Out:
# 0

# %%
selected_mirai_dataset.shape
# Out:
# (2057846, 26)

# %%
import numpy as np

# Select columns for z-score calculation (excluding the last column)
column_features = selected_mirai_dataset.iloc[:, :-1]

# Calculate z-scores for each column
z_scores = (column_features - column_features.mean()) / column_features.std()

# Set a threshold for z-score beyond which a data point is considered an outlier
z_score_threshold = 3  # Adjust this threshold as needed

# Identify rows where any z-score exceeds the threshold
outlier_mask = (np.abs(z_scores) > z_score_threshold).any(axis=1)

# Remove outliers from the dataset
selected_mirai_dataset = selected_mirai_dataset[~outlier_mask]

# %%
selected_mirai_dataset.shape
# Out:
# (1970649, 26)

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the columns to be normalized (excluding the 'label' column)
column_to_normalize = selected_mirai_dataset.columns[selected_mirai_dataset.columns != 'label']


# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
selected_mirai_dataset[column_to_normalize] = scaler.fit_transform(selected_mirai_dataset[column_to_normalize])

# %%
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000       2.636780e-16       0.000000
# 1      0.000039          0.000039       5.547170e-01       0.000179
# 2      0.001219          0.001219       5.660395e-01       0.000289
# 3      0.000000          0.000000       5.226415e-01       0.000000
# 4      0.000000          0.000000       2.612201e-01       0.000111
#
#     H_L0.1_mean  MI_dir_L1_mean     H_L1_mean  H_L0.01_variance  \
# 0  4.163336e-17    1.249001e-16  1.249001e-16          0.000000
# 1  5.408092e-01    4.823113e-01  4.817053e-01          0.000193
# 2  5.509964e-01    4.923052e-01  4.918483e-01          0.000712
# 3  5.226581e-01    4.544225e-01  4.544225e-01          0.000000
# 4  2.603220e-01    2.184604e-01  2.184604e-01          0.167279
#
#    MI_dir_L0.01_variance   H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.000000  0.000000e+00  ...              0.000000
# 1               0.000000  1.174383e-10  ...              0.000000
# 2               0.000314  3.148369e-03  ...              0.000311
# 3               0.000000  0.000000e+00  ...              0.000000
# 4               0.167279  2.496382e-03  ...              0.165695
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  \
# 0    1.249001e-16    1.110223e-16    9.813673e-01    9.813673e-01
# 1    4.510277e-01    4.226888e-01    3.245507e-09    3.245505e-09
# 2    4.606554e-01    4.319749e-01    1.513729e-09    1.562845e-09
# 3    4.249479e-01    3.982476e-01    9.813673e-01    9.813673e-01
# 4    1.880207e-01    1.612269e-01    9.813673e-01    9.813673e-01
#
#       H_L3_mean  HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight   label
# 0  1.249001e-16         0.000000          0.000000           0.000000  benign
# 1  4.510271e-01         0.331530          0.000000           0.000291  benign
# 2  4.606549e-01         0.338607          0.002146           0.000359  benign
# 3  4.249479e-01         0.312360          0.000000           0.000000  benign
# 4  1.880207e-01         0.477094          0.001867           0.000000  benign
#
# [5 rows x 26 columns]

# %%
selected_mirai_dataset = selected_mirai_dataset.sample(frac=1).reset_index(drop=True)
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000           0.521544       0.505705
# 1      0.000108          0.000108           0.185116       0.001147
# 2      0.001207          0.001207           0.020756       0.001147
# 3      0.365574          0.365574           0.523108       0.516265
# 4      0.000000          0.000000           0.017738       0.744389
#
#    H_L0.1_mean  MI_dir_L1_mean  H_L1_mean  H_L0.01_variance  \
# 0     0.522337        0.444576   0.444576          0.524454
# 1     0.118109        0.018681   0.018681          0.421878
# 2     0.023412        0.014130   0.014130          0.003344
# 3     0.525792        0.477173   0.477173          0.524025
# 4     0.017960        0.016922   0.016922          0.000378
#
#    MI_dir_L0.01_variance  H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.524454     0.457333  ...              0.519279
# 1               0.421878     0.000004  ...              0.242123
# 2               0.003344     0.003073  ...              0.003812
# 3               0.524025     0.323968  ...              0.518312
# 4               0.000378     0.378821  ...              0.000369
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  H_L3_mean  \
# 0        0.372336        0.294594    9.826693e-01    9.826693e-01   0.372336
# 1        0.021151        0.020109    2.614423e-09    2.614027e-09   0.021151
# 2        0.010392        0.008908    1.420423e-09    1.504356e-09   0.010392
# 3        0.497183        0.525856    2.188626e-12    2.208649e-12   0.497183
# 4        0.017771        0.017381    9.826679e-01    9.826679e-01   0.017771
#
#    HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight           label
# 0         0.000000          0.436825           0.000000  mirai_udpplain
# 1         0.050352          0.000037           0.000195          benign
# 2         0.070288          0.002636           0.001276          benign
# 3         0.557061          0.375316           0.405565  mirai_udpplain
# 4         0.000000          0.431810           0.000000       mirai_syn
#
# [5 rows x 26 columns]

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# Calculate percentage values
class_counts = selected_mirai_dataset['label'].value_counts(normalize=True) * 100

plt.title("Class Distribution")
bar_plot = selected_mirai_dataset['label'].value_counts().plot(kind='bar')
plt.xlabel('Classes')
plt.ylabel('Frequency')

# Annotate each bar with its percentage value
for i, val in enumerate(class_counts):
    plt.text(i, selected_mirai_dataset['label'].value_counts()[i], f'{val:.2f}%', ha='center')

plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(selected_mirai_dataset['label'].value_counts())
# Out:
# mirai_udp         544764
# benign            422293
# mirai_syn         312508
# mirai_ack         280144
# mirai_scan        256151
# mirai_udpplain    154789
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(selected_mirai_dataset, test_size=0.2, random_state=42, stratify=selected_mirai_dataset["label"])

# %%
features = list(train_df.columns)
features.remove("label")

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_df["label"] = label_encoder.fit_transform(train_df["label"])
test_df["label"] = label_encoder.transform(test_df["label"])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=18)
X_train = train_df[features].values
X_train = pca.fit_transform(X_train)
y_train = train_df["label"].values

X_test = test_df[features].values
X_test = pca.fit_transform(X_test)
y_test = test_df["label"].values

# %%
import statsmodels.api as sm
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from tabulate import tabulate

# %%
#X_train = X_train.reshape((-1, X_train.shape[-1], 1))
#X_test = X_test.reshape((-1, X_test.shape[-1], 1))

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train)

class_weights = {k: v for k,v in enumerate(class_weights)}
class_weights
# Out:
# {0: 0.7777582086665837,
#  1: 1.1724033048509321,
#  2: 1.282216886832812,
#  3: 1.0509832391359708,
#  4: 0.6029062292293372,
#  5: 2.1218690527143176}

# %%
input_shape = X_train.shape[1:]
nb_classes = len(label_encoder.classes_)

# %%
input_shape
# Out:
# (18,)

# %%
from tensorflow.keras.utils import to_categorical

def convert_to_categorical(y, nb_classes):
    return to_categorical(y, num_classes=nb_classes)

# %%
import random

def data_indices(labels: np.ndarray, nb_clients: int):
    data_len = len(labels)
    indices = np.arange(data_len)
    np.random.shuffle(indices)
    chunk_size = data_len // nb_clients
    chunks = [indices[i:i+chunk_size] for i in range(0, data_len, chunk_size)]

    # Ensure non-IID distribution by shuffling 2 of the 4 chunks
    chunks[-1] = np.random.permutation(chunks[-1])
    chunks[-3] = np.random.permutation(chunks[-3])
    

    return chunks

# %%
def sample(y:np.ndarray, nb_clients: int):
    sampler_fn = data_indices
    client_data_indices = sampler_fn(y, nb_clients)
    return client_data_indices

# %%
def assign_data_to_clients(clients: dict, X:np.ndarray, y:np.ndarray, nb_classes:int):
    sampled_data_indices = sample(y, len(clients.keys()))  # Use the sample function to get data indices
    for client_name, data_indices in zip(clients.keys(), sampled_data_indices):
        X = X_train[data_indices]  # Subset the features for the current client
        y = y_train[data_indices]  # Subset the labels for the current client
        y = convert_to_categorical(y, nb_classes)  # Convert labels to categorical format if needed
        clients[client_name] = list(zip(X, y))  # Assign data to the current client
    return clients

# %%
def create_clients(X, y, nb_classes, num_clients=4, initial='clients'):
    # Create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]
    clients = {client_names[i] : [] for i in range(len(client_names))}
    return assign_data_to_clients(clients, X, y, nb_classes)

# %%
def batch_data(data_shard, batch_size=64):
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    del data_shard

    len_label = len(label)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    del data, label
    return dataset.shuffle(len_label).batch(batch_size)

# %%
import keras.backend as K
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import keras
import os
from keras.models import Model
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Activation, BatchNormalization, GRU, Dense, Dropout, Input

def get_model(input_shape, nb_classes):
    inputs = Input(shape=input_shape)
    
    x = Dense(32, activation="relu")(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = Dropout(0.2)(x)
    outputs = Dense(nb_classes, activation="softmax")(x)
    
    return keras.Model(inputs, outputs)

# %%
import tensorflow_privacy
from tensorflow_privacy.privacy.optimizers import dp_optimizer_keras  
from keras.metrics import Recall, Precision
from tensorflow.keras.utils import plot_model

learning_rate = 1e-3
comms_round = 5
loss='categorical_crossentropy'
metrics = ["accuracy", Recall(), Precision(), f1_score]
#optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
optimizer = tensorflow_privacy.DPKerasAdamOptimizer(l2_norm_clip= 1.6, noise_multiplier= 0.01, num_microbatches=1, learning_rate= learning_rate)


#initialize global model
global_model = get_model(input_shape, nb_classes)

global_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18)]              0
#
#  dense (Dense)               (None, 32)                608
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  batch_normalization_2 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 4358 (17.02 KB)
# Trainable params: 4166 (16.27 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
BATCH_SIZE = 64

# create clients
clients_batched = create_clients(X_train, y_train, nb_classes, num_clients=4, initial='client')

del X_train, y_train

# process and batch the training data for each client
client_set = {k: {} for k in clients_batched.keys()}

for (client_name, data) in clients_batched.items():
    client_set[client_name]["dataset"] = batch_data(data, BATCH_SIZE)
    local_model = get_model(input_shape, nb_classes)
    local_model.compile(loss=loss,
                      optimizer=optimizer,
                      metrics=metrics)
    client_set[client_name]["model"] = local_model

# %%
#process and batch the test set

y_test = convert_to_categorical(y_test, nb_classes)

test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

del X_test, y_test

# %%
# Define a function to calculate the weight scaling factor
def weight_scalling_factor(clients, client_name):
    client_names = list(clients.keys())
    # Get the batch size
    bs = list(clients[client_name]["dataset"])[0][0].shape[0]
    # Calculate the total training data points across clients
    global_count = sum([tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() for client_name in client_names]) * bs
    # Calculate the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() * bs
    return local_count / global_count

# %%
# Define a function to scale model weights
def scale_model_weights(weight, scalar):
    '''function for scaling a model's weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final

# %%
def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights --> FedAvg'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)

    return avg_grad

# %%
from sklearn.metrics import accuracy_score

def test_model(X_test, y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(y_test, logits)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(np.argmax(y_test, axis=1), np.argmax(logits, axis=1))

    r = Recall()
    r.update_state(y_test, logits)
    recall = r.result().numpy()

    p = Precision()
    p.update_state(y_test, logits)
    precision = p.result().numpy()

    f = f1_score(y_test, logits)
    f1 = f.numpy()

    print('comm_round: {} | global_loss: {} | global_accuracy: {:.4} | global_recall: {:.4} | global_precision: {:.4} | global_f1_score: {:.4} \n'.format(comm_round, loss, accuracy, recall, precision, f1))
    return loss, accuracy, precision, recall, f1

# %%
def train_client(client, global_weights):
    client_set[client]["model"] = client_set[client]["model"]

    #set local model weight to the weight of the global model
    client_set[client]["model"].set_weights(global_weights)

    #fit local model with client's data
    print(f"Round: {comm_round} | Client: {client} training")
    client_set[client]["model"].fit(client_set[client]["dataset"], epochs=20, verbose=1)

    #scale the model weights and add to list
    scaling_factor = weight_scalling_factor(client_set, client)
    scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
    return scaled_weights

# %%
import random

#commence global training loop
global_loss=[]
global_accuracy=[]
global_precision=[]
global_recall=[]
global_f1=[]
best_global_accuracy = 0

for comm_round in range(comms_round):
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()

    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(client_set.keys())
    random.shuffle(client_names)

    #loop through each client and create new local model
    for client in client_names:
        scaled_weights = train_client(client, global_weights)

        scaled_local_weight_list.append(scaled_weights)

    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)

    #update global model
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    g_accuracy = 0
    for(x_batch, y_batch) in test_batched:
        g_loss, g_accuracy, g_precision, g_recall, g_f1 = test_model(x_batch, y_batch, global_model, comm_round)
        global_loss.append(g_loss)
        global_accuracy.append(g_accuracy)
        global_precision.append(g_precision)
        global_recall.append(g_recall)
        global_f1.append(g_f1)

    if g_accuracy > best_global_accuracy:
        best_global_accuracy = g_accuracy
        global_model.save_weights('FL_DP_Mirai_MLP.h5')
        print("New Weights Saved")
# Out:
# Round: 0 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 46s 5ms/step - loss: 0.2824 - accuracy: 0.8741 - recall: 0.8466 - precision: 0.9019 - f1_score: 0.8704
# Epoch 2/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0953 - accuracy: 0.9692 - recall: 0.9670 - precision: 0.9716 - f1_score: 0.9692
# Epoch 3/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0758 - accuracy: 0.9783 - recall: 0.9773 - precision: 0.9794 - f1_score: 0.9784
# Epoch 4/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0677 - accuracy: 0.9812 - recall: 0.9804 - precision: 0.9821 - f1_score: 0.9812
# Epoch 5/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0646 - accuracy: 0.9820 - recall: 0.9812 - precision: 0.9830 - f1_score: 0.9821
# Epoch 6/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0594 - accuracy: 0.9834 - recall: 0.9827 - precision: 0.9843 - f1_score: 0.9835
# Epoch 7/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0588 - accuracy: 0.9838 - recall: 0.9831 - precision: 0.9847 - f1_score: 0.9839
# Epoch 8/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0561 - accuracy: 0.9844 - recall: 0.9837 - precision: 0.9852 - f1_score: 0.9844
# Epoch 9/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0554 - accuracy: 0.9847 - recall: 0.9841 - precision: 0.9854 - f1_score: 0.9848
# Epoch 10/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0528 - accuracy: 0.9851 - recall: 0.9845 - precision: 0.9858 - f1_score: 0.9852
# Epoch 11/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0506 - accuracy: 0.9860 - recall: 0.9854 - precision: 0.9867 - f1_score: 0.9861
# Epoch 12/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0488 - accuracy: 0.9867 - recall: 0.9863 - precision: 0.9873 - f1_score: 0.9868
# Epoch 13/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0490 - accuracy: 0.9872 - recall: 0.9867 - precision: 0.9877 - f1_score: 0.9872
# Epoch 14/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0461 - accuracy: 0.9878 - recall: 0.9873 - precision: 0.9883 - f1_score: 0.9878
# Epoch 15/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0456 - accuracy: 0.9880 - recall: 0.9875 - precision: 0.9885 - f1_score: 0.9880
# Epoch 16/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0450 - accuracy: 0.9881 - recall: 0.9877 - precision: 0.9886 - f1_score: 0.9881
# Epoch 17/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0436 - accuracy: 0.9885 - recall: 0.9882 - precision: 0.9890 - f1_score: 0.9886
# Epoch 18/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0440 - accuracy: 0.9886 - recall: 0.9882 - precision: 0.9890 - f1_score: 0.9886
# Epoch 19/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0431 - accuracy: 0.9887 - recall: 0.9883 - precision: 0.9892 - f1_score: 0.9887
# Epoch 20/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0403 - accuracy: 0.9893 - recall: 0.9889 - precision: 0.9898 - f1_score: 0.9894
# Round: 0 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 45s 5ms/step - loss: 0.2330 - accuracy: 0.8956 - recall: 0.9319 - precision: 0.9549 - f1_score: 0.8944
# Epoch 2/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0905 - accuracy: 0.9708 - recall: 0.9685 - precision: 0.9732 - f1_score: 0.9708
# Epoch 3/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0731 - accuracy: 0.9786 - recall: 0.9775 - precision: 0.9798 - f1_score: 0.9786
# Epoch 4/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0639 - accuracy: 0.9820 - recall: 0.9812 - precision: 0.9830 - f1_score: 0.9821
# Epoch 5/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0563 - accuracy: 0.9844 - recall: 0.9837 - precision: 0.9852 - f1_score: 0.9845
# Epoch 6/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0541 - accuracy: 0.9853 - recall: 0.9847 - precision: 0.9860 - f1_score: 0.9854
# Epoch 7/20
# 6159/6159 [==============================] - 52s 8ms/step - loss: 0.0490 - accuracy: 0.9870 - recall: 0.9866 - precision: 0.9875 - f1_score: 0.9870
# Epoch 8/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.0478 - accuracy: 0.9874 - recall: 0.9869 - precision: 0.9879 - f1_score: 0.9874
# Epoch 9/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.0458 - accuracy: 0.9879 - recall: 0.9875 - precision: 0.9883 - f1_score: 0.9879
# Epoch 10/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0457 - accuracy: 0.9882 - recall: 0.9878 - precision: 0.9887 - f1_score: 0.9883
# Epoch 11/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0426 - accuracy: 0.9890 - recall: 0.9886 - precision: 0.9894 - f1_score: 0.9890
# Epoch 12/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0423 - accuracy: 0.9892 - recall: 0.9889 - precision: 0.9895 - f1_score: 0.9892
# Epoch 13/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0413 - accuracy: 0.9894 - recall: 0.9890 - precision: 0.9898 - f1_score: 0.9894
# Epoch 14/20
# 6159/6159 [==============================] - 35s 5ms/step - loss: 0.0410 - accuracy: 0.9896 - recall: 0.9893 - precision: 0.9900 - f1_score: 0.9896
# Epoch 15/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0400 - accuracy: 0.9901 - recall: 0.9899 - precision: 0.9905 - f1_score: 0.9902
# Epoch 16/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0392 - accuracy: 0.9902 - recall: 0.9899 - precision: 0.9905 - f1_score: 0.9902
# Epoch 17/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0395 - accuracy: 0.9901 - recall: 0.9898 - precision: 0.9904 - f1_score: 0.9900
# Epoch 18/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0392 - accuracy: 0.9903 - recall: 0.9900 - precision: 0.9907 - f1_score: 0.9903
# Epoch 19/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0376 - accuracy: 0.9907 - recall: 0.9904 - precision: 0.9910 - f1_score: 0.9907
# Epoch 20/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0366 - accuracy: 0.9909 - recall: 0.9907 - precision: 0.9912 - f1_score: 0.9909
# Round: 0 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 51s 6ms/step - loss: 0.2152 - accuracy: 0.9056 - recall: 0.9395 - precision: 0.9591 - f1_score: 0.9052
# Epoch 2/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1131 - accuracy: 0.9594 - recall: 0.9564 - precision: 0.9628 - f1_score: 0.9596
# Epoch 3/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0826 - accuracy: 0.9752 - recall: 0.9740 - precision: 0.9767 - f1_score: 0.9753
# Epoch 4/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0715 - accuracy: 0.9792 - recall: 0.9782 - precision: 0.9803 - f1_score: 0.9793
# Epoch 5/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0638 - accuracy: 0.9817 - recall: 0.9810 - precision: 0.9826 - f1_score: 0.9818
# Epoch 6/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0592 - accuracy: 0.9835 - recall: 0.9829 - precision: 0.9843 - f1_score: 0.9836
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0558 - accuracy: 0.9845 - recall: 0.9840 - precision: 0.9851 - f1_score: 0.9845
# Epoch 8/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0529 - accuracy: 0.9854 - recall: 0.9849 - precision: 0.9859 - f1_score: 0.9854
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0500 - accuracy: 0.9863 - recall: 0.9858 - precision: 0.9867 - f1_score: 0.9863
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0476 - accuracy: 0.9871 - recall: 0.9866 - precision: 0.9875 - f1_score: 0.9871
# Epoch 11/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0454 - accuracy: 0.9882 - recall: 0.9879 - precision: 0.9885 - f1_score: 0.9882
# Epoch 12/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0443 - accuracy: 0.9886 - recall: 0.9883 - precision: 0.9890 - f1_score: 0.9887
# Epoch 13/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0436 - accuracy: 0.9887 - recall: 0.9884 - precision: 0.9891 - f1_score: 0.9888
# Epoch 14/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0423 - accuracy: 0.9892 - recall: 0.9889 - precision: 0.9895 - f1_score: 0.9892
# Epoch 15/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0413 - accuracy: 0.9895 - recall: 0.9892 - precision: 0.9898 - f1_score: 0.9895
# Epoch 16/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0395 - accuracy: 0.9899 - recall: 0.9897 - precision: 0.9902 - f1_score: 0.9899
# Epoch 17/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0393 - accuracy: 0.9901 - recall: 0.9899 - precision: 0.9904 - f1_score: 0.9902
# Epoch 18/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0391 - accuracy: 0.9904 - recall: 0.9901 - precision: 0.9906 - f1_score: 0.9904
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0386 - accuracy: 0.9904 - recall: 0.9901 - precision: 0.9907 - f1_score: 0.9904
# Epoch 20/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.0365 - accuracy: 0.9906 - recall: 0.9903 - precision: 0.9909 - f1_score: 0.9906
# Round: 0 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 46s 6ms/step - loss: 0.2699 - accuracy: 0.8767 - recall: 0.9212 - precision: 0.9482 - f1_score: 0.8754
# Epoch 2/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.1107 - accuracy: 0.9605 - recall: 0.9570 - precision: 0.9639 - f1_score: 0.9604
# Epoch 3/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0914 - accuracy: 0.9709 - recall: 0.9695 - precision: 0.9724 - f1_score: 0.9709
# Epoch 4/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0773 - accuracy: 0.9764 - recall: 0.9755 - precision: 0.9777 - f1_score: 0.9766
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0717 - accuracy: 0.9791 - recall: 0.9782 - precision: 0.9802 - f1_score: 0.9792
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0652 - accuracy: 0.9813 - recall: 0.9807 - precision: 0.9820 - f1_score: 0.9813
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0595 - accuracy: 0.9836 - recall: 0.9831 - precision: 0.9843 - f1_score: 0.9837
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0572 - accuracy: 0.9841 - recall: 0.9837 - precision: 0.9846 - f1_score: 0.9841
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0549 - accuracy: 0.9853 - recall: 0.9849 - precision: 0.9858 - f1_score: 0.9853
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0535 - accuracy: 0.9854 - recall: 0.9850 - precision: 0.9858 - f1_score: 0.9854
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0502 - accuracy: 0.9866 - recall: 0.9862 - precision: 0.9870 - f1_score: 0.9866
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0489 - accuracy: 0.9870 - recall: 0.9867 - precision: 0.9874 - f1_score: 0.9870
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0486 - accuracy: 0.9873 - recall: 0.9870 - precision: 0.9877 - f1_score: 0.9873
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0455 - accuracy: 0.9880 - recall: 0.9877 - precision: 0.9884 - f1_score: 0.9881
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0458 - accuracy: 0.9880 - recall: 0.9878 - precision: 0.9883 - f1_score: 0.9880
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0454 - accuracy: 0.9881 - recall: 0.9879 - precision: 0.9884 - f1_score: 0.9881
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0453 - accuracy: 0.9883 - recall: 0.9880 - precision: 0.9886 - f1_score: 0.9883
# Epoch 18/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0444 - accuracy: 0.9889 - recall: 0.9886 - precision: 0.9891 - f1_score: 0.9889
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0436 - accuracy: 0.9885 - recall: 0.9882 - precision: 0.9889 - f1_score: 0.9885
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0437 - accuracy: 0.9887 - recall: 0.9885 - precision: 0.9890 - f1_score: 0.9887
# 12317/12317 [==============================] - 24s 2ms/step
# comm_round: 0 | global_loss: 1.739202857017517 | global_accuracy: 0.2764 | global_recall: 0.0 | global_precision: 0.0 | global_f1_score: 0.0
#
# New Weights Saved
# Round: 1 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.0992 - accuracy: 0.9672 - recall: 0.9626 - precision: 0.9720 - f1_score: 0.9669
# Epoch 2/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.0600 - accuracy: 0.9824 - recall: 0.9816 - precision: 0.9834 - f1_score: 0.9825
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0558 - accuracy: 0.9842 - recall: 0.9835 - precision: 0.9850 - f1_score: 0.9842
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0515 - accuracy: 0.9858 - recall: 0.9852 - precision: 0.9864 - f1_score: 0.9858
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0504 - accuracy: 0.9861 - recall: 0.9855 - precision: 0.9868 - f1_score: 0.9861
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0485 - accuracy: 0.9868 - recall: 0.9863 - precision: 0.9873 - f1_score: 0.9868
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0480 - accuracy: 0.9866 - recall: 0.9861 - precision: 0.9871 - f1_score: 0.9866
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0450 - accuracy: 0.9877 - recall: 0.9872 - precision: 0.9883 - f1_score: 0.9877
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0450 - accuracy: 0.9877 - recall: 0.9872 - precision: 0.9882 - f1_score: 0.9877
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0439 - accuracy: 0.9882 - recall: 0.9878 - precision: 0.9886 - f1_score: 0.9882
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0417 - accuracy: 0.9886 - recall: 0.9882 - precision: 0.9890 - f1_score: 0.9886
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0397 - accuracy: 0.9890 - recall: 0.9886 - precision: 0.9895 - f1_score: 0.9890
# Epoch 13/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0399 - accuracy: 0.9893 - recall: 0.9889 - precision: 0.9897 - f1_score: 0.9893
# Epoch 14/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0391 - accuracy: 0.9895 - recall: 0.9892 - precision: 0.9900 - f1_score: 0.9896
# Epoch 15/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0381 - accuracy: 0.9897 - recall: 0.9894 - precision: 0.9901 - f1_score: 0.9898
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0371 - accuracy: 0.9901 - recall: 0.9898 - precision: 0.9905 - f1_score: 0.9902
# Epoch 17/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0350 - accuracy: 0.9906 - recall: 0.9903 - precision: 0.9910 - f1_score: 0.9906
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0341 - accuracy: 0.9907 - recall: 0.9904 - precision: 0.9910 - f1_score: 0.9907
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0345 - accuracy: 0.9908 - recall: 0.9905 - precision: 0.9911 - f1_score: 0.9908
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0335 - accuracy: 0.9911 - recall: 0.9909 - precision: 0.9914 - f1_score: 0.9912
# Round: 1 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0966 - accuracy: 0.9681 - recall: 0.9638 - precision: 0.9726 - f1_score: 0.9679
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0575 - accuracy: 0.9834 - recall: 0.9826 - precision: 0.9844 - f1_score: 0.9835
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0522 - accuracy: 0.9856 - recall: 0.9850 - precision: 0.9863 - f1_score: 0.9857
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0502 - accuracy: 0.9863 - recall: 0.9857 - precision: 0.9869 - f1_score: 0.9863
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0469 - accuracy: 0.9871 - recall: 0.9866 - precision: 0.9877 - f1_score: 0.9871
# Epoch 6/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0466 - accuracy: 0.9878 - recall: 0.9874 - precision: 0.9882 - f1_score: 0.9878
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0436 - accuracy: 0.9883 - recall: 0.9878 - precision: 0.9887 - f1_score: 0.9883
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0422 - accuracy: 0.9887 - recall: 0.9883 - precision: 0.9893 - f1_score: 0.9888
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0415 - accuracy: 0.9892 - recall: 0.9888 - precision: 0.9896 - f1_score: 0.9892
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0406 - accuracy: 0.9895 - recall: 0.9891 - precision: 0.9898 - f1_score: 0.9895
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0404 - accuracy: 0.9893 - recall: 0.9890 - precision: 0.9897 - f1_score: 0.9894
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0385 - accuracy: 0.9900 - recall: 0.9897 - precision: 0.9904 - f1_score: 0.9901
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0378 - accuracy: 0.9902 - recall: 0.9898 - precision: 0.9905 - f1_score: 0.9902
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0380 - accuracy: 0.9900 - recall: 0.9897 - precision: 0.9903 - f1_score: 0.9900
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0365 - accuracy: 0.9903 - recall: 0.9900 - precision: 0.9907 - f1_score: 0.9903
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0352 - accuracy: 0.9908 - recall: 0.9905 - precision: 0.9912 - f1_score: 0.9908
# Epoch 17/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0346 - accuracy: 0.9910 - recall: 0.9908 - precision: 0.9913 - f1_score: 0.9911
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0336 - accuracy: 0.9914 - recall: 0.9911 - precision: 0.9917 - f1_score: 0.9914
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0323 - accuracy: 0.9915 - recall: 0.9912 - precision: 0.9918 - f1_score: 0.9915
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0340 - accuracy: 0.9913 - recall: 0.9910 - precision: 0.9915 - f1_score: 0.9913
# Round: 1 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.1028 - accuracy: 0.9658 - recall: 0.9610 - precision: 0.9709 - f1_score: 0.9655
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0594 - accuracy: 0.9826 - recall: 0.9817 - precision: 0.9834 - f1_score: 0.9826
# Epoch 3/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0549 - accuracy: 0.9844 - recall: 0.9837 - precision: 0.9851 - f1_score: 0.9844
# Epoch 4/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0533 - accuracy: 0.9853 - recall: 0.9847 - precision: 0.9860 - f1_score: 0.9854
# Epoch 5/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0495 - accuracy: 0.9867 - recall: 0.9862 - precision: 0.9873 - f1_score: 0.9867
# Epoch 6/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0482 - accuracy: 0.9871 - recall: 0.9867 - precision: 0.9876 - f1_score: 0.9871
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0445 - accuracy: 0.9881 - recall: 0.9876 - precision: 0.9885 - f1_score: 0.9881
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0425 - accuracy: 0.9887 - recall: 0.9882 - precision: 0.9892 - f1_score: 0.9887
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0421 - accuracy: 0.9887 - recall: 0.9884 - precision: 0.9892 - f1_score: 0.9888
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0412 - accuracy: 0.9891 - recall: 0.9887 - precision: 0.9895 - f1_score: 0.9891
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0402 - accuracy: 0.9893 - recall: 0.9889 - precision: 0.9897 - f1_score: 0.9893
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0397 - accuracy: 0.9895 - recall: 0.9890 - precision: 0.9900 - f1_score: 0.9895
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0382 - accuracy: 0.9897 - recall: 0.9893 - precision: 0.9901 - f1_score: 0.9897
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0396 - accuracy: 0.9895 - recall: 0.9892 - precision: 0.9900 - f1_score: 0.9896
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0375 - accuracy: 0.9901 - recall: 0.9897 - precision: 0.9905 - f1_score: 0.9901
# Epoch 16/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0364 - accuracy: 0.9901 - recall: 0.9898 - precision: 0.9906 - f1_score: 0.9902
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0352 - accuracy: 0.9907 - recall: 0.9903 - precision: 0.9910 - f1_score: 0.9907
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0345 - accuracy: 0.9907 - recall: 0.9904 - precision: 0.9910 - f1_score: 0.9907
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0335 - accuracy: 0.9908 - recall: 0.9905 - precision: 0.9912 - f1_score: 0.9909
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0339 - accuracy: 0.9910 - recall: 0.9907 - precision: 0.9914 - f1_score: 0.9910
# Round: 1 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0974 - accuracy: 0.9681 - recall: 0.9640 - precision: 0.9727 - f1_score: 0.9680
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0548 - accuracy: 0.9843 - recall: 0.9835 - precision: 0.9852 - f1_score: 0.9843
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0484 - accuracy: 0.9868 - recall: 0.9862 - precision: 0.9874 - f1_score: 0.9868
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0459 - accuracy: 0.9879 - recall: 0.9874 - precision: 0.9885 - f1_score: 0.9879
# Epoch 5/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0428 - accuracy: 0.9888 - recall: 0.9884 - precision: 0.9893 - f1_score: 0.9888
# Epoch 6/20
# 6159/6159 [==============================] - 49s 8ms/step - loss: 0.0431 - accuracy: 0.9890 - recall: 0.9887 - precision: 0.9893 - f1_score: 0.9890
# Epoch 7/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0409 - accuracy: 0.9895 - recall: 0.9892 - precision: 0.9899 - f1_score: 0.9895
# Epoch 8/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0394 - accuracy: 0.9899 - recall: 0.9896 - precision: 0.9903 - f1_score: 0.9899
# Epoch 9/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0391 - accuracy: 0.9901 - recall: 0.9898 - precision: 0.9905 - f1_score: 0.9901
# Epoch 10/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.0370 - accuracy: 0.9907 - recall: 0.9903 - precision: 0.9911 - f1_score: 0.9907
# Epoch 11/20
# 6159/6159 [==============================] - 47s 7ms/step - loss: 0.0368 - accuracy: 0.9907 - recall: 0.9904 - precision: 0.9910 - f1_score: 0.9907
# Epoch 12/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0346 - accuracy: 0.9911 - recall: 0.9908 - precision: 0.9915 - f1_score: 0.9911
# Epoch 13/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0346 - accuracy: 0.9911 - recall: 0.9908 - precision: 0.9915 - f1_score: 0.9912
# Epoch 14/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0339 - accuracy: 0.9914 - recall: 0.9911 - precision: 0.9917 - f1_score: 0.9914
# Epoch 15/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0331 - accuracy: 0.9915 - recall: 0.9912 - precision: 0.9919 - f1_score: 0.9915
# Epoch 16/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0323 - accuracy: 0.9917 - recall: 0.9914 - precision: 0.9921 - f1_score: 0.9918
# Epoch 17/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0309 - accuracy: 0.9922 - recall: 0.9919 - precision: 0.9925 - f1_score: 0.9922
# Epoch 18/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0301 - accuracy: 0.9924 - recall: 0.9922 - precision: 0.9927 - f1_score: 0.9924
# Epoch 19/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0303 - accuracy: 0.9925 - recall: 0.9923 - precision: 0.9927 - f1_score: 0.9925
# Epoch 20/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0314 - accuracy: 0.9923 - recall: 0.9921 - precision: 0.9926 - f1_score: 0.9923
# 12317/12317 [==============================] - 31s 2ms/step
# comm_round: 1 | global_loss: 1.0465089082717896 | global_accuracy: 0.9974 | global_recall: 0.9974 | global_precision: 0.9974 | global_f1_score: 0.9974
#
# New Weights Saved
# Round: 2 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.0342 - accuracy: 0.9908 - recall: 0.9905 - precision: 0.9911 - f1_score: 0.9908
# Epoch 2/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.0323 - accuracy: 0.9912 - recall: 0.9910 - precision: 0.9916 - f1_score: 0.9913
# Epoch 3/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0322 - accuracy: 0.9913 - recall: 0.9910 - precision: 0.9916 - f1_score: 0.9913
# Epoch 4/20
# 6159/6159 [==============================] - 41s 7ms/step - loss: 0.0322 - accuracy: 0.9914 - recall: 0.9912 - precision: 0.9916 - f1_score: 0.9914
# Epoch 5/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0319 - accuracy: 0.9915 - recall: 0.9911 - precision: 0.9918 - f1_score: 0.9915
# Epoch 6/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0323 - accuracy: 0.9915 - recall: 0.9912 - precision: 0.9918 - f1_score: 0.9915
# Epoch 7/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0315 - accuracy: 0.9918 - recall: 0.9916 - precision: 0.9921 - f1_score: 0.9918
# Epoch 8/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0315 - accuracy: 0.9916 - recall: 0.9914 - precision: 0.9919 - f1_score: 0.9916
# Epoch 9/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0303 - accuracy: 0.9919 - recall: 0.9918 - precision: 0.9922 - f1_score: 0.9920
# Epoch 10/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0301 - accuracy: 0.9920 - recall: 0.9917 - precision: 0.9922 - f1_score: 0.9919
# Epoch 11/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0309 - accuracy: 0.9917 - recall: 0.9915 - precision: 0.9921 - f1_score: 0.9918
# Epoch 12/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0298 - accuracy: 0.9921 - recall: 0.9919 - precision: 0.9923 - f1_score: 0.9921
# Epoch 13/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0300 - accuracy: 0.9920 - recall: 0.9918 - precision: 0.9923 - f1_score: 0.9920
# Epoch 14/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0294 - accuracy: 0.9922 - recall: 0.9920 - precision: 0.9925 - f1_score: 0.9922
# Epoch 15/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0298 - accuracy: 0.9922 - recall: 0.9920 - precision: 0.9924 - f1_score: 0.9922
# Epoch 16/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0288 - accuracy: 0.9924 - recall: 0.9921 - precision: 0.9927 - f1_score: 0.9924
# Epoch 17/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0298 - accuracy: 0.9924 - recall: 0.9922 - precision: 0.9926 - f1_score: 0.9924
# Epoch 18/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0280 - accuracy: 0.9925 - recall: 0.9923 - precision: 0.9928 - f1_score: 0.9926
# Epoch 19/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0283 - accuracy: 0.9924 - recall: 0.9922 - precision: 0.9927 - f1_score: 0.9924
# Epoch 20/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0277 - accuracy: 0.9924 - recall: 0.9921 - precision: 0.9926 - f1_score: 0.9924
# Round: 2 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0339 - accuracy: 0.9908 - recall: 0.9905 - precision: 0.9911 - f1_score: 0.9908
# Epoch 2/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0329 - accuracy: 0.9911 - recall: 0.9908 - precision: 0.9914 - f1_score: 0.9911
# Epoch 3/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0319 - accuracy: 0.9911 - recall: 0.9908 - precision: 0.9914 - f1_score: 0.9911
# Epoch 4/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0317 - accuracy: 0.9916 - recall: 0.9913 - precision: 0.9919 - f1_score: 0.9916
# Epoch 5/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0329 - accuracy: 0.9911 - recall: 0.9909 - precision: 0.9914 - f1_score: 0.9911
# Epoch 6/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0305 - accuracy: 0.9918 - recall: 0.9915 - precision: 0.9921 - f1_score: 0.9918
# Epoch 7/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0319 - accuracy: 0.9916 - recall: 0.9914 - precision: 0.9919 - f1_score: 0.9916
# Epoch 8/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0301 - accuracy: 0.9919 - recall: 0.9916 - precision: 0.9922 - f1_score: 0.9919
# Epoch 9/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0311 - accuracy: 0.9917 - recall: 0.9915 - precision: 0.9920 - f1_score: 0.9917
# Epoch 10/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0290 - accuracy: 0.9922 - recall: 0.9919 - precision: 0.9925 - f1_score: 0.9922
# Epoch 11/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0302 - accuracy: 0.9921 - recall: 0.9919 - precision: 0.9923 - f1_score: 0.9921
# Epoch 12/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0299 - accuracy: 0.9922 - recall: 0.9920 - precision: 0.9925 - f1_score: 0.9923
# Epoch 13/20
# 6159/6159 [==============================] - 46s 7ms/step - loss: 0.0290 - accuracy: 0.9924 - recall: 0.9921 - precision: 0.9927 - f1_score: 0.9924
# Epoch 14/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0298 - accuracy: 0.9921 - recall: 0.9919 - precision: 0.9923 - f1_score: 0.9921
# Epoch 15/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.0296 - accuracy: 0.9923 - recall: 0.9920 - precision: 0.9925 - f1_score: 0.9923
# Epoch 16/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0288 - accuracy: 0.9922 - recall: 0.9920 - precision: 0.9924 - f1_score: 0.9922
# Epoch 17/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0285 - accuracy: 0.9925 - recall: 0.9922 - precision: 0.9928 - f1_score: 0.9925
# Epoch 18/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0282 - accuracy: 0.9924 - recall: 0.9921 - precision: 0.9926 - f1_score: 0.9924
# Epoch 19/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0288 - accuracy: 0.9924 - recall: 0.9922 - precision: 0.9927 - f1_score: 0.9924
# Epoch 20/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0286 - accuracy: 0.9923 - recall: 0.9921 - precision: 0.9925 - f1_score: 0.9923
# Round: 2 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0342 - accuracy: 0.9909 - recall: 0.9906 - precision: 0.9912 - f1_score: 0.9909
# Epoch 2/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0322 - accuracy: 0.9914 - recall: 0.9911 - precision: 0.9916 - f1_score: 0.9914
# Epoch 3/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.0322 - accuracy: 0.9915 - recall: 0.9913 - precision: 0.9918 - f1_score: 0.9916
# Epoch 4/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.0315 - accuracy: 0.9914 - recall: 0.9912 - precision: 0.9918 - f1_score: 0.9915
# Epoch 5/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0330 - accuracy: 0.9913 - recall: 0.9911 - precision: 0.9916 - f1_score: 0.9914
# Epoch 6/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0318 - accuracy: 0.9917 - recall: 0.9914 - precision: 0.9920 - f1_score: 0.9917
# Epoch 7/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0331 - accuracy: 0.9915 - recall: 0.9912 - precision: 0.9918 - f1_score: 0.9915
# Epoch 8/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0312 - accuracy: 0.9919 - recall: 0.9916 - precision: 0.9921 - f1_score: 0.9918
# Epoch 9/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0314 - accuracy: 0.9918 - recall: 0.9916 - precision: 0.9920 - f1_score: 0.9918
# Epoch 10/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0301 - accuracy: 0.9920 - recall: 0.9918 - precision: 0.9923 - f1_score: 0.9921
# Epoch 11/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0305 - accuracy: 0.9923 - recall: 0.9921 - precision: 0.9925 - f1_score: 0.9923
# Epoch 12/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0286 - accuracy: 0.9924 - recall: 0.9921 - precision: 0.9927 - f1_score: 0.9924
# Epoch 13/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0296 - accuracy: 0.9922 - recall: 0.9920 - precision: 0.9924 - f1_score: 0.9922
# Epoch 14/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0298 - accuracy: 0.9924 - recall: 0.9921 - precision: 0.9926 - f1_score: 0.9924
# Epoch 15/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0303 - accuracy: 0.9920 - recall: 0.9917 - precision: 0.9922 - f1_score: 0.9920
# Epoch 16/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0290 - accuracy: 0.9923 - recall: 0.9921 - precision: 0.9926 - f1_score: 0.9924
# Epoch 17/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0278 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9927
# Epoch 18/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0284 - accuracy: 0.9927 - recall: 0.9924 - precision: 0.9929 - f1_score: 0.9926
# Epoch 19/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0311 - accuracy: 0.9918 - recall: 0.9916 - precision: 0.9921 - f1_score: 0.9918
# Epoch 20/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0300 - accuracy: 0.9922 - recall: 0.9920 - precision: 0.9924 - f1_score: 0.9922
# Round: 2 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0333 - accuracy: 0.9910 - recall: 0.9907 - precision: 0.9913 - f1_score: 0.9910
# Epoch 2/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0329 - accuracy: 0.9911 - recall: 0.9909 - precision: 0.9915 - f1_score: 0.9912
# Epoch 3/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0326 - accuracy: 0.9910 - recall: 0.9908 - precision: 0.9913 - f1_score: 0.9911
# Epoch 4/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0326 - accuracy: 0.9913 - recall: 0.9910 - precision: 0.9916 - f1_score: 0.9913
# Epoch 5/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0322 - accuracy: 0.9915 - recall: 0.9912 - precision: 0.9918 - f1_score: 0.9915
# Epoch 6/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0317 - accuracy: 0.9915 - recall: 0.9913 - precision: 0.9919 - f1_score: 0.9916
# Epoch 7/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0312 - accuracy: 0.9919 - recall: 0.9916 - precision: 0.9922 - f1_score: 0.9919
# Epoch 8/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0312 - accuracy: 0.9918 - recall: 0.9915 - precision: 0.9920 - f1_score: 0.9918
# Epoch 9/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0320 - accuracy: 0.9917 - recall: 0.9914 - precision: 0.9920 - f1_score: 0.9917
# Epoch 10/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0304 - accuracy: 0.9920 - recall: 0.9917 - precision: 0.9922 - f1_score: 0.9920
# Epoch 11/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0316 - accuracy: 0.9918 - recall: 0.9916 - precision: 0.9921 - f1_score: 0.9918
# Epoch 12/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0300 - accuracy: 0.9921 - recall: 0.9919 - precision: 0.9924 - f1_score: 0.9921
# Epoch 13/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0299 - accuracy: 0.9920 - recall: 0.9917 - precision: 0.9923 - f1_score: 0.9920
# Epoch 14/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0299 - accuracy: 0.9920 - recall: 0.9918 - precision: 0.9923 - f1_score: 0.9921
# Epoch 15/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0299 - accuracy: 0.9919 - recall: 0.9917 - precision: 0.9922 - f1_score: 0.9919
# Epoch 16/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0286 - accuracy: 0.9925 - recall: 0.9923 - precision: 0.9928 - f1_score: 0.9926
# Epoch 17/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0282 - accuracy: 0.9925 - recall: 0.9922 - precision: 0.9927 - f1_score: 0.9925
# Epoch 18/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0279 - accuracy: 0.9925 - recall: 0.9923 - precision: 0.9928 - f1_score: 0.9926
# Epoch 19/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0286 - accuracy: 0.9926 - recall: 0.9923 - precision: 0.9928 - f1_score: 0.9926
# Epoch 20/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0272 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9927
# 12317/12317 [==============================] - 32s 3ms/step
# comm_round: 2 | global_loss: 1.0452262163162231 | global_accuracy: 0.9992 | global_recall: 0.9991 | global_precision: 0.9992 | global_f1_score: 0.9992
#
# New Weights Saved
# Round: 3 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0277 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 2/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0277 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9927
# Epoch 3/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0267 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 4/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0264 - accuracy: 0.9931 - recall: 0.9930 - precision: 0.9933 - f1_score: 0.9932
# Epoch 5/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0277 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 6/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0266 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9932 - f1_score: 0.9929
# Epoch 7/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0270 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 8/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0275 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 9/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0272 - accuracy: 0.9925 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 10/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0267 - accuracy: 0.9929 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 11/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0283 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 12/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0274 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9927
# Epoch 13/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0270 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 14/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0266 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 15/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0264 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 16/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0271 - accuracy: 0.9927 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 17/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0267 - accuracy: 0.9928 - recall: 0.9927 - precision: 0.9930 - f1_score: 0.9928
# Epoch 18/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0257 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 19/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0258 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 20/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0257 - accuracy: 0.9932 - recall: 0.9930 - precision: 0.9933 - f1_score: 0.9932
# Round: 3 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0276 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 2/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0265 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 3/20
# 6159/6159 [==============================] - 46s 7ms/step - loss: 0.0264 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 4/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0269 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 5/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0281 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 6/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0269 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 7/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0271 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9929 - f1_score: 0.9927
# Epoch 8/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0270 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9927
# Epoch 9/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0281 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 10/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0279 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 11/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.0274 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 12/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.0265 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 13/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0270 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 14/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0265 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 15/20
# 6159/6159 [==============================] - 46s 7ms/step - loss: 0.0268 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 16/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0262 - accuracy: 0.9932 - recall: 0.9929 - precision: 0.9934 - f1_score: 0.9932
# Epoch 17/20
# 6159/6159 [==============================] - 50s 8ms/step - loss: 0.0274 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9929 - f1_score: 0.9926
# Epoch 18/20
# 6159/6159 [==============================] - 50s 8ms/step - loss: 0.0260 - accuracy: 0.9931 - recall: 0.9929 - precision: 0.9934 - f1_score: 0.9931
# Epoch 19/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0264 - accuracy: 0.9930 - recall: 0.9929 - precision: 0.9932 - f1_score: 0.9930
# Epoch 20/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.0260 - accuracy: 0.9930 - recall: 0.9929 - precision: 0.9933 - f1_score: 0.9930
# Round: 3 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 41s 7ms/step - loss: 0.0269 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 2/20
# 6159/6159 [==============================] - 41s 7ms/step - loss: 0.0271 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9929 - f1_score: 0.9927
# Epoch 3/20
# 6159/6159 [==============================] - 41s 7ms/step - loss: 0.0264 - accuracy: 0.9929 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 4/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0271 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 5/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0270 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 6/20
# 6159/6159 [==============================] - 41s 7ms/step - loss: 0.0270 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9929 - f1_score: 0.9927
# Epoch 7/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0270 - accuracy: 0.9927 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 8/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0272 - accuracy: 0.9928 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 9/20
# 6159/6159 [==============================] - 50s 8ms/step - loss: 0.0277 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9927
# Epoch 10/20
# 6159/6159 [==============================] - 47s 7ms/step - loss: 0.0266 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 11/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.0272 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 12/20
# 6159/6159 [==============================] - 52s 8ms/step - loss: 0.0278 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9929 - f1_score: 0.9927
# Epoch 13/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0271 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9929 - f1_score: 0.9927
# Epoch 14/20
# ...
# Epoch 5/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0270 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 6/20
# 6159/6159 [==============================] - 44s 7ms/step - loss: 0.0266 - accuracy: 0.9929 - recall: 0.9928 - precision: 0.9931 - f1_score: 0.9929
# Epoch 7/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0270 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9929 - f1_score: 0.9927
# Epoch 8/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0266 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9930 - f1_score: 0.9928
# Epoch 9/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.0266 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 10/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0264 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9928
# Epoch 11/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0272 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9929 - f1_score: 0.9928
# Epoch 12/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0263 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 13/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0267 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 14/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0268 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 15/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0264 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 16/20
# 6159/6159 [==============================] - 48s 8ms/step - loss: 0.0261 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 17/20
# 6159/6159 [==============================] - 50s 8ms/step - loss: 0.0269 - accuracy: 0.9929 - recall: 0.9928 - precision: 0.9931 - f1_score: 0.9929
# Epoch 18/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.0254 - accuracy: 0.9932 - recall: 0.9931 - precision: 0.9934 - f1_score: 0.9932
# Epoch 19/20
# 6159/6159 [==============================] - 49s 8ms/step - loss: 0.0254 - accuracy: 0.9931 - recall: 0.9930 - precision: 0.9933 - f1_score: 0.9931
# Epoch 20/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0266 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# 12317/12317 [==============================] - 24s 2ms/step
# comm_round: 3 | global_loss: 1.0449532270431519 | global_accuracy: 0.9993 | global_recall: 0.9993 | global_precision: 0.9993 | global_f1_score: 0.9993
#
# New Weights Saved
# Round: 4 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0259 - accuracy: 0.9931 - recall: 0.9930 - precision: 0.9933 - f1_score: 0.9932
# Epoch 2/20
# 6159/6159 [==============================] - 41s 7ms/step - loss: 0.0258 - accuracy: 0.9930 - recall: 0.9929 - precision: 0.9933 - f1_score: 0.9931
# Epoch 3/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0262 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 4/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0270 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 5/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0261 - accuracy: 0.9931 - recall: 0.9930 - precision: 0.9933 - f1_score: 0.9931
# Epoch 6/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0266 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 7/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0255 - accuracy: 0.9933 - recall: 0.9931 - precision: 0.9935 - f1_score: 0.9933
# Epoch 8/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0261 - accuracy: 0.9929 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 9/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0249 - accuracy: 0.9933 - recall: 0.9931 - precision: 0.9935 - f1_score: 0.9933
# Epoch 10/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0254 - accuracy: 0.9933 - recall: 0.9932 - precision: 0.9935 - f1_score: 0.9933
# Epoch 11/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0258 - accuracy: 0.9932 - recall: 0.9930 - precision: 0.9933 - f1_score: 0.9932
# Epoch 12/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0251 - accuracy: 0.9934 - recall: 0.9932 - precision: 0.9936 - f1_score: 0.9934
# Epoch 13/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0260 - accuracy: 0.9930 - recall: 0.9927 - precision: 0.9932 - f1_score: 0.9929
# Epoch 14/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0260 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9933 - f1_score: 0.9931
# Epoch 15/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0253 - accuracy: 0.9933 - recall: 0.9931 - precision: 0.9935 - f1_score: 0.9933
# Epoch 16/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0258 - accuracy: 0.9931 - recall: 0.9929 - precision: 0.9934 - f1_score: 0.9931
# Epoch 17/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0273 - accuracy: 0.9927 - recall: 0.9924 - precision: 0.9929 - f1_score: 0.9927
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0254 - accuracy: 0.9932 - recall: 0.9930 - precision: 0.9934 - f1_score: 0.9932
# Epoch 19/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0247 - accuracy: 0.9933 - recall: 0.9931 - precision: 0.9935 - f1_score: 0.9933
# Epoch 20/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0259 - accuracy: 0.9930 - recall: 0.9929 - precision: 0.9932 - f1_score: 0.9930
# Round: 4 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0266 - accuracy: 0.9931 - recall: 0.9929 - precision: 0.9933 - f1_score: 0.9931
# Epoch 2/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.0258 - accuracy: 0.9932 - recall: 0.9930 - precision: 0.9934 - f1_score: 0.9932
# Epoch 3/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0264 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 4/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0265 - accuracy: 0.9930 - recall: 0.9929 - precision: 0.9933 - f1_score: 0.9931
# Epoch 5/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0268 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9931 - f1_score: 0.9929
# Epoch 6/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0251 - accuracy: 0.9933 - recall: 0.9931 - precision: 0.9935 - f1_score: 0.9933
# Epoch 7/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0262 - accuracy: 0.9931 - recall: 0.9930 - precision: 0.9934 - f1_score: 0.9932
# Epoch 8/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0262 - accuracy: 0.9931 - recall: 0.9930 - precision: 0.9933 - f1_score: 0.9931
# Epoch 9/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0259 - accuracy: 0.9932 - recall: 0.9930 - precision: 0.9934 - f1_score: 0.9932
# Epoch 10/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0256 - accuracy: 0.9932 - recall: 0.9931 - precision: 0.9934 - f1_score: 0.9933
# Epoch 11/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.0263 - accuracy: 0.9930 - recall: 0.9929 - precision: 0.9933 - f1_score: 0.9931
# Epoch 12/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0257 - accuracy: 0.9931 - recall: 0.9930 - precision: 0.9934 - f1_score: 0.9932
# Epoch 13/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0253 - accuracy: 0.9933 - recall: 0.9931 - precision: 0.9935 - f1_score: 0.9933
# Epoch 14/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.0261 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 15/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0261 - accuracy: 0.9934 - recall: 0.9931 - precision: 0.9936 - f1_score: 0.9934
# Epoch 16/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0256 - accuracy: 0.9932 - recall: 0.9930 - precision: 0.9935 - f1_score: 0.9932
# Epoch 17/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0252 - accuracy: 0.9934 - recall: 0.9932 - precision: 0.9937 - f1_score: 0.9934
# Epoch 18/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0264 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 19/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0252 - accuracy: 0.9933 - recall: 0.9931 - precision: 0.9935 - f1_score: 0.9933
# Epoch 20/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0246 - accuracy: 0.9934 - recall: 0.9933 - precision: 0.9936 - f1_score: 0.9934
# Round: 4 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0274 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9929 - f1_score: 0.9927
# Epoch 2/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.0283 - accuracy: 0.9925 - recall: 0.9923 - precision: 0.9927 - f1_score: 0.9925
# Epoch 3/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.0277 - accuracy: 0.9925 - recall: 0.9923 - precision: 0.9928 - f1_score: 0.9925
# Epoch 4/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0285 - accuracy: 0.9924 - recall: 0.9922 - precision: 0.9926 - f1_score: 0.9924
# Epoch 5/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.0272 - accuracy: 0.9930 - recall: 0.9929 - precision: 0.9932 - f1_score: 0.9930
# Epoch 6/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0271 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 7/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0272 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9929 - f1_score: 0.9927
# Epoch 8/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0270 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 9/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0267 - accuracy: 0.9928 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9928
# Epoch 10/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0270 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 11/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0264 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0267 - accuracy: 0.9928 - recall: 0.9926 - precision: 0.9930 - f1_score: 0.9928
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0270 - accuracy: 0.9928 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9928
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0267 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0274 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9927
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0272 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0268 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9929 - f1_score: 0.9927
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0261 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9932 - f1_score: 0.9930
# Epoch 19/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0262 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0256 - accuracy: 0.9932 - recall: 0.9930 - precision: 0.9934 - f1_score: 0.9932
# Round: 4 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0261 - accuracy: 0.9932 - recall: 0.9930 - precision: 0.9934 - f1_score: 0.9932
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0248 - accuracy: 0.9933 - recall: 0.9931 - precision: 0.9935 - f1_score: 0.9933
# Epoch 3/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.0264 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9933 - f1_score: 0.9929
# Epoch 4/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0258 - accuracy: 0.9931 - recall: 0.9929 - precision: 0.9933 - f1_score: 0.9931
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0266 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0261 - accuracy: 0.9930 - recall: 0.9928 - precision: 0.9932 - f1_score: 0.9930
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0258 - accuracy: 0.9931 - recall: 0.9929 - precision: 0.9933 - f1_score: 0.9931
# Epoch 8/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0252 - accuracy: 0.9933 - recall: 0.9931 - precision: 0.9935 - f1_score: 0.9933
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0250 - accuracy: 0.9932 - recall: 0.9930 - precision: 0.9935 - f1_score: 0.9932
# Epoch 10/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0267 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9928
# Epoch 11/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0257 - accuracy: 0.9931 - recall: 0.9929 - precision: 0.9933 - f1_score: 0.9931
# Epoch 12/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.0283 - accuracy: 0.9926 - recall: 0.9923 - precision: 0.9928 - f1_score: 0.9926
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0276 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9928 - f1_score: 0.9926
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0279 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9929 - f1_score: 0.9927
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0269 - accuracy: 0.9927 - recall: 0.9924 - precision: 0.9930 - f1_score: 0.9927
# Epoch 16/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0270 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9931 - f1_score: 0.9929
# Epoch 17/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.0270 - accuracy: 0.9927 - recall: 0.9925 - precision: 0.9930 - f1_score: 0.9927
# Epoch 18/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.0275 - accuracy: 0.9926 - recall: 0.9924 - precision: 0.9929 - f1_score: 0.9926
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0269 - accuracy: 0.9929 - recall: 0.9927 - precision: 0.9932 - f1_score: 0.9929
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.0260 - accuracy: 0.9930 - recall: 0.9929 - precision: 0.9933 - f1_score: 0.9931
# 12317/12317 [==============================] - 25s 2ms/step
# comm_round: 4 | global_loss: 1.0450845956802368 | global_accuracy: 0.9986 | global_recall: 0.9986 | global_precision: 0.9986 | global_f1_score: 0.9986

# %%
global_model.load_weights("FL_DP_Mirai_MLP.h5")

# %%
loss, accuracy, precision, recall, f1_score = test_model(x_batch, y_batch, global_model, comm_round)
print("loss : ", loss.numpy())
print("accuracy : ", accuracy)
print("precision : ", precision)
print("recall : ", recall)
print("f1_score : ", f1_score)
# Out:
# 12317/12317 [==============================] - 25s 2ms/step
# comm_round: 4 | global_loss: 1.0449532270431519 | global_accuracy: 0.9993 | global_recall: 0.9993 | global_precision: 0.9993 | global_f1_score: 0.9993
#
# loss :  1.0449532
# accuracy :  0.9993403191840255
# precision :  0.99934286
# recall :  0.9993403
# f1_score :  0.9993415

# %%
for(x_batch, y_batch) in test_batched:
    logits = global_model.predict(x_batch)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_batch, axis=1)
# Out:
# 12317/12317 [==============================] - 24s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report, precision_score, recall_score
from sklearn.metrics import matthews_corrcoef, roc_auc_score
from sklearn.metrics import f1_score as f1_score_rep
import seaborn as sn
import numpy as np

def print_score(y_pred, y_real, label_encoder):
    accuracy = accuracy_score(y_real, y_pred)
    precision = precision_score(y_real, y_pred, average="weighted")
    recall = recall_score(y_real, y_pred, average="weighted")
    f1 = f1_score_rep(y_real, y_pred, average="weighted")
    auc = roc_auc_score(y_real, logits, multi_class='ovr')

    print("Accuracy: {:.4f}".format(accuracy))
    print("Precision:: {:.4f}".format(precision))
    print("Recall:: {:.4f}".format(recall))
    print("F1_Score:: {:.4f}".format(f1))
    print("AUC:: {:.4f}".format(auc))
    
    print()
    print("Confusion Matrix")
    cm = confusion_matrix(y_real, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cm, index=[str(i) for i in label_encoder.classes_], columns=[str(i) for i in label_encoder.classes_])
    plt.figure(figsize=(10, 7))
    sn.heatmap(df_cm, annot=True)

    print()
    print("Classification Report")
    print(classification_report(y_real, y_pred, target_names=[str(i) for i in label_encoder.classes_]))

# %%
print_score(y_hat, y_true, label_encoder)
# Out:
# Accuracy: 0.9993
# Precision:: 0.9993
# Recall:: 0.9993
# F1_Score:: 0.9993
# AUC:: 1.0000
#
# Confusion Matrix
#
# Classification Report
#                 precision    recall  f1-score   support
#
#         benign       1.00      1.00      1.00     84459
#      mirai_ack       1.00      1.00      1.00     56029
#     mirai_scan       1.00      1.00      1.00     51230
#      mirai_syn       1.00      1.00      1.00     62501
#      mirai_udp       1.00      1.00      1.00    108953
# mirai_udpplain       1.00      1.00      1.00     30958
#
#       accuracy                           1.00    394130
#      macro avg       1.00      1.00      1.00    394130
#   weighted avg       1.00      1.00      1.00    394130

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, n_classes):
    lw = 2
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_ohe[:, i], y_hat_ohe[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes
    fpr["weighted"] = all_fpr
    tpr["weighted"] = mean_tpr
    roc_auc["weighted"] = auc(fpr["weighted"], tpr["weighted"])

    #fpr["micro"], tpr["micro"], _ = roc_curve(y_true_ohe.ravel(), y_hat_ohe.ravel())
    #roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    plt.figure(figsize=(8,8))
    plt.plot(
        fpr["weighted"],
        tpr["weighted"],
        label="weighted-average ROC curve (area = {0:0.2f})".format(roc_auc["weighted"]),
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )



    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(label_encoder.classes_[i], roc_auc[i]))

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("multiclass characteristic")
    plt.legend(loc="lower right")
    plt.show()

# %%
y_true_ohe = to_categorical(y_true, num_classes=len(label_encoder.classes_))
y_hat_ohe =  to_categorical(y_hat, num_classes=len(label_encoder.classes_))

# %%
ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, len(label_encoder.classes_))

# %%
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  forward_pass = tf.function(model.call, input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])
  graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
  flops = graph_info.total_float_ops
  return flops

# %%
# Calculate FLOPS
flops = get_flops(global_model)
# Out:
# WARNING:tensorflow:From c:\Users\Lambert\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.

# %%
print(f"FLOPS: {flops / 10 ** 6:.03} M")
# Out:
# FLOPS: 0.00861 M

# %%
print(f"FLOPS: {flops}")
# Out:
# FLOPS: 8612

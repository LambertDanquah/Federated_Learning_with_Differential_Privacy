# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(42)

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(42)

# %%
#Benign
benign_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.benign.csv')
benign_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.benign.csv')
benign_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.benign.csv')
benign_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.benign.csv')
benign_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.benign.csv')
benign_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.benign.csv')
benign_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.benign.csv')

benign_traffic = pd.concat([benign_1, benign_2, benign_4, benign_5, benign_6, benign_8, benign_9], ignore_index=True)

benign_traffic.shape
# Out:
# (464682, 115)

# %%
#Scan
mirai_scan_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.scan.csv')
mirai_scan_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.scan.csv')
mirai_scan_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.scan.csv')
mirai_scan_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.scan.csv')
mirai_scan_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.scan.csv')
mirai_scan_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.scan.csv')
mirai_scan_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.scan.csv')

mirai_scan_traffic = pd.concat([mirai_scan_1, mirai_scan_2, mirai_scan_4, mirai_scan_5, mirai_scan_6, mirai_scan_8, mirai_scan_9], ignore_index=True)

mirai_scan_traffic.shape
# Out:
# (537979, 115)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')
mirai_syn_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.syn.csv')
mirai_syn_8  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.syn.csv')
mirai_syn_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.syn.csv')


mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5, mirai_syn_6, mirai_syn_8, mirai_syn_9], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (733299, 115)

# %%
#Ack
mirai_ack_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.ack.csv')
mirai_ack_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.ack.csv')
mirai_ack_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.ack.csv')
mirai_ack_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.ack.csv')
mirai_ack_6  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.ack.csv')
mirai_ack_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.ack.csv')
mirai_ack_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.ack.csv')

mirai_ack_traffic = pd.concat([mirai_ack_1 , mirai_ack_2, mirai_ack_4, mirai_ack_5, mirai_ack_6, mirai_ack_8, mirai_ack_9], ignore_index=True)

mirai_ack_traffic.shape
# Out:
# (643821, 115)

# %%
#Udp Flooding
mirai_udp_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udp.csv')
mirai_udp_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udp.csv')
mirai_udp_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udp.csv')
mirai_udp_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udp.csv')
mirai_udp_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udp.csv')
mirai_udp_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udp.csv')
mirai_udp_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udp.csv')

mirai_udp_traffic = pd.concat([mirai_udp_1 , mirai_udp_2, mirai_udp_4, mirai_udp_5], ignore_index=True)

mirai_udp_traffic.shape
# Out:
# (762428, 115)

# %%
#Udp plain Flooding
mirai_udpplain_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udpplain.csv')
mirai_udpplain_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udpplain.csv')
mirai_udpplain_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udpplain.csv')
mirai_udpplain_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udpplain.csv')
mirai_udpplain_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udpplain.csv')
mirai_udpplain_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udpplain.csv')
mirai_udpplain_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udpplain.csv')

mirai_udpplain_traffic = pd.concat([mirai_udpplain_1 , mirai_udpplain_2, mirai_udpplain_4, mirai_udpplain_5, mirai_udpplain_6, mirai_udpplain_8, mirai_udpplain_9], ignore_index=True)

mirai_udpplain_traffic.shape
# Out:
# (523304, 115)

# %%
benign_traffic['label'] = 'benign'
mirai_scan_traffic['label'] = 'mirai_scan'
mirai_syn_traffic['label'] = 'mirai_syn'
mirai_ack_traffic['label'] = 'mirai_ack'
mirai_udp_traffic['label'] = 'mirai_udp'
mirai_udpplain_traffic['label'] = 'mirai_udpplain'

selected_mirai_dataset  = pd.concat([benign_traffic, mirai_scan_traffic, mirai_syn_traffic,
                mirai_ack_traffic, mirai_udp_traffic, mirai_udpplain_traffic],
                axis=0, sort=False, ignore_index=True)

# %%
selected_mirai_dataset.shape
# Out:
# (3665513, 116)

# %%
#Number of Missing Values in the Dataset
selected_mirai_dataset.isnull().sum().sum()
# Out:
# 0

# %%
#Number of Duplicate Rows in the Dataset
selected_mirai_dataset.duplicated().sum()
# Out:
# 1607667

# %%
# Remove duplicate rows from the Dataset
selected_mirai_dataset = selected_mirai_dataset.drop_duplicates()

# Check the number of duplicate rows after removal
selected_mirai_dataset.duplicated().sum()
# Out:
# 0

# %%
selected_mirai_dataset.shape
# Out:
# (2057846, 116)

# %%
import numpy as np

# Select columns for z-score calculation (excluding the last column)
column_features = selected_mirai_dataset.iloc[:, :-1]

# Calculate z-scores for each column
z_scores = (column_features - column_features.mean()) / column_features.std()

# Set a threshold for z-score beyond which a data point is considered an outlier
z_score_threshold = 3  # Adjust this threshold as needed

# Identify rows where any z-score exceeds the threshold
outlier_mask = (np.abs(z_scores) > z_score_threshold).any(axis=1)

# Remove outliers from the dataset
selected_mirai_dataset = selected_mirai_dataset[~outlier_mask]

# %%
selected_mirai_dataset.shape
# Out:
# (1791013, 116)

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the columns to be normalized (excluding the 'label' column)
column_to_normalize = selected_mirai_dataset.columns[selected_mirai_dataset.columns != 'label']


# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
selected_mirai_dataset[column_to_normalize] = scaler.fit_transform(selected_mirai_dataset[column_to_normalize])

# %%
selected_mirai_dataset.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          0.000000    1.249001e-16            0.000000          0.000000
# 1          0.000000    4.819672e-01            0.000000          0.000000
# 2          0.003148    4.925557e-01            0.000359          0.002146
# 3          0.000000    4.540984e-01            0.000000          0.000000
# 4          0.002496    1.838376e-01            0.185459          0.001867
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0    1.249001e-16            0.000000          0.000000    1.249001e-16
# 1    4.819672e-01            0.000000          0.000000    4.823113e-01
# 2    4.922553e-01            0.000349          0.000831    4.923052e-01
# 3    4.540984e-01            0.000000          0.000000    4.544225e-01
# 4    2.009185e-01            0.184052          0.000793    2.184604e-01
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  \
# 0            0.000000            0.000000  ...              0.621779
# 1            0.000000            0.000000  ...              0.621779
# 2            0.000372            0.000112  ...              0.621779
# 3            0.000000            0.000000  ...              0.621779
# 4            0.198016            0.000111  ...              0.621779
#
#    HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0        0.48983           0.000000     2.775558e-17        0.000000
# 1        0.48983           0.000324     4.660044e-01        0.044165
# 2        0.48983           0.000399     4.716444e-01        0.084709
# 3        0.48983           0.000000     4.540984e-01        0.000000
# 4        0.48983           0.000000     2.775558e-17        0.000000
#
#    HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0          2.775558e-17           0.000000               0.615715
# 1          4.570463e-01           0.000277               0.615715
# 2          4.625779e-01           0.001019               0.615715
# 3          4.453691e-01           0.000000               0.615715
# 4          2.775558e-17           0.000000               0.615715
#
#    HpHp_L0.01_pcc   label
# 0        0.481785  benign
# 1        0.481785  benign
# 2        0.481785  benign
# 3        0.481785  benign
# 4        0.481785  benign
#
# [5 rows x 116 columns]

# %%
selected_mirai_dataset = selected_mirai_dataset.sample(frac=1).reset_index(drop=True)
selected_mirai_dataset.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          0.287190        0.505192            0.611501          0.340858
# 1          0.359868        0.741996            0.187679          0.418616
# 2          0.533150        0.013100            0.000482          0.563160
# 3          0.547366        0.307905            0.576886          0.528022
# 4          0.617502        0.010703            0.000489          0.563486
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0        0.571984            0.532849          0.472836        0.624271
# 1        0.673638            0.331671          0.513224        0.579656
# 2        0.013830            0.000457          0.590421        0.015965
# 3        0.365199            0.587526          0.535065        0.473057
# 4        0.011628            0.000476          0.501688        0.013839
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  \
# 0            0.493508            0.706866  ...              0.621779
# 1            0.513586            0.711377  ...              0.621779
# 2            0.000430            0.537546  ...              0.621779
# 3            0.613038            0.718392  ...              0.621779
# 4            0.000487            0.413594  ...              0.621779
#
#    HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0        0.48983                0.0         0.829508             0.0
# 1        0.48983                0.0         0.809836             0.0
# 2        0.48983                0.0         0.022951             0.0
# 3        0.48983                0.0         0.809836             0.0
# 4        0.48983                0.0         0.022951             0.0
#
#    HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0              0.813562                0.0               0.615715
# 1              0.794268                0.0               0.615715
# 2              0.022510                0.0               0.615715
# 3              0.794268                0.0               0.615715
# 4              0.022510                0.0               0.615715
#
#    HpHp_L0.01_pcc      label
# 0        0.481785  mirai_ack
# 1        0.481785  mirai_udp
# 2        0.481785  mirai_syn
# 3        0.481785  mirai_udp
# 4        0.481785  mirai_syn
#
# [5 rows x 116 columns]

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# Calculate percentage values
class_counts = selected_mirai_dataset['label'].value_counts(normalize=True) * 100

plt.title("Class Distribution")
bar_plot = selected_mirai_dataset['label'].value_counts().plot(kind='bar')
plt.xlabel('Classes')
plt.ylabel('Frequency')

# Annotate each bar with its percentage value
for i, val in enumerate(class_counts):
    plt.text(i, selected_mirai_dataset['label'].value_counts()[i], f'{val:.2f}%', ha='center')

plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(selected_mirai_dataset['label'].value_counts())
# Out:
# mirai_udp         542583
# mirai_syn         307920
# benign            286720
# mirai_ack         279524
# mirai_scan        255818
# mirai_udpplain    118448
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(selected_mirai_dataset, test_size=0.2, random_state=42, stratify=selected_mirai_dataset["label"])

# %%
features = list(train_df.columns)
features.remove("label")

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_df["label"] = label_encoder.fit_transform(train_df["label"])
test_df["label"] = label_encoder.transform(test_df["label"])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=18)
X_train = train_df[features].values
#X_train = pca.fit_transform(X_train)
y_train = train_df["label"].values

X_test = test_df[features].values
#X_test = pca.fit_transform(X_test)
y_test = test_df["label"].values

# %%
import statsmodels.api as sm
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from tabulate import tabulate

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train)

class_weights = {k: v for k,v in enumerate(class_weights)}
class_weights
# Out:
# {0: 1.0410926455543155,
#  1: 1.0678952444410656,
#  2: 1.1668556034412554,
#  3: 0.9694144041742444,
#  4: 0.5501505915383068,
#  5: 2.5200948370779206}

# %%
input_shape = X_train.shape[1:]
nb_classes = len(label_encoder.classes_)

# %%
input_shape
# Out:
# (115,)

# %%
from tensorflow.keras.utils import to_categorical

def convert_to_categorical(y, nb_classes):
    return to_categorical(y, num_classes=nb_classes)

# %%
import random

def data_indices(labels: np.ndarray, nb_clients: int):
    data_len = len(labels)
    indices = np.arange(data_len)
    np.random.shuffle(indices)
    chunk_size = data_len // nb_clients
    chunks = [indices[i:i+chunk_size] for i in range(0, data_len, chunk_size)]

    # Ensure non-IID distribution by shuffling 2 of the 4 chunks
    chunks[-1] = np.random.permutation(chunks[-1])
    chunks[-3] = np.random.permutation(chunks[-3])
    

    return chunks

# %%
def sample(y:np.ndarray, nb_clients: int):
    sampler_fn = data_indices
    client_data_indices = sampler_fn(y, nb_clients)
    return client_data_indices

# %%
def assign_data_to_clients(clients: dict, X:np.ndarray, y:np.ndarray, nb_classes:int):
    sampled_data_indices = sample(y, len(clients.keys()))  # Use the sample function to get data indices
    for client_name, data_indices in zip(clients.keys(), sampled_data_indices):
        X = X_train[data_indices]  # Subset the features for the current client
        y = y_train[data_indices]  # Subset the labels for the current client
        y = convert_to_categorical(y, nb_classes)  # Convert labels to categorical format if needed
        clients[client_name] = list(zip(X, y))  # Assign data to the current client
    return clients

# %%
def create_clients(X, y, nb_classes, num_clients=4, initial='clients'):
    # Create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]
    clients = {client_names[i] : [] for i in range(len(client_names))}
    return assign_data_to_clients(clients, X, y, nb_classes)

# %%
def batch_data(data_shard, batch_size=64):
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    del data_shard

    len_label = len(label)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    del data, label
    return dataset.shuffle(len_label).batch(batch_size)

# %%
import keras.backend as K
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import keras
import os
from keras.models import Model
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Activation, BatchNormalization, GRU, Dense, Dropout, Input

def get_model(input_shape, nb_classes):
    inputs = Input(shape=input_shape)
    
    x = Dense(32, activation="relu")(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = Dropout(0.2)(x)
    outputs = Dense(nb_classes, activation="softmax")(x)
    
    return keras.Model(inputs, outputs)

# %%
import tensorflow_privacy
from tensorflow_privacy.privacy.optimizers import dp_optimizer_keras  
from keras.metrics import Recall, Precision
from tensorflow.keras.utils import plot_model

learning_rate = 1e-3
comms_round = 5
loss='categorical_crossentropy'
metrics = ["accuracy", Recall(), Precision(), f1_score]
#optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
optimizer = tensorflow_privacy.DPKerasAdamOptimizer(l2_norm_clip= 1.6, noise_multiplier= 0.01, num_microbatches=1, learning_rate= learning_rate)


#initialize global model
global_model = get_model(input_shape, nb_classes)

global_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 115)]             0
#
#  dense (Dense)               (None, 32)                3712
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  batch_normalization_2 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 7462 (29.15 KB)
# Trainable params: 7270 (28.40 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
BATCH_SIZE = 64

# create clients
clients_batched = create_clients(X_train, y_train, nb_classes, num_clients=4, initial='client')

del X_train, y_train

# process and batch the training data for each client
client_set = {k: {} for k in clients_batched.keys()}

for (client_name, data) in clients_batched.items():
    client_set[client_name]["dataset"] = batch_data(data, BATCH_SIZE)
    local_model = get_model(input_shape, nb_classes)
    local_model.compile(loss=loss,
                      optimizer=optimizer,
                      metrics=metrics)
    client_set[client_name]["model"] = local_model

# %%
#process and batch the test set

y_test = convert_to_categorical(y_test, nb_classes)

test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

del X_test, y_test

# %%
# Define a function to calculate the weight scaling factor
def weight_scalling_factor(clients, client_name):
    client_names = list(clients.keys())
    # Get the batch size
    bs = list(clients[client_name]["dataset"])[0][0].shape[0]
    # Calculate the total training data points across clients
    global_count = sum([tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() for client_name in client_names]) * bs
    # Calculate the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() * bs
    return local_count / global_count

# %%
# Define a function to scale model weights
def scale_model_weights(weight, scalar):
    '''function for scaling a model's weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final

# %%
def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights --> FedAvg'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)

    return avg_grad

# %%
from sklearn.metrics import accuracy_score

def test_model(X_test, y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(y_test, logits)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(np.argmax(y_test, axis=1), np.argmax(logits, axis=1))

    r = Recall()
    r.update_state(y_test, logits)
    recall = r.result().numpy()

    p = Precision()
    p.update_state(y_test, logits)
    precision = p.result().numpy()

    f = f1_score(y_test, logits)
    f1 = f.numpy()

    print('comm_round: {} | global_loss: {} | global_accuracy: {:.4} | global_recall: {:.4} | global_precision: {:.4} | global_f1_score: {:.4} \n'.format(comm_round, loss, accuracy, recall, precision, f1))
    return loss, accuracy, precision, recall, f1

# %%
def train_client(client, global_weights):
    client_set[client]["model"] = client_set[client]["model"]

    #set local model weight to the weight of the global model
    client_set[client]["model"].set_weights(global_weights)

    #fit local model with client's data
    print(f"Round: {comm_round} | Client: {client} training")
    client_set[client]["model"].fit(client_set[client]["dataset"], epochs=20, verbose=1)

    #scale the model weights and add to list
    scaling_factor = weight_scalling_factor(client_set, client)
    scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
    return scaled_weights

# %%
import random

#commence global training loop
global_loss=[]
global_accuracy=[]
global_precision=[]
global_recall=[]
global_f1=[]
best_global_accuracy = 0

for comm_round in range(comms_round):
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()

    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(client_set.keys())
    random.shuffle(client_names)

    #loop through each client and create new local model
    for client in client_names:
        scaled_weights = train_client(client, global_weights)

        scaled_local_weight_list.append(scaled_weights)

    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)

    #update global model
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    g_accuracy = 0
    for(x_batch, y_batch) in test_batched:
        g_loss, g_accuracy, g_precision, g_recall, g_f1 = test_model(x_batch, y_batch, global_model, comm_round)
        global_loss.append(g_loss)
        global_accuracy.append(g_accuracy)
        global_precision.append(g_precision)
        global_recall.append(g_recall)
        global_f1.append(g_f1)

    if g_accuracy > best_global_accuracy:
        best_global_accuracy = g_accuracy
        global_model.save_weights('FL_DP_FS.h5')
        print("New Weights Saved")
# Out:
# Round: 0 | Client: client_3 training
# Epoch 1/20
# 5597/5597 [==============================] - 62s 5ms/step - loss: 0.4292 - accuracy: 0.7856 - recall: 0.7318 - precision: 0.8366 - f1_score: 0.7784
# Epoch 2/20
# 5597/5597 [==============================] - 28s 5ms/step - loss: 0.3545 - accuracy: 0.8125 - recall: 0.7767 - precision: 0.8460 - f1_score: 0.8095
# Epoch 3/20
# 5597/5597 [==============================] - 27s 5ms/step - loss: 0.3396 - accuracy: 0.8181 - recall: 0.7897 - precision: 0.8441 - f1_score: 0.8158
# Epoch 4/20
# 5597/5597 [==============================] - 27s 5ms/step - loss: 0.3303 - accuracy: 0.8246 - recall: 0.7985 - precision: 0.8487 - f1_score: 0.8227
# Epoch 5/20
# 5597/5597 [==============================] - 28s 5ms/step - loss: 0.3143 - accuracy: 0.8496 - recall: 0.8271 - precision: 0.8718 - f1_score: 0.8487
# Epoch 6/20
# 5597/5597 [==============================] - 28s 5ms/step - loss: 0.2873 - accuracy: 0.8788 - recall: 0.8588 - precision: 0.8989 - f1_score: 0.8782
# Epoch 7/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.2364 - accuracy: 0.9034 - recall: 0.8892 - precision: 0.9182 - f1_score: 0.9033
# Epoch 8/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.2143 - accuracy: 0.9122 - recall: 0.8989 - precision: 0.9262 - f1_score: 0.9122
# Epoch 9/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.2041 - accuracy: 0.9163 - recall: 0.9039 - precision: 0.9294 - f1_score: 0.9164
# Epoch 10/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1988 - accuracy: 0.9182 - recall: 0.9059 - precision: 0.9308 - f1_score: 0.9181
# Epoch 11/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1925 - accuracy: 0.9193 - recall: 0.9078 - precision: 0.9315 - f1_score: 0.9194
# Epoch 12/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1912 - accuracy: 0.9195 - recall: 0.9087 - precision: 0.9314 - f1_score: 0.9198
# Epoch 13/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1867 - accuracy: 0.9225 - recall: 0.9124 - precision: 0.9334 - f1_score: 0.9227
# Epoch 14/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1873 - accuracy: 0.9212 - recall: 0.9104 - precision: 0.9330 - f1_score: 0.9215
# Epoch 15/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1848 - accuracy: 0.9221 - recall: 0.9124 - precision: 0.9325 - f1_score: 0.9223
# Epoch 16/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1814 - accuracy: 0.9230 - recall: 0.9135 - precision: 0.9335 - f1_score: 0.9233
# Epoch 17/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1790 - accuracy: 0.9237 - recall: 0.9142 - precision: 0.9339 - f1_score: 0.9238
# Epoch 18/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1635 - accuracy: 0.9301 - recall: 0.9218 - precision: 0.9387 - f1_score: 0.9301
# Epoch 19/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1624 - accuracy: 0.9321 - recall: 0.9252 - precision: 0.9392 - f1_score: 0.9321
# Epoch 20/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1587 - accuracy: 0.9335 - recall: 0.9272 - precision: 0.9401 - f1_score: 0.9336
# Round: 0 | Client: client_2 training
# Epoch 1/20
# 5597/5597 [==============================] - 37s 5ms/step - loss: 0.3878 - accuracy: 0.8009 - recall: 0.8405 - precision: 0.8962 - f1_score: 0.7970
# Epoch 2/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2292 - accuracy: 0.8975 - recall: 0.8759 - precision: 0.9211 - f1_score: 0.8978
# Epoch 3/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2053 - accuracy: 0.9066 - recall: 0.8886 - precision: 0.9266 - f1_score: 0.9071
# Epoch 4/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1950 - accuracy: 0.9110 - recall: 0.8936 - precision: 0.9293 - f1_score: 0.9110
# Epoch 5/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1848 - accuracy: 0.9202 - recall: 0.9068 - precision: 0.9345 - f1_score: 0.9203
# Epoch 6/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1723 - accuracy: 0.9298 - recall: 0.9214 - precision: 0.9394 - f1_score: 0.9302
# Epoch 7/20
# 5597/5597 [==============================] - 32s 5ms/step - loss: 0.1668 - accuracy: 0.9316 - recall: 0.9230 - precision: 0.9425 - f1_score: 0.9326
# Epoch 8/20
# 5597/5597 [==============================] - 31s 5ms/step - loss: 0.1644 - accuracy: 0.9318 - recall: 0.9230 - precision: 0.9429 - f1_score: 0.9328
# Epoch 9/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1587 - accuracy: 0.9346 - recall: 0.9262 - precision: 0.9447 - f1_score: 0.9353
# Epoch 10/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1542 - accuracy: 0.9367 - recall: 0.9283 - precision: 0.9473 - f1_score: 0.9376
# Epoch 11/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1529 - accuracy: 0.9377 - recall: 0.9287 - precision: 0.9487 - f1_score: 0.9385
# Epoch 12/20
# 5597/5597 [==============================] - 32s 6ms/step - loss: 0.1483 - accuracy: 0.9397 - recall: 0.9309 - precision: 0.9506 - f1_score: 0.9405
# Epoch 13/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1473 - accuracy: 0.9407 - recall: 0.9318 - precision: 0.9515 - f1_score: 0.9415
# Epoch 14/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1442 - accuracy: 0.9430 - recall: 0.9349 - precision: 0.9525 - f1_score: 0.9435
# Epoch 15/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1402 - accuracy: 0.9449 - recall: 0.9382 - precision: 0.9532 - f1_score: 0.9456
# Epoch 16/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1391 - accuracy: 0.9471 - recall: 0.9410 - precision: 0.9543 - f1_score: 0.9475
# Epoch 17/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1308 - accuracy: 0.9506 - recall: 0.9454 - precision: 0.9571 - f1_score: 0.9512
# Epoch 18/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1152 - accuracy: 0.9597 - recall: 0.9556 - precision: 0.9640 - f1_score: 0.9597
# Epoch 19/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1083 - accuracy: 0.9635 - recall: 0.9603 - precision: 0.9670 - f1_score: 0.9636
# Epoch 20/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1059 - accuracy: 0.9645 - recall: 0.9614 - precision: 0.9678 - f1_score: 0.9646
# Round: 0 | Client: client_4 training
# Epoch 1/20
# 5597/5597 [==============================] - 35s 5ms/step - loss: 0.4036 - accuracy: 0.7889 - recall: 0.8508 - precision: 0.9076 - f1_score: 0.7859
# Epoch 2/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.3575 - accuracy: 0.8116 - recall: 0.7733 - precision: 0.8490 - f1_score: 0.8091
# Epoch 3/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.3184 - accuracy: 0.8520 - recall: 0.8266 - precision: 0.8783 - f1_score: 0.8514
# Epoch 4/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.2644 - accuracy: 0.8915 - recall: 0.8738 - precision: 0.9092 - f1_score: 0.8910
# Epoch 5/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.2446 - accuracy: 0.9015 - recall: 0.8866 - precision: 0.9166 - f1_score: 0.9012
# Epoch 6/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.2323 - accuracy: 0.9071 - recall: 0.8936 - precision: 0.9202 - f1_score: 0.9065
# Epoch 7/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2113 - accuracy: 0.9188 - recall: 0.9078 - precision: 0.9298 - f1_score: 0.9186
# Epoch 8/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1570 - accuracy: 0.9414 - recall: 0.9346 - precision: 0.9487 - f1_score: 0.9415
# Epoch 9/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1498 - accuracy: 0.9447 - recall: 0.9387 - precision: 0.9513 - f1_score: 0.9449
# Epoch 10/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1415 - accuracy: 0.9471 - recall: 0.9418 - precision: 0.9533 - f1_score: 0.9475
# Epoch 11/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1355 - accuracy: 0.9497 - recall: 0.9450 - precision: 0.9552 - f1_score: 0.9500
# Epoch 12/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1308 - accuracy: 0.9517 - recall: 0.9472 - precision: 0.9569 - f1_score: 0.9520
# Epoch 13/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1258 - accuracy: 0.9538 - recall: 0.9494 - precision: 0.9589 - f1_score: 0.9541
# Epoch 14/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1226 - accuracy: 0.9556 - recall: 0.9516 - precision: 0.9600 - f1_score: 0.9557
# Epoch 15/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1186 - accuracy: 0.9574 - recall: 0.9540 - precision: 0.9612 - f1_score: 0.9576
# Epoch 16/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1162 - accuracy: 0.9591 - recall: 0.9558 - precision: 0.9632 - f1_score: 0.9594
# Epoch 17/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.1138 - accuracy: 0.9599 - recall: 0.9568 - precision: 0.9635 - f1_score: 0.9601
# Epoch 18/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1056 - accuracy: 0.9636 - recall: 0.9603 - precision: 0.9673 - f1_score: 0.9637
# Epoch 19/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.0987 - accuracy: 0.9669 - recall: 0.9641 - precision: 0.9702 - f1_score: 0.9671
# Epoch 20/20
# 5597/5597 [==============================] - 29s 5ms/step - loss: 0.0954 - accuracy: 0.9682 - recall: 0.9656 - precision: 0.9712 - f1_score: 0.9684
# Round: 0 | Client: client_1 training
# Epoch 1/20
# 5597/5597 [==============================] - 37s 5ms/step - loss: 0.3991 - accuracy: 0.7898 - recall: 0.8507 - precision: 0.9125 - f1_score: 0.7860
# Epoch 2/20
# 5597/5597 [==============================] - 32s 6ms/step - loss: 0.3477 - accuracy: 0.8240 - recall: 0.7802 - precision: 0.8668 - f1_score: 0.8209
# Epoch 3/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2983 - accuracy: 0.8700 - recall: 0.8409 - precision: 0.8992 - f1_score: 0.8689
# Epoch 4/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2683 - accuracy: 0.8890 - recall: 0.8680 - precision: 0.9094 - f1_score: 0.8880
# Epoch 5/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2458 - accuracy: 0.9019 - recall: 0.8863 - precision: 0.9166 - f1_score: 0.9011
# Epoch 6/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2325 - accuracy: 0.9095 - recall: 0.8981 - precision: 0.9208 - f1_score: 0.9092
# Epoch 7/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2229 - accuracy: 0.9144 - recall: 0.9050 - precision: 0.9241 - f1_score: 0.9144
# Epoch 8/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2187 - accuracy: 0.9169 - recall: 0.9075 - precision: 0.9263 - f1_score: 0.9167
# Epoch 9/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2111 - accuracy: 0.9199 - recall: 0.9114 - precision: 0.9282 - f1_score: 0.9196
# Epoch 10/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2064 - accuracy: 0.9220 - recall: 0.9140 - precision: 0.9300 - f1_score: 0.9219
# Epoch 11/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2079 - accuracy: 0.9221 - recall: 0.9142 - precision: 0.9301 - f1_score: 0.9220
# Epoch 12/20
# 5597/5597 [==============================] - 31s 5ms/step - loss: 0.2025 - accuracy: 0.9240 - recall: 0.9169 - precision: 0.9314 - f1_score: 0.9240
# Epoch 13/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.2004 - accuracy: 0.9260 - recall: 0.9188 - precision: 0.9334 - f1_score: 0.9260
# Epoch 14/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1970 - accuracy: 0.9276 - recall: 0.9209 - precision: 0.9343 - f1_score: 0.9275
# Epoch 15/20
# 5597/5597 [==============================] - 31s 5ms/step - loss: 0.1923 - accuracy: 0.9302 - recall: 0.9242 - precision: 0.9366 - f1_score: 0.9303
# Epoch 16/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1866 - accuracy: 0.9328 - recall: 0.9268 - precision: 0.9387 - f1_score: 0.9327
# Epoch 17/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1826 - accuracy: 0.9341 - recall: 0.9291 - precision: 0.9395 - f1_score: 0.9342
# Epoch 18/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1792 - accuracy: 0.9361 - recall: 0.9310 - precision: 0.9418 - f1_score: 0.9363
# Epoch 19/20
# 5597/5597 [==============================] - 31s 5ms/step - loss: 0.1766 - accuracy: 0.9370 - recall: 0.9319 - precision: 0.9423 - f1_score: 0.9370
# Epoch 20/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1714 - accuracy: 0.9389 - recall: 0.9337 - precision: 0.9444 - f1_score: 0.9390
# 11194/11194 [==============================] - 24s 2ms/step
# comm_round: 0 | global_loss: 1.718988299369812 | global_accuracy: 0.3065 | global_recall: 0.0 | global_precision: 0.0 | global_f1_score: 0.0
#
# New Weights Saved
# Round: 1 | Client: client_4 training
# Epoch 1/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1829 - accuracy: 0.9291 - recall: 0.9181 - precision: 0.9410 - f1_score: 0.9291
# Epoch 2/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1504 - accuracy: 0.9435 - recall: 0.9375 - precision: 0.9499 - f1_score: 0.9436
# Epoch 3/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1416 - accuracy: 0.9483 - recall: 0.9439 - precision: 0.9532 - f1_score: 0.9485
# Epoch 4/20
# 5597/5597 [==============================] - 30s 5ms/step - loss: 0.1376 - accuracy: 0.9503 - recall: 0.9462 - precision: 0.9550 - f1_score: 0.9506
# Epoch 5/20
# 5597/5597 [==============================] - 32s 6ms/step - loss: 0.1333 - accuracy: 0.9525 - recall: 0.9488 - precision: 0.9564 - f1_score: 0.9525
# Epoch 6/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1306 - accuracy: 0.9535 - recall: 0.9501 - precision: 0.9573 - f1_score: 0.9536
# Epoch 7/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1302 - accuracy: 0.9537 - recall: 0.9505 - precision: 0.9573 - f1_score: 0.9538
# Epoch 8/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1259 - accuracy: 0.9553 - recall: 0.9522 - precision: 0.9587 - f1_score: 0.9554
# Epoch 9/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.1221 - accuracy: 0.9572 - recall: 0.9542 - precision: 0.9605 - f1_score: 0.9573
# Epoch 10/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.1108 - accuracy: 0.9623 - recall: 0.9598 - precision: 0.9650 - f1_score: 0.9624
# Epoch 11/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1046 - accuracy: 0.9647 - recall: 0.9624 - precision: 0.9674 - f1_score: 0.9649
# Epoch 12/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1001 - accuracy: 0.9663 - recall: 0.9642 - precision: 0.9687 - f1_score: 0.9664
# Epoch 13/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0990 - accuracy: 0.9671 - recall: 0.9649 - precision: 0.9694 - f1_score: 0.9671
# Epoch 14/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0974 - accuracy: 0.9676 - recall: 0.9656 - precision: 0.9697 - f1_score: 0.9676
# Epoch 15/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0935 - accuracy: 0.9684 - recall: 0.9666 - precision: 0.9707 - f1_score: 0.9686
# Epoch 16/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0932 - accuracy: 0.9689 - recall: 0.9670 - precision: 0.9711 - f1_score: 0.9690
# Epoch 17/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0905 - accuracy: 0.9696 - recall: 0.9681 - precision: 0.9715 - f1_score: 0.9698
# Epoch 18/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0888 - accuracy: 0.9704 - recall: 0.9688 - precision: 0.9722 - f1_score: 0.9705
# Epoch 19/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0874 - accuracy: 0.9712 - recall: 0.9697 - precision: 0.9728 - f1_score: 0.9712
# Epoch 20/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0875 - accuracy: 0.9710 - recall: 0.9692 - precision: 0.9729 - f1_score: 0.9710
# Round: 1 | Client: client_3 training
# Epoch 1/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1660 - accuracy: 0.9384 - recall: 0.9292 - precision: 0.9476 - f1_score: 0.9380
# Epoch 2/20
# 5597/5597 [==============================] - 38s 7ms/step - loss: 0.1351 - accuracy: 0.9509 - recall: 0.9458 - precision: 0.9562 - f1_score: 0.9509
# Epoch 3/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.1303 - accuracy: 0.9540 - recall: 0.9501 - precision: 0.9582 - f1_score: 0.9541
# Epoch 4/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1218 - accuracy: 0.9570 - recall: 0.9537 - precision: 0.9607 - f1_score: 0.9571
# Epoch 5/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.1188 - accuracy: 0.9580 - recall: 0.9550 - precision: 0.9616 - f1_score: 0.9583
# Epoch 6/20
# 5597/5597 [==============================] - 39s 7ms/step - loss: 0.1176 - accuracy: 0.9591 - recall: 0.9561 - precision: 0.9624 - f1_score: 0.9592
# Epoch 7/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1164 - accuracy: 0.9592 - recall: 0.9566 - precision: 0.9624 - f1_score: 0.9594
# Epoch 8/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1134 - accuracy: 0.9609 - recall: 0.9583 - precision: 0.9639 - f1_score: 0.9611
# Epoch 9/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1108 - accuracy: 0.9616 - recall: 0.9592 - precision: 0.9645 - f1_score: 0.9618
# Epoch 10/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1094 - accuracy: 0.9623 - recall: 0.9599 - precision: 0.9648 - f1_score: 0.9623
# Epoch 11/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1074 - accuracy: 0.9632 - recall: 0.9609 - precision: 0.9658 - f1_score: 0.9633
# Epoch 12/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1035 - accuracy: 0.9647 - recall: 0.9625 - precision: 0.9670 - f1_score: 0.9648
# Epoch 13/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1045 - accuracy: 0.9649 - recall: 0.9629 - precision: 0.9672 - f1_score: 0.9650
# Epoch 14/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1024 - accuracy: 0.9651 - recall: 0.9632 - precision: 0.9673 - f1_score: 0.9652
# Epoch 15/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0986 - accuracy: 0.9665 - recall: 0.9646 - precision: 0.9685 - f1_score: 0.9665
# Epoch 16/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0970 - accuracy: 0.9670 - recall: 0.9653 - precision: 0.9691 - f1_score: 0.9672
# Epoch 17/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0968 - accuracy: 0.9676 - recall: 0.9660 - precision: 0.9695 - f1_score: 0.9677
# Epoch 18/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0974 - accuracy: 0.9676 - recall: 0.9659 - precision: 0.9694 - f1_score: 0.9676
# Epoch 19/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0950 - accuracy: 0.9685 - recall: 0.9668 - precision: 0.9705 - f1_score: 0.9686
# Epoch 20/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0946 - accuracy: 0.9683 - recall: 0.9667 - precision: 0.9701 - f1_score: 0.9684
# Round: 1 | Client: client_1 training
# Epoch 1/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1875 - accuracy: 0.9304 - recall: 0.9193 - precision: 0.9424 - f1_score: 0.9304
# Epoch 2/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1479 - accuracy: 0.9443 - recall: 0.9366 - precision: 0.9533 - f1_score: 0.9448
# Epoch 3/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1436 - accuracy: 0.9469 - recall: 0.9401 - precision: 0.9544 - f1_score: 0.9471
# Epoch 4/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1350 - accuracy: 0.9499 - recall: 0.9443 - precision: 0.9568 - f1_score: 0.9505
# Epoch 5/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1339 - accuracy: 0.9511 - recall: 0.9459 - precision: 0.9570 - f1_score: 0.9514
# Epoch 6/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1328 - accuracy: 0.9514 - recall: 0.9466 - precision: 0.9571 - f1_score: 0.9518
# Epoch 7/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1279 - accuracy: 0.9535 - recall: 0.9493 - precision: 0.9584 - f1_score: 0.9538
# Epoch 8/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1258 - accuracy: 0.9547 - recall: 0.9508 - precision: 0.9592 - f1_score: 0.9549
# Epoch 9/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1213 - accuracy: 0.9563 - recall: 0.9529 - precision: 0.9602 - f1_score: 0.9565
# Epoch 10/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1182 - accuracy: 0.9582 - recall: 0.9550 - precision: 0.9616 - f1_score: 0.9583
# Epoch 11/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1160 - accuracy: 0.9585 - recall: 0.9554 - precision: 0.9618 - f1_score: 0.9586
# Epoch 12/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1127 - accuracy: 0.9606 - recall: 0.9578 - precision: 0.9635 - f1_score: 0.9606
# Epoch 13/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1113 - accuracy: 0.9606 - recall: 0.9581 - precision: 0.9637 - f1_score: 0.9609
# Epoch 14/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1115 - accuracy: 0.9612 - recall: 0.9584 - precision: 0.9638 - f1_score: 0.9611
# Epoch 15/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1108 - accuracy: 0.9609 - recall: 0.9586 - precision: 0.9637 - f1_score: 0.9611
# Epoch 16/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1058 - accuracy: 0.9625 - recall: 0.9603 - precision: 0.9649 - f1_score: 0.9626
# Epoch 17/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1031 - accuracy: 0.9635 - recall: 0.9614 - precision: 0.9659 - f1_score: 0.9636
# Epoch 18/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1042 - accuracy: 0.9640 - recall: 0.9619 - precision: 0.9662 - f1_score: 0.9640
# Epoch 19/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1035 - accuracy: 0.9642 - recall: 0.9622 - precision: 0.9665 - f1_score: 0.9643
# Epoch 20/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1012 - accuracy: 0.9647 - recall: 0.9628 - precision: 0.9669 - f1_score: 0.9648
# Round: 1 | Client: client_2 training
# Epoch 1/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1736 - accuracy: 0.9363 - recall: 0.9268 - precision: 0.9460 - f1_score: 0.9360
# Epoch 2/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1386 - accuracy: 0.9501 - recall: 0.9451 - precision: 0.9556 - f1_score: 0.9503
# Epoch 3/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1316 - accuracy: 0.9535 - recall: 0.9495 - precision: 0.9581 - f1_score: 0.9537
# Epoch 4/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1277 - accuracy: 0.9554 - recall: 0.9518 - precision: 0.9594 - f1_score: 0.9555
# Epoch 5/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1240 - accuracy: 0.9569 - recall: 0.9539 - precision: 0.9606 - f1_score: 0.9572
# Epoch 6/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1209 - accuracy: 0.9582 - recall: 0.9551 - precision: 0.9615 - f1_score: 0.9583
# Epoch 7/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1187 - accuracy: 0.9593 - recall: 0.9562 - precision: 0.9625 - f1_score: 0.9593
# Epoch 8/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1186 - accuracy: 0.9589 - recall: 0.9561 - precision: 0.9624 - f1_score: 0.9592
# Epoch 9/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1130 - accuracy: 0.9608 - recall: 0.9582 - precision: 0.9635 - f1_score: 0.9608
# Epoch 10/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1119 - accuracy: 0.9619 - recall: 0.9595 - precision: 0.9647 - f1_score: 0.9621
# Epoch 11/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1108 - accuracy: 0.9627 - recall: 0.9604 - precision: 0.9653 - f1_score: 0.9628
# Epoch 12/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1084 - accuracy: 0.9633 - recall: 0.9610 - precision: 0.9660 - f1_score: 0.9634
# Epoch 13/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1077 - accuracy: 0.9636 - recall: 0.9612 - precision: 0.9660 - f1_score: 0.9635
# Epoch 14/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1061 - accuracy: 0.9642 - recall: 0.9621 - precision: 0.9666 - f1_score: 0.9643
# Epoch 15/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1059 - accuracy: 0.9642 - recall: 0.9620 - precision: 0.9665 - f1_score: 0.9643
# Epoch 16/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1046 - accuracy: 0.9649 - recall: 0.9629 - precision: 0.9672 - f1_score: 0.9650
# Epoch 17/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1032 - accuracy: 0.9650 - recall: 0.9630 - precision: 0.9673 - f1_score: 0.9651
# Epoch 18/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1023 - accuracy: 0.9654 - recall: 0.9633 - precision: 0.9676 - f1_score: 0.9654
# Epoch 19/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1009 - accuracy: 0.9659 - recall: 0.9638 - precision: 0.9682 - f1_score: 0.9660
# Epoch 20/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1003 - accuracy: 0.9663 - recall: 0.9642 - precision: 0.9686 - f1_score: 0.9664
# 11194/11194 [==============================] - 25s 2ms/step
# comm_round: 1 | global_loss: 1.068495512008667 | global_accuracy: 0.9784 | global_recall: 0.9775 | global_precision: 0.9798 | global_f1_score: 0.9787
#
# New Weights Saved
# Round: 2 | Client: client_2 training
# Epoch 1/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0866 - accuracy: 0.9718 - recall: 0.9702 - precision: 0.9737 - f1_score: 0.9719
# Epoch 2/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0836 - accuracy: 0.9727 - recall: 0.9710 - precision: 0.9745 - f1_score: 0.9728
# Epoch 3/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0848 - accuracy: 0.9722 - recall: 0.9707 - precision: 0.9741 - f1_score: 0.9724
# Epoch 4/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0828 - accuracy: 0.9724 - recall: 0.9710 - precision: 0.9742 - f1_score: 0.9726
# Epoch 5/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0831 - accuracy: 0.9725 - recall: 0.9710 - precision: 0.9743 - f1_score: 0.9726
# Epoch 6/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0808 - accuracy: 0.9733 - recall: 0.9718 - precision: 0.9750 - f1_score: 0.9734
# Epoch 7/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0799 - accuracy: 0.9738 - recall: 0.9724 - precision: 0.9753 - f1_score: 0.9738
# Epoch 8/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0786 - accuracy: 0.9742 - recall: 0.9728 - precision: 0.9758 - f1_score: 0.9743
# Epoch 9/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0792 - accuracy: 0.9744 - recall: 0.9731 - precision: 0.9760 - f1_score: 0.9745
# Epoch 10/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0781 - accuracy: 0.9747 - recall: 0.9732 - precision: 0.9763 - f1_score: 0.9748
# Epoch 11/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0791 - accuracy: 0.9744 - recall: 0.9730 - precision: 0.9761 - f1_score: 0.9745
# Epoch 12/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0785 - accuracy: 0.9744 - recall: 0.9732 - precision: 0.9759 - f1_score: 0.9745
# Epoch 13/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0753 - accuracy: 0.9758 - recall: 0.9747 - precision: 0.9772 - f1_score: 0.9759
# Epoch 14/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0758 - accuracy: 0.9760 - recall: 0.9748 - precision: 0.9773 - f1_score: 0.9760
# Epoch 15/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0767 - accuracy: 0.9749 - recall: 0.9737 - precision: 0.9764 - f1_score: 0.9750
# Epoch 16/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0754 - accuracy: 0.9756 - recall: 0.9745 - precision: 0.9770 - f1_score: 0.9757
# Epoch 17/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0742 - accuracy: 0.9758 - recall: 0.9746 - precision: 0.9772 - f1_score: 0.9759
# Epoch 18/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0758 - accuracy: 0.9755 - recall: 0.9743 - precision: 0.9769 - f1_score: 0.9756
# Epoch 19/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0726 - accuracy: 0.9764 - recall: 0.9753 - precision: 0.9776 - f1_score: 0.9764
# Epoch 20/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0725 - accuracy: 0.9767 - recall: 0.9754 - precision: 0.9780 - f1_score: 0.9767
# Round: 2 | Client: client_4 training
# Epoch 1/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0864 - accuracy: 0.9714 - recall: 0.9700 - precision: 0.9734 - f1_score: 0.9717
# Epoch 2/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0838 - accuracy: 0.9724 - recall: 0.9707 - precision: 0.9743 - f1_score: 0.9725
# Epoch 3/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0833 - accuracy: 0.9724 - recall: 0.9709 - precision: 0.9742 - f1_score: 0.9725
# Epoch 4/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0842 - accuracy: 0.9728 - recall: 0.9713 - precision: 0.9745 - f1_score: 0.9729
# Epoch 5/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0801 - accuracy: 0.9740 - recall: 0.9726 - precision: 0.9755 - f1_score: 0.9740
# Epoch 6/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0804 - accuracy: 0.9739 - recall: 0.9724 - precision: 0.9755 - f1_score: 0.9739
# Epoch 7/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0791 - accuracy: 0.9742 - recall: 0.9729 - precision: 0.9758 - f1_score: 0.9743
# Epoch 8/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0815 - accuracy: 0.9732 - recall: 0.9719 - precision: 0.9748 - f1_score: 0.9733
# Epoch 9/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0786 - accuracy: 0.9743 - recall: 0.9730 - precision: 0.9759 - f1_score: 0.9745
# Epoch 10/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0805 - accuracy: 0.9739 - recall: 0.9724 - precision: 0.9757 - f1_score: 0.9740
# Epoch 11/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0779 - accuracy: 0.9747 - recall: 0.9732 - precision: 0.9764 - f1_score: 0.9748
# Epoch 12/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0778 - accuracy: 0.9746 - recall: 0.9732 - precision: 0.9761 - f1_score: 0.9747
# Epoch 13/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0754 - accuracy: 0.9757 - recall: 0.9746 - precision: 0.9771 - f1_score: 0.9758
# Epoch 14/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0762 - accuracy: 0.9754 - recall: 0.9743 - precision: 0.9769 - f1_score: 0.9755
# Epoch 15/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0761 - accuracy: 0.9756 - recall: 0.9744 - precision: 0.9769 - f1_score: 0.9757
# Epoch 16/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0754 - accuracy: 0.9755 - recall: 0.9743 - precision: 0.9769 - f1_score: 0.9756
# Epoch 17/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0766 - accuracy: 0.9751 - recall: 0.9739 - precision: 0.9764 - f1_score: 0.9752
# Epoch 18/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0746 - accuracy: 0.9763 - recall: 0.9752 - precision: 0.9777 - f1_score: 0.9764
# Epoch 19/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0734 - accuracy: 0.9765 - recall: 0.9754 - precision: 0.9777 - f1_score: 0.9765
# Epoch 20/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0730 - accuracy: 0.9764 - recall: 0.9753 - precision: 0.9777 - f1_score: 0.9765
# Round: 2 | Client: client_3 training
# Epoch 1/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0866 - accuracy: 0.9712 - recall: 0.9694 - precision: 0.9731 - f1_score: 0.9713
# Epoch 2/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0854 - accuracy: 0.9720 - recall: 0.9704 - precision: 0.9737 - f1_score: 0.9720
# Epoch 3/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1167 - accuracy: 0.9584 - recall: 0.9559 - precision: 0.9613 - f1_score: 0.9585
# Epoch 4/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1261 - accuracy: 0.9544 - recall: 0.9516 - precision: 0.9576 - f1_score: 0.9546
# Epoch 5/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1239 - accuracy: 0.9564 - recall: 0.9535 - precision: 0.9598 - f1_score: 0.9566
# Epoch 6/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1181 - accuracy: 0.9587 - recall: 0.9559 - precision: 0.9616 - f1_score: 0.9587
# Epoch 7/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1174 - accuracy: 0.9594 - recall: 0.9569 - precision: 0.9622 - f1_score: 0.9595
# Epoch 8/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1153 - accuracy: 0.9600 - recall: 0.9573 - precision: 0.9629 - f1_score: 0.9601
# Epoch 9/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1131 - accuracy: 0.9610 - recall: 0.9583 - precision: 0.9638 - f1_score: 0.9610
# Epoch 10/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1107 - accuracy: 0.9621 - recall: 0.9597 - precision: 0.9648 - f1_score: 0.9622
# Epoch 11/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.1126 - accuracy: 0.9609 - recall: 0.9585 - precision: 0.9637 - f1_score: 0.9610
# Epoch 12/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1100 - accuracy: 0.9618 - recall: 0.9596 - precision: 0.9645 - f1_score: 0.9620
# Epoch 13/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1088 - accuracy: 0.9632 - recall: 0.9612 - precision: 0.9655 - f1_score: 0.9633
# Epoch 14/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1074 - accuracy: 0.9628 - recall: 0.9609 - precision: 0.9652 - f1_score: 0.9630
# Epoch 15/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1053 - accuracy: 0.9637 - recall: 0.9616 - precision: 0.9661 - f1_score: 0.9638
# Epoch 16/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1061 - accuracy: 0.9635 - recall: 0.9614 - precision: 0.9659 - f1_score: 0.9636
# Epoch 17/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1046 - accuracy: 0.9640 - recall: 0.9619 - precision: 0.9663 - f1_score: 0.9641
# Epoch 18/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1033 - accuracy: 0.9644 - recall: 0.9624 - precision: 0.9666 - f1_score: 0.9645
# Epoch 19/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.1028 - accuracy: 0.9650 - recall: 0.9628 - precision: 0.9672 - f1_score: 0.9650
# Epoch 20/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.1004 - accuracy: 0.9652 - recall: 0.9634 - precision: 0.9675 - f1_score: 0.9654
# Round: 2 | Client: client_1 training
# Epoch 1/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0870 - accuracy: 0.9715 - recall: 0.9699 - precision: 0.9735 - f1_score: 0.9717
# Epoch 2/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0839 - accuracy: 0.9723 - recall: 0.9708 - precision: 0.9741 - f1_score: 0.9725
# Epoch 3/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0837 - accuracy: 0.9728 - recall: 0.9713 - precision: 0.9747 - f1_score: 0.9729
# Epoch 4/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0838 - accuracy: 0.9730 - recall: 0.9716 - precision: 0.9745 - f1_score: 0.9730
# Epoch 5/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0835 - accuracy: 0.9724 - recall: 0.9709 - precision: 0.9741 - f1_score: 0.9725
# Epoch 6/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0809 - accuracy: 0.9735 - recall: 0.9719 - precision: 0.9751 - f1_score: 0.9735
# Epoch 7/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0797 - accuracy: 0.9741 - recall: 0.9728 - precision: 0.9755 - f1_score: 0.9742
# Epoch 8/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0795 - accuracy: 0.9738 - recall: 0.9725 - precision: 0.9753 - f1_score: 0.9739
# Epoch 9/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0794 - accuracy: 0.9745 - recall: 0.9731 - precision: 0.9760 - f1_score: 0.9745
# Epoch 10/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0773 - accuracy: 0.9750 - recall: 0.9737 - precision: 0.9765 - f1_score: 0.9751
# Epoch 11/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0772 - accuracy: 0.9747 - recall: 0.9734 - precision: 0.9764 - f1_score: 0.9749
# Epoch 12/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0790 - accuracy: 0.9745 - recall: 0.9732 - precision: 0.9760 - f1_score: 0.9746
# Epoch 13/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0779 - accuracy: 0.9749 - recall: 0.9737 - precision: 0.9764 - f1_score: 0.9750
# Epoch 14/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0767 - accuracy: 0.9752 - recall: 0.9740 - precision: 0.9765 - f1_score: 0.9753
# Epoch 15/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0754 - accuracy: 0.9755 - recall: 0.9744 - precision: 0.9768 - f1_score: 0.9756
# Epoch 16/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0758 - accuracy: 0.9755 - recall: 0.9742 - precision: 0.9768 - f1_score: 0.9755
# Epoch 17/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0744 - accuracy: 0.9757 - recall: 0.9745 - precision: 0.9771 - f1_score: 0.9758
# Epoch 18/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0753 - accuracy: 0.9753 - recall: 0.9741 - precision: 0.9765 - f1_score: 0.9753
# Epoch 19/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0749 - accuracy: 0.9757 - recall: 0.9745 - precision: 0.9770 - f1_score: 0.9757
# Epoch 20/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0723 - accuracy: 0.9768 - recall: 0.9758 - precision: 0.9781 - f1_score: 0.9770
# 11194/11194 [==============================] - 25s 2ms/step
# comm_round: 2 | global_loss: 1.0494637489318848 | global_accuracy: 0.9971 | global_recall: 0.9969 | global_precision: 0.9973 | global_f1_score: 0.9971
#
# New Weights Saved
# Round: 3 | Client: client_2 training
# Epoch 1/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0717 - accuracy: 0.9766 - recall: 0.9754 - precision: 0.9780 - f1_score: 0.9767
# Epoch 2/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0722 - accuracy: 0.9768 - recall: 0.9756 - precision: 0.9780 - f1_score: 0.9768
# Epoch 3/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0739 - accuracy: 0.9765 - recall: 0.9752 - precision: 0.9778 - f1_score: 0.9765
# Epoch 4/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0727 - accuracy: 0.9767 - recall: 0.9755 - precision: 0.9780 - f1_score: 0.9767
# Epoch 5/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0735 - accuracy: 0.9762 - recall: 0.9750 - precision: 0.9775 - f1_score: 0.9763
# Epoch 6/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0739 - accuracy: 0.9760 - recall: 0.9747 - precision: 0.9774 - f1_score: 0.9760
# Epoch 7/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0715 - accuracy: 0.9769 - recall: 0.9758 - precision: 0.9782 - f1_score: 0.9770
# Epoch 8/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0725 - accuracy: 0.9768 - recall: 0.9757 - precision: 0.9781 - f1_score: 0.9769
# Epoch 9/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0719 - accuracy: 0.9767 - recall: 0.9757 - precision: 0.9780 - f1_score: 0.9768
# Epoch 10/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0721 - accuracy: 0.9767 - recall: 0.9756 - precision: 0.9780 - f1_score: 0.9768
# Epoch 11/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0695 - accuracy: 0.9773 - recall: 0.9762 - precision: 0.9785 - f1_score: 0.9774
# Epoch 12/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0700 - accuracy: 0.9771 - recall: 0.9760 - precision: 0.9784 - f1_score: 0.9771
# Epoch 13/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0690 - accuracy: 0.9775 - recall: 0.9765 - precision: 0.9789 - f1_score: 0.9777
# Epoch 14/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0691 - accuracy: 0.9774 - recall: 0.9763 - precision: 0.9787 - f1_score: 0.9775
# Epoch 15/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0759 - accuracy: 0.9751 - recall: 0.9739 - precision: 0.9766 - f1_score: 0.9752
# Epoch 16/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0690 - accuracy: 0.9773 - recall: 0.9762 - precision: 0.9786 - f1_score: 0.9774
# Epoch 17/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0678 - accuracy: 0.9780 - recall: 0.9769 - precision: 0.9792 - f1_score: 0.9780
# Epoch 18/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0691 - accuracy: 0.9773 - recall: 0.9762 - precision: 0.9786 - f1_score: 0.9773
# Epoch 19/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0675 - accuracy: 0.9782 - recall: 0.9772 - precision: 0.9794 - f1_score: 0.9783
# Epoch 20/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0669 - accuracy: 0.9787 - recall: 0.9777 - precision: 0.9797 - f1_score: 0.9787
# Round: 3 | Client: client_3 training
# Epoch 1/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0748 - accuracy: 0.9756 - recall: 0.9745 - precision: 0.9771 - f1_score: 0.9758
# Epoch 2/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0743 - accuracy: 0.9764 - recall: 0.9752 - precision: 0.9777 - f1_score: 0.9764
# Epoch 3/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0734 - accuracy: 0.9766 - recall: 0.9753 - precision: 0.9779 - f1_score: 0.9766
# Epoch 4/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0747 - accuracy: 0.9760 - recall: 0.9748 - precision: 0.9774 - f1_score: 0.9761
# Epoch 5/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0730 - accuracy: 0.9767 - recall: 0.9755 - precision: 0.9781 - f1_score: 0.9768
# Epoch 6/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0747 - accuracy: 0.9763 - recall: 0.9751 - precision: 0.9776 - f1_score: 0.9763
# Epoch 7/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0723 - accuracy: 0.9769 - recall: 0.9756 - precision: 0.9782 - f1_score: 0.9769
# Epoch 8/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0731 - accuracy: 0.9764 - recall: 0.9752 - precision: 0.9777 - f1_score: 0.9764
# Epoch 9/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0712 - accuracy: 0.9770 - recall: 0.9759 - precision: 0.9782 - f1_score: 0.9770
# Epoch 10/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0686 - accuracy: 0.9774 - recall: 0.9763 - precision: 0.9786 - f1_score: 0.9775
# Epoch 11/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0818 - accuracy: 0.9732 - recall: 0.9716 - precision: 0.9749 - f1_score: 0.9733
# Epoch 12/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0835 - accuracy: 0.9727 - recall: 0.9712 - precision: 0.9744 - f1_score: 0.9728
# Epoch 13/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0834 - accuracy: 0.9727 - recall: 0.9711 - precision: 0.9746 - f1_score: 0.9728
# Epoch 14/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0840 - accuracy: 0.9727 - recall: 0.9712 - precision: 0.9744 - f1_score: 0.9728
# Epoch 15/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0824 - accuracy: 0.9730 - recall: 0.9715 - precision: 0.9746 - f1_score: 0.9730
# Epoch 16/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0799 - accuracy: 0.9739 - recall: 0.9724 - precision: 0.9758 - f1_score: 0.9740
# Epoch 17/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0792 - accuracy: 0.9738 - recall: 0.9723 - precision: 0.9757 - f1_score: 0.9740
# Epoch 18/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0795 - accuracy: 0.9740 - recall: 0.9725 - precision: 0.9757 - f1_score: 0.9741
# Epoch 19/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0772 - accuracy: 0.9745 - recall: 0.9730 - precision: 0.9762 - f1_score: 0.9746
# Epoch 20/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0764 - accuracy: 0.9751 - recall: 0.9737 - precision: 0.9766 - f1_score: 0.9752
# Round: 3 | Client: client_1 training
# Epoch 1/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0720 - accuracy: 0.9763 - recall: 0.9750 - precision: 0.9776 - f1_score: 0.9763
# Epoch 2/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0722 - accuracy: 0.9768 - recall: 0.9756 - precision: 0.9781 - f1_score: 0.9768
# Epoch 3/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0740 - accuracy: 0.9762 - recall: 0.9750 - precision: 0.9776 - f1_score: 0.9762
# Epoch 4/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0722 - accuracy: 0.9768 - recall: 0.9757 - precision: 0.9781 - f1_score: 0.9769
# Epoch 5/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0726 - accuracy: 0.9766 - recall: 0.9754 - precision: 0.9779 - f1_score: 0.9766
# Epoch 6/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0725 - accuracy: 0.9765 - recall: 0.9753 - precision: 0.9779 - f1_score: 0.9766
# Epoch 7/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0723 - accuracy: 0.9765 - recall: 0.9753 - precision: 0.9779 - f1_score: 0.9766
# Epoch 8/20
# 5597/5597 [==============================] - 38s 7ms/step - loss: 0.0719 - accuracy: 0.9769 - recall: 0.9757 - precision: 0.9782 - f1_score: 0.9769
# Epoch 9/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0701 - accuracy: 0.9772 - recall: 0.9760 - precision: 0.9784 - f1_score: 0.9772
# Epoch 10/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0712 - accuracy: 0.9772 - recall: 0.9760 - precision: 0.9783 - f1_score: 0.9772
# Epoch 11/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0708 - accuracy: 0.9772 - recall: 0.9762 - precision: 0.9784 - f1_score: 0.9773
# Epoch 12/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0690 - accuracy: 0.9775 - recall: 0.9763 - precision: 0.9787 - f1_score: 0.9775
# Epoch 13/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0692 - accuracy: 0.9776 - recall: 0.9765 - precision: 0.9788 - f1_score: 0.9777
# Epoch 14/20
# ...
# Epoch 5/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0732 - accuracy: 0.9764 - recall: 0.9753 - precision: 0.9777 - f1_score: 0.9765
# Epoch 6/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0795 - accuracy: 0.9743 - recall: 0.9729 - precision: 0.9758 - f1_score: 0.9743
# Epoch 7/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0818 - accuracy: 0.9735 - recall: 0.9720 - precision: 0.9750 - f1_score: 0.9735
# Epoch 8/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0773 - accuracy: 0.9751 - recall: 0.9738 - precision: 0.9767 - f1_score: 0.9752
# Epoch 9/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0778 - accuracy: 0.9749 - recall: 0.9736 - precision: 0.9764 - f1_score: 0.9750
# Epoch 10/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0763 - accuracy: 0.9751 - recall: 0.9738 - precision: 0.9766 - f1_score: 0.9752
# Epoch 11/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0743 - accuracy: 0.9760 - recall: 0.9747 - precision: 0.9775 - f1_score: 0.9761
# Epoch 12/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0748 - accuracy: 0.9757 - recall: 0.9746 - precision: 0.9770 - f1_score: 0.9758
# Epoch 13/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0723 - accuracy: 0.9765 - recall: 0.9753 - precision: 0.9779 - f1_score: 0.9766
# Epoch 14/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0724 - accuracy: 0.9765 - recall: 0.9753 - precision: 0.9779 - f1_score: 0.9766
# Epoch 15/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0732 - accuracy: 0.9766 - recall: 0.9755 - precision: 0.9779 - f1_score: 0.9767
# Epoch 16/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0730 - accuracy: 0.9766 - recall: 0.9755 - precision: 0.9779 - f1_score: 0.9767
# Epoch 17/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0728 - accuracy: 0.9767 - recall: 0.9754 - precision: 0.9781 - f1_score: 0.9768
# Epoch 18/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0702 - accuracy: 0.9772 - recall: 0.9762 - precision: 0.9786 - f1_score: 0.9774
# Epoch 19/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0719 - accuracy: 0.9773 - recall: 0.9761 - precision: 0.9786 - f1_score: 0.9773
# Epoch 20/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0696 - accuracy: 0.9776 - recall: 0.9765 - precision: 0.9788 - f1_score: 0.9776
# 11194/11194 [==============================] - 26s 2ms/step
# comm_round: 3 | global_loss: 1.051461100578308 | global_accuracy: 0.9947 | global_recall: 0.9946 | global_precision: 0.9949 | global_f1_score: 0.9947
#
# Round: 4 | Client: client_2 training
# Epoch 1/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0684 - accuracy: 0.9776 - recall: 0.9767 - precision: 0.9788 - f1_score: 0.9777
# Epoch 2/20
# 5597/5597 [==============================] - 34s 6ms/step - loss: 0.0696 - accuracy: 0.9776 - recall: 0.9766 - precision: 0.9787 - f1_score: 0.9777
# Epoch 3/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0691 - accuracy: 0.9778 - recall: 0.9768 - precision: 0.9790 - f1_score: 0.9779
# Epoch 4/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0697 - accuracy: 0.9775 - recall: 0.9765 - precision: 0.9786 - f1_score: 0.9776
# Epoch 5/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0693 - accuracy: 0.9781 - recall: 0.9770 - precision: 0.9793 - f1_score: 0.9782
# Epoch 6/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0689 - accuracy: 0.9776 - recall: 0.9766 - precision: 0.9788 - f1_score: 0.9777
# Epoch 7/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0676 - accuracy: 0.9783 - recall: 0.9772 - precision: 0.9794 - f1_score: 0.9783
# Epoch 8/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0672 - accuracy: 0.9788 - recall: 0.9779 - precision: 0.9798 - f1_score: 0.9788
# Epoch 9/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0680 - accuracy: 0.9782 - recall: 0.9771 - precision: 0.9792 - f1_score: 0.9781
# Epoch 10/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0697 - accuracy: 0.9777 - recall: 0.9767 - precision: 0.9789 - f1_score: 0.9778
# Epoch 11/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0658 - accuracy: 0.9787 - recall: 0.9778 - precision: 0.9797 - f1_score: 0.9787
# Epoch 12/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0651 - accuracy: 0.9791 - recall: 0.9782 - precision: 0.9802 - f1_score: 0.9792
# Epoch 13/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0657 - accuracy: 0.9790 - recall: 0.9781 - precision: 0.9799 - f1_score: 0.9790
# Epoch 14/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0644 - accuracy: 0.9792 - recall: 0.9783 - precision: 0.9803 - f1_score: 0.9793
# Epoch 15/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0648 - accuracy: 0.9793 - recall: 0.9783 - precision: 0.9805 - f1_score: 0.9794
# Epoch 16/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0675 - accuracy: 0.9786 - recall: 0.9776 - precision: 0.9798 - f1_score: 0.9787
# Epoch 17/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0719 - accuracy: 0.9764 - recall: 0.9752 - precision: 0.9777 - f1_score: 0.9765
# Epoch 18/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0698 - accuracy: 0.9779 - recall: 0.9767 - precision: 0.9792 - f1_score: 0.9780
# Epoch 19/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0692 - accuracy: 0.9781 - recall: 0.9770 - precision: 0.9794 - f1_score: 0.9782
# Epoch 20/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0694 - accuracy: 0.9779 - recall: 0.9768 - precision: 0.9791 - f1_score: 0.9779
# Round: 4 | Client: client_3 training
# Epoch 1/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0728 - accuracy: 0.9766 - recall: 0.9754 - precision: 0.9780 - f1_score: 0.9767
# Epoch 2/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0695 - accuracy: 0.9773 - recall: 0.9764 - precision: 0.9785 - f1_score: 0.9774
# Epoch 3/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0690 - accuracy: 0.9780 - recall: 0.9771 - precision: 0.9790 - f1_score: 0.9780
# Epoch 4/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0691 - accuracy: 0.9776 - recall: 0.9765 - precision: 0.9787 - f1_score: 0.9776
# Epoch 5/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0703 - accuracy: 0.9776 - recall: 0.9766 - precision: 0.9787 - f1_score: 0.9776
# Epoch 6/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0689 - accuracy: 0.9780 - recall: 0.9769 - precision: 0.9791 - f1_score: 0.9780
# Epoch 7/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0695 - accuracy: 0.9778 - recall: 0.9768 - precision: 0.9789 - f1_score: 0.9778
# Epoch 8/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0673 - accuracy: 0.9787 - recall: 0.9779 - precision: 0.9797 - f1_score: 0.9788
# Epoch 9/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0667 - accuracy: 0.9783 - recall: 0.9774 - precision: 0.9794 - f1_score: 0.9784
# Epoch 10/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0669 - accuracy: 0.9785 - recall: 0.9776 - precision: 0.9796 - f1_score: 0.9786
# Epoch 11/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0665 - accuracy: 0.9786 - recall: 0.9777 - precision: 0.9797 - f1_score: 0.9787
# Epoch 12/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0650 - accuracy: 0.9790 - recall: 0.9782 - precision: 0.9801 - f1_score: 0.9791
# Epoch 13/20
# 5597/5597 [==============================] - 38s 7ms/step - loss: 0.0657 - accuracy: 0.9789 - recall: 0.9780 - precision: 0.9799 - f1_score: 0.9790
# Epoch 14/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0645 - accuracy: 0.9790 - recall: 0.9782 - precision: 0.9799 - f1_score: 0.9791
# Epoch 15/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0653 - accuracy: 0.9792 - recall: 0.9782 - precision: 0.9803 - f1_score: 0.9792
# Epoch 16/20
# 5597/5597 [==============================] - 44s 8ms/step - loss: 0.0648 - accuracy: 0.9795 - recall: 0.9787 - precision: 0.9806 - f1_score: 0.9796
# Epoch 17/20
# 5597/5597 [==============================] - 42s 7ms/step - loss: 0.0643 - accuracy: 0.9795 - recall: 0.9786 - precision: 0.9805 - f1_score: 0.9796
# Epoch 18/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0631 - accuracy: 0.9802 - recall: 0.9794 - precision: 0.9811 - f1_score: 0.9803
# Epoch 19/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0610 - accuracy: 0.9803 - recall: 0.9794 - precision: 0.9812 - f1_score: 0.9803
# Epoch 20/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0631 - accuracy: 0.9798 - recall: 0.9789 - precision: 0.9809 - f1_score: 0.9799
# Round: 4 | Client: client_4 training
# Epoch 1/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0700 - accuracy: 0.9774 - recall: 0.9764 - precision: 0.9785 - f1_score: 0.9774
# Epoch 2/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0681 - accuracy: 0.9777 - recall: 0.9768 - precision: 0.9788 - f1_score: 0.9778
# Epoch 3/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0697 - accuracy: 0.9774 - recall: 0.9765 - precision: 0.9785 - f1_score: 0.9775
# Epoch 4/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0680 - accuracy: 0.9777 - recall: 0.9767 - precision: 0.9789 - f1_score: 0.9778
# Epoch 5/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0675 - accuracy: 0.9782 - recall: 0.9773 - precision: 0.9792 - f1_score: 0.9783
# Epoch 6/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0683 - accuracy: 0.9781 - recall: 0.9771 - precision: 0.9793 - f1_score: 0.9782
# Epoch 7/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0692 - accuracy: 0.9780 - recall: 0.9769 - precision: 0.9791 - f1_score: 0.9780
# Epoch 8/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0677 - accuracy: 0.9786 - recall: 0.9776 - precision: 0.9798 - f1_score: 0.9787
# Epoch 9/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0650 - accuracy: 0.9792 - recall: 0.9783 - precision: 0.9802 - f1_score: 0.9792
# Epoch 10/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0662 - accuracy: 0.9788 - recall: 0.9778 - precision: 0.9798 - f1_score: 0.9788
# Epoch 11/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0663 - accuracy: 0.9787 - recall: 0.9778 - precision: 0.9796 - f1_score: 0.9787
# Epoch 12/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0646 - accuracy: 0.9792 - recall: 0.9784 - precision: 0.9803 - f1_score: 0.9793
# Epoch 13/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0633 - accuracy: 0.9799 - recall: 0.9791 - precision: 0.9808 - f1_score: 0.9799
# Epoch 14/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0636 - accuracy: 0.9798 - recall: 0.9789 - precision: 0.9808 - f1_score: 0.9798
# Epoch 15/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0643 - accuracy: 0.9794 - recall: 0.9785 - precision: 0.9805 - f1_score: 0.9795
# Epoch 16/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0642 - accuracy: 0.9795 - recall: 0.9786 - precision: 0.9805 - f1_score: 0.9795
# Epoch 17/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0640 - accuracy: 0.9793 - recall: 0.9783 - precision: 0.9805 - f1_score: 0.9794
# Epoch 18/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0623 - accuracy: 0.9802 - recall: 0.9793 - precision: 0.9813 - f1_score: 0.9803
# Epoch 19/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0618 - accuracy: 0.9804 - recall: 0.9795 - precision: 0.9814 - f1_score: 0.9805
# Epoch 20/20
# 5597/5597 [==============================] - 35s 6ms/step - loss: 0.0614 - accuracy: 0.9804 - recall: 0.9796 - precision: 0.9814 - f1_score: 0.9805
# Round: 4 | Client: client_1 training
# Epoch 1/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0707 - accuracy: 0.9769 - recall: 0.9759 - precision: 0.9782 - f1_score: 0.9770
# Epoch 2/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0687 - accuracy: 0.9778 - recall: 0.9768 - precision: 0.9790 - f1_score: 0.9779
# Epoch 3/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0699 - accuracy: 0.9776 - recall: 0.9766 - precision: 0.9788 - f1_score: 0.9777
# Epoch 4/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0704 - accuracy: 0.9775 - recall: 0.9766 - precision: 0.9786 - f1_score: 0.9776
# Epoch 5/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0674 - accuracy: 0.9780 - recall: 0.9770 - precision: 0.9792 - f1_score: 0.9781
# Epoch 6/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0672 - accuracy: 0.9781 - recall: 0.9771 - precision: 0.9792 - f1_score: 0.9782
# Epoch 7/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0698 - accuracy: 0.9777 - recall: 0.9766 - precision: 0.9789 - f1_score: 0.9778
# Epoch 8/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0673 - accuracy: 0.9782 - recall: 0.9772 - precision: 0.9793 - f1_score: 0.9782
# Epoch 9/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0680 - accuracy: 0.9784 - recall: 0.9774 - precision: 0.9794 - f1_score: 0.9784
# Epoch 10/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0724 - accuracy: 0.9771 - recall: 0.9758 - precision: 0.9782 - f1_score: 0.9770
# Epoch 11/20
# 5597/5597 [==============================] - 38s 7ms/step - loss: 0.0815 - accuracy: 0.9732 - recall: 0.9718 - precision: 0.9748 - f1_score: 0.9733
# Epoch 12/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0778 - accuracy: 0.9750 - recall: 0.9738 - precision: 0.9765 - f1_score: 0.9751
# Epoch 13/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0791 - accuracy: 0.9743 - recall: 0.9730 - precision: 0.9758 - f1_score: 0.9744
# Epoch 14/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0782 - accuracy: 0.9745 - recall: 0.9734 - precision: 0.9760 - f1_score: 0.9747
# Epoch 15/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0764 - accuracy: 0.9752 - recall: 0.9739 - precision: 0.9768 - f1_score: 0.9753
# Epoch 16/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0752 - accuracy: 0.9757 - recall: 0.9744 - precision: 0.9770 - f1_score: 0.9757
# Epoch 17/20
# 5597/5597 [==============================] - 38s 7ms/step - loss: 0.0748 - accuracy: 0.9759 - recall: 0.9747 - precision: 0.9774 - f1_score: 0.9760
# Epoch 18/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0748 - accuracy: 0.9758 - recall: 0.9746 - precision: 0.9773 - f1_score: 0.9759
# Epoch 19/20
# 5597/5597 [==============================] - 37s 6ms/step - loss: 0.0721 - accuracy: 0.9768 - recall: 0.9756 - precision: 0.9782 - f1_score: 0.9769
# Epoch 20/20
# 5597/5597 [==============================] - 36s 6ms/step - loss: 0.0720 - accuracy: 0.9768 - recall: 0.9756 - precision: 0.9781 - f1_score: 0.9769
# 11194/11194 [==============================] - 26s 2ms/step
# comm_round: 4 | global_loss: 1.0478720664978027 | global_accuracy: 0.9975 | global_recall: 0.9975 | global_precision: 0.9976 | global_f1_score: 0.9975
#
# New Weights Saved

# %%
global_model.load_weights("FL_DP_FS.h5")

# %%
loss, accuracy, precision, recall, f1_score = test_model(x_batch, y_batch, global_model, comm_round)
print("loss : ", loss.numpy())
print("accuracy : ", accuracy)
print("precision : ", precision)
print("recall : ", recall)
print("f1_score : ", f1_score)
# Out:
# 11194/11194 [==============================] - 24s 2ms/step
# comm_round: 4 | global_loss: 1.0478720664978027 | global_accuracy: 0.9975 | global_recall: 0.9975 | global_precision: 0.9976 | global_f1_score: 0.9975
#
# loss :  1.0478721
# accuracy :  0.9975349173513343
# precision :  0.9976183
# recall :  0.99746233
# f1_score :  0.9975402

# %%
for(x_batch, y_batch) in test_batched:
    logits = global_model.predict(x_batch)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_batch, axis=1)
# Out:
# 11194/11194 [==============================] - 25s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report, precision_score, recall_score
from sklearn.metrics import matthews_corrcoef, roc_auc_score
from sklearn.metrics import f1_score as f1_score_rep
import seaborn as sn
import numpy as np

def print_score(y_pred, y_real, label_encoder):
    accuracy = accuracy_score(y_real, y_pred)
    precision = precision_score(y_real, y_pred, average="weighted")
    recall = recall_score(y_real, y_pred, average="weighted")
    f1 = f1_score_rep(y_real, y_pred, average="weighted")
    auc = roc_auc_score(y_real, logits, multi_class='ovr')

    print("Accuracy: {:.4f}".format(accuracy))
    print("Precision:: {:.4f}".format(precision))
    print("Recall:: {:.4f}".format(recall))
    print("F1_Score:: {:.4f}".format(f1))
    print("AUC:: {:.4f}".format(auc))
    
    print()
    print("Confusion Matrix")
    cm = confusion_matrix(y_real, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cm, index=[str(i) for i in label_encoder.classes_], columns=[str(i) for i in label_encoder.classes_])
    plt.figure(figsize=(10, 7))
    sn.heatmap(df_cm, annot=True)

    print()
    print("Classification Report")
    print(classification_report(y_real, y_pred, target_names=[str(i) for i in label_encoder.classes_]))

# %%
print_score(y_hat, y_true, label_encoder)
# Out:
# Accuracy: 0.9975
# Precision:: 0.9975
# Recall:: 0.9975
# F1_Score:: 0.9975
# AUC:: 0.9999
#
# Confusion Matrix
#
# Classification Report
#                 precision    recall  f1-score   support
#
#         benign       1.00      1.00      1.00     57344
#      mirai_ack       1.00      1.00      1.00     55905
#     mirai_scan       1.00      1.00      1.00     51164
#      mirai_syn       1.00      1.00      1.00     61584
#      mirai_udp       1.00      1.00      1.00    108517
# mirai_udpplain       0.99      0.98      0.99     23689
#
#       accuracy                           1.00    358203
#      macro avg       1.00      1.00      1.00    358203
#   weighted avg       1.00      1.00      1.00    358203

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, n_classes):
    lw = 2
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_ohe[:, i], y_hat_ohe[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes
    fpr["weighted"] = all_fpr
    tpr["weighted"] = mean_tpr
    roc_auc["weighted"] = auc(fpr["weighted"], tpr["weighted"])

    #fpr["micro"], tpr["micro"], _ = roc_curve(y_true_ohe.ravel(), y_hat_ohe.ravel())
    #roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    plt.figure(figsize=(8,8))
    plt.plot(
        fpr["weighted"],
        tpr["weighted"],
        label="weighted-average ROC curve (area = {0:0.2f})".format(roc_auc["weighted"]),
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )



    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(label_encoder.classes_[i], roc_auc[i]))

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("multiclass characteristic")
    plt.legend(loc="lower right")
    plt.show()

# %%
y_true_ohe = to_categorical(y_true, num_classes=len(label_encoder.classes_))
y_hat_ohe =  to_categorical(y_hat, num_classes=len(label_encoder.classes_))

# %%
ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, len(label_encoder.classes_))

# %%
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  forward_pass = tf.function(model.call, input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])
  graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
  flops = graph_info.total_float_ops
  return flops

# %%
# Calculate FLOPS
flops = get_flops(global_model)
# Out:
# WARNING:tensorflow:From c:\Users\Lambert\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.

# %%
print(f"FLOPS: {flops / 10 ** 6:.03} M")
# Out:
# FLOPS: 0.0148 M

# %%
print(f"FLOPS: {flops}")
# Out:
# FLOPS: 14820

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(42)

# %%
#Benign
benign_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.benign.csv')
benign_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.benign.csv')
benign_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.benign.csv')
benign_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.benign.csv')
benign_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.benign.csv')
benign_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.benign.csv')
benign_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.benign.csv')

benign_traffic = pd.concat([benign_1, benign_2, benign_4, benign_5, benign_6, benign_8, benign_9], ignore_index=True)

benign_traffic.shape
# Out:
# (464682, 115)

# %%
#Scan
mirai_scan_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.scan.csv')
mirai_scan_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.scan.csv')
mirai_scan_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.scan.csv')
mirai_scan_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.scan.csv')
mirai_scan_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.scan.csv')
mirai_scan_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.scan.csv')
mirai_scan_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.scan.csv')

mirai_scan_traffic = pd.concat([mirai_scan_1, mirai_scan_2, mirai_scan_4, mirai_scan_5, mirai_scan_6, mirai_scan_8, mirai_scan_9], ignore_index=True)

mirai_scan_traffic.shape
# Out:
# (537979, 115)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')
mirai_syn_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.syn.csv')
mirai_syn_8  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.syn.csv')
mirai_syn_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.syn.csv')


mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5, mirai_syn_6, mirai_syn_8, mirai_syn_9], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (733299, 115)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')
mirai_syn_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.syn.csv')
mirai_syn_8  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.syn.csv')
mirai_syn_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.syn.csv')


mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5, mirai_syn_6, mirai_syn_8, mirai_syn_9], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (733299, 115)

# %%
#Ack
mirai_ack_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.ack.csv')
mirai_ack_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.ack.csv')
mirai_ack_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.ack.csv')
mirai_ack_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.ack.csv')
mirai_ack_6  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.ack.csv')
mirai_ack_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.ack.csv')
mirai_ack_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.ack.csv')

mirai_ack_traffic = pd.concat([mirai_ack_1 , mirai_ack_2, mirai_ack_4, mirai_ack_5, mirai_ack_6, mirai_ack_8, mirai_ack_9], ignore_index=True)

mirai_ack_traffic.shape
# Out:
# (643821, 115)

# %%
#Udp Flooding
mirai_udp_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udp.csv')
mirai_udp_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udp.csv')
mirai_udp_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udp.csv')
mirai_udp_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udp.csv')
mirai_udp_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udp.csv')
mirai_udp_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udp.csv')
mirai_udp_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udp.csv')

mirai_udp_traffic = pd.concat([mirai_udp_1 , mirai_udp_2, mirai_udp_4, mirai_udp_5], ignore_index=True)

mirai_udp_traffic.shape
# Out:
# (762428, 115)

# %%
#Udp plain Flooding
mirai_udpplain_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udpplain.csv')
mirai_udpplain_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udpplain.csv')
mirai_udpplain_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udpplain.csv')
mirai_udpplain_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udpplain.csv')
mirai_udpplain_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udpplain.csv')
mirai_udpplain_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udpplain.csv')
mirai_udpplain_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udpplain.csv')

mirai_udpplain_traffic = pd.concat([mirai_udpplain_1 , mirai_udpplain_2, mirai_udpplain_4, mirai_udpplain_5, mirai_udpplain_6, mirai_udpplain_8, mirai_udpplain_9], ignore_index=True)

mirai_udpplain_traffic.shape
# Out:
# (523304, 115)

# %%
benign_traffic['label'] = 'benign'
mirai_scan_traffic['label'] = 'mirai_scan'
mirai_syn_traffic['label'] = 'mirai_syn'
mirai_ack_traffic['label'] = 'mirai_ack'
mirai_udp_traffic['label'] = 'mirai_udp'
mirai_udpplain_traffic['label'] = 'mirai_udpplain'

mirai_dataset = pd.concat([benign_traffic, mirai_scan_traffic, mirai_syn_traffic,
                mirai_ack_traffic, mirai_udp_traffic, mirai_udpplain_traffic],
                axis=0, sort=False, ignore_index=True)

# %%
selected_features = ['HH_L1_weight', 'HH_jit_L1_weight', 'MI_dir_L0.01_mean',
       'H_L0.1_weight', 'H_L0.1_mean', 'MI_dir_L1_mean', 'H_L1_mean',
       'H_L0.01_variance', 'MI_dir_L0.01_variance', 'H_L5_weight',
       'H_L0.1_variance', 'MI_dir_L0.1_weight', 'MI_dir_L0.1_mean',
       'MI_dir_L5_weight', 'H_L0.01_mean', 'H_L5_mean', 'MI_dir_L0.1_variance',
       'MI_dir_L3_mean', 'MI_dir_L5_mean', 'HH_jit_L5_mean', 'HH_jit_L3_mean',
       'H_L3_mean', 'HH_L3_magnitude', 'MI_dir_L3_weight', 'HpHp_L0.01_weight', 'label']

# %%
selected_mirai_dataset = mirai_dataset[selected_features].copy()

# %%
selected_mirai_dataset.shape
# Out:
# (3665513, 26)

# %%
#Number of Missing Values in the Dataset
selected_mirai_dataset.isnull().sum().sum()
# Out:
# 0

# %%
#Number of Duplicate Rows in the Dataset
selected_mirai_dataset.duplicated().sum()
# Out:
# 1607667

# %%
# Remove duplicate rows from the Dataset
selected_mirai_dataset = selected_mirai_dataset.drop_duplicates()

# Check the number of duplicate rows after removal
selected_mirai_dataset.duplicated().sum()
# Out:
# 0

# %%
import numpy as np

# Select columns for z-score calculation (excluding the last column)
column_features = selected_mirai_dataset.iloc[:, :-1]

# Calculate z-scores for each column
z_scores = (column_features - column_features.mean()) / column_features.std()

# Set a threshold for z-score beyond which a data point is considered an outlier
z_score_threshold = 3  # Adjust this threshold as needed

# Identify rows where any z-score exceeds the threshold
outlier_mask = (np.abs(z_scores) > z_score_threshold).any(axis=1)

# Remove outliers from the dataset
selected_mirai_dataset = selected_mirai_dataset[~outlier_mask]

# %%
selected_mirai_dataset.shape
# Out:
# (1970649, 26)

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the columns to be normalized (excluding the 'label' column)
column_to_normalize = selected_mirai_dataset.columns[selected_mirai_dataset.columns != 'label']


# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
selected_mirai_dataset[column_to_normalize] = scaler.fit_transform(selected_mirai_dataset[column_to_normalize])

# %%
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000       2.636780e-16       0.000000
# 1      0.000039          0.000039       5.547170e-01       0.000179
# 2      0.001219          0.001219       5.660395e-01       0.000289
# 3      0.000000          0.000000       5.226415e-01       0.000000
# 4      0.000000          0.000000       2.612201e-01       0.000111
#
#     H_L0.1_mean  MI_dir_L1_mean     H_L1_mean  H_L0.01_variance  \
# 0  4.163336e-17    1.249001e-16  1.249001e-16          0.000000
# 1  5.408092e-01    4.823113e-01  4.817053e-01          0.000193
# 2  5.509964e-01    4.923052e-01  4.918483e-01          0.000712
# 3  5.226581e-01    4.544225e-01  4.544225e-01          0.000000
# 4  2.603220e-01    2.184604e-01  2.184604e-01          0.167279
#
#    MI_dir_L0.01_variance   H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.000000  0.000000e+00  ...              0.000000
# 1               0.000000  1.174383e-10  ...              0.000000
# 2               0.000314  3.148369e-03  ...              0.000311
# 3               0.000000  0.000000e+00  ...              0.000000
# 4               0.167279  2.496382e-03  ...              0.165695
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  \
# 0    1.249001e-16    1.110223e-16    9.813673e-01    9.813673e-01
# 1    4.510277e-01    4.226888e-01    3.245507e-09    3.245505e-09
# 2    4.606554e-01    4.319749e-01    1.513729e-09    1.562845e-09
# 3    4.249479e-01    3.982476e-01    9.813673e-01    9.813673e-01
# 4    1.880207e-01    1.612269e-01    9.813673e-01    9.813673e-01
#
#       H_L3_mean  HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight   label
# 0  1.249001e-16         0.000000          0.000000           0.000000  benign
# 1  4.510271e-01         0.331530          0.000000           0.000291  benign
# 2  4.606549e-01         0.338607          0.002146           0.000359  benign
# 3  4.249479e-01         0.312360          0.000000           0.000000  benign
# 4  1.880207e-01         0.477094          0.001867           0.000000  benign
#
# [5 rows x 26 columns]

# %%
selected_mirai_dataset = selected_mirai_dataset.sample(frac=1).reset_index(drop=True)
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000           0.521544       0.505705
# 1      0.000108          0.000108           0.185116       0.001147
# 2      0.001207          0.001207           0.020756       0.001147
# 3      0.365574          0.365574           0.523108       0.516265
# 4      0.000000          0.000000           0.017738       0.744389
#
#    H_L0.1_mean  MI_dir_L1_mean  H_L1_mean  H_L0.01_variance  \
# 0     0.522337        0.444576   0.444576          0.524454
# 1     0.118109        0.018681   0.018681          0.421878
# 2     0.023412        0.014130   0.014130          0.003344
# 3     0.525792        0.477173   0.477173          0.524025
# 4     0.017960        0.016922   0.016922          0.000378
#
#    MI_dir_L0.01_variance  H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.524454     0.457333  ...              0.519279
# 1               0.421878     0.000004  ...              0.242123
# 2               0.003344     0.003073  ...              0.003812
# 3               0.524025     0.323968  ...              0.518312
# 4               0.000378     0.378821  ...              0.000369
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  H_L3_mean  \
# 0        0.372336        0.294594    9.826693e-01    9.826693e-01   0.372336
# 1        0.021151        0.020109    2.614423e-09    2.614027e-09   0.021151
# 2        0.010392        0.008908    1.420423e-09    1.504356e-09   0.010392
# 3        0.497183        0.525856    2.188626e-12    2.208649e-12   0.497183
# 4        0.017771        0.017381    9.826679e-01    9.826679e-01   0.017771
#
#    HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight           label
# 0         0.000000          0.436825           0.000000  mirai_udpplain
# 1         0.050352          0.000037           0.000195          benign
# 2         0.070288          0.002636           0.001276          benign
# 3         0.557061          0.375316           0.405565  mirai_udpplain
# 4         0.000000          0.431810           0.000000       mirai_syn
#
# [5 rows x 26 columns]

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# Calculate percentage values
class_counts = selected_mirai_dataset['label'].value_counts(normalize=True) * 100

plt.title("Class Distribution")
bar_plot = selected_mirai_dataset['label'].value_counts().plot(kind='bar')
plt.xlabel('Classes')
plt.ylabel('Frequency')

# Annotate each bar with its percentage value
for i, val in enumerate(class_counts):
    plt.text(i, selected_mirai_dataset['label'].value_counts()[i], f'{val:.2f}%', ha='center')

plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(selected_mirai_dataset['label'].value_counts())
# Out:
# mirai_udp         544764
# benign            422293
# mirai_syn         312508
# mirai_ack         280144
# mirai_scan        256151
# mirai_udpplain    154789
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(selected_mirai_dataset, test_size=0.2, random_state=42, stratify=selected_mirai_dataset["label"])

# %%
features = list(train_df.columns)
features.remove("label")

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_df["label"] = label_encoder.fit_transform(train_df["label"])
test_df["label"] = label_encoder.transform(test_df["label"])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=18)
X_train = train_df[features].values
X_train = pca.fit_transform(X_train)
y_train = train_df["label"].values

X_test = test_df[features].values
X_test = pca.fit_transform(X_test)
y_test = test_df["label"].values

# %%
import statsmodels.api as sm
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from tabulate import tabulate

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train)

class_weights = {k: v for k,v in enumerate(class_weights)}
class_weights
# Out:
# {0: 0.7777582086665837,
#  1: 1.1724033048509321,
#  2: 1.282216886832812,
#  3: 1.0509832391359708,
#  4: 0.6029062292293372,
#  5: 2.1218690527143176}

# %%
input_shape = X_train.shape[1:]
nb_classes = len(label_encoder.classes_)

# %%
input_shape
# Out:
# (18,)

# %%
from tensorflow.keras.utils import to_categorical

def convert_to_categorical(y, nb_classes):
    return to_categorical(y, num_classes=nb_classes)

# %%
import random

def data_indices(labels: np.ndarray, nb_clients: int):
    data_len = len(labels)
    indices = np.arange(data_len)
    np.random.shuffle(indices)
    chunk_size = data_len // nb_clients
    chunks = [indices[i:i+chunk_size] for i in range(0, data_len, chunk_size)]

    # Ensure non-IID distribution by shuffling 2 of the 4 chunks
    chunks[-1] = np.random.permutation(chunks[-1])
    chunks[-3] = np.random.permutation(chunks[-3])
    

    return chunks

# %%
def sample(y:np.ndarray, nb_clients: int):
    sampler_fn = data_indices
    client_data_indices = sampler_fn(y, nb_clients)
    return client_data_indices

# %%
def assign_data_to_clients(clients: dict, X:np.ndarray, y:np.ndarray, nb_classes:int):
    sampled_data_indices = sample(y, len(clients.keys()))  # Use the sample function to get data indices
    for client_name, data_indices in zip(clients.keys(), sampled_data_indices):
        X = X_train[data_indices]  # Subset the features for the current client
        y = y_train[data_indices]  # Subset the labels for the current client
        y = convert_to_categorical(y, nb_classes)  # Convert labels to categorical format if needed
        clients[client_name] = list(zip(X, y))  # Assign data to the current client
    return clients

# %%
def create_clients(X, y, nb_classes, num_clients=4, initial='clients'):
    # Create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]
    clients = {client_names[i] : [] for i in range(len(client_names))}
    return assign_data_to_clients(clients, X, y, nb_classes)

# %%
def batch_data(data_shard, batch_size=64):
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    del data_shard

    len_label = len(label)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    del data, label
    return dataset.shuffle(len_label).batch(batch_size)

# %%
import keras.backend as K
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import keras
import os
from keras.models import Model
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Activation, BatchNormalization, GRU, Dense, Dropout, Input

def get_model(input_shape, nb_classes):
    inputs = Input(shape=input_shape)
    
    x = Dense(32, activation="relu")(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation="relu")(x)
    x = Dropout(0.2)(x)
    outputs = Dense(nb_classes, activation="softmax")(x)
    
    return keras.Model(inputs, outputs)

# %%
import tensorflow_privacy
from tensorflow_privacy.privacy.optimizers import dp_optimizer_keras  
from keras.metrics import Recall, Precision
from tensorflow.keras.utils import plot_model

learning_rate = 1e-3
comms_round = 5
loss='categorical_crossentropy'
metrics = ["accuracy", Recall(), Precision(), f1_score]
#optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
optimizer = tensorflow_privacy.DPKerasAdamOptimizer(l2_norm_clip= 1.6, noise_multiplier= 0.25, num_microbatches=1, learning_rate= learning_rate)


#initialize global model
global_model = get_model(input_shape, nb_classes)

global_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18)]              0
#
#  dense (Dense)               (None, 32)                608
#
#  batch_normalization (Batch  (None, 32)                128
#  Normalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  batch_normalization_2 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 4358 (17.02 KB)
# Trainable params: 4166 (16.27 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
BATCH_SIZE = 64

# create clients
clients_batched = create_clients(X_train, y_train, nb_classes, num_clients=4, initial='client')

del X_train, y_train

# process and batch the training data for each client
client_set = {k: {} for k in clients_batched.keys()}

for (client_name, data) in clients_batched.items():
    client_set[client_name]["dataset"] = batch_data(data, BATCH_SIZE)
    local_model = get_model(input_shape, nb_classes)
    local_model.compile(loss=loss,
                      optimizer=optimizer,
                      metrics=metrics)
    client_set[client_name]["model"] = local_model

# %%
#process and batch the test set

y_test = convert_to_categorical(y_test, nb_classes)

test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

del X_test, y_test

# %%
# Define a function to calculate the weight scaling factor
def weight_scalling_factor(clients, client_name):
    client_names = list(clients.keys())
    # Get the batch size
    bs = list(clients[client_name]["dataset"])[0][0].shape[0]
    # Calculate the total training data points across clients
    global_count = sum([tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() for client_name in client_names]) * bs
    # Calculate the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() * bs
    return local_count / global_count

# %%
# Define a function to scale model weights
def scale_model_weights(weight, scalar):
    '''function for scaling a model's weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final

# %%
def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights --> FedAvg'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)

    return avg_grad

# %%
from sklearn.metrics import accuracy_score

def test_model(X_test, y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(y_test, logits)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(np.argmax(y_test, axis=1), np.argmax(logits, axis=1))

    r = Recall()
    r.update_state(y_test, logits)
    recall = r.result().numpy()

    p = Precision()
    p.update_state(y_test, logits)
    precision = p.result().numpy()

    f = f1_score(y_test, logits)
    f1 = f.numpy()

    print('comm_round: {} | global_loss: {} | global_accuracy: {:.4} | global_recall: {:.4} | global_precision: {:.4} | global_f1_score: {:.4} \n'.format(comm_round, loss, accuracy, recall, precision, f1))
    return loss, accuracy, precision, recall, f1

# %%
def train_client(client, global_weights):
    client_set[client]["model"] = client_set[client]["model"]

    #set local model weight to the weight of the global model
    client_set[client]["model"].set_weights(global_weights)

    #fit local model with client's data
    print(f"Round: {comm_round} | Client: {client} training")
    client_set[client]["model"].fit(client_set[client]["dataset"], epochs=20, verbose=1)

    #scale the model weights and add to list
    scaling_factor = weight_scalling_factor(client_set, client)
    scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
    return scaled_weights

# %%
import random

#commence global training loop
global_loss=[]
global_accuracy=[]
global_precision=[]
global_recall=[]
global_f1=[]
best_global_accuracy = 0

for comm_round in range(comms_round):
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()

    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(client_set.keys())
    random.shuffle(client_names)

    #loop through each client and create new local model
    for client in client_names:
        scaled_weights = train_client(client, global_weights)

        scaled_local_weight_list.append(scaled_weights)

    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)

    #update global model
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    g_accuracy = 0
    for(x_batch, y_batch) in test_batched:
        g_loss, g_accuracy, g_precision, g_recall, g_f1 = test_model(x_batch, y_batch, global_model, comm_round)
        global_loss.append(g_loss)
        global_accuracy.append(g_accuracy)
        global_precision.append(g_precision)
        global_recall.append(g_recall)
        global_f1.append(g_f1)

    if g_accuracy > best_global_accuracy:
        best_global_accuracy = g_accuracy
        global_model.save_weights('FL_DP_0_5.h5')
        print("New Weights Saved")
# Out:
# Round: 0 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 63s 4ms/step - loss: 0.7990 - accuracy: 0.6871 - recall: 0.5541 - precision: 0.8077 - f1_score: 0.6448
# Epoch 2/20
# 6159/6159 [==============================] - 27s 4ms/step - loss: 0.5424 - accuracy: 0.7645 - recall: 0.6889 - precision: 0.8202 - f1_score: 0.7479
# Epoch 3/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.5040 - accuracy: 0.7774 - recall: 0.7253 - precision: 0.8172 - f1_score: 0.7678
# Epoch 4/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4849 - accuracy: 0.7827 - recall: 0.7366 - precision: 0.8180 - f1_score: 0.7746
# Epoch 5/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4765 - accuracy: 0.7860 - recall: 0.7363 - precision: 0.8248 - f1_score: 0.7775
# Epoch 6/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4720 - accuracy: 0.7855 - recall: 0.7406 - precision: 0.8212 - f1_score: 0.7783
# Epoch 7/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4724 - accuracy: 0.7834 - recall: 0.7389 - precision: 0.8205 - f1_score: 0.7771
# Epoch 8/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4759 - accuracy: 0.7828 - recall: 0.7394 - precision: 0.8176 - f1_score: 0.7760
# Epoch 9/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4696 - accuracy: 0.7828 - recall: 0.7386 - precision: 0.8185 - f1_score: 0.7759
# Epoch 10/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4641 - accuracy: 0.7845 - recall: 0.7415 - precision: 0.8211 - f1_score: 0.7787
# Epoch 11/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4616 - accuracy: 0.7835 - recall: 0.7464 - precision: 0.8175 - f1_score: 0.7799
# Epoch 12/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4584 - accuracy: 0.7829 - recall: 0.7384 - precision: 0.8229 - f1_score: 0.7779
# Epoch 13/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4526 - accuracy: 0.7849 - recall: 0.7420 - precision: 0.8236 - f1_score: 0.7803
# Epoch 14/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4573 - accuracy: 0.7838 - recall: 0.7454 - precision: 0.8196 - f1_score: 0.7804
# Epoch 15/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4492 - accuracy: 0.7864 - recall: 0.7498 - precision: 0.8216 - f1_score: 0.7837
# Epoch 16/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4497 - accuracy: 0.7876 - recall: 0.7491 - precision: 0.8225 - f1_score: 0.7837
# Epoch 17/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4488 - accuracy: 0.7879 - recall: 0.7517 - precision: 0.8217 - f1_score: 0.7848
# Epoch 18/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4440 - accuracy: 0.7903 - recall: 0.7571 - precision: 0.8218 - f1_score: 0.7878
# Epoch 19/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4504 - accuracy: 0.7889 - recall: 0.7560 - precision: 0.8208 - f1_score: 0.7869
# Epoch 20/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4541 - accuracy: 0.7884 - recall: 0.7539 - precision: 0.8216 - f1_score: 0.7860
# Round: 0 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 35s 4ms/step - loss: 0.7081 - accuracy: 0.7134 - recall: 0.6787 - precision: 0.8130 - f1_score: 0.6827
# Epoch 2/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.5420 - accuracy: 0.7621 - recall: 0.6885 - precision: 0.8161 - f1_score: 0.7461
# Epoch 3/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4999 - accuracy: 0.7780 - recall: 0.7284 - precision: 0.8148 - f1_score: 0.7686
# Epoch 4/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4798 - accuracy: 0.7848 - recall: 0.7372 - precision: 0.8212 - f1_score: 0.7763
# Epoch 5/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4701 - accuracy: 0.7870 - recall: 0.7354 - precision: 0.8266 - f1_score: 0.7777
# Epoch 6/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4670 - accuracy: 0.7857 - recall: 0.7409 - precision: 0.8210 - f1_score: 0.7784
# Epoch 7/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4667 - accuracy: 0.7837 - recall: 0.7383 - precision: 0.8216 - f1_score: 0.7772
# Epoch 8/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4702 - accuracy: 0.7848 - recall: 0.7429 - precision: 0.8194 - f1_score: 0.7789
# Epoch 9/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4668 - accuracy: 0.7826 - recall: 0.7391 - precision: 0.8185 - f1_score: 0.7763
# Epoch 10/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4636 - accuracy: 0.7833 - recall: 0.7378 - precision: 0.8218 - f1_score: 0.7771
# Epoch 11/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4667 - accuracy: 0.7813 - recall: 0.7361 - precision: 0.8203 - f1_score: 0.7755
# Epoch 12/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4651 - accuracy: 0.7810 - recall: 0.7317 - precision: 0.8232 - f1_score: 0.7743
# Epoch 13/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4590 - accuracy: 0.7832 - recall: 0.7404 - precision: 0.8195 - f1_score: 0.7776
# Epoch 14/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4593 - accuracy: 0.7843 - recall: 0.7480 - precision: 0.8166 - f1_score: 0.7805
# Epoch 15/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4559 - accuracy: 0.7858 - recall: 0.7468 - precision: 0.8206 - f1_score: 0.7816
# Epoch 16/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4605 - accuracy: 0.7842 - recall: 0.7409 - precision: 0.8224 - f1_score: 0.7791
# Epoch 17/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4581 - accuracy: 0.7857 - recall: 0.7462 - precision: 0.8206 - f1_score: 0.7812
# Epoch 18/20
# 6159/6159 [==============================] - 28s 5ms/step - loss: 0.4562 - accuracy: 0.7868 - recall: 0.7538 - precision: 0.8171 - f1_score: 0.7839
# Epoch 19/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4585 - accuracy: 0.7866 - recall: 0.7542 - precision: 0.8174 - f1_score: 0.7843
# Epoch 20/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4606 - accuracy: 0.7852 - recall: 0.7476 - precision: 0.8198 - f1_score: 0.7817
# Round: 0 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 34s 4ms/step - loss: 0.7099 - accuracy: 0.7116 - recall: 0.6749 - precision: 0.8122 - f1_score: 0.6824
# Epoch 2/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.5434 - accuracy: 0.7607 - recall: 0.6865 - precision: 0.8171 - f1_score: 0.7453
# Epoch 3/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4992 - accuracy: 0.7754 - recall: 0.7252 - precision: 0.8161 - f1_score: 0.7674
# Epoch 4/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4794 - accuracy: 0.7829 - recall: 0.7367 - precision: 0.8205 - f1_score: 0.7758
# Epoch 5/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4665 - accuracy: 0.7873 - recall: 0.7398 - precision: 0.8257 - f1_score: 0.7798
# Epoch 6/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4620 - accuracy: 0.7873 - recall: 0.7455 - precision: 0.8212 - f1_score: 0.7811
# Epoch 7/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4645 - accuracy: 0.7860 - recall: 0.7427 - precision: 0.8225 - f1_score: 0.7801
# Epoch 8/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4686 - accuracy: 0.7846 - recall: 0.7457 - precision: 0.8189 - f1_score: 0.7802
# Epoch 9/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4669 - accuracy: 0.7838 - recall: 0.7417 - precision: 0.8198 - f1_score: 0.7784
# Epoch 10/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4678 - accuracy: 0.7829 - recall: 0.7388 - precision: 0.8212 - f1_score: 0.7774
# Epoch 11/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4685 - accuracy: 0.7810 - recall: 0.7364 - precision: 0.8197 - f1_score: 0.7754
# Epoch 12/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4692 - accuracy: 0.7806 - recall: 0.7314 - precision: 0.8220 - f1_score: 0.7736
# Epoch 13/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4625 - accuracy: 0.7819 - recall: 0.7392 - precision: 0.8196 - f1_score: 0.7770
# Epoch 14/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4647 - accuracy: 0.7820 - recall: 0.7439 - precision: 0.8168 - f1_score: 0.7783
# Epoch 15/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4585 - accuracy: 0.7833 - recall: 0.7445 - precision: 0.8206 - f1_score: 0.7804
# Epoch 16/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4598 - accuracy: 0.7829 - recall: 0.7425 - precision: 0.8219 - f1_score: 0.7799
# Epoch 17/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4586 - accuracy: 0.7850 - recall: 0.7462 - precision: 0.8220 - f1_score: 0.7820
# Epoch 18/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4553 - accuracy: 0.7877 - recall: 0.7546 - precision: 0.8199 - f1_score: 0.7856
# Epoch 19/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4592 - accuracy: 0.7869 - recall: 0.7556 - precision: 0.8166 - f1_score: 0.7847
# Epoch 20/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4594 - accuracy: 0.7846 - recall: 0.7471 - precision: 0.8203 - f1_score: 0.7817
# Round: 0 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 35s 4ms/step - loss: 0.7090 - accuracy: 0.7130 - recall: 0.6749 - precision: 0.8130 - f1_score: 0.6829
# Epoch 2/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.5448 - accuracy: 0.7609 - recall: 0.6868 - precision: 0.8179 - f1_score: 0.7459
# Epoch 3/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.5006 - accuracy: 0.7768 - recall: 0.7276 - precision: 0.8166 - f1_score: 0.7689
# Epoch 4/20
# 6159/6159 [==============================] - 28s 4ms/step - loss: 0.4832 - accuracy: 0.7837 - recall: 0.7366 - precision: 0.8209 - f1_score: 0.7759
# Epoch 5/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4713 - accuracy: 0.7862 - recall: 0.7355 - precision: 0.8265 - f1_score: 0.7777
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4672 - accuracy: 0.7851 - recall: 0.7403 - precision: 0.8209 - f1_score: 0.7780
# Epoch 7/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.4682 - accuracy: 0.7833 - recall: 0.7373 - precision: 0.8212 - f1_score: 0.7765
# Epoch 8/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.4727 - accuracy: 0.7839 - recall: 0.7425 - precision: 0.8176 - f1_score: 0.7778
# Epoch 9/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4670 - accuracy: 0.7822 - recall: 0.7387 - precision: 0.8185 - f1_score: 0.7761
# Epoch 10/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4656 - accuracy: 0.7822 - recall: 0.7359 - precision: 0.8216 - f1_score: 0.7759
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4669 - accuracy: 0.7811 - recall: 0.7349 - precision: 0.8208 - f1_score: 0.7750
# Epoch 12/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4667 - accuracy: 0.7803 - recall: 0.7311 - precision: 0.8221 - f1_score: 0.7735
# Epoch 13/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4572 - accuracy: 0.7847 - recall: 0.7425 - precision: 0.8203 - f1_score: 0.7791
# Epoch 14/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4616 - accuracy: 0.7841 - recall: 0.7481 - precision: 0.8159 - f1_score: 0.7802
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4580 - accuracy: 0.7855 - recall: 0.7471 - precision: 0.8205 - f1_score: 0.7817
# Epoch 16/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4585 - accuracy: 0.7844 - recall: 0.7434 - precision: 0.8220 - f1_score: 0.7804
# Epoch 17/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4551 - accuracy: 0.7865 - recall: 0.7472 - precision: 0.8220 - f1_score: 0.7824
# Epoch 18/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4511 - accuracy: 0.7890 - recall: 0.7568 - precision: 0.8187 - f1_score: 0.7863
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4558 - accuracy: 0.7882 - recall: 0.7572 - precision: 0.8173 - f1_score: 0.7859
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4607 - accuracy: 0.7858 - recall: 0.7493 - precision: 0.8188 - f1_score: 0.7822
# 12317/12317 [==============================] - 28s 2ms/step
# comm_round: 0 | global_loss: 1.744193196296692 | global_accuracy: 0.2795 | global_recall: 0.0 | global_precision: 0.0 | global_f1_score: 0.0
#
# New Weights Saved
# Round: 1 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.5520 - accuracy: 0.7591 - recall: 0.6822 - precision: 0.8137 - f1_score: 0.7403
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4750 - accuracy: 0.7816 - recall: 0.7325 - precision: 0.8185 - f1_score: 0.7727
# Epoch 3/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4671 - accuracy: 0.7848 - recall: 0.7389 - precision: 0.8205 - f1_score: 0.7771
# Epoch 4/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4681 - accuracy: 0.7834 - recall: 0.7396 - precision: 0.8193 - f1_score: 0.7771
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4579 - accuracy: 0.7852 - recall: 0.7454 - precision: 0.8186 - f1_score: 0.7799
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4536 - accuracy: 0.7861 - recall: 0.7496 - precision: 0.8171 - f1_score: 0.7815
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4539 - accuracy: 0.7855 - recall: 0.7499 - precision: 0.8171 - f1_score: 0.7817
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4551 - accuracy: 0.7867 - recall: 0.7477 - precision: 0.8213 - f1_score: 0.7824
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4509 - accuracy: 0.7876 - recall: 0.7536 - precision: 0.8195 - f1_score: 0.7849
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4489 - accuracy: 0.7887 - recall: 0.7536 - precision: 0.8228 - f1_score: 0.7864
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4483 - accuracy: 0.7872 - recall: 0.7529 - precision: 0.8197 - f1_score: 0.7846
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4448 - accuracy: 0.7883 - recall: 0.7586 - precision: 0.8163 - f1_score: 0.7862
# Epoch 13/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4522 - accuracy: 0.7858 - recall: 0.7548 - precision: 0.8154 - f1_score: 0.7837
# Epoch 14/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4525 - accuracy: 0.7873 - recall: 0.7578 - precision: 0.8154 - f1_score: 0.7853
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4503 - accuracy: 0.7858 - recall: 0.7516 - precision: 0.8171 - f1_score: 0.7828
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4506 - accuracy: 0.7849 - recall: 0.7484 - precision: 0.8184 - f1_score: 0.7816
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4471 - accuracy: 0.7876 - recall: 0.7509 - precision: 0.8206 - f1_score: 0.7838
# Epoch 18/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.4373 - accuracy: 0.7918 - recall: 0.7592 - precision: 0.8214 - f1_score: 0.7889
# Epoch 19/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4344 - accuracy: 0.7934 - recall: 0.7623 - precision: 0.8207 - f1_score: 0.7902
# Epoch 20/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4374 - accuracy: 0.7914 - recall: 0.7552 - precision: 0.8239 - f1_score: 0.7878
# Round: 1 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.5507 - accuracy: 0.7599 - recall: 0.6820 - precision: 0.8138 - f1_score: 0.7403
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4739 - accuracy: 0.7817 - recall: 0.7331 - precision: 0.8175 - f1_score: 0.7726
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4660 - accuracy: 0.7852 - recall: 0.7401 - precision: 0.8205 - f1_score: 0.7778
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4680 - accuracy: 0.7845 - recall: 0.7420 - precision: 0.8193 - f1_score: 0.7783
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4590 - accuracy: 0.7859 - recall: 0.7467 - precision: 0.8181 - f1_score: 0.7804
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4531 - accuracy: 0.7856 - recall: 0.7496 - precision: 0.8166 - f1_score: 0.7813
# Epoch 7/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4521 - accuracy: 0.7860 - recall: 0.7510 - precision: 0.8166 - f1_score: 0.7820
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4537 - accuracy: 0.7875 - recall: 0.7495 - precision: 0.8210 - f1_score: 0.7832
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4488 - accuracy: 0.7888 - recall: 0.7553 - precision: 0.8192 - f1_score: 0.7857
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4494 - accuracy: 0.7886 - recall: 0.7537 - precision: 0.8221 - f1_score: 0.7861
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4499 - accuracy: 0.7876 - recall: 0.7534 - precision: 0.8191 - f1_score: 0.7846
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4440 - accuracy: 0.7894 - recall: 0.7604 - precision: 0.8167 - f1_score: 0.7873
# Epoch 13/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4539 - accuracy: 0.7850 - recall: 0.7545 - precision: 0.8134 - f1_score: 0.7826
# Epoch 14/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4534 - accuracy: 0.7879 - recall: 0.7585 - precision: 0.8143 - f1_score: 0.7852
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4499 - accuracy: 0.7862 - recall: 0.7533 - precision: 0.8166 - f1_score: 0.7834
# Epoch 16/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.4494 - accuracy: 0.7859 - recall: 0.7496 - precision: 0.8184 - f1_score: 0.7822
# Epoch 17/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.4461 - accuracy: 0.7875 - recall: 0.7512 - precision: 0.8206 - f1_score: 0.7841
# Epoch 18/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.4376 - accuracy: 0.7914 - recall: 0.7595 - precision: 0.8203 - f1_score: 0.7885
# Epoch 19/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.4357 - accuracy: 0.7927 - recall: 0.7617 - precision: 0.8200 - f1_score: 0.7895
# Epoch 20/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.4360 - accuracy: 0.7928 - recall: 0.7566 - precision: 0.8245 - f1_score: 0.7888
# Round: 1 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.5512 - accuracy: 0.7599 - recall: 0.6820 - precision: 0.8144 - f1_score: 0.7405
# Epoch 2/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.4758 - accuracy: 0.7808 - recall: 0.7323 - precision: 0.8171 - f1_score: 0.7719
# Epoch 3/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.4665 - accuracy: 0.7850 - recall: 0.7397 - precision: 0.8202 - f1_score: 0.7775
# Epoch 4/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.4676 - accuracy: 0.7848 - recall: 0.7422 - precision: 0.8200 - f1_score: 0.7788
# Epoch 5/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.4587 - accuracy: 0.7860 - recall: 0.7466 - precision: 0.8186 - f1_score: 0.7805
# Epoch 6/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.4540 - accuracy: 0.7856 - recall: 0.7494 - precision: 0.8161 - f1_score: 0.7809
# Epoch 7/20
# 6159/6159 [==============================] - 47s 7ms/step - loss: 0.4523 - accuracy: 0.7860 - recall: 0.7504 - precision: 0.8168 - f1_score: 0.7818
# Epoch 8/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.4536 - accuracy: 0.7873 - recall: 0.7484 - precision: 0.8209 - f1_score: 0.7826
# Epoch 9/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.4501 - accuracy: 0.7885 - recall: 0.7543 - precision: 0.8190 - f1_score: 0.7851
# Epoch 10/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.4482 - accuracy: 0.7888 - recall: 0.7539 - precision: 0.8229 - f1_score: 0.7866
# Epoch 11/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.4484 - accuracy: 0.7878 - recall: 0.7544 - precision: 0.8191 - f1_score: 0.7851
# Epoch 12/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.4454 - accuracy: 0.7893 - recall: 0.7599 - precision: 0.8166 - f1_score: 0.7870
# Epoch 13/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.4530 - accuracy: 0.7849 - recall: 0.7545 - precision: 0.8141 - f1_score: 0.7829
# Epoch 14/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.4533 - accuracy: 0.7872 - recall: 0.7583 - precision: 0.8148 - f1_score: 0.7853
# Epoch 15/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.4510 - accuracy: 0.7864 - recall: 0.7528 - precision: 0.8169 - f1_score: 0.7833
# Epoch 16/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.4509 - accuracy: 0.7863 - recall: 0.7504 - precision: 0.8182 - f1_score: 0.7825
# Epoch 17/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.4459 - accuracy: 0.7879 - recall: 0.7521 - precision: 0.8200 - f1_score: 0.7843
# Epoch 18/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4383 - accuracy: 0.7919 - recall: 0.7598 - precision: 0.8211 - f1_score: 0.7891
# Epoch 19/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4358 - accuracy: 0.7932 - recall: 0.7629 - precision: 0.8201 - f1_score: 0.7902
# Epoch 20/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.4375 - accuracy: 0.7925 - recall: 0.7556 - precision: 0.8250 - f1_score: 0.7885
# Round: 1 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.5496 - accuracy: 0.7611 - recall: 0.6835 - precision: 0.8153 - f1_score: 0.7418
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4754 - accuracy: 0.7811 - recall: 0.7325 - precision: 0.8173 - f1_score: 0.7722
# Epoch 3/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4662 - accuracy: 0.7859 - recall: 0.7403 - precision: 0.8205 - f1_score: 0.7779
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4677 - accuracy: 0.7848 - recall: 0.7425 - precision: 0.8191 - f1_score: 0.7786
# Epoch 5/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4571 - accuracy: 0.7863 - recall: 0.7477 - precision: 0.8185 - f1_score: 0.7811
# Epoch 6/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4540 - accuracy: 0.7859 - recall: 0.7501 - precision: 0.8161 - f1_score: 0.7813
# Epoch 7/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4520 - accuracy: 0.7862 - recall: 0.7516 - precision: 0.8162 - f1_score: 0.7822
# Epoch 8/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4530 - accuracy: 0.7884 - recall: 0.7501 - precision: 0.8218 - f1_score: 0.7839
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4491 - accuracy: 0.7891 - recall: 0.7549 - precision: 0.8188 - f1_score: 0.7853
# Epoch 10/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4492 - accuracy: 0.7889 - recall: 0.7546 - precision: 0.8220 - f1_score: 0.7866
# Epoch 11/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4485 - accuracy: 0.7880 - recall: 0.7539 - precision: 0.8195 - f1_score: 0.7850
# Epoch 12/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.4443 - accuracy: 0.7889 - recall: 0.7597 - precision: 0.8162 - f1_score: 0.7867
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4522 - accuracy: 0.7859 - recall: 0.7549 - precision: 0.8143 - f1_score: 0.7832
# Epoch 14/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.4534 - accuracy: 0.7875 - recall: 0.7580 - precision: 0.8143 - f1_score: 0.7849
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4472 - accuracy: 0.7871 - recall: 0.7538 - precision: 0.8175 - f1_score: 0.7841
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4504 - accuracy: 0.7869 - recall: 0.7505 - precision: 0.8188 - f1_score: 0.7829
# Epoch 17/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4451 - accuracy: 0.7880 - recall: 0.7518 - precision: 0.8199 - f1_score: 0.7841
# Epoch 18/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4365 - accuracy: 0.7926 - recall: 0.7603 - precision: 0.8215 - f1_score: 0.7895
# Epoch 19/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4346 - accuracy: 0.7929 - recall: 0.7629 - precision: 0.8197 - f1_score: 0.7900
# Epoch 20/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4379 - accuracy: 0.7923 - recall: 0.7562 - precision: 0.8238 - f1_score: 0.7883
# 12317/12317 [==============================] - 26s 2ms/step
# comm_round: 1 | global_loss: 1.2555102109909058 | global_accuracy: 0.8181 | global_recall: 0.7649 | global_precision: 0.8592 | global_f1_score: 0.8093
#
# New Weights Saved
# Round: 2 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4375 - accuracy: 0.7924 - recall: 0.7589 - precision: 0.8231 - f1_score: 0.7895
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4373 - accuracy: 0.7940 - recall: 0.7640 - precision: 0.8211 - f1_score: 0.7913
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4326 - accuracy: 0.7972 - recall: 0.7681 - precision: 0.8232 - f1_score: 0.7945
# Epoch 4/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.4259 - accuracy: 0.8024 - recall: 0.7666 - precision: 0.8330 - f1_score: 0.7982
# Epoch 5/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.4087 - accuracy: 0.8169 - recall: 0.7839 - precision: 0.8496 - f1_score: 0.8152
# Epoch 6/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.3886 - accuracy: 0.8337 - recall: 0.8060 - precision: 0.8625 - f1_score: 0.8331
# Epoch 7/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.3650 - accuracy: 0.8506 - recall: 0.8275 - precision: 0.8744 - f1_score: 0.8500
# Epoch 8/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.3471 - accuracy: 0.8638 - recall: 0.8435 - precision: 0.8847 - f1_score: 0.8635
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3391 - accuracy: 0.8690 - recall: 0.8497 - precision: 0.8891 - f1_score: 0.8688
# Epoch 10/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.3311 - accuracy: 0.8744 - recall: 0.8567 - precision: 0.8927 - f1_score: 0.8742
# Epoch 11/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.3258 - accuracy: 0.8763 - recall: 0.8605 - precision: 0.8938 - f1_score: 0.8767
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3138 - accuracy: 0.8789 - recall: 0.8616 - precision: 0.8975 - f1_score: 0.8791
# Epoch 13/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.3072 - accuracy: 0.8831 - recall: 0.8646 - precision: 0.9023 - f1_score: 0.8829
# Epoch 14/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.3022 - accuracy: 0.8840 - recall: 0.8672 - precision: 0.9018 - f1_score: 0.8840
# Epoch 15/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.3030 - accuracy: 0.8845 - recall: 0.8651 - precision: 0.9049 - f1_score: 0.8844
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3041 - accuracy: 0.8841 - recall: 0.8642 - precision: 0.9045 - f1_score: 0.8837
# Epoch 17/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2977 - accuracy: 0.8867 - recall: 0.8667 - precision: 0.9074 - f1_score: 0.8864
# Epoch 18/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.2894 - accuracy: 0.8887 - recall: 0.8671 - precision: 0.9105 - f1_score: 0.8881
# Epoch 19/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2905 - accuracy: 0.8888 - recall: 0.8714 - precision: 0.9060 - f1_score: 0.8882
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2923 - accuracy: 0.8862 - recall: 0.8680 - precision: 0.9046 - f1_score: 0.8858
# Round: 2 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4384 - accuracy: 0.7921 - recall: 0.7576 - precision: 0.8230 - f1_score: 0.7887
# Epoch 2/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.4368 - accuracy: 0.7933 - recall: 0.7625 - precision: 0.8207 - f1_score: 0.7903
# Epoch 3/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.4313 - accuracy: 0.7969 - recall: 0.7676 - precision: 0.8237 - f1_score: 0.7944
# Epoch 4/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.4253 - accuracy: 0.8018 - recall: 0.7660 - precision: 0.8333 - f1_score: 0.7980
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4073 - accuracy: 0.8165 - recall: 0.7832 - precision: 0.8492 - f1_score: 0.8147
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3883 - accuracy: 0.8333 - recall: 0.8055 - precision: 0.8624 - f1_score: 0.8328
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3637 - accuracy: 0.8515 - recall: 0.8285 - precision: 0.8751 - f1_score: 0.8510
# Epoch 8/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.3459 - accuracy: 0.8647 - recall: 0.8446 - precision: 0.8847 - f1_score: 0.8640
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3379 - accuracy: 0.8695 - recall: 0.8505 - precision: 0.8890 - f1_score: 0.8692
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3277 - accuracy: 0.8743 - recall: 0.8571 - precision: 0.8935 - f1_score: 0.8748
# Epoch 11/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.3241 - accuracy: 0.8766 - recall: 0.8609 - precision: 0.8939 - f1_score: 0.8770
# Epoch 12/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.3138 - accuracy: 0.8790 - recall: 0.8614 - precision: 0.8974 - f1_score: 0.8789
# Epoch 13/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.3034 - accuracy: 0.8839 - recall: 0.8652 - precision: 0.9030 - f1_score: 0.8835
# Epoch 14/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.3016 - accuracy: 0.8847 - recall: 0.8676 - precision: 0.9029 - f1_score: 0.8848
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3011 - accuracy: 0.8849 - recall: 0.8662 - precision: 0.9058 - f1_score: 0.8854
# Epoch 16/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.3030 - accuracy: 0.8838 - recall: 0.8641 - precision: 0.9045 - f1_score: 0.8837
# Epoch 17/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2965 - accuracy: 0.8869 - recall: 0.8669 - precision: 0.9071 - f1_score: 0.8864
# Epoch 18/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.2870 - accuracy: 0.8892 - recall: 0.8686 - precision: 0.9104 - f1_score: 0.8889
# Epoch 19/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2866 - accuracy: 0.8901 - recall: 0.8734 - precision: 0.9074 - f1_score: 0.8899
# Epoch 20/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2897 - accuracy: 0.8873 - recall: 0.8695 - precision: 0.9052 - f1_score: 0.8868
# Round: 2 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.4395 - accuracy: 0.7915 - recall: 0.7582 - precision: 0.8222 - f1_score: 0.7887
# Epoch 2/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.4375 - accuracy: 0.7935 - recall: 0.7634 - precision: 0.8207 - f1_score: 0.7908
# Epoch 3/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4320 - accuracy: 0.7974 - recall: 0.7682 - precision: 0.8234 - f1_score: 0.7947
# Epoch 4/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.4249 - accuracy: 0.8022 - recall: 0.7661 - precision: 0.8339 - f1_score: 0.7983
# Epoch 5/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.4085 - accuracy: 0.8166 - recall: 0.7829 - precision: 0.8505 - f1_score: 0.8151
# Epoch 6/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.3885 - accuracy: 0.8338 - recall: 0.8056 - precision: 0.8627 - f1_score: 0.8330
# Epoch 7/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.3641 - accuracy: 0.8516 - recall: 0.8283 - precision: 0.8750 - f1_score: 0.8508
# Epoch 8/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.3470 - accuracy: 0.8640 - recall: 0.8435 - precision: 0.8846 - f1_score: 0.8634
# Epoch 9/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.3414 - accuracy: 0.8688 - recall: 0.8493 - precision: 0.8880 - f1_score: 0.8681
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3340 - accuracy: 0.8736 - recall: 0.8566 - precision: 0.8917 - f1_score: 0.8737
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3282 - accuracy: 0.8761 - recall: 0.8601 - precision: 0.8934 - f1_score: 0.8763
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3177 - accuracy: 0.8778 - recall: 0.8598 - precision: 0.8963 - f1_score: 0.8776
# Epoch 13/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.3087 - accuracy: 0.8829 - recall: 0.8648 - precision: 0.9020 - f1_score: 0.8828
# Epoch 14/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.3038 - accuracy: 0.8836 - recall: 0.8667 - precision: 0.9018 - f1_score: 0.8838
# Epoch 15/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.3092 - accuracy: 0.8833 - recall: 0.8643 - precision: 0.9038 - f1_score: 0.8834
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3084 - accuracy: 0.8833 - recall: 0.8640 - precision: 0.9036 - f1_score: 0.8832
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2989 - accuracy: 0.8870 - recall: 0.8671 - precision: 0.9076 - f1_score: 0.8867
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2905 - accuracy: 0.8889 - recall: 0.8684 - precision: 0.9100 - f1_score: 0.8886
# Epoch 19/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2949 - accuracy: 0.8878 - recall: 0.8708 - precision: 0.9048 - f1_score: 0.8873
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2953 - accuracy: 0.8846 - recall: 0.8663 - precision: 0.9030 - f1_score: 0.8842
# Round: 2 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4378 - accuracy: 0.7922 - recall: 0.7587 - precision: 0.8226 - f1_score: 0.7891
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4374 - accuracy: 0.7941 - recall: 0.7640 - precision: 0.8214 - f1_score: 0.7914
# Epoch 3/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4297 - accuracy: 0.7986 - recall: 0.7696 - precision: 0.8244 - f1_score: 0.7959
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.4252 - accuracy: 0.8026 - recall: 0.7675 - precision: 0.8339 - f1_score: 0.7990
# Epoch 5/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.4064 - accuracy: 0.8188 - recall: 0.7857 - precision: 0.8514 - f1_score: 0.8170
# Epoch 6/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3856 - accuracy: 0.8357 - recall: 0.8085 - precision: 0.8642 - f1_score: 0.8352
# Epoch 7/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3620 - accuracy: 0.8524 - recall: 0.8298 - precision: 0.8761 - f1_score: 0.8521
# Epoch 8/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.3459 - accuracy: 0.8646 - recall: 0.8441 - precision: 0.8851 - f1_score: 0.8640
# Epoch 9/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3408 - accuracy: 0.8692 - recall: 0.8500 - precision: 0.8887 - f1_score: 0.8688
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3311 - accuracy: 0.8744 - recall: 0.8574 - precision: 0.8927 - f1_score: 0.8746
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3285 - accuracy: 0.8761 - recall: 0.8601 - precision: 0.8941 - f1_score: 0.8766
# Epoch 12/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3155 - accuracy: 0.8794 - recall: 0.8617 - precision: 0.8984 - f1_score: 0.8795
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3075 - accuracy: 0.8827 - recall: 0.8640 - precision: 0.9023 - f1_score: 0.8826
# Epoch 14/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.3052 - accuracy: 0.8834 - recall: 0.8664 - precision: 0.9014 - f1_score: 0.8834
# Epoch 15/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.3056 - accuracy: 0.8840 - recall: 0.8644 - precision: 0.9047 - f1_score: 0.8839
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.3046 - accuracy: 0.8837 - recall: 0.8640 - precision: 0.9043 - f1_score: 0.8835
# Epoch 17/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2972 - accuracy: 0.8868 - recall: 0.8670 - precision: 0.9074 - f1_score: 0.8866
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2906 - accuracy: 0.8875 - recall: 0.8665 - precision: 0.9095 - f1_score: 0.8873
# Epoch 19/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2948 - accuracy: 0.8877 - recall: 0.8703 - precision: 0.9050 - f1_score: 0.8872
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2925 - accuracy: 0.8861 - recall: 0.8673 - precision: 0.9049 - f1_score: 0.8856
# 12317/12317 [==============================] - 24s 2ms/step
# comm_round: 2 | global_loss: 1.1510270833969116 | global_accuracy: 0.9279 | global_recall: 0.8893 | global_precision: 0.9853 | global_f1_score: 0.9348
#
# New Weights Saved
# Round: 3 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2814 - accuracy: 0.8887 - recall: 0.8707 - precision: 0.9079 - f1_score: 0.8888
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2760 - accuracy: 0.8933 - recall: 0.8790 - precision: 0.9083 - f1_score: 0.8933
# Epoch 3/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2731 - accuracy: 0.8941 - recall: 0.8809 - precision: 0.9083 - f1_score: 0.8943
# Epoch 4/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2759 - accuracy: 0.8963 - recall: 0.8829 - precision: 0.9108 - f1_score: 0.8965
# Epoch 5/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2713 - accuracy: 0.8978 - recall: 0.8848 - precision: 0.9124 - f1_score: 0.8983
# Epoch 6/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2704 - accuracy: 0.8987 - recall: 0.8876 - precision: 0.9109 - f1_score: 0.8990
# Epoch 7/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2665 - accuracy: 0.9001 - recall: 0.8890 - precision: 0.9125 - f1_score: 0.9005
# Epoch 8/20
# 6159/6159 [==============================] - 45s 7ms/step - loss: 0.2732 - accuracy: 0.8981 - recall: 0.8875 - precision: 0.9099 - f1_score: 0.8984
# Epoch 9/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.2739 - accuracy: 0.8978 - recall: 0.8872 - precision: 0.9091 - f1_score: 0.8979
# Epoch 10/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.2756 - accuracy: 0.8950 - recall: 0.8839 - precision: 0.9071 - f1_score: 0.8953
# Epoch 11/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2762 - accuracy: 0.8949 - recall: 0.8800 - precision: 0.9111 - f1_score: 0.8951
# Epoch 12/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2687 - accuracy: 0.8959 - recall: 0.8805 - precision: 0.9123 - f1_score: 0.8960
# Epoch 13/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2738 - accuracy: 0.8962 - recall: 0.8827 - precision: 0.9109 - f1_score: 0.8965
# Epoch 14/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2712 - accuracy: 0.8983 - recall: 0.8848 - precision: 0.9129 - f1_score: 0.8985
# Epoch 15/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2727 - accuracy: 0.8982 - recall: 0.8864 - precision: 0.9110 - f1_score: 0.8984
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2752 - accuracy: 0.8984 - recall: 0.8859 - precision: 0.9119 - f1_score: 0.8986
# Epoch 17/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2751 - accuracy: 0.8977 - recall: 0.8868 - precision: 0.9097 - f1_score: 0.8980
# Epoch 18/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2802 - accuracy: 0.8956 - recall: 0.8838 - precision: 0.9091 - f1_score: 0.8962
# Epoch 19/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2758 - accuracy: 0.8963 - recall: 0.8834 - precision: 0.9100 - f1_score: 0.8964
# Epoch 20/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2772 - accuracy: 0.8970 - recall: 0.8856 - precision: 0.9097 - f1_score: 0.8974
# Round: 3 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2811 - accuracy: 0.8892 - recall: 0.8710 - precision: 0.9080 - f1_score: 0.8890
# Epoch 2/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2751 - accuracy: 0.8938 - recall: 0.8796 - precision: 0.9085 - f1_score: 0.8937
# Epoch 3/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2736 - accuracy: 0.8950 - recall: 0.8816 - precision: 0.9090 - f1_score: 0.8950
# Epoch 4/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2784 - accuracy: 0.8951 - recall: 0.8823 - precision: 0.9093 - f1_score: 0.8955
# Epoch 5/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2704 - accuracy: 0.8978 - recall: 0.8853 - precision: 0.9125 - f1_score: 0.8986
# Epoch 6/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2702 - accuracy: 0.8982 - recall: 0.8866 - precision: 0.9112 - f1_score: 0.8986
# Epoch 7/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2657 - accuracy: 0.9003 - recall: 0.8891 - precision: 0.9126 - f1_score: 0.9006
# Epoch 8/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2713 - accuracy: 0.8989 - recall: 0.8883 - precision: 0.9103 - f1_score: 0.8991
# Epoch 9/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2754 - accuracy: 0.8978 - recall: 0.8877 - precision: 0.9089 - f1_score: 0.8981
# Epoch 10/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2754 - accuracy: 0.8957 - recall: 0.8848 - precision: 0.9075 - f1_score: 0.8959
# Epoch 11/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2746 - accuracy: 0.8963 - recall: 0.8814 - precision: 0.9118 - f1_score: 0.8962
# Epoch 12/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2692 - accuracy: 0.8968 - recall: 0.8816 - precision: 0.9133 - f1_score: 0.8971
# Epoch 13/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2724 - accuracy: 0.8967 - recall: 0.8833 - precision: 0.9113 - f1_score: 0.8970
# Epoch 14/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2710 - accuracy: 0.8981 - recall: 0.8847 - precision: 0.9126 - f1_score: 0.8983
# Epoch 15/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2734 - accuracy: 0.8990 - recall: 0.8867 - precision: 0.9120 - f1_score: 0.8991
# Epoch 16/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.2753 - accuracy: 0.8984 - recall: 0.8860 - precision: 0.9124 - f1_score: 0.8989
# Epoch 17/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2750 - accuracy: 0.8978 - recall: 0.8869 - precision: 0.9097 - f1_score: 0.8980
# Epoch 18/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2810 - accuracy: 0.8953 - recall: 0.8831 - precision: 0.9090 - f1_score: 0.8958
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2798 - accuracy: 0.8954 - recall: 0.8823 - precision: 0.9096 - f1_score: 0.8956
# Epoch 20/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2774 - accuracy: 0.8969 - recall: 0.8845 - precision: 0.9100 - f1_score: 0.8970
# Round: 3 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2818 - accuracy: 0.8895 - recall: 0.8714 - precision: 0.9077 - f1_score: 0.8890
# Epoch 2/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.2756 - accuracy: 0.8941 - recall: 0.8802 - precision: 0.9088 - f1_score: 0.8942
# Epoch 3/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2748 - accuracy: 0.8936 - recall: 0.8803 - precision: 0.9080 - f1_score: 0.8939
# Epoch 4/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2747 - accuracy: 0.8960 - recall: 0.8832 - precision: 0.9103 - f1_score: 0.8964
# Epoch 5/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2716 - accuracy: 0.8980 - recall: 0.8850 - precision: 0.9122 - f1_score: 0.8982
# Epoch 6/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.2708 - accuracy: 0.8982 - recall: 0.8868 - precision: 0.9111 - f1_score: 0.8987
# Epoch 7/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2678 - accuracy: 0.8992 - recall: 0.8881 - precision: 0.9118 - f1_score: 0.8997
# Epoch 8/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2705 - accuracy: 0.8990 - recall: 0.8883 - precision: 0.9102 - f1_score: 0.8990
# Epoch 9/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.2730 - accuracy: 0.8976 - recall: 0.8876 - precision: 0.9086 - f1_score: 0.8979
# Epoch 10/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.2776 - accuracy: 0.8947 - recall: 0.8835 - precision: 0.9064 - f1_score: 0.8947
# Epoch 11/20
# 6159/6159 [==============================] - 35s 5ms/step - loss: 0.2732 - accuracy: 0.8958 - recall: 0.8807 - precision: 0.9116 - f1_score: 0.8958
# Epoch 12/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2675 - accuracy: 0.8964 - recall: 0.8810 - precision: 0.9133 - f1_score: 0.8967
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2718 - accuracy: 0.8969 - recall: 0.8829 - precision: 0.9116 - f1_score: 0.8969
# Epoch 14/20
# ...
# Epoch 5/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2696 - accuracy: 0.8975 - recall: 0.8847 - precision: 0.9119 - f1_score: 0.8980
# Epoch 6/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2695 - accuracy: 0.8982 - recall: 0.8867 - precision: 0.9112 - f1_score: 0.8987
# Epoch 7/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.2650 - accuracy: 0.9000 - recall: 0.8887 - precision: 0.9123 - f1_score: 0.9002
# Epoch 8/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2722 - accuracy: 0.8983 - recall: 0.8878 - precision: 0.9099 - f1_score: 0.8986
# Epoch 9/20
# 6159/6159 [==============================] - 35s 5ms/step - loss: 0.2711 - accuracy: 0.8982 - recall: 0.8880 - precision: 0.9093 - f1_score: 0.8984
# Epoch 10/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2744 - accuracy: 0.8957 - recall: 0.8847 - precision: 0.9073 - f1_score: 0.8958
# Epoch 11/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.2727 - accuracy: 0.8950 - recall: 0.8802 - precision: 0.9111 - f1_score: 0.8953
# Epoch 12/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2697 - accuracy: 0.8964 - recall: 0.8812 - precision: 0.9126 - f1_score: 0.8965
# Epoch 13/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2735 - accuracy: 0.8958 - recall: 0.8821 - precision: 0.9104 - f1_score: 0.8959
# Epoch 14/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.2728 - accuracy: 0.8978 - recall: 0.8847 - precision: 0.9123 - f1_score: 0.8982
# Epoch 15/20
# 6159/6159 [==============================] - 41s 6ms/step - loss: 0.2696 - accuracy: 0.8990 - recall: 0.8874 - precision: 0.9112 - f1_score: 0.8991
# Epoch 16/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.2752 - accuracy: 0.8982 - recall: 0.8867 - precision: 0.9107 - f1_score: 0.8984
# Epoch 17/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2778 - accuracy: 0.8974 - recall: 0.8872 - precision: 0.9089 - f1_score: 0.8978
# Epoch 18/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.2807 - accuracy: 0.8962 - recall: 0.8850 - precision: 0.9084 - f1_score: 0.8964
# Epoch 19/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2768 - accuracy: 0.8961 - recall: 0.8844 - precision: 0.9089 - f1_score: 0.8964
# Epoch 20/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2787 - accuracy: 0.8966 - recall: 0.8855 - precision: 0.9082 - f1_score: 0.8966
# 12317/12317 [==============================] - 23s 2ms/step
# comm_round: 3 | global_loss: 1.1097314357757568 | global_accuracy: 0.9386 | global_recall: 0.8984 | global_precision: 0.9831 | global_f1_score: 0.9389
#
# New Weights Saved
# Round: 4 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2531 - accuracy: 0.9023 - recall: 0.8866 - precision: 0.9188 - f1_score: 0.9023
# Epoch 2/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2601 - accuracy: 0.9011 - recall: 0.8877 - precision: 0.9149 - f1_score: 0.9010
# Epoch 3/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2598 - accuracy: 0.9026 - recall: 0.8900 - precision: 0.9155 - f1_score: 0.9025
# Epoch 4/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2591 - accuracy: 0.9006 - recall: 0.8879 - precision: 0.9143 - f1_score: 0.9008
# Epoch 5/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2611 - accuracy: 0.9005 - recall: 0.8849 - precision: 0.9174 - f1_score: 0.9007
# Epoch 6/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2596 - accuracy: 0.9014 - recall: 0.8844 - precision: 0.9199 - f1_score: 0.9016
# Epoch 7/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2616 - accuracy: 0.9026 - recall: 0.8876 - precision: 0.9186 - f1_score: 0.9027
# Epoch 8/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2646 - accuracy: 0.9022 - recall: 0.8913 - precision: 0.9139 - f1_score: 0.9024
# Epoch 9/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2606 - accuracy: 0.9032 - recall: 0.8949 - precision: 0.9127 - f1_score: 0.9036
# Epoch 10/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2545 - accuracy: 0.9048 - recall: 0.8971 - precision: 0.9133 - f1_score: 0.9050
# Epoch 11/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2622 - accuracy: 0.9035 - recall: 0.8965 - precision: 0.9118 - f1_score: 0.9040
# Epoch 12/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2590 - accuracy: 0.9044 - recall: 0.8935 - precision: 0.9160 - f1_score: 0.9045
# Epoch 13/20
# 6159/6159 [==============================] - 38s 6ms/step - loss: 0.2616 - accuracy: 0.9032 - recall: 0.8922 - precision: 0.9155 - f1_score: 0.9036
# Epoch 14/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2696 - accuracy: 0.9020 - recall: 0.8915 - precision: 0.9137 - f1_score: 0.9023
# Epoch 15/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2658 - accuracy: 0.9012 - recall: 0.8898 - precision: 0.9139 - f1_score: 0.9016
# Epoch 16/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.2659 - accuracy: 0.9001 - recall: 0.8887 - precision: 0.9124 - f1_score: 0.9003
# Epoch 17/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2672 - accuracy: 0.8996 - recall: 0.8899 - precision: 0.9102 - f1_score: 0.8998
# Epoch 18/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2650 - accuracy: 0.9013 - recall: 0.8917 - precision: 0.9115 - f1_score: 0.9014
# Epoch 19/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.2616 - accuracy: 0.9003 - recall: 0.8879 - precision: 0.9132 - f1_score: 0.9003
# Epoch 20/20
# 6159/6159 [==============================] - 43s 7ms/step - loss: 0.2667 - accuracy: 0.9023 - recall: 0.8903 - precision: 0.9152 - f1_score: 0.9024
# Round: 4 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 39s 6ms/step - loss: 0.2515 - accuracy: 0.9027 - recall: 0.8871 - precision: 0.9193 - f1_score: 0.9028
# Epoch 2/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2590 - accuracy: 0.9011 - recall: 0.8878 - precision: 0.9146 - f1_score: 0.9009
# Epoch 3/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2630 - accuracy: 0.9019 - recall: 0.8893 - precision: 0.9153 - f1_score: 0.9020
# Epoch 4/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2577 - accuracy: 0.9019 - recall: 0.8891 - precision: 0.9153 - f1_score: 0.9019
# Epoch 5/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2599 - accuracy: 0.9015 - recall: 0.8862 - precision: 0.9180 - f1_score: 0.9017
# Epoch 6/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2573 - accuracy: 0.9031 - recall: 0.8866 - precision: 0.9209 - f1_score: 0.9032
# Epoch 7/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2636 - accuracy: 0.9025 - recall: 0.8885 - precision: 0.9185 - f1_score: 0.9032
# Epoch 8/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2684 - accuracy: 0.9012 - recall: 0.8905 - precision: 0.9132 - f1_score: 0.9016
# Epoch 9/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2588 - accuracy: 0.9034 - recall: 0.8951 - precision: 0.9129 - f1_score: 0.9038
# Epoch 10/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2558 - accuracy: 0.9044 - recall: 0.8967 - precision: 0.9131 - f1_score: 0.9048
# Epoch 11/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2598 - accuracy: 0.9047 - recall: 0.8972 - precision: 0.9127 - f1_score: 0.9048
# Epoch 12/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2556 - accuracy: 0.9053 - recall: 0.8948 - precision: 0.9168 - f1_score: 0.9055
# Epoch 13/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2615 - accuracy: 0.9045 - recall: 0.8936 - precision: 0.9160 - f1_score: 0.9046
# Epoch 14/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2718 - accuracy: 0.9019 - recall: 0.8917 - precision: 0.9129 - f1_score: 0.9021
# Epoch 15/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2657 - accuracy: 0.9023 - recall: 0.8909 - precision: 0.9143 - f1_score: 0.9024
# Epoch 16/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2672 - accuracy: 0.9003 - recall: 0.8889 - precision: 0.9127 - f1_score: 0.9006
# Epoch 17/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2655 - accuracy: 0.9008 - recall: 0.8906 - precision: 0.9119 - f1_score: 0.9010
# Epoch 18/20
# 6159/6159 [==============================] - 36s 6ms/step - loss: 0.2661 - accuracy: 0.9009 - recall: 0.8908 - precision: 0.9110 - f1_score: 0.9007
# Epoch 19/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2597 - accuracy: 0.9014 - recall: 0.8892 - precision: 0.9140 - f1_score: 0.9013
# Epoch 20/20
# 6159/6159 [==============================] - 42s 7ms/step - loss: 0.2671 - accuracy: 0.9023 - recall: 0.8906 - precision: 0.9149 - f1_score: 0.9025
# Round: 4 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2489 - accuracy: 0.9032 - recall: 0.8874 - precision: 0.9199 - f1_score: 0.9032
# Epoch 2/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2592 - accuracy: 0.9011 - recall: 0.8876 - precision: 0.9149 - f1_score: 0.9009
# Epoch 3/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2607 - accuracy: 0.9020 - recall: 0.8895 - precision: 0.9154 - f1_score: 0.9022
# Epoch 4/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2586 - accuracy: 0.9009 - recall: 0.8880 - precision: 0.9147 - f1_score: 0.9010
# Epoch 5/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2593 - accuracy: 0.9008 - recall: 0.8852 - precision: 0.9180 - f1_score: 0.9012
# Epoch 6/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2571 - accuracy: 0.9021 - recall: 0.8849 - precision: 0.9205 - f1_score: 0.9022
# Epoch 7/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2602 - accuracy: 0.9025 - recall: 0.8876 - precision: 0.9186 - f1_score: 0.9027
# Epoch 8/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2646 - accuracy: 0.9020 - recall: 0.8911 - precision: 0.9139 - f1_score: 0.9023
# Epoch 9/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2584 - accuracy: 0.9042 - recall: 0.8955 - precision: 0.9134 - f1_score: 0.9043
# Epoch 10/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2528 - accuracy: 0.9046 - recall: 0.8968 - precision: 0.9135 - f1_score: 0.9050
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2573 - accuracy: 0.9047 - recall: 0.8973 - precision: 0.9129 - f1_score: 0.9050
# Epoch 12/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2578 - accuracy: 0.9035 - recall: 0.8922 - precision: 0.9157 - f1_score: 0.9037
# Epoch 13/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2598 - accuracy: 0.9039 - recall: 0.8928 - precision: 0.9160 - f1_score: 0.9041
# Epoch 14/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2691 - accuracy: 0.9017 - recall: 0.8913 - precision: 0.9134 - f1_score: 0.9021
# Epoch 15/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2668 - accuracy: 0.9008 - recall: 0.8887 - precision: 0.9139 - f1_score: 0.9010
# Epoch 16/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2674 - accuracy: 0.8992 - recall: 0.8874 - precision: 0.9121 - f1_score: 0.8995
# Epoch 17/20
# 6159/6159 [==============================] - 40s 6ms/step - loss: 0.2676 - accuracy: 0.8994 - recall: 0.8887 - precision: 0.9102 - f1_score: 0.8992
# Epoch 18/20
# 6159/6159 [==============================] - 34s 5ms/step - loss: 0.2659 - accuracy: 0.8998 - recall: 0.8899 - precision: 0.9108 - f1_score: 0.9001
# Epoch 19/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2608 - accuracy: 0.9002 - recall: 0.8872 - precision: 0.9137 - f1_score: 0.9001
# Epoch 20/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2660 - accuracy: 0.9026 - recall: 0.8905 - precision: 0.9157 - f1_score: 0.9028
# Round: 4 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2521 - accuracy: 0.9025 - recall: 0.8868 - precision: 0.9192 - f1_score: 0.9026
# Epoch 2/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2588 - accuracy: 0.9012 - recall: 0.8881 - precision: 0.9151 - f1_score: 0.9013
# Epoch 3/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2593 - accuracy: 0.9038 - recall: 0.8912 - precision: 0.9167 - f1_score: 0.9037
# Epoch 4/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2596 - accuracy: 0.9009 - recall: 0.8880 - precision: 0.9145 - f1_score: 0.9009
# Epoch 5/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2603 - accuracy: 0.9014 - recall: 0.8858 - precision: 0.9180 - f1_score: 0.9015
# Epoch 6/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2588 - accuracy: 0.9026 - recall: 0.8859 - precision: 0.9207 - f1_score: 0.9028
# Epoch 7/20
# 6159/6159 [==============================] - 37s 6ms/step - loss: 0.2627 - accuracy: 0.9028 - recall: 0.8879 - precision: 0.9187 - f1_score: 0.9030
# Epoch 8/20
# 6159/6159 [==============================] - 32s 5ms/step - loss: 0.2651 - accuracy: 0.9021 - recall: 0.8915 - precision: 0.9139 - f1_score: 0.9025
# Epoch 9/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2599 - accuracy: 0.9038 - recall: 0.8954 - precision: 0.9131 - f1_score: 0.9041
# Epoch 10/20
# 6159/6159 [==============================] - 35s 6ms/step - loss: 0.2575 - accuracy: 0.9041 - recall: 0.8965 - precision: 0.9127 - f1_score: 0.9044
# Epoch 11/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2603 - accuracy: 0.9041 - recall: 0.8969 - precision: 0.9121 - f1_score: 0.9043
# Epoch 12/20
# 6159/6159 [==============================] - 29s 5ms/step - loss: 0.2594 - accuracy: 0.9033 - recall: 0.8925 - precision: 0.9152 - f1_score: 0.9036
# Epoch 13/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2592 - accuracy: 0.9041 - recall: 0.8934 - precision: 0.9160 - f1_score: 0.9044
# Epoch 14/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2702 - accuracy: 0.9013 - recall: 0.8912 - precision: 0.9128 - f1_score: 0.9018
# Epoch 15/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2698 - accuracy: 0.9002 - recall: 0.8886 - precision: 0.9128 - f1_score: 0.9004
# Epoch 16/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2652 - accuracy: 0.9013 - recall: 0.8894 - precision: 0.9133 - f1_score: 0.9011
# Epoch 17/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2667 - accuracy: 0.9012 - recall: 0.8914 - precision: 0.9115 - f1_score: 0.9013
# Epoch 18/20
# 6159/6159 [==============================] - 31s 5ms/step - loss: 0.2634 - accuracy: 0.9009 - recall: 0.8912 - precision: 0.9114 - f1_score: 0.9011
# Epoch 19/20
# 6159/6159 [==============================] - 30s 5ms/step - loss: 0.2602 - accuracy: 0.9004 - recall: 0.8883 - precision: 0.9135 - f1_score: 0.9006
# Epoch 20/20
# 6159/6159 [==============================] - 33s 5ms/step - loss: 0.2668 - accuracy: 0.9029 - recall: 0.8915 - precision: 0.9152 - f1_score: 0.9031
# 12317/12317 [==============================] - 26s 2ms/step
# comm_round: 4 | global_loss: 1.1038118600845337 | global_accuracy: 0.9313 | global_recall: 0.9076 | global_precision: 0.9528 | global_f1_score: 0.9297

# %%
global_model.load_weights("FL_DP_0_5.h5")

# %%
loss, accuracy, precision, recall, f1_score = test_model(x_batch, y_batch, global_model, comm_round)
print("loss : ", loss.numpy())
print("accuracy : ", accuracy)
print("precision : ", precision)
print("recall : ", recall)
print("f1_score : ", f1_score)
# Out:
# 12317/12317 [==============================] - 32s 3ms/step
# comm_round: 4 | global_loss: 1.1097314357757568 | global_accuracy: 0.9386 | global_recall: 0.8984 | global_precision: 0.9831 | global_f1_score: 0.9389
#
# loss :  1.1097314
# accuracy :  0.938583716032781
# precision :  0.98311365
# recall :  0.8984117
# f1_score :  0.9388561

# %%
for(x_batch, y_batch) in test_batched:
    logits = global_model.predict(x_batch)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_batch, axis=1)
# Out:
# 12317/12317 [==============================] - 27s 2ms/step

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report, precision_score, recall_score
from sklearn.metrics import matthews_corrcoef, roc_auc_score
from sklearn.metrics import f1_score as f1_score_rep
import seaborn as sn
import numpy as np

def print_score(y_pred, y_real, label_encoder):
    accuracy = accuracy_score(y_real, y_pred)
    precision = precision_score(y_real, y_pred, average="weighted")
    recall = recall_score(y_real, y_pred, average="weighted")
    f1 = f1_score_rep(y_real, y_pred, average="weighted")
    auc = roc_auc_score(y_real, logits, multi_class='ovr')

    print("Accuracy: {:.4f}".format(accuracy))
    print("Precision:: {:.4f}".format(precision))
    print("Recall:: {:.4f}".format(recall))
    print("F1_Score:: {:.4f}".format(f1))
    print("AUC:: {:.4f}".format(auc))
    
    print()
    print("Confusion Matrix")
    cm = confusion_matrix(y_real, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cm, index=[str(i) for i in label_encoder.classes_], columns=[str(i) for i in label_encoder.classes_])
    plt.figure(figsize=(10, 7))
    sn.heatmap(df_cm, annot=True)

    print()
    print("Classification Report")
    print(classification_report(y_real, y_pred, target_names=[str(i) for i in label_encoder.classes_]))

# %%
print_score(y_hat, y_true, label_encoder)
# Out:
# Accuracy: 0.9386
# Precision:: 0.9478
# Recall:: 0.9386
# F1_Score:: 0.9317
# AUC:: 0.9962
#
# Confusion Matrix
#
# Classification Report
#                 precision    recall  f1-score   support
#
#         benign       1.00      1.00      1.00     84459
#      mirai_ack       1.00      0.91      0.95     56029
#     mirai_scan       0.99      1.00      0.99     51230
#      mirai_syn       1.00      0.99      0.99     62501
#      mirai_udp       0.83      1.00      0.90    108953
# mirai_udpplain       0.99      0.42      0.59     30958
#
#       accuracy                           0.94    394130
#      macro avg       0.97      0.89      0.90    394130
#   weighted avg       0.95      0.94      0.93    394130

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, n_classes):
    lw = 2
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_ohe[:, i], y_hat_ohe[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes
    fpr["weighted"] = all_fpr
    tpr["weighted"] = mean_tpr
    roc_auc["weighted"] = auc(fpr["weighted"], tpr["weighted"])

    #fpr["micro"], tpr["micro"], _ = roc_curve(y_true_ohe.ravel(), y_hat_ohe.ravel())
    #roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    plt.figure(figsize=(8,8))
    plt.plot(
        fpr["weighted"],
        tpr["weighted"],
        label="weighted-average ROC curve (area = {0:0.2f})".format(roc_auc["weighted"]),
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )



    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(label_encoder.classes_[i], roc_auc[i]))

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("multiclass characteristic")
    plt.legend(loc="lower right")
    plt.show()

# %%
y_true_ohe = to_categorical(y_true, num_classes=len(label_encoder.classes_))
y_hat_ohe =  to_categorical(y_hat, num_classes=len(label_encoder.classes_))

# %%
ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, len(label_encoder.classes_))

# %%
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  forward_pass = tf.function(model.call, input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])
  graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
  flops = graph_info.total_float_ops
  return flops

# %%
# Calculate FLOPS
flops = get_flops(global_model)
# Out:
# WARNING:tensorflow:From c:\Users\Lambert\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:453: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.

# %%
print(f"FLOPS: {flops / 10 ** 6:.03} M")
# Out:
# FLOPS: 0.00861 M

# %%
print(f"FLOPS: {flops}")
# Out:
# FLOPS: 8612

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import tensorflow as tf
tf.keras.utils.set_random_seed(42)

# %%
#Benign
benign_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.benign.csv')
benign_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.benign.csv')
benign_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.benign.csv')
benign_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.benign.csv')
benign_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.benign.csv')
benign_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.benign.csv')
benign_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.benign.csv')

benign_traffic = pd.concat([benign_1, benign_2, benign_4, benign_5, benign_6, benign_8, benign_9], ignore_index=True)

benign_traffic.shape
# Out:
# (464682, 115)

# %%
#Scan
mirai_scan_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.scan.csv')
mirai_scan_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.scan.csv')
mirai_scan_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.scan.csv')
mirai_scan_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.scan.csv')
mirai_scan_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.scan.csv')
mirai_scan_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.scan.csv')
mirai_scan_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.scan.csv')

mirai_scan_traffic = pd.concat([mirai_scan_1, mirai_scan_2, mirai_scan_4, mirai_scan_5, mirai_scan_6, mirai_scan_8, mirai_scan_9], ignore_index=True)

mirai_scan_traffic.shape
# Out:
# (537979, 115)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')
mirai_syn_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.syn.csv')
mirai_syn_8  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.syn.csv')
mirai_syn_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.syn.csv')


mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5, mirai_syn_6, mirai_syn_8, mirai_syn_9], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (733299, 115)

# %%
#Ack
mirai_ack_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.ack.csv')
mirai_ack_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.ack.csv')
mirai_ack_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.ack.csv')
mirai_ack_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.ack.csv')
mirai_ack_6  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.ack.csv')
mirai_ack_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.ack.csv')
mirai_ack_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.ack.csv')

mirai_ack_traffic = pd.concat([mirai_ack_1 , mirai_ack_2, mirai_ack_4, mirai_ack_5, mirai_ack_6, mirai_ack_8, mirai_ack_9], ignore_index=True)

mirai_ack_traffic.shape
# Out:
# (643821, 115)

# %%
#Udp Flooding
mirai_udp_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udp.csv')
mirai_udp_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udp.csv')
mirai_udp_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udp.csv')
mirai_udp_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udp.csv')
mirai_udp_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udp.csv')
mirai_udp_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udp.csv')
mirai_udp_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udp.csv')

mirai_udp_traffic = pd.concat([mirai_udp_1 , mirai_udp_2, mirai_udp_4, mirai_udp_5], ignore_index=True)

mirai_udp_traffic.shape
# Out:
# (762428, 115)

# %%
#Udp plain Flooding
mirai_udpplain_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.udpplain.csv')
mirai_udpplain_2 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.udpplain.csv')
mirai_udpplain_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.udpplain.csv')
mirai_udpplain_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.udpplain.csv')
mirai_udpplain_6 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/6.mirai.udpplain.csv')
mirai_udpplain_8 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/8.mirai.udpplain.csv')
mirai_udpplain_9 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/9.mirai.udpplain.csv')

mirai_udpplain_traffic = pd.concat([mirai_udpplain_1 , mirai_udpplain_2, mirai_udpplain_4, mirai_udpplain_5, mirai_udpplain_6, mirai_udpplain_8, mirai_udpplain_9], ignore_index=True)

mirai_udpplain_traffic.shape
# Out:
# (523304, 115)

# %%
benign_traffic['label'] = 'benign'
mirai_scan_traffic['label'] = 'mirai_scan'
mirai_syn_traffic['label'] = 'mirai_syn'
mirai_ack_traffic['label'] = 'mirai_ack'
mirai_udp_traffic['label'] = 'mirai_udp'
mirai_udpplain_traffic['label'] = 'mirai_udpplain'

mirai_dataset = pd.concat([benign_traffic, mirai_scan_traffic, mirai_syn_traffic,
                mirai_ack_traffic, mirai_udp_traffic, mirai_udpplain_traffic],
                axis=0, sort=False, ignore_index=True)

# %%
#Syn
mirai_syn_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.syn.csv')
mirai_syn_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.syn.csv')
mirai_syn_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.syn.csv')
mirai_syn_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.syn.csv')

mirai_syn_traffic = pd.concat([mirai_syn_1, mirai_syn_2, mirai_syn_4, mirai_syn_5], ignore_index=True)

mirai_syn_traffic.shape
# Out:
# (423254, 115)

# %%
#Ack
mirai_ack_1 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/1.mirai.ack.csv')
mirai_ack_2  = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/2.mirai.ack.csv')
mirai_ack_4 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/4.mirai.ack.csv')
mirai_ack_5 = pd.read_csv('C:/Users/Lambert/Desktop/nbaiot-dataset/5.mirai.ack.csv')

mirai_ack_traffic = pd.concat([mirai_ack_1 , mirai_ack_2, mirai_ack_4, mirai_ack_5], ignore_index=True)

mirai_ack_traffic.shape
# Out:
# (367157, 115)

# %%
selected_features = ['HH_L1_weight', 'HH_jit_L1_weight', 'MI_dir_L0.01_mean',
       'H_L0.1_weight', 'H_L0.1_mean', 'MI_dir_L1_mean', 'H_L1_mean',
       'H_L0.01_variance', 'MI_dir_L0.01_variance', 'H_L5_weight',
       'H_L0.1_variance', 'MI_dir_L0.1_weight', 'MI_dir_L0.1_mean',
       'MI_dir_L5_weight', 'H_L0.01_mean', 'H_L5_mean', 'MI_dir_L0.1_variance',
       'MI_dir_L3_mean', 'MI_dir_L5_mean', 'HH_jit_L5_mean', 'HH_jit_L3_mean',
       'H_L3_mean', 'HH_L3_magnitude', 'MI_dir_L3_weight', 'HpHp_L0.01_weight', 'label']

# %%
selected_mirai_dataset = mirai_dataset[selected_features].copy()

# %%
selected_mirai_dataset.shape
# Out:
# (3665513, 26)

# %%
#Number of Missing Values in the Dataset
selected_mirai_dataset.isnull().sum().sum()
# Out:
# 0

# %%
#Number of Duplicate Rows in the Dataset
selected_mirai_dataset.duplicated().sum()
# Out:
# 1607667

# %%
# Remove duplicate rows from the Dataset
selected_mirai_dataset = selected_mirai_dataset.drop_duplicates()

# Check the number of duplicate rows after removal
selected_mirai_dataset.duplicated().sum()
# Out:
# 0

# %%
selected_mirai_dataset.shape
# Out:
# (2057846, 26)

# %%
import numpy as np

# Select columns for z-score calculation (excluding the last column)
column_features = selected_mirai_dataset.iloc[:, :-1]

# Calculate z-scores for each column
z_scores = (column_features - column_features.mean()) / column_features.std()

# Set a threshold for z-score beyond which a data point is considered an outlier
z_score_threshold = 3  # Adjust this threshold as needed

# Identify rows where any z-score exceeds the threshold
outlier_mask = (np.abs(z_scores) > z_score_threshold).any(axis=1)

# Remove outliers from the dataset
selected_mirai_dataset = selected_mirai_dataset[~outlier_mask]

# %%
selected_mirai_dataset.shape
# Out:
# (1970649, 26)

# %%
from sklearn.preprocessing import MinMaxScaler

# Extract the columns to be normalized (excluding the 'label' column)
column_to_normalize = selected_mirai_dataset.columns[selected_mirai_dataset.columns != 'label']


# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the selected columns
selected_mirai_dataset[column_to_normalize] = scaler.fit_transform(selected_mirai_dataset[column_to_normalize])

# %%
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000       2.636780e-16       0.000000
# 1      0.000039          0.000039       5.547170e-01       0.000179
# 2      0.001219          0.001219       5.660395e-01       0.000289
# 3      0.000000          0.000000       5.226415e-01       0.000000
# 4      0.000000          0.000000       2.612201e-01       0.000111
#
#     H_L0.1_mean  MI_dir_L1_mean     H_L1_mean  H_L0.01_variance  \
# 0  4.163336e-17    1.249001e-16  1.249001e-16          0.000000
# 1  5.408092e-01    4.823113e-01  4.817053e-01          0.000193
# 2  5.509964e-01    4.923052e-01  4.918483e-01          0.000712
# 3  5.226581e-01    4.544225e-01  4.544225e-01          0.000000
# 4  2.603220e-01    2.184604e-01  2.184604e-01          0.167279
#
#    MI_dir_L0.01_variance   H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.000000  0.000000e+00  ...              0.000000
# 1               0.000000  1.174383e-10  ...              0.000000
# 2               0.000314  3.148369e-03  ...              0.000311
# 3               0.000000  0.000000e+00  ...              0.000000
# 4               0.167279  2.496382e-03  ...              0.165695
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  \
# 0    1.249001e-16    1.110223e-16    9.813673e-01    9.813673e-01
# 1    4.510277e-01    4.226888e-01    3.245507e-09    3.245505e-09
# 2    4.606554e-01    4.319749e-01    1.513729e-09    1.562845e-09
# 3    4.249479e-01    3.982476e-01    9.813673e-01    9.813673e-01
# 4    1.880207e-01    1.612269e-01    9.813673e-01    9.813673e-01
#
#       H_L3_mean  HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight   label
# 0  1.249001e-16         0.000000          0.000000           0.000000  benign
# 1  4.510271e-01         0.331530          0.000000           0.000291  benign
# 2  4.606549e-01         0.338607          0.002146           0.000359  benign
# 3  4.249479e-01         0.312360          0.000000           0.000000  benign
# 4  1.880207e-01         0.477094          0.001867           0.000000  benign
#
# [5 rows x 26 columns]

# %%
selected_mirai_dataset = selected_mirai_dataset.sample(frac=1).reset_index(drop=True)
selected_mirai_dataset.head()
# Out:
#    HH_L1_weight  HH_jit_L1_weight  MI_dir_L0.01_mean  H_L0.1_weight  \
# 0      0.000000          0.000000           0.521544       0.505705
# 1      0.000108          0.000108           0.185116       0.001147
# 2      0.001207          0.001207           0.020756       0.001147
# 3      0.365574          0.365574           0.523108       0.516265
# 4      0.000000          0.000000           0.017738       0.744389
#
#    H_L0.1_mean  MI_dir_L1_mean  H_L1_mean  H_L0.01_variance  \
# 0     0.522337        0.444576   0.444576          0.524454
# 1     0.118109        0.018681   0.018681          0.421878
# 2     0.023412        0.014130   0.014130          0.003344
# 3     0.525792        0.477173   0.477173          0.524025
# 4     0.017960        0.016922   0.016922          0.000378
#
#    MI_dir_L0.01_variance  H_L5_weight  ...  MI_dir_L0.1_variance  \
# 0               0.524454     0.457333  ...              0.519279
# 1               0.421878     0.000004  ...              0.242123
# 2               0.003344     0.003073  ...              0.003812
# 3               0.524025     0.323968  ...              0.518312
# 4               0.000378     0.378821  ...              0.000369
#
#    MI_dir_L3_mean  MI_dir_L5_mean  HH_jit_L5_mean  HH_jit_L3_mean  H_L3_mean  \
# 0        0.372336        0.294594    9.826693e-01    9.826693e-01   0.372336
# 1        0.021151        0.020109    2.614423e-09    2.614027e-09   0.021151
# 2        0.010392        0.008908    1.420423e-09    1.504356e-09   0.010392
# 3        0.497183        0.525856    2.188626e-12    2.208649e-12   0.497183
# 4        0.017771        0.017381    9.826679e-01    9.826679e-01   0.017771
#
#    HH_L3_magnitude  MI_dir_L3_weight  HpHp_L0.01_weight           label
# 0         0.000000          0.436825           0.000000  mirai_udpplain
# 1         0.050352          0.000037           0.000195          benign
# 2         0.070288          0.002636           0.001276          benign
# 3         0.557061          0.375316           0.405565  mirai_udpplain
# 4         0.000000          0.431810           0.000000       mirai_syn
#
# [5 rows x 26 columns]

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

# Calculate percentage values
class_counts = selected_mirai_dataset['label'].value_counts(normalize=True) * 100

plt.title("Class Distribution")
bar_plot = selected_mirai_dataset['label'].value_counts().plot(kind='bar')
plt.xlabel('Classes')
plt.ylabel('Frequency')

# Annotate each bar with its percentage value
for i, val in enumerate(class_counts):
    plt.text(i, selected_mirai_dataset['label'].value_counts()[i], f'{val:.2f}%', ha='center')

plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(selected_mirai_dataset['label'].value_counts())
# Out:
# mirai_udp         544764
# benign            422293
# mirai_syn         312508
# mirai_ack         280144
# mirai_scan        256151
# mirai_udpplain    154789
# Name: label, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(selected_mirai_dataset, test_size=0.2, random_state=42, stratify=selected_mirai_dataset["label"])

# %%
features = list(train_df.columns)
features.remove("label")

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
train_df["label"] = label_encoder.fit_transform(train_df["label"])
test_df["label"] = label_encoder.transform(test_df["label"])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=18)
X_train = train_df[features].values
X_train = pca.fit_transform(X_train)
y_train = train_df["label"].values

X_test = test_df[features].values
X_test = pca.fit_transform(X_test)
y_test = test_df["label"].values

# %%
import statsmodels.api as sm
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from tabulate import tabulate

# %%
X_train = X_train.reshape((-1, X_train.shape[-1], 1))
X_test = X_test.reshape((-1, X_test.shape[-1], 1))

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train)

class_weights = {k: v for k,v in enumerate(class_weights)}
class_weights
# Out:
# {0: 0.7777582086665837,
#  1: 1.1724033048509321,
#  2: 1.282216886832812,
#  3: 1.0509832391359708,
#  4: 0.6029062292293372,
#  5: 2.1218690527143176}

# %%
input_shape = X_train.shape[1:]
nb_classes = len(label_encoder.classes_)

# %%
input_shape
# Out:
# (18, 1)

# %%
from tensorflow.keras.utils import to_categorical

def convert_to_categorical(y, nb_classes):
    return to_categorical(y, num_classes=nb_classes)

# %%
import random

def data_indices(labels: np.ndarray, nb_clients: int):
    data_len = len(labels)
    indices = np.arange(data_len)
    np.random.shuffle(indices)
    chunk_size = data_len // nb_clients
    chunks = [indices[i:i+chunk_size] for i in range(0, data_len, chunk_size)]

    # Ensure non-IID distribution by shuffling 2 of the 4 chunks
    chunks[-1] = np.random.permutation(chunks[-1])
    chunks[-3] = np.random.permutation(chunks[-3])
    

    return chunks

# %%
def sample(y:np.ndarray, nb_clients: int):
    sampler_fn = data_indices
    client_data_indices = sampler_fn(y, nb_clients)
    return client_data_indices

# %%
def assign_data_to_clients(clients: dict, X:np.ndarray, y:np.ndarray, nb_classes:int):
    sampled_data_indices = sample(y, len(clients.keys()))  # Use the sample function to get data indices
    for client_name, data_indices in zip(clients.keys(), sampled_data_indices):
        X = X_train[data_indices]  # Subset the features for the current client
        y = y_train[data_indices]  # Subset the labels for the current client
        y = convert_to_categorical(y, nb_classes)  # Convert labels to categorical format if needed
        clients[client_name] = list(zip(X, y))  # Assign data to the current client
    return clients

# %%
def create_clients(X, y, nb_classes, num_clients=4, initial='clients'):
    # Create a list of client names
    client_names = ['{}_{}'.format(initial, i+1) for i in range(num_clients)]
    clients = {client_names[i] : [] for i in range(len(client_names))}
    return assign_data_to_clients(clients, X, y, nb_classes)

# %%
def batch_data(data_shard, batch_size=64):
    #seperate shard into data and labels lists
    data, label = zip(*data_shard)
    del data_shard

    len_label = len(label)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    del data, label
    return dataset.shuffle(len_label).batch(batch_size)

# %%
import keras.backend as K
def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import keras
import os
from keras.models import Model
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Activation, BatchNormalization, GRU, Dense, Dropout, Input

def get_model(input_shape, nb_classes):
    inputs = Input(shape=input_shape)
    
    # CNN layers
    x = Conv1D(10, 10, padding='same', activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Conv1D(10, 10, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = MaxPooling1D(pool_size=2)(x)
    x = Conv1D(10, 10, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = MaxPooling1D(pool_size=2)(x)
    
    x = GlobalAveragePooling1D(data_format="channels_last")(x)
    
    # Dense layers
    x = Dense(32, activation="relu")(x)
    x = Dropout(0.2)(x)
    
    outputs = Dense(nb_classes, activation="softmax")(x)
    
    return keras.Model(inputs, outputs)

# %%
import tensorflow_privacy
from tensorflow_privacy.privacy.optimizers import dp_optimizer_keras  
from keras.metrics import Recall, Precision
from tensorflow.keras.utils import plot_model

learning_rate = 1e-3
comms_round = 5
loss='categorical_crossentropy'
metrics = ["accuracy", Recall(), Precision(), f1_score]
#optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
optimizer = tensorflow_privacy.DPKerasAdamOptimizer(l2_norm_clip= 1.6, noise_multiplier= 0.01, num_microbatches=1, learning_rate= learning_rate)


#initialize global model
global_model = get_model(input_shape, nb_classes)

global_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18, 1)]           0
#
#  conv1d (Conv1D)             (None, 18, 10)            110
#
#  batch_normalization (Batch  (None, 18, 10)            40
#  Normalization)
#
#  dropout (Dropout)           (None, 18, 10)            0
#
#  max_pooling1d (MaxPooling1  (None, 9, 10)             0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 9, 10)             1010
#
#  batch_normalization_1 (Bat  (None, 9, 10)             40
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 9, 10)             0
#
#  max_pooling1d_1 (MaxPoolin  (None, 4, 10)             0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 4, 10)             1010
#
#  batch_normalization_2 (Bat  (None, 4, 10)             40
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 4, 10)             0
#
#  max_pooling1d_2 (MaxPoolin  (None, 2, 10)             0
#  g1D)
#
#  global_average_pooling1d (  (None, 10)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 32)                352
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 2800 (10.94 KB)
# Trainable params: 2740 (10.70 KB)
# Non-trainable params: 60 (240.00 Byte)
# _________________________________________________________________

# %%
BATCH_SIZE = 64

# create clients
clients_batched = create_clients(X_train, y_train, nb_classes, num_clients=4, initial='client')

del X_train, y_train

# process and batch the training data for each client
client_set = {k: {} for k in clients_batched.keys()}

for (client_name, data) in clients_batched.items():
    client_set[client_name]["dataset"] = batch_data(data, BATCH_SIZE)
    local_model = get_model(input_shape, nb_classes)
    local_model.compile(loss=loss,
                      optimizer=optimizer,
                      metrics=metrics)
    client_set[client_name]["model"] = local_model

# %%
#process and batch the test set

y_test = convert_to_categorical(y_test, nb_classes)

test_batched = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(len(y_test))

del X_test, y_test

# %%
# Define a function to calculate the weight scaling factor
def weight_scalling_factor(clients, client_name):
    client_names = list(clients.keys())
    # Get the batch size
    bs = list(clients[client_name]["dataset"])[0][0].shape[0]
    # Calculate the total training data points across clients
    global_count = sum([tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() for client_name in client_names]) * bs
    # Calculate the total number of data points held by a client
    local_count = tf.data.experimental.cardinality(clients[client_name]["dataset"]).numpy() * bs
    return local_count / global_count

# %%
# Define a function to scale model weights
def scale_model_weights(weight, scalar):
    '''function for scaling a model's weights'''
    weight_final = []
    steps = len(weight)
    for i in range(steps):
        weight_final.append(scalar * weight[i])
    return weight_final

# %%
def sum_scaled_weights(scaled_weight_list):
    '''Return the sum of the listed scaled weights --> FedAvg'''
    avg_grad = list()
    #get the average grad accross all client gradients
    for grad_list_tuple in zip(*scaled_weight_list):
        layer_mean = tf.math.reduce_sum(grad_list_tuple, axis=0)
        avg_grad.append(layer_mean)

    return avg_grad

# %%
from sklearn.metrics import accuracy_score

def test_model(X_test, y_test,  model, comm_round):
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    #logits = model.predict(X_test, batch_size=100)
    logits = model.predict(X_test)
    loss = cce(y_test, logits)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_test, axis=1)

    accuracy = accuracy_score(np.argmax(y_test, axis=1), np.argmax(logits, axis=1))

    r = Recall()
    r.update_state(y_test, logits)
    recall = r.result().numpy()

    p = Precision()
    p.update_state(y_test, logits)
    precision = p.result().numpy()

    f = f1_score(y_test, logits)
    f1 = f.numpy()

    print('comm_round: {} | global_loss: {} | global_accuracy: {:.4} | global_recall: {:.4} | global_precision: {:.4} | global_f1_score: {:.4} \n'.format(comm_round, loss, accuracy, recall, precision, f1))
    return loss, accuracy, precision, recall, f1

# %%
def train_client(client, global_weights):
    client_set[client]["model"] = client_set[client]["model"]

    #set local model weight to the weight of the global model
    client_set[client]["model"].set_weights(global_weights)

    #fit local model with client's data
    print(f"Round: {comm_round} | Client: {client} training")
    client_set[client]["model"].fit(client_set[client]["dataset"], epochs=20, verbose=1)

    #scale the model weights and add to list
    scaling_factor = weight_scalling_factor(client_set, client)
    scaled_weights = scale_model_weights(local_model.get_weights(), scaling_factor)
    return scaled_weights

# %%
import random

#commence global training loop
global_loss=[]
global_accuracy=[]
global_precision=[]
global_recall=[]
global_f1=[]
best_global_accuracy = 0

for comm_round in range(comms_round):
    # get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()

    #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(client_set.keys())
    random.shuffle(client_names)

    #loop through each client and create new local model
    for client in client_names:
        scaled_weights = train_client(client, global_weights)

        scaled_local_weight_list.append(scaled_weights)

    #to get the average over all the local model, we simply take the sum of the scaled weights
    average_weights = sum_scaled_weights(scaled_local_weight_list)

    #update global model
    global_model.set_weights(average_weights)

    #test global model and print out metrics after each communications round
    g_accuracy = 0
    for(x_batch, y_batch) in test_batched:
        g_loss, g_accuracy, g_precision, g_recall, g_f1 = test_model(x_batch, y_batch, global_model, comm_round)
        global_loss.append(g_loss)
        global_accuracy.append(g_accuracy)
        global_precision.append(g_precision)
        global_recall.append(g_recall)
        global_f1.append(g_f1)

    if g_accuracy > best_global_accuracy:
        best_global_accuracy = g_accuracy
        global_model.save_weights('FL_DP_Mirai_CNN.h5')
        print("New Weights Saved")
# Out:
# Round: 0 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 86s 9ms/step - loss: 0.4155 - accuracy: 0.8102 - recall: 0.7765 - precision: 0.8388 - f1_score: 0.8030
# Epoch 2/20
# 6159/6159 [==============================] - 59s 9ms/step - loss: 0.2660 - accuracy: 0.8983 - recall: 0.8879 - precision: 0.9086 - f1_score: 0.8979
# Epoch 3/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.2033 - accuracy: 0.9345 - recall: 0.9288 - precision: 0.9406 - f1_score: 0.9346
# Epoch 4/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1927 - accuracy: 0.9374 - recall: 0.9323 - precision: 0.9430 - f1_score: 0.9376
# Epoch 5/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1818 - accuracy: 0.9406 - recall: 0.9355 - precision: 0.9460 - f1_score: 0.9406
# Epoch 6/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1756 - accuracy: 0.9415 - recall: 0.9363 - precision: 0.9471 - f1_score: 0.9416
# Epoch 7/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1666 - accuracy: 0.9438 - recall: 0.9390 - precision: 0.9490 - f1_score: 0.9439
# Epoch 8/20
# 6159/6159 [==============================] - 59s 9ms/step - loss: 0.1591 - accuracy: 0.9464 - recall: 0.9420 - precision: 0.9512 - f1_score: 0.9465
# Epoch 9/20
# 6159/6159 [==============================] - 59s 9ms/step - loss: 0.1533 - accuracy: 0.9484 - recall: 0.9440 - precision: 0.9532 - f1_score: 0.9485
# Epoch 10/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1507 - accuracy: 0.9497 - recall: 0.9454 - precision: 0.9543 - f1_score: 0.9498
# Epoch 11/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.1503 - accuracy: 0.9498 - recall: 0.9455 - precision: 0.9545 - f1_score: 0.9499
# Epoch 12/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.1468 - accuracy: 0.9505 - recall: 0.9466 - precision: 0.9550 - f1_score: 0.9507
# Epoch 13/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.1467 - accuracy: 0.9505 - recall: 0.9465 - precision: 0.9550 - f1_score: 0.9507
# Epoch 14/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1453 - accuracy: 0.9513 - recall: 0.9471 - precision: 0.9557 - f1_score: 0.9513
# Epoch 15/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.1437 - accuracy: 0.9516 - recall: 0.9477 - precision: 0.9561 - f1_score: 0.9518
# Epoch 16/20
# 6159/6159 [==============================] - 59s 9ms/step - loss: 0.1423 - accuracy: 0.9525 - recall: 0.9486 - precision: 0.9566 - f1_score: 0.9525
# Epoch 17/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.1411 - accuracy: 0.9526 - recall: 0.9488 - precision: 0.9568 - f1_score: 0.9528
# Epoch 18/20
# 6159/6159 [==============================] - 59s 9ms/step - loss: 0.1391 - accuracy: 0.9533 - recall: 0.9497 - precision: 0.9571 - f1_score: 0.9533
# Epoch 19/20
# 6159/6159 [==============================] - 59s 9ms/step - loss: 0.1373 - accuracy: 0.9534 - recall: 0.9497 - precision: 0.9575 - f1_score: 0.9536
# Epoch 20/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1360 - accuracy: 0.9540 - recall: 0.9503 - precision: 0.9581 - f1_score: 0.9542
# Round: 0 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 68s 10ms/step - loss: 0.3984 - accuracy: 0.8054 - recall: 0.8574 - precision: 0.9034 - f1_score: 0.8009
# Epoch 2/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.3543 - accuracy: 0.8285 - recall: 0.7985 - precision: 0.8564 - f1_score: 0.8261
# Epoch 3/20
# 6159/6159 [==============================] - 59s 9ms/step - loss: 0.3243 - accuracy: 0.8574 - recall: 0.8322 - precision: 0.8829 - f1_score: 0.8566
# Epoch 4/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.2866 - accuracy: 0.8806 - recall: 0.8543 - precision: 0.9072 - f1_score: 0.8797
# Epoch 5/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.2651 - accuracy: 0.8918 - recall: 0.8657 - precision: 0.9182 - f1_score: 0.8909
# Epoch 6/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.2501 - accuracy: 0.9012 - recall: 0.8796 - precision: 0.9225 - f1_score: 0.9004
# Epoch 7/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.2423 - accuracy: 0.9062 - recall: 0.8855 - precision: 0.9261 - f1_score: 0.9052
# Epoch 8/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.2359 - accuracy: 0.9093 - recall: 0.8906 - precision: 0.9270 - f1_score: 0.9083
# Epoch 9/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.2294 - accuracy: 0.9132 - recall: 0.8974 - precision: 0.9285 - f1_score: 0.9126
# Epoch 10/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.2264 - accuracy: 0.9152 - recall: 0.8990 - precision: 0.9303 - f1_score: 0.9143
# Epoch 11/20
# 6159/6159 [==============================] - 59s 10ms/step - loss: 0.2245 - accuracy: 0.9166 - recall: 0.9014 - precision: 0.9312 - f1_score: 0.9159
# Epoch 12/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.2179 - accuracy: 0.9198 - recall: 0.9050 - precision: 0.9335 - f1_score: 0.9189
# Epoch 13/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.2129 - accuracy: 0.9222 - recall: 0.9098 - precision: 0.9339 - f1_score: 0.9216
# Epoch 14/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.2110 - accuracy: 0.9232 - recall: 0.9129 - precision: 0.9340 - f1_score: 0.9232
# Epoch 15/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.2074 - accuracy: 0.9244 - recall: 0.9149 - precision: 0.9344 - f1_score: 0.9245
# Epoch 16/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.2051 - accuracy: 0.9260 - recall: 0.9165 - precision: 0.9357 - f1_score: 0.9259
# Epoch 17/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.2016 - accuracy: 0.9270 - recall: 0.9186 - precision: 0.9357 - f1_score: 0.9270
# Epoch 18/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1993 - accuracy: 0.9282 - recall: 0.9201 - precision: 0.9367 - f1_score: 0.9282
# Epoch 19/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1952 - accuracy: 0.9296 - recall: 0.9213 - precision: 0.9378 - f1_score: 0.9294
# Epoch 20/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1931 - accuracy: 0.9310 - recall: 0.9228 - precision: 0.9393 - f1_score: 0.9309
# Round: 0 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 68s 10ms/step - loss: 0.3861 - accuracy: 0.8181 - recall: 0.8559 - precision: 0.8925 - f1_score: 0.8142
# Epoch 2/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.2526 - accuracy: 0.9083 - recall: 0.8968 - precision: 0.9189 - f1_score: 0.9076
# Epoch 3/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.2118 - accuracy: 0.9307 - recall: 0.9244 - precision: 0.9373 - f1_score: 0.9307
# Epoch 4/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.2003 - accuracy: 0.9351 - recall: 0.9296 - precision: 0.9407 - f1_score: 0.9351
# Epoch 5/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1899 - accuracy: 0.9380 - recall: 0.9330 - precision: 0.9430 - f1_score: 0.9380
# Epoch 6/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1558 - accuracy: 0.9509 - recall: 0.9467 - precision: 0.9556 - f1_score: 0.9511
# Epoch 7/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.1412 - accuracy: 0.9572 - recall: 0.9536 - precision: 0.9608 - f1_score: 0.9572
# Epoch 8/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1378 - accuracy: 0.9582 - recall: 0.9552 - precision: 0.9616 - f1_score: 0.9584
# Epoch 9/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1323 - accuracy: 0.9601 - recall: 0.9571 - precision: 0.9635 - f1_score: 0.9602
# Epoch 10/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1295 - accuracy: 0.9606 - recall: 0.9578 - precision: 0.9638 - f1_score: 0.9607
# Epoch 11/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1285 - accuracy: 0.9615 - recall: 0.9587 - precision: 0.9645 - f1_score: 0.9616
# Epoch 12/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1257 - accuracy: 0.9625 - recall: 0.9600 - precision: 0.9653 - f1_score: 0.9627
# Epoch 13/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1234 - accuracy: 0.9634 - recall: 0.9607 - precision: 0.9662 - f1_score: 0.9634
# Epoch 14/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1206 - accuracy: 0.9643 - recall: 0.9619 - precision: 0.9672 - f1_score: 0.9645
# Epoch 15/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.1196 - accuracy: 0.9646 - recall: 0.9624 - precision: 0.9674 - f1_score: 0.9649
# Epoch 16/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1187 - accuracy: 0.9650 - recall: 0.9628 - precision: 0.9678 - f1_score: 0.9652
# Epoch 17/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1154 - accuracy: 0.9663 - recall: 0.9641 - precision: 0.9689 - f1_score: 0.9665
# Epoch 18/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1158 - accuracy: 0.9665 - recall: 0.9643 - precision: 0.9691 - f1_score: 0.9667
# Epoch 19/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1146 - accuracy: 0.9668 - recall: 0.9646 - precision: 0.9693 - f1_score: 0.9669
# Epoch 20/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1141 - accuracy: 0.9667 - recall: 0.9646 - precision: 0.9692 - f1_score: 0.9669
# Round: 0 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 70s 10ms/step - loss: 0.3840 - accuracy: 0.8215 - recall: 0.8784 - precision: 0.9099 - f1_score: 0.8173
# Epoch 2/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.2358 - accuracy: 0.9182 - recall: 0.9108 - precision: 0.9257 - f1_score: 0.9181
# Epoch 3/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.2007 - accuracy: 0.9354 - recall: 0.9310 - precision: 0.9402 - f1_score: 0.9355
# Epoch 4/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1912 - accuracy: 0.9391 - recall: 0.9349 - precision: 0.9437 - f1_score: 0.9392
# Epoch 5/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1811 - accuracy: 0.9434 - recall: 0.9391 - precision: 0.9478 - f1_score: 0.9434
# Epoch 6/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1653 - accuracy: 0.9483 - recall: 0.9448 - precision: 0.9522 - f1_score: 0.9485
# Epoch 7/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1553 - accuracy: 0.9529 - recall: 0.9493 - precision: 0.9567 - f1_score: 0.9530
# Epoch 8/20
# 6159/6159 [==============================] - 68s 11ms/step - loss: 0.1511 - accuracy: 0.9542 - recall: 0.9508 - precision: 0.9579 - f1_score: 0.9543
# Epoch 9/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1488 - accuracy: 0.9550 - recall: 0.9519 - precision: 0.9588 - f1_score: 0.9553
# Epoch 10/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1454 - accuracy: 0.9565 - recall: 0.9535 - precision: 0.9601 - f1_score: 0.9568
# Epoch 11/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1434 - accuracy: 0.9569 - recall: 0.9539 - precision: 0.9603 - f1_score: 0.9570
# Epoch 12/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1417 - accuracy: 0.9578 - recall: 0.9548 - precision: 0.9612 - f1_score: 0.9580
# Epoch 13/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1388 - accuracy: 0.9591 - recall: 0.9562 - precision: 0.9621 - f1_score: 0.9591
# Epoch 14/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1361 - accuracy: 0.9596 - recall: 0.9568 - precision: 0.9625 - f1_score: 0.9596
# Epoch 15/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1339 - accuracy: 0.9602 - recall: 0.9577 - precision: 0.9631 - f1_score: 0.9603
# Epoch 16/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1330 - accuracy: 0.9609 - recall: 0.9583 - precision: 0.9639 - f1_score: 0.9611
# Epoch 17/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1305 - accuracy: 0.9620 - recall: 0.9594 - precision: 0.9648 - f1_score: 0.9620
# Epoch 18/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1299 - accuracy: 0.9621 - recall: 0.9599 - precision: 0.9648 - f1_score: 0.9623
# Epoch 19/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1286 - accuracy: 0.9627 - recall: 0.9607 - precision: 0.9653 - f1_score: 0.9629
# Epoch 20/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1297 - accuracy: 0.9623 - recall: 0.9600 - precision: 0.9647 - f1_score: 0.9623
# 12317/12317 [==============================] - 41s 3ms/step
# comm_round: 0 | global_loss: 1.7828140258789062 | global_accuracy: 0.2764 | global_recall: 0.2372 | global_precision: 0.6029 | global_f1_score: 0.3404
#
# New Weights Saved
# Round: 1 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.2082 - accuracy: 0.9328 - recall: 0.9251 - precision: 0.9404 - f1_score: 0.9324
# Epoch 2/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1814 - accuracy: 0.9427 - recall: 0.9386 - precision: 0.9472 - f1_score: 0.9428
# Epoch 3/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1758 - accuracy: 0.9442 - recall: 0.9402 - precision: 0.9482 - f1_score: 0.9441
# Epoch 4/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1730 - accuracy: 0.9451 - recall: 0.9415 - precision: 0.9488 - f1_score: 0.9451
# Epoch 5/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1714 - accuracy: 0.9452 - recall: 0.9418 - precision: 0.9489 - f1_score: 0.9453
# Epoch 6/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1690 - accuracy: 0.9467 - recall: 0.9436 - precision: 0.9501 - f1_score: 0.9468
# Epoch 7/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1670 - accuracy: 0.9472 - recall: 0.9440 - precision: 0.9506 - f1_score: 0.9472
# Epoch 8/20
# 6159/6159 [==============================] - 72s 11ms/step - loss: 0.1652 - accuracy: 0.9471 - recall: 0.9441 - precision: 0.9508 - f1_score: 0.9474
# Epoch 9/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1631 - accuracy: 0.9477 - recall: 0.9445 - precision: 0.9512 - f1_score: 0.9478
# Epoch 10/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1622 - accuracy: 0.9479 - recall: 0.9447 - precision: 0.9515 - f1_score: 0.9480
# Epoch 11/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1601 - accuracy: 0.9488 - recall: 0.9455 - precision: 0.9523 - f1_score: 0.9489
# Epoch 12/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1576 - accuracy: 0.9492 - recall: 0.9460 - precision: 0.9528 - f1_score: 0.9493
# Epoch 13/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1586 - accuracy: 0.9490 - recall: 0.9461 - precision: 0.9525 - f1_score: 0.9493
# Epoch 14/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1552 - accuracy: 0.9504 - recall: 0.9475 - precision: 0.9535 - f1_score: 0.9505
# Epoch 15/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1548 - accuracy: 0.9507 - recall: 0.9480 - precision: 0.9537 - f1_score: 0.9508
# Epoch 16/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1552 - accuracy: 0.9502 - recall: 0.9474 - precision: 0.9535 - f1_score: 0.9505
# Epoch 17/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1532 - accuracy: 0.9508 - recall: 0.9478 - precision: 0.9541 - f1_score: 0.9509
# Epoch 18/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1524 - accuracy: 0.9507 - recall: 0.9478 - precision: 0.9541 - f1_score: 0.9509
# Epoch 19/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1503 - accuracy: 0.9516 - recall: 0.9486 - precision: 0.9548 - f1_score: 0.9517
# Epoch 20/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1490 - accuracy: 0.9515 - recall: 0.9483 - precision: 0.9549 - f1_score: 0.9515
# Round: 1 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1553 - accuracy: 0.9532 - recall: 0.9465 - precision: 0.9598 - f1_score: 0.9528
# Epoch 2/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1273 - accuracy: 0.9625 - recall: 0.9594 - precision: 0.9660 - f1_score: 0.9626
# Epoch 3/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1241 - accuracy: 0.9637 - recall: 0.9610 - precision: 0.9668 - f1_score: 0.9638
# Epoch 4/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1217 - accuracy: 0.9645 - recall: 0.9619 - precision: 0.9675 - f1_score: 0.9646
# Epoch 5/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1211 - accuracy: 0.9650 - recall: 0.9626 - precision: 0.9677 - f1_score: 0.9651
# Epoch 6/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1199 - accuracy: 0.9651 - recall: 0.9627 - precision: 0.9679 - f1_score: 0.9653
# Epoch 7/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1193 - accuracy: 0.9658 - recall: 0.9635 - precision: 0.9685 - f1_score: 0.9659
# Epoch 8/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1166 - accuracy: 0.9665 - recall: 0.9643 - precision: 0.9692 - f1_score: 0.9667
# Epoch 9/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1161 - accuracy: 0.9670 - recall: 0.9649 - precision: 0.9695 - f1_score: 0.9672
# Epoch 10/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1139 - accuracy: 0.9676 - recall: 0.9656 - precision: 0.9701 - f1_score: 0.9677
# Epoch 11/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1131 - accuracy: 0.9682 - recall: 0.9663 - precision: 0.9706 - f1_score: 0.9684
# Epoch 12/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1126 - accuracy: 0.9680 - recall: 0.9659 - precision: 0.9706 - f1_score: 0.9682
# Epoch 13/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1114 - accuracy: 0.9684 - recall: 0.9666 - precision: 0.9707 - f1_score: 0.9687
# Epoch 14/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1105 - accuracy: 0.9684 - recall: 0.9667 - precision: 0.9705 - f1_score: 0.9686
# Epoch 15/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1106 - accuracy: 0.9686 - recall: 0.9668 - precision: 0.9705 - f1_score: 0.9687
# Epoch 16/20
# 6159/6159 [==============================] - 81s 13ms/step - loss: 0.1091 - accuracy: 0.9692 - recall: 0.9676 - precision: 0.9713 - f1_score: 0.9694
# Epoch 17/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1103 - accuracy: 0.9692 - recall: 0.9673 - precision: 0.9714 - f1_score: 0.9693
# Epoch 18/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1080 - accuracy: 0.9695 - recall: 0.9678 - precision: 0.9716 - f1_score: 0.9697
# Epoch 19/20
# 6159/6159 [==============================] - 77s 12ms/step - loss: 0.1088 - accuracy: 0.9693 - recall: 0.9674 - precision: 0.9715 - f1_score: 0.9694
# Epoch 20/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1058 - accuracy: 0.9705 - recall: 0.9687 - precision: 0.9725 - f1_score: 0.9705
# Round: 1 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1555 - accuracy: 0.9533 - recall: 0.9460 - precision: 0.9601 - f1_score: 0.9527
# Epoch 2/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1269 - accuracy: 0.9626 - recall: 0.9596 - precision: 0.9661 - f1_score: 0.9628
# Epoch 3/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1231 - accuracy: 0.9641 - recall: 0.9613 - precision: 0.9671 - f1_score: 0.9642
# Epoch 4/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1219 - accuracy: 0.9645 - recall: 0.9620 - precision: 0.9674 - f1_score: 0.9647
# Epoch 5/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1202 - accuracy: 0.9652 - recall: 0.9629 - precision: 0.9679 - f1_score: 0.9654
# Epoch 6/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1211 - accuracy: 0.9649 - recall: 0.9626 - precision: 0.9675 - f1_score: 0.9650
# Epoch 7/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1189 - accuracy: 0.9657 - recall: 0.9634 - precision: 0.9682 - f1_score: 0.9658
# Epoch 8/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1164 - accuracy: 0.9661 - recall: 0.9639 - precision: 0.9687 - f1_score: 0.9663
# Epoch 9/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1149 - accuracy: 0.9670 - recall: 0.9648 - precision: 0.9694 - f1_score: 0.9671
# Epoch 10/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1148 - accuracy: 0.9672 - recall: 0.9652 - precision: 0.9695 - f1_score: 0.9673
# Epoch 11/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1122 - accuracy: 0.9681 - recall: 0.9662 - precision: 0.9704 - f1_score: 0.9683
# Epoch 12/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1131 - accuracy: 0.9679 - recall: 0.9660 - precision: 0.9703 - f1_score: 0.9681
# Epoch 13/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1098 - accuracy: 0.9688 - recall: 0.9669 - precision: 0.9710 - f1_score: 0.9689
# Epoch 14/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1114 - accuracy: 0.9683 - recall: 0.9666 - precision: 0.9704 - f1_score: 0.9685
# Epoch 15/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1100 - accuracy: 0.9688 - recall: 0.9672 - precision: 0.9707 - f1_score: 0.9689
# Epoch 16/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1098 - accuracy: 0.9692 - recall: 0.9676 - precision: 0.9712 - f1_score: 0.9693
# Epoch 17/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1098 - accuracy: 0.9691 - recall: 0.9675 - precision: 0.9711 - f1_score: 0.9693
# Epoch 18/20
# 6159/6159 [==============================] - 72s 11ms/step - loss: 0.1085 - accuracy: 0.9697 - recall: 0.9681 - precision: 0.9716 - f1_score: 0.9699
# Epoch 19/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1064 - accuracy: 0.9702 - recall: 0.9683 - precision: 0.9723 - f1_score: 0.9703
# Epoch 20/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1064 - accuracy: 0.9703 - recall: 0.9685 - precision: 0.9724 - f1_score: 0.9704
# Round: 1 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1568 - accuracy: 0.9518 - recall: 0.9443 - precision: 0.9589 - f1_score: 0.9512
# Epoch 2/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1283 - accuracy: 0.9626 - recall: 0.9595 - precision: 0.9660 - f1_score: 0.9627
# Epoch 3/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1237 - accuracy: 0.9639 - recall: 0.9612 - precision: 0.9669 - f1_score: 0.9640
# Epoch 4/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1219 - accuracy: 0.9645 - recall: 0.9620 - precision: 0.9673 - f1_score: 0.9646
# Epoch 5/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1209 - accuracy: 0.9651 - recall: 0.9627 - precision: 0.9677 - f1_score: 0.9652
# Epoch 6/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1192 - accuracy: 0.9654 - recall: 0.9630 - precision: 0.9681 - f1_score: 0.9655
# Epoch 7/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1180 - accuracy: 0.9662 - recall: 0.9639 - precision: 0.9687 - f1_score: 0.9663
# Epoch 8/20
# 6159/6159 [==============================] - 70s 11ms/step - loss: 0.1155 - accuracy: 0.9670 - recall: 0.9648 - precision: 0.9695 - f1_score: 0.9671
# Epoch 9/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1149 - accuracy: 0.9673 - recall: 0.9652 - precision: 0.9695 - f1_score: 0.9673
# Epoch 10/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1129 - accuracy: 0.9680 - recall: 0.9659 - precision: 0.9702 - f1_score: 0.9681
# Epoch 11/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1142 - accuracy: 0.9675 - recall: 0.9656 - precision: 0.9699 - f1_score: 0.9677
# Epoch 12/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1128 - accuracy: 0.9679 - recall: 0.9658 - precision: 0.9702 - f1_score: 0.9680
# Epoch 13/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1126 - accuracy: 0.9681 - recall: 0.9661 - precision: 0.9705 - f1_score: 0.9683
# Epoch 14/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1110 - accuracy: 0.9687 - recall: 0.9670 - precision: 0.9708 - f1_score: 0.9689
# Epoch 15/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1123 - accuracy: 0.9683 - recall: 0.9667 - precision: 0.9704 - f1_score: 0.9685
# Epoch 16/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1100 - accuracy: 0.9691 - recall: 0.9672 - precision: 0.9712 - f1_score: 0.9692
# Epoch 17/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1098 - accuracy: 0.9692 - recall: 0.9674 - precision: 0.9713 - f1_score: 0.9693
# Epoch 18/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1069 - accuracy: 0.9698 - recall: 0.9681 - precision: 0.9719 - f1_score: 0.9700
# Epoch 19/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1076 - accuracy: 0.9697 - recall: 0.9679 - precision: 0.9719 - f1_score: 0.9699
# Epoch 20/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1052 - accuracy: 0.9703 - recall: 0.9686 - precision: 0.9725 - f1_score: 0.9705
# 12317/12317 [==============================] - 41s 3ms/step
# comm_round: 1 | global_loss: 1.0632811784744263 | global_accuracy: 0.9925 | global_recall: 0.9922 | global_precision: 0.9928 | global_f1_score: 0.9925
#
# New Weights Saved
# Round: 2 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1506 - accuracy: 0.9510 - recall: 0.9479 - precision: 0.9544 - f1_score: 0.9511
# Epoch 2/20
# 6159/6159 [==============================] - 67s 11ms/step - loss: 0.1476 - accuracy: 0.9518 - recall: 0.9488 - precision: 0.9550 - f1_score: 0.9519
# Epoch 3/20
# 6159/6159 [==============================] - 61s 10ms/step - loss: 0.1483 - accuracy: 0.9520 - recall: 0.9492 - precision: 0.9552 - f1_score: 0.9521
# Epoch 4/20
# 6159/6159 [==============================] - 59s 9ms/step - loss: 0.1473 - accuracy: 0.9521 - recall: 0.9494 - precision: 0.9553 - f1_score: 0.9523
# Epoch 5/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1481 - accuracy: 0.9521 - recall: 0.9490 - precision: 0.9554 - f1_score: 0.9522
# Epoch 6/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1456 - accuracy: 0.9525 - recall: 0.9495 - precision: 0.9557 - f1_score: 0.9525
# Epoch 7/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1465 - accuracy: 0.9521 - recall: 0.9493 - precision: 0.9553 - f1_score: 0.9522
# Epoch 8/20
# 6159/6159 [==============================] - 56s 9ms/step - loss: 0.1446 - accuracy: 0.9532 - recall: 0.9503 - precision: 0.9564 - f1_score: 0.9533
# Epoch 9/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1445 - accuracy: 0.9529 - recall: 0.9500 - precision: 0.9561 - f1_score: 0.9530
# Epoch 10/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.1448 - accuracy: 0.9526 - recall: 0.9499 - precision: 0.9559 - f1_score: 0.9529
# Epoch 11/20
# 6159/6159 [==============================] - 56s 9ms/step - loss: 0.1442 - accuracy: 0.9528 - recall: 0.9501 - precision: 0.9559 - f1_score: 0.9530
# Epoch 12/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1434 - accuracy: 0.9530 - recall: 0.9502 - precision: 0.9560 - f1_score: 0.9531
# Epoch 13/20
# 6159/6159 [==============================] - 56s 9ms/step - loss: 0.1423 - accuracy: 0.9529 - recall: 0.9502 - precision: 0.9560 - f1_score: 0.9531
# Epoch 14/20
# 6159/6159 [==============================] - 56s 9ms/step - loss: 0.1417 - accuracy: 0.9535 - recall: 0.9506 - precision: 0.9566 - f1_score: 0.9536
# Epoch 15/20
# 6159/6159 [==============================] - 56s 9ms/step - loss: 0.1421 - accuracy: 0.9534 - recall: 0.9505 - precision: 0.9565 - f1_score: 0.9535
# Epoch 16/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1412 - accuracy: 0.9536 - recall: 0.9508 - precision: 0.9566 - f1_score: 0.9536
# Epoch 17/20
# 6159/6159 [==============================] - 60s 10ms/step - loss: 0.1397 - accuracy: 0.9541 - recall: 0.9514 - precision: 0.9573 - f1_score: 0.9543
# Epoch 18/20
# 6159/6159 [==============================] - 59s 9ms/step - loss: 0.1406 - accuracy: 0.9539 - recall: 0.9511 - precision: 0.9568 - f1_score: 0.9540
# Epoch 19/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.1402 - accuracy: 0.9540 - recall: 0.9514 - precision: 0.9570 - f1_score: 0.9541
# Epoch 20/20
# 6159/6159 [==============================] - 58s 9ms/step - loss: 0.1406 - accuracy: 0.9536 - recall: 0.9510 - precision: 0.9567 - f1_score: 0.9538
# Round: 2 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1502 - accuracy: 0.9511 - recall: 0.9480 - precision: 0.9546 - f1_score: 0.9512
# Epoch 2/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1490 - accuracy: 0.9515 - recall: 0.9486 - precision: 0.9546 - f1_score: 0.9516
# Epoch 3/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1484 - accuracy: 0.9517 - recall: 0.9490 - precision: 0.9548 - f1_score: 0.9518
# Epoch 4/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1478 - accuracy: 0.9522 - recall: 0.9493 - precision: 0.9552 - f1_score: 0.9522
# Epoch 5/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1462 - accuracy: 0.9524 - recall: 0.9494 - precision: 0.9559 - f1_score: 0.9526
# Epoch 6/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1464 - accuracy: 0.9518 - recall: 0.9487 - precision: 0.9551 - f1_score: 0.9519
# Epoch 7/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1450 - accuracy: 0.9525 - recall: 0.9497 - precision: 0.9557 - f1_score: 0.9526
# Epoch 8/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1453 - accuracy: 0.9525 - recall: 0.9497 - precision: 0.9557 - f1_score: 0.9527
# Epoch 9/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1458 - accuracy: 0.9523 - recall: 0.9494 - precision: 0.9553 - f1_score: 0.9523
# Epoch 10/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1443 - accuracy: 0.9527 - recall: 0.9500 - precision: 0.9558 - f1_score: 0.9529
# Epoch 11/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1430 - accuracy: 0.9532 - recall: 0.9505 - precision: 0.9563 - f1_score: 0.9533
# Epoch 12/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1423 - accuracy: 0.9533 - recall: 0.9505 - precision: 0.9564 - f1_score: 0.9534
# Epoch 13/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1416 - accuracy: 0.9529 - recall: 0.9502 - precision: 0.9558 - f1_score: 0.9530
# Epoch 14/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1423 - accuracy: 0.9531 - recall: 0.9504 - precision: 0.9561 - f1_score: 0.9532
# Epoch 15/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1415 - accuracy: 0.9533 - recall: 0.9505 - precision: 0.9565 - f1_score: 0.9535
# Epoch 16/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1415 - accuracy: 0.9535 - recall: 0.9508 - precision: 0.9564 - f1_score: 0.9536
# Epoch 17/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1413 - accuracy: 0.9533 - recall: 0.9508 - precision: 0.9562 - f1_score: 0.9534
# Epoch 18/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1395 - accuracy: 0.9539 - recall: 0.9513 - precision: 0.9568 - f1_score: 0.9540
# Epoch 19/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1379 - accuracy: 0.9544 - recall: 0.9519 - precision: 0.9573 - f1_score: 0.9545
# Epoch 20/20
# 6159/6159 [==============================] - 68s 11ms/step - loss: 0.1398 - accuracy: 0.9536 - recall: 0.9510 - precision: 0.9566 - f1_score: 0.9538
# Round: 2 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1496 - accuracy: 0.9515 - recall: 0.9486 - precision: 0.9549 - f1_score: 0.9517
# Epoch 2/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1488 - accuracy: 0.9521 - recall: 0.9491 - precision: 0.9553 - f1_score: 0.9522
# Epoch 3/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1480 - accuracy: 0.9519 - recall: 0.9490 - precision: 0.9549 - f1_score: 0.9519
# Epoch 4/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1479 - accuracy: 0.9518 - recall: 0.9490 - precision: 0.9550 - f1_score: 0.9519
# Epoch 5/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1474 - accuracy: 0.9522 - recall: 0.9491 - precision: 0.9557 - f1_score: 0.9523
# Epoch 6/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1467 - accuracy: 0.9519 - recall: 0.9490 - precision: 0.9554 - f1_score: 0.9521
# Epoch 7/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1463 - accuracy: 0.9522 - recall: 0.9492 - precision: 0.9554 - f1_score: 0.9523
# Epoch 8/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1436 - accuracy: 0.9531 - recall: 0.9502 - precision: 0.9563 - f1_score: 0.9532
# Epoch 9/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1453 - accuracy: 0.9530 - recall: 0.9502 - precision: 0.9559 - f1_score: 0.9530
# Epoch 10/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1444 - accuracy: 0.9528 - recall: 0.9501 - precision: 0.9559 - f1_score: 0.9530
# Epoch 11/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1449 - accuracy: 0.9528 - recall: 0.9500 - precision: 0.9561 - f1_score: 0.9530
# Epoch 12/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1425 - accuracy: 0.9532 - recall: 0.9504 - precision: 0.9565 - f1_score: 0.9534
# Epoch 13/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1431 - accuracy: 0.9531 - recall: 0.9504 - precision: 0.9563 - f1_score: 0.9533
# Epoch 14/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1438 - accuracy: 0.9530 - recall: 0.9502 - precision: 0.9562 - f1_score: 0.9531
# Epoch 15/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1420 - accuracy: 0.9534 - recall: 0.9505 - precision: 0.9564 - f1_score: 0.9534
# Epoch 16/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1416 - accuracy: 0.9535 - recall: 0.9506 - precision: 0.9567 - f1_score: 0.9536
# Epoch 17/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1408 - accuracy: 0.9537 - recall: 0.9507 - precision: 0.9568 - f1_score: 0.9537
# Epoch 18/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1407 - accuracy: 0.9537 - recall: 0.9509 - precision: 0.9569 - f1_score: 0.9538
# Epoch 19/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1402 - accuracy: 0.9539 - recall: 0.9513 - precision: 0.9570 - f1_score: 0.9541
# Epoch 20/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1400 - accuracy: 0.9539 - recall: 0.9512 - precision: 0.9568 - f1_score: 0.9540
# Round: 2 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1476 - accuracy: 0.9522 - recall: 0.9495 - precision: 0.9554 - f1_score: 0.9524
# Epoch 2/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1473 - accuracy: 0.9522 - recall: 0.9493 - precision: 0.9554 - f1_score: 0.9523
# Epoch 3/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1464 - accuracy: 0.9529 - recall: 0.9502 - precision: 0.9559 - f1_score: 0.9530
# Epoch 4/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1471 - accuracy: 0.9525 - recall: 0.9498 - precision: 0.9557 - f1_score: 0.9527
# Epoch 5/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1472 - accuracy: 0.9526 - recall: 0.9494 - precision: 0.9558 - f1_score: 0.9525
# Epoch 6/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1466 - accuracy: 0.9523 - recall: 0.9494 - precision: 0.9554 - f1_score: 0.9524
# Epoch 7/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1458 - accuracy: 0.9524 - recall: 0.9495 - precision: 0.9556 - f1_score: 0.9525
# Epoch 8/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1439 - accuracy: 0.9534 - recall: 0.9505 - precision: 0.9564 - f1_score: 0.9534
# Epoch 9/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1450 - accuracy: 0.9527 - recall: 0.9498 - precision: 0.9561 - f1_score: 0.9529
# Epoch 10/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1450 - accuracy: 0.9524 - recall: 0.9496 - precision: 0.9555 - f1_score: 0.9525
# Epoch 11/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1440 - accuracy: 0.9529 - recall: 0.9502 - precision: 0.9560 - f1_score: 0.9531
# Epoch 12/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1425 - accuracy: 0.9533 - recall: 0.9506 - precision: 0.9563 - f1_score: 0.9534
# Epoch 13/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1432 - accuracy: 0.9532 - recall: 0.9507 - precision: 0.9560 - f1_score: 0.9533
# Epoch 14/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1426 - accuracy: 0.9533 - recall: 0.9505 - precision: 0.9564 - f1_score: 0.9534
# Epoch 15/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1413 - accuracy: 0.9537 - recall: 0.9510 - precision: 0.9567 - f1_score: 0.9538
# Epoch 16/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1400 - accuracy: 0.9543 - recall: 0.9517 - precision: 0.9571 - f1_score: 0.9544
# Epoch 17/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1414 - accuracy: 0.9537 - recall: 0.9511 - precision: 0.9567 - f1_score: 0.9539
# Epoch 18/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1405 - accuracy: 0.9531 - recall: 0.9505 - precision: 0.9561 - f1_score: 0.9533
# Epoch 19/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1395 - accuracy: 0.9544 - recall: 0.9518 - precision: 0.9573 - f1_score: 0.9545
# Epoch 20/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1400 - accuracy: 0.9541 - recall: 0.9514 - precision: 0.9572 - f1_score: 0.9543
# 12317/12317 [==============================] - 37s 3ms/step
# comm_round: 2 | global_loss: 1.0577176809310913 | global_accuracy: 0.9928 | global_recall: 0.9925 | global_precision: 0.993 | global_f1_score: 0.9928
#
# New Weights Saved
# Round: 3 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1396 - accuracy: 0.9544 - recall: 0.9520 - precision: 0.9574 - f1_score: 0.9546
# Epoch 2/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1395 - accuracy: 0.9541 - recall: 0.9517 - precision: 0.9571 - f1_score: 0.9543
# Epoch 3/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1397 - accuracy: 0.9540 - recall: 0.9513 - precision: 0.9570 - f1_score: 0.9541
# Epoch 4/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1389 - accuracy: 0.9541 - recall: 0.9513 - precision: 0.9572 - f1_score: 0.9542
# Epoch 5/20
# 6159/6159 [==============================] - 68s 11ms/step - loss: 0.1392 - accuracy: 0.9545 - recall: 0.9518 - precision: 0.9574 - f1_score: 0.9546
# Epoch 6/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1377 - accuracy: 0.9551 - recall: 0.9524 - precision: 0.9581 - f1_score: 0.9552
# Epoch 7/20
# 6159/6159 [==============================] - 68s 11ms/step - loss: 0.1393 - accuracy: 0.9545 - recall: 0.9517 - precision: 0.9574 - f1_score: 0.9545
# Epoch 8/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1389 - accuracy: 0.9543 - recall: 0.9518 - precision: 0.9571 - f1_score: 0.9544
# Epoch 9/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1382 - accuracy: 0.9546 - recall: 0.9520 - precision: 0.9574 - f1_score: 0.9547
# Epoch 10/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1379 - accuracy: 0.9543 - recall: 0.9518 - precision: 0.9572 - f1_score: 0.9545
# Epoch 11/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1375 - accuracy: 0.9546 - recall: 0.9521 - precision: 0.9574 - f1_score: 0.9547
# Epoch 12/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1362 - accuracy: 0.9548 - recall: 0.9523 - precision: 0.9576 - f1_score: 0.9549
# Epoch 13/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1393 - accuracy: 0.9541 - recall: 0.9517 - precision: 0.9570 - f1_score: 0.9543
# Epoch 14/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1366 - accuracy: 0.9545 - recall: 0.9520 - precision: 0.9574 - f1_score: 0.9547
# Epoch 15/20
# 6159/6159 [==============================] - 68s 11ms/step - loss: 0.1373 - accuracy: 0.9548 - recall: 0.9521 - precision: 0.9577 - f1_score: 0.9549
# Epoch 16/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1378 - accuracy: 0.9549 - recall: 0.9522 - precision: 0.9578 - f1_score: 0.9549
# Epoch 17/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1364 - accuracy: 0.9548 - recall: 0.9522 - precision: 0.9577 - f1_score: 0.9549
# Epoch 18/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1351 - accuracy: 0.9555 - recall: 0.9529 - precision: 0.9584 - f1_score: 0.9556
# Epoch 19/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1367 - accuracy: 0.9544 - recall: 0.9518 - precision: 0.9573 - f1_score: 0.9545
# Epoch 20/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1357 - accuracy: 0.9551 - recall: 0.9525 - precision: 0.9579 - f1_score: 0.9551
# Round: 3 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1394 - accuracy: 0.9544 - recall: 0.9520 - precision: 0.9572 - f1_score: 0.9545
# Epoch 2/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1399 - accuracy: 0.9538 - recall: 0.9513 - precision: 0.9567 - f1_score: 0.9540
# Epoch 3/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1404 - accuracy: 0.9538 - recall: 0.9511 - precision: 0.9569 - f1_score: 0.9540
# Epoch 4/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1389 - accuracy: 0.9545 - recall: 0.9520 - precision: 0.9576 - f1_score: 0.9548
# Epoch 5/20
# 6159/6159 [==============================] - 67s 11ms/step - loss: 0.1391 - accuracy: 0.9544 - recall: 0.9519 - precision: 0.9574 - f1_score: 0.9546
# Epoch 6/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1394 - accuracy: 0.9541 - recall: 0.9514 - precision: 0.9572 - f1_score: 0.9543
# Epoch 7/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1390 - accuracy: 0.9541 - recall: 0.9515 - precision: 0.9571 - f1_score: 0.9542
# Epoch 8/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1388 - accuracy: 0.9545 - recall: 0.9520 - precision: 0.9573 - f1_score: 0.9546
# Epoch 9/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1378 - accuracy: 0.9547 - recall: 0.9524 - precision: 0.9575 - f1_score: 0.9549
# Epoch 10/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1382 - accuracy: 0.9544 - recall: 0.9519 - precision: 0.9574 - f1_score: 0.9546
# Epoch 11/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1374 - accuracy: 0.9548 - recall: 0.9522 - precision: 0.9576 - f1_score: 0.9549
# Epoch 12/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1382 - accuracy: 0.9542 - recall: 0.9515 - precision: 0.9572 - f1_score: 0.9543
# Epoch 13/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1388 - accuracy: 0.9540 - recall: 0.9515 - precision: 0.9571 - f1_score: 0.9542
# Epoch 14/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1372 - accuracy: 0.9545 - recall: 0.9520 - precision: 0.9576 - f1_score: 0.9547
# Epoch 15/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1377 - accuracy: 0.9542 - recall: 0.9517 - precision: 0.9570 - f1_score: 0.9544
# Epoch 16/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1376 - accuracy: 0.9548 - recall: 0.9522 - precision: 0.9577 - f1_score: 0.9549
# Epoch 17/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1381 - accuracy: 0.9546 - recall: 0.9520 - precision: 0.9575 - f1_score: 0.9547
# Epoch 18/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1381 - accuracy: 0.9546 - recall: 0.9520 - precision: 0.9574 - f1_score: 0.9547
# Epoch 19/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1369 - accuracy: 0.9546 - recall: 0.9521 - precision: 0.9576 - f1_score: 0.9548
# Epoch 20/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1362 - accuracy: 0.9549 - recall: 0.9524 - precision: 0.9579 - f1_score: 0.9551
# Round: 3 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1393 - accuracy: 0.9541 - recall: 0.9518 - precision: 0.9570 - f1_score: 0.9543
# Epoch 2/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1390 - accuracy: 0.9549 - recall: 0.9523 - precision: 0.9576 - f1_score: 0.9549
# Epoch 3/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1408 - accuracy: 0.9535 - recall: 0.9510 - precision: 0.9566 - f1_score: 0.9537
# Epoch 4/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1400 - accuracy: 0.9543 - recall: 0.9516 - precision: 0.9571 - f1_score: 0.9543
# Epoch 5/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1393 - accuracy: 0.9539 - recall: 0.9514 - precision: 0.9568 - f1_score: 0.9541
# Epoch 6/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1400 - accuracy: 0.9540 - recall: 0.9514 - precision: 0.9570 - f1_score: 0.9542
# Epoch 7/20
# 6159/6159 [==============================] - 62s 10ms/step - loss: 0.1384 - accuracy: 0.9545 - recall: 0.9519 - precision: 0.9573 - f1_score: 0.9546
# Epoch 8/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1385 - accuracy: 0.9546 - recall: 0.9521 - precision: 0.9573 - f1_score: 0.9547
# Epoch 9/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1391 - accuracy: 0.9540 - recall: 0.9515 - precision: 0.9566 - f1_score: 0.9540
# Epoch 10/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1375 - accuracy: 0.9544 - recall: 0.9519 - precision: 0.9572 - f1_score: 0.9545
# Epoch 11/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1358 - accuracy: 0.9551 - recall: 0.9526 - precision: 0.9579 - f1_score: 0.9552
# Epoch 12/20
# ...
# Epoch 6/20
# 6159/6159 [==============================] - 57s 9ms/step - loss: 0.1396 - accuracy: 0.9542 - recall: 0.9515 - precision: 0.9573 - f1_score: 0.9544
# Epoch 7/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1358 - accuracy: 0.9550 - recall: 0.9524 - precision: 0.9578 - f1_score: 0.9551
# Epoch 8/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1390 - accuracy: 0.9543 - recall: 0.9517 - precision: 0.9572 - f1_score: 0.9544
# Epoch 9/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1378 - accuracy: 0.9544 - recall: 0.9519 - precision: 0.9571 - f1_score: 0.9545
# Epoch 10/20
# 6159/6159 [==============================] - 69s 11ms/step - loss: 0.1388 - accuracy: 0.9545 - recall: 0.9517 - precision: 0.9573 - f1_score: 0.9545
# Epoch 11/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1362 - accuracy: 0.9547 - recall: 0.9521 - precision: 0.9576 - f1_score: 0.9548
# Epoch 12/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1379 - accuracy: 0.9541 - recall: 0.9517 - precision: 0.9571 - f1_score: 0.9544
# Epoch 13/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1393 - accuracy: 0.9542 - recall: 0.9518 - precision: 0.9572 - f1_score: 0.9544
# Epoch 14/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1363 - accuracy: 0.9545 - recall: 0.9520 - precision: 0.9573 - f1_score: 0.9546
# Epoch 15/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1380 - accuracy: 0.9545 - recall: 0.9519 - precision: 0.9575 - f1_score: 0.9547
# Epoch 16/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1375 - accuracy: 0.9545 - recall: 0.9521 - precision: 0.9574 - f1_score: 0.9547
# Epoch 17/20
# 6159/6159 [==============================] - 63s 10ms/step - loss: 0.1374 - accuracy: 0.9542 - recall: 0.9515 - precision: 0.9573 - f1_score: 0.9543
# Epoch 18/20
# 6159/6159 [==============================] - 64s 10ms/step - loss: 0.1357 - accuracy: 0.9548 - recall: 0.9522 - precision: 0.9578 - f1_score: 0.9550
# Epoch 19/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1358 - accuracy: 0.9551 - recall: 0.9525 - precision: 0.9580 - f1_score: 0.9552
# Epoch 20/20
# 6159/6159 [==============================] - 66s 11ms/step - loss: 0.1363 - accuracy: 0.9547 - recall: 0.9521 - precision: 0.9575 - f1_score: 0.9548
# 12317/12317 [==============================] - 38s 3ms/step
# comm_round: 3 | global_loss: 1.0568631887435913 | global_accuracy: 0.9931 | global_recall: 0.9927 | global_precision: 0.9933 | global_f1_score: 0.993
#
# New Weights Saved
# Round: 4 | Client: client_2 training
# Epoch 1/20
# 6159/6159 [==============================] - 65s 10ms/step - loss: 0.1360 - accuracy: 0.9552 - recall: 0.9528 - precision: 0.9579 - f1_score: 0.9553
# Epoch 2/20
# 6159/6159 [==============================] - 68s 11ms/step - loss: 0.1375 - accuracy: 0.9549 - recall: 0.9522 - precision: 0.9578 - f1_score: 0.9550
# Epoch 3/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1366 - accuracy: 0.9552 - recall: 0.9526 - precision: 0.9580 - f1_score: 0.9553
# Epoch 4/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1365 - accuracy: 0.9547 - recall: 0.9520 - precision: 0.9576 - f1_score: 0.9548
# Epoch 5/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1358 - accuracy: 0.9546 - recall: 0.9519 - precision: 0.9576 - f1_score: 0.9547
# Epoch 6/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1362 - accuracy: 0.9549 - recall: 0.9521 - precision: 0.9580 - f1_score: 0.9550
# Epoch 7/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1362 - accuracy: 0.9551 - recall: 0.9523 - precision: 0.9582 - f1_score: 0.9552
# Epoch 8/20
# 6159/6159 [==============================] - 71s 11ms/step - loss: 0.1364 - accuracy: 0.9548 - recall: 0.9522 - precision: 0.9578 - f1_score: 0.9550
# Epoch 9/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1355 - accuracy: 0.9553 - recall: 0.9526 - precision: 0.9583 - f1_score: 0.9554
# Epoch 10/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1370 - accuracy: 0.9545 - recall: 0.9517 - precision: 0.9578 - f1_score: 0.9547
# Epoch 11/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1367 - accuracy: 0.9550 - recall: 0.9524 - precision: 0.9580 - f1_score: 0.9551
# Epoch 12/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1356 - accuracy: 0.9550 - recall: 0.9523 - precision: 0.9579 - f1_score: 0.9551
# Epoch 13/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1347 - accuracy: 0.9554 - recall: 0.9529 - precision: 0.9583 - f1_score: 0.9555
# Epoch 14/20
# 6159/6159 [==============================] - 77s 12ms/step - loss: 0.1357 - accuracy: 0.9551 - recall: 0.9528 - precision: 0.9580 - f1_score: 0.9553
# Epoch 15/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1336 - accuracy: 0.9555 - recall: 0.9529 - precision: 0.9585 - f1_score: 0.9557
# Epoch 16/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1346 - accuracy: 0.9554 - recall: 0.9528 - precision: 0.9583 - f1_score: 0.9555
# Epoch 17/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1347 - accuracy: 0.9554 - recall: 0.9528 - precision: 0.9583 - f1_score: 0.9555
# Epoch 18/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1356 - accuracy: 0.9549 - recall: 0.9524 - precision: 0.9579 - f1_score: 0.9551
# Epoch 19/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1345 - accuracy: 0.9555 - recall: 0.9529 - precision: 0.9583 - f1_score: 0.9555
# Epoch 20/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1361 - accuracy: 0.9554 - recall: 0.9528 - precision: 0.9583 - f1_score: 0.9556
# Round: 4 | Client: client_3 training
# Epoch 1/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1369 - accuracy: 0.9549 - recall: 0.9525 - precision: 0.9578 - f1_score: 0.9551
# Epoch 2/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1367 - accuracy: 0.9549 - recall: 0.9524 - precision: 0.9580 - f1_score: 0.9552
# Epoch 3/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1362 - accuracy: 0.9552 - recall: 0.9526 - precision: 0.9581 - f1_score: 0.9553
# Epoch 4/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1367 - accuracy: 0.9550 - recall: 0.9523 - precision: 0.9580 - f1_score: 0.9551
# Epoch 5/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1372 - accuracy: 0.9545 - recall: 0.9518 - precision: 0.9575 - f1_score: 0.9546
# Epoch 6/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1371 - accuracy: 0.9547 - recall: 0.9519 - precision: 0.9578 - f1_score: 0.9548
# Epoch 7/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1362 - accuracy: 0.9553 - recall: 0.9524 - precision: 0.9581 - f1_score: 0.9552
# Epoch 8/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1363 - accuracy: 0.9548 - recall: 0.9521 - precision: 0.9576 - f1_score: 0.9548
# Epoch 9/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1371 - accuracy: 0.9547 - recall: 0.9520 - precision: 0.9577 - f1_score: 0.9548
# Epoch 10/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1352 - accuracy: 0.9549 - recall: 0.9523 - precision: 0.9581 - f1_score: 0.9551
# Epoch 11/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1349 - accuracy: 0.9547 - recall: 0.9523 - precision: 0.9577 - f1_score: 0.9550
# Epoch 12/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1359 - accuracy: 0.9546 - recall: 0.9519 - precision: 0.9576 - f1_score: 0.9547
# Epoch 13/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1362 - accuracy: 0.9549 - recall: 0.9524 - precision: 0.9578 - f1_score: 0.9550
# Epoch 14/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1360 - accuracy: 0.9549 - recall: 0.9523 - precision: 0.9578 - f1_score: 0.9550
# Epoch 15/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1350 - accuracy: 0.9552 - recall: 0.9527 - precision: 0.9581 - f1_score: 0.9554
# Epoch 16/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1344 - accuracy: 0.9557 - recall: 0.9533 - precision: 0.9586 - f1_score: 0.9559
# Epoch 17/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1340 - accuracy: 0.9559 - recall: 0.9532 - precision: 0.9588 - f1_score: 0.9559
# Epoch 18/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1373 - accuracy: 0.9546 - recall: 0.9518 - precision: 0.9576 - f1_score: 0.9546
# Epoch 19/20
# 6159/6159 [==============================] - 78s 12ms/step - loss: 0.1344 - accuracy: 0.9554 - recall: 0.9529 - precision: 0.9582 - f1_score: 0.9556
# Epoch 20/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1353 - accuracy: 0.9552 - recall: 0.9527 - precision: 0.9580 - f1_score: 0.9554
# Round: 4 | Client: client_4 training
# Epoch 1/20
# 6159/6159 [==============================] - 72s 12ms/step - loss: 0.1353 - accuracy: 0.9555 - recall: 0.9530 - precision: 0.9583 - f1_score: 0.9556
# Epoch 2/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1364 - accuracy: 0.9554 - recall: 0.9531 - precision: 0.9582 - f1_score: 0.9556
# Epoch 3/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1364 - accuracy: 0.9547 - recall: 0.9520 - precision: 0.9577 - f1_score: 0.9549
# Epoch 4/20
# 6159/6159 [==============================] - 73s 12ms/step - loss: 0.1357 - accuracy: 0.9550 - recall: 0.9525 - precision: 0.9579 - f1_score: 0.9552
# Epoch 5/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1370 - accuracy: 0.9547 - recall: 0.9521 - precision: 0.9578 - f1_score: 0.9549
# Epoch 6/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1352 - accuracy: 0.9548 - recall: 0.9520 - precision: 0.9580 - f1_score: 0.9550
# Epoch 7/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1369 - accuracy: 0.9545 - recall: 0.9517 - precision: 0.9575 - f1_score: 0.9546
# Epoch 8/20
# 6159/6159 [==============================] - 80s 13ms/step - loss: 0.1371 - accuracy: 0.9545 - recall: 0.9520 - precision: 0.9574 - f1_score: 0.9546
# Epoch 9/20
# 6159/6159 [==============================] - 78s 12ms/step - loss: 0.1361 - accuracy: 0.9546 - recall: 0.9520 - precision: 0.9575 - f1_score: 0.9547
# Epoch 10/20
# 6159/6159 [==============================] - 86s 14ms/step - loss: 0.1345 - accuracy: 0.9554 - recall: 0.9527 - precision: 0.9583 - f1_score: 0.9554
# Epoch 11/20
# 6159/6159 [==============================] - 80s 13ms/step - loss: 0.1350 - accuracy: 0.9556 - recall: 0.9531 - precision: 0.9583 - f1_score: 0.9557
# Epoch 12/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1352 - accuracy: 0.9549 - recall: 0.9522 - precision: 0.9578 - f1_score: 0.9550
# Epoch 13/20
# 6159/6159 [==============================] - 77s 12ms/step - loss: 0.1359 - accuracy: 0.9549 - recall: 0.9524 - precision: 0.9578 - f1_score: 0.9551
# Epoch 14/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1361 - accuracy: 0.9552 - recall: 0.9528 - precision: 0.9578 - f1_score: 0.9553
# Epoch 15/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1352 - accuracy: 0.9552 - recall: 0.9527 - precision: 0.9581 - f1_score: 0.9554
# Epoch 16/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1342 - accuracy: 0.9559 - recall: 0.9534 - precision: 0.9587 - f1_score: 0.9560
# Epoch 17/20
# 6159/6159 [==============================] - 77s 12ms/step - loss: 0.1348 - accuracy: 0.9552 - recall: 0.9526 - precision: 0.9579 - f1_score: 0.9552
# Epoch 18/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1354 - accuracy: 0.9549 - recall: 0.9525 - precision: 0.9578 - f1_score: 0.9551
# Epoch 19/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1364 - accuracy: 0.9548 - recall: 0.9523 - precision: 0.9578 - f1_score: 0.9550
# Epoch 20/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1330 - accuracy: 0.9562 - recall: 0.9538 - precision: 0.9588 - f1_score: 0.9563
# Round: 4 | Client: client_1 training
# Epoch 1/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1360 - accuracy: 0.9553 - recall: 0.9528 - precision: 0.9580 - f1_score: 0.9554
# Epoch 2/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1361 - accuracy: 0.9553 - recall: 0.9528 - precision: 0.9583 - f1_score: 0.9555
# Epoch 3/20
# 6159/6159 [==============================] - 78s 13ms/step - loss: 0.1354 - accuracy: 0.9549 - recall: 0.9524 - precision: 0.9580 - f1_score: 0.9552
# Epoch 4/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1369 - accuracy: 0.9546 - recall: 0.9522 - precision: 0.9577 - f1_score: 0.9549
# Epoch 5/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1360 - accuracy: 0.9550 - recall: 0.9523 - precision: 0.9580 - f1_score: 0.9551
# Epoch 6/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1361 - accuracy: 0.9547 - recall: 0.9520 - precision: 0.9580 - f1_score: 0.9550
# Epoch 7/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1365 - accuracy: 0.9547 - recall: 0.9520 - precision: 0.9578 - f1_score: 0.9548
# Epoch 8/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1353 - accuracy: 0.9548 - recall: 0.9523 - precision: 0.9576 - f1_score: 0.9549
# Epoch 9/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1355 - accuracy: 0.9551 - recall: 0.9524 - precision: 0.9579 - f1_score: 0.9551
# Epoch 10/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1352 - accuracy: 0.9548 - recall: 0.9522 - precision: 0.9577 - f1_score: 0.9549
# Epoch 11/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1356 - accuracy: 0.9548 - recall: 0.9522 - precision: 0.9574 - f1_score: 0.9548
# Epoch 12/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1358 - accuracy: 0.9548 - recall: 0.9523 - precision: 0.9577 - f1_score: 0.9550
# Epoch 13/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1347 - accuracy: 0.9550 - recall: 0.9524 - precision: 0.9578 - f1_score: 0.9551
# Epoch 14/20
# 6159/6159 [==============================] - 76s 12ms/step - loss: 0.1341 - accuracy: 0.9554 - recall: 0.9531 - precision: 0.9582 - f1_score: 0.9556
# Epoch 15/20
# 6159/6159 [==============================] - 77s 12ms/step - loss: 0.1339 - accuracy: 0.9556 - recall: 0.9531 - precision: 0.9583 - f1_score: 0.9557
# Epoch 16/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1350 - accuracy: 0.9553 - recall: 0.9528 - precision: 0.9581 - f1_score: 0.9554
# Epoch 17/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1340 - accuracy: 0.9558 - recall: 0.9534 - precision: 0.9586 - f1_score: 0.9560
# Epoch 18/20
# 6159/6159 [==============================] - 74s 12ms/step - loss: 0.1356 - accuracy: 0.9549 - recall: 0.9524 - precision: 0.9579 - f1_score: 0.9551
# Epoch 19/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1359 - accuracy: 0.9547 - recall: 0.9523 - precision: 0.9576 - f1_score: 0.9549
# Epoch 20/20
# 6159/6159 [==============================] - 75s 12ms/step - loss: 0.1338 - accuracy: 0.9556 - recall: 0.9532 - precision: 0.9584 - f1_score: 0.9558
# 12317/12317 [==============================] - 45s 4ms/step
# comm_round: 4 | global_loss: 1.053915023803711 | global_accuracy: 0.9935 | global_recall: 0.9932 | global_precision: 0.9938 | global_f1_score: 0.9935
#
# New Weights Saved

# %%
global_model.load_weights("FL_DP_Mirai_CNN.h5")

# %%
loss, accuracy, precision, recall, f1_score = test_model(x_batch, y_batch, global_model, comm_round)
print("loss : ", loss.numpy())
print("accuracy : ", accuracy)
print("precision : ", precision)
print("recall : ", recall)
print("f1_score : ", f1_score)
# Out:
# 12317/12317 [==============================] - 36s 3ms/step
# comm_round: 4 | global_loss: 1.053915023803711 | global_accuracy: 0.9935 | global_recall: 0.9932 | global_precision: 0.9938 | global_f1_score: 0.9935
#
# loss :  1.053915
# accuracy :  0.9934564737523153
# precision :  0.9937549
# recall :  0.99320024
# f1_score :  0.9934774

# %%
for(x_batch, y_batch) in test_batched:
    logits = global_model.predict(x_batch)
    y_hat = np.argmax(logits, axis=1)
    y_true = np.argmax(y_batch, axis=1)
# Out:
# 12317/12317 [==============================] - 37s 3ms/step

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report, precision_score, recall_score
from sklearn.metrics import matthews_corrcoef, roc_auc_score
from sklearn.metrics import f1_score as f1_score_rep
import seaborn as sn
import numpy as np

def print_score(y_pred, y_real, label_encoder):
    accuracy = accuracy_score(y_real, y_pred)
    precision = precision_score(y_real, y_pred, average="weighted")
    recall = recall_score(y_real, y_pred, average="weighted")
    f1 = f1_score_rep(y_real, y_pred, average="weighted")
    auc = roc_auc_score(y_real, logits, multi_class='ovr')

    print("Accuracy: {:.4f}".format(accuracy))
    print("Precision:: {:.4f}".format(precision))
    print("Recall:: {:.4f}".format(recall))
    print("F1_Score:: {:.4f}".format(f1))
    print("AUC:: {:.4f}".format(auc))
    
    print()
    print("Confusion Matrix")
    cm = confusion_matrix(y_real, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    df_cm = pd.DataFrame(cm, index=[str(i) for i in label_encoder.classes_], columns=[str(i) for i in label_encoder.classes_])
    plt.figure(figsize=(10, 7))
    sn.heatmap(df_cm, annot=True)

    print()
    print("Classification Report")
    print(classification_report(y_real, y_pred, target_names=[str(i) for i in label_encoder.classes_]))

# %%
print_score(y_hat, y_true, label_encoder)
# Out:
# Accuracy: 0.9935
# Precision:: 0.9935
# Recall:: 0.9935
# F1_Score:: 0.9935
# AUC:: 0.9999
#
# Confusion Matrix
#
# Classification Report
#                 precision    recall  f1-score   support
#
#         benign       1.00      1.00      1.00     84459
#      mirai_ack       0.99      0.99      0.99     56029
#     mirai_scan       0.99      1.00      0.99     51230
#      mirai_syn       1.00      0.99      1.00     62501
#      mirai_udp       0.99      0.99      0.99    108953
# mirai_udpplain       0.97      0.97      0.97     30958
#
#       accuracy                           0.99    394130
#      macro avg       0.99      0.99      0.99    394130
#   weighted avg       0.99      0.99      0.99    394130

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, n_classes):
    lw = 2
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_ohe[:, i], y_hat_ohe[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    mean_tpr /= n_classes
    fpr["weighted"] = all_fpr
    tpr["weighted"] = mean_tpr
    roc_auc["weighted"] = auc(fpr["weighted"], tpr["weighted"])

    #fpr["micro"], tpr["micro"], _ = roc_curve(y_true_ohe.ravel(), y_hat_ohe.ravel())
    #roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    plt.figure(figsize=(8,8))
    plt.plot(
        fpr["weighted"],
        tpr["weighted"],
        label="weighted-average ROC curve (area = {0:0.2f})".format(roc_auc["weighted"]),
        color="deeppink",
        linestyle=":",
        linewidth=4,
    )



    colors = cycle(["aqua", "darkorange", "cornflowerblue"])
    for i, color in zip(range(n_classes), colors):
        plt.plot(
            fpr[i],
            tpr[i],
            color=color,
            lw=lw,
            label="ROC curve of class {0} (area = {1:0.2f})".format(label_encoder.classes_[i], roc_auc[i]))

    plt.plot([0, 1], [0, 1], "k--", lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("multiclass characteristic")
    plt.legend(loc="lower right")
    plt.show()

# %%
y_true_ohe = to_categorical(y_true, num_classes=len(label_encoder.classes_))
y_hat_ohe =  to_categorical(y_hat, num_classes=len(label_encoder.classes_))

# %%
ROC_plot(y_true_ohe, y_hat_ohe, label_encoder, len(label_encoder.classes_))

# %%
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  forward_pass = tf.function(model.call, input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])
  graph_info = profile(forward_pass.get_concrete_function().graph, options=ProfileOptionBuilder.float_operation())
  flops = graph_info.total_float_ops
  return flops

# %%
# Calculate FLOPS
flops = get_flops(global_model)
# Out:
# WARNING:tensorflow:From c:\Users\Lambert\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\nn_ops.py:5253: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.

# %%
print(f"FLOPS: {flops / 10 ** 6:.03} M")
# Out:
# FLOPS: 0.0321 M

# %%
print(f"FLOPS: {flops / 10 }")
